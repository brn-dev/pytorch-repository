# %%
from gymnasium.wrappers import TransformReward
import gymnasium as gym

from stable_baselines3.sac.sac import SAC

env = gym.make("HalfCheetah-v4")
# env = TransformReward(env, lambda r: 5 * r)

model = SAC("MlpPolicy", env, verbose=10, learning_starts=10000, stats_window_size=1) # , seed=594371)
model.learn(total_timesteps=3_500_000, log_interval=1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 10
#       7 # env = TransformReward(env, lambda r: 5 * r)
#       9 model = SAC("MlpPolicy", env, verbose=10, learning_starts=10000, stats_window_size=1) # , seed=594371)
# ---> 10 model.learn(total_timesteps=3_500_000, log_interval=1)
#
# File C:\Program Files\Python311\Lib\site-packages\stable_baselines3\sac\sac.py:307, in SAC.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     298 def learn(
#     299     self: SelfSAC,
#     300     total_timesteps: int,
#    (...)
#     305     progress_bar: bool = False,
#     306 ) -> SelfSAC:
# --> 307     return super().learn(
#     308         total_timesteps=total_timesteps,
#     309         callback=callback,
#     310         log_interval=log_interval,
#     311         tb_log_name=tb_log_name,
#     312         reset_num_timesteps=reset_num_timesteps,
#     313         progress_bar=progress_bar,
#     314     )
#
# File C:\Program Files\Python311\Lib\site-packages\stable_baselines3\common\off_policy_algorithm.py:347, in OffPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     345         # Special case when the user passes `gradient_steps=0`
#     346         if gradient_steps > 0:
# --> 347             self.train(batch_size=self.batch_size, gradient_steps=gradient_steps)
#     349 callback.on_training_end()
#     351 return self
#
# File C:\Program Files\Python311\Lib\site-packages\stable_baselines3\sac\sac.py:247, in SAC.train(self, gradient_steps, batch_size)
#     243     self.ent_coef_optimizer.step()
#     245 with th.no_grad():
#     246     # Select action according to policy
# --> 247     next_actions, next_log_prob = self.actor.action_log_prob(replay_data.next_observations)
#     248     # Compute the next Q values: min over all critics targets
#     249     next_q_values = th.cat(self.critic_target(replay_data.next_observations, next_actions), dim=1)
#
# File C:\Program Files\Python311\Lib\site-packages\stable_baselines3\sac\policies.py:173, in Actor.action_log_prob(self, obs)
#     172 def action_log_prob(self, obs: PyTorchObs) -> Tuple[th.Tensor, th.Tensor]:
# --> 173     mean_actions, log_std, kwargs = self.get_action_dist_params(obs)
#     174     # return action and associated log prob
#     175     return self.action_dist.log_prob_from_params(mean_actions, log_std, **kwargs)
#
# File C:\Program Files\Python311\Lib\site-packages\stable_baselines3\sac\policies.py:156, in Actor.get_action_dist_params(self, obs)
#     148 """
#     149 Get the parameters for the action distribution.
#     150
#    (...)
#     153     Mean, standard deviation and optional keyword arguments.
#     154 """
#     155 features = self.extract_features(obs, self.features_extractor)
# --> 156 latent_pi = self.latent_pi(features)
#     157 mean_actions = self.mu(latent_pi)
#     159 if self.use_sde:
#
# File C:\Program Files\Python311\Lib\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File C:\Program Files\Python311\Lib\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File C:\Program Files\Python311\Lib\site-packages\torch\nn\modules\container.py:215, in Sequential.forward(self, input)
#     213 def forward(self, input):
#     214     for module in self:
# --> 215         input = module(input)
#     216     return input
#
# File C:\Program Files\Python311\Lib\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File C:\Program Files\Python311\Lib\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File C:\Program Files\Python311\Lib\site-packages\torch\nn\modules\linear.py:114, in Linear.forward(self, input)
#     113 def forward(self, input: Tensor) -> Tensor:
# --> 114     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:
