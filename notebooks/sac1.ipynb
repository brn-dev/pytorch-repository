# %%
import inspect
import os
import time
from pathlib import Path

import gymnasium
from gymnasium import Env
from gymnasium.vector import VectorEnv

from sac import init_action_selector, init_policy, init_optimizer, wrap_env, policy_construction_hyper_parameter
from src.datetime import get_current_timestamp
from src.experiment_logging.experiment_logger import ExperimentLogger, log_experiment
from src.model_db.model_db import ModelDB
from src.model_db.dummy_model_db import DummyModelDB
from src.np_functions import inv_symmetric_log
from src.reinforcement_learning.algorithms.policy_mitosis.mitosis_policy_info import MitosisPolicyInfo
from src.model_db.tiny_model_db import TinyModelDB
from src.module_analysis import count_parameters, get_gradients_per_parameter
from src.moving_averages import ExponentialMovingAverage
from src.reinforcement_learning.core.action_selectors.action_selector import ActionSelector
from src.reinforcement_learning.core.action_selectors.predicted_std_action_selector import PredictedStdActionSelector
from src.reinforcement_learning.core.action_selectors.state_dependent_noise_action_selector import \
    StateDependentNoiseActionSelector
from src.reinforcement_learning.core.generalized_advantage_estimate import compute_episode_returns, compute_returns
from src.reinforcement_learning.core.policies.base_policy import BasePolicy
from src.reinforcement_learning.core.policy_construction import InitActionSelectorFunction, PolicyConstruction
from src.reinforcement_learning.gym.envs.test_env import TestEnv
from src.schedulers import FixedValueScheduler, OneStepRecursiveScheduler
from src.stopwatch import Stopwatch
from src.summary_statistics import format_summary_statics
from src.reinforcement_learning.core.policies.actor_critic_policy import ActorCriticPolicy
from typing import Any, SupportsFloat, Optional
from gymnasium.wrappers import RecordVideo, AutoResetWrapper, NormalizeReward, TransformReward, TransformObservation, ClipAction
from src.reinforcement_learning.core.callback import Callback
from src.reinforcement_learning.algorithms.sac.sac import SAC, SAC_DEFAULT_OPTIMIZER_PROVIDER
from src.reinforcement_learning.algorithms.ppo.ppo import PPO, PPOLoggingConfig
from src.reinforcement_learning.core.normalization import NormalizationType
from src.torch_device import set_default_torch_device, optimizer_to_device
from src.reinforcement_learning.gym.parallelize_env import parallelize_env_async
from torch.distributions import Normal, Categorical

import torch
from torch import optim, nn
import torch.distributions as dist
import gymnasium as gym
import numpy as np

from src.torch_functions import antisymmetric_power

# %load_ext autoreload
# %autoreload 2
# Out:
# pygame 2.5.2 (SDL 2.28.3, Python 3.11.7)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
from src.summary_statistics import maybe_compute_summary_statistics
from src.reinforcement_learning.core.loss_config import LossLoggingConfig
from src.reinforcement_learning.algorithms.sac.sac import SAC, SACLoggingConfig
def get_setup() -> dict[str, str]:
    import inspect
    import sac
    return {
        'sac.py': inspect.getsource(sac),
        'notebook': _ih[1] + '\n\n' + _ih[-1], # first and last cell input (imports and this cell)
    }

policy_id: str
policy: BasePolicy
optimizer: optim.Optimizer
wrapped_env: Env
steps_trained: int
def get_policy(create_new_if_exists: bool):
    
    global policy_id, policy, optimizer, wrapped_env, steps_trained
    
    policy_in_ram = 'policy' in globals()
    if not policy_in_ram or create_new_if_exists:
        if not policy_in_ram:
            print('No policy in RAM, creating a new one')
        
        policy_id = get_current_timestamp()
        policy, optimizer, wrapped_env = PolicyConstruction.init_from_info(
            env=env,
            info=PolicyConstruction.create_policy_initialization_info(
                init_action_selector=init_action_selector,
                init_policy=init_policy,
                init_optimizer=init_optimizer,
                wrap_env=wrap_env,
                hyper_parameters=policy_construction_hyper_parameter,
            ),
        )
        steps_trained = 0
        print(f'New policy {policy_id} created')
    
    if parent_policy_id is not None:
        model_entry = policy_db.load_model_state_dict(policy, parent_policy_id)
        steps_trained = model_entry['model_info']['steps_trained']
        print(f'Loading state dict from policy {parent_policy_id}')
    
    print(f'Using policy {policy_id} with parent policy {parent_policy_id}')
    return policy_id, policy, optimizer, wrapped_env, steps_trained

score_mean_ema = ExponentialMovingAverage(alpha=0.25)
step_stopwatch = Stopwatch()
total_stopwatch = Stopwatch()
best_iteration_score = -1e6

def on_rollout_done(rl: SAC, step: int, info: dict[str, Any], scheduler_values: dict[str, Any]):
    
    if step % 1000 != 0:
        return
    
    tail_indices = rl.buffer.tail_indices(1000)
    
    # rewards = rl.buffer.rewards[tail_indices]
    # if 'raw_rewards' in info['rollout']:
    #     rewards = info['rollout']['raw_rewards']
    
    # episode_scores = compute_episode_returns(
    #     rewards=rewards,
    #     episode_starts=np.repeat(np.arange(len(tail_indices)).reshape(-1, 1), num_envs, axis=1) % 1000 == 0,
    #     last_episode_starts=info['last_episode_starts'],
    #     gamma=1.0,
    #     gae_lambda=1.0,
    #     normalize_rewards=None,
    #     remove_unfinished_episodes=True,
    # )
    
    episode_scores = rl.buffer.compute_most_recent_episode_scores(rl.num_envs)
    
    if len(episode_scores) > 0:
    
        global best_iteration_score
        iteration_score = episode_scores.mean()
        score_moving_average = score_mean_ema.update(iteration_score)
        if iteration_score >= best_iteration_score:
            best_iteration_score = iteration_score
            policy_db.save_model_state_dict(
                model_id=policy_id,
                parent_model_id=parent_policy_id,
                model_info={
                    'score': iteration_score.item(),
                    'steps_trained': steps_trained,
                    'wrap_env_source_code': wrap_env_source_code_source,
                    'init_policy_source_code': init_policy_source
                },
                model=policy,
                optimizer=optimizer,
            )
        info['score_moving_average'] = score_moving_average
    
    info['episode_scores'] = episode_scores
        
def on_optimization_done(rl: SAC, step: int, info: dict[str, Any], scheduler_values: dict[str, Any]):
    # global steps_trained
    # steps_trained += rl.buffer.pos
    
    if step % 1000 != 0:
        return
    num_env_steps = step * rl.num_envs
    
    step_time = step_stopwatch.reset()
    total_time = total_stopwatch.time_passed()
    
    tail_indices = rl.buffer.tail_indices(1000)
    
    episode_scores = info.get('episode_scores')
    score_moving_average = info.get('score_moving_average') or 0.0
    
    scores = format_summary_statics(
        episode_scores, 
        mean_format=' 6.3f',
        std_format='4.3f',
        min_value_format=' 6.3f',
        max_value_format='5.3f',
        n_format='>2'
    )
    # scores2 = format_summary_statics(
    #     rl.buffer.compute_most_recent_episode_scores(rl.num_envs, lambda r: 1 * r), 
    #     mean_format=' 6.3f',
    #     std_format='4.3f',
    #     min_value_format=' 6.3f',
    #     max_value_format='5.3f',
    #     n_format='>2'
    # )
    # advantages = format_summary_statics(
    #     rl.buffer.advantages, 
    #     mean_format=' 6.3f',
    #     std_format='.1f',
    #     min_value_format=' 7.3f',
    #     max_value_format='6.3f',
    # )
    actor_loss = format_summary_statics(
        info['final_actor_loss'],  
        mean_format=' 5.3f',
        # std_format='5.3f',
        std_format=None,
        min_value_format=None,
        max_value_format=None,
    )
    # actor_loss_raw = format_summary_statics(
    #     info['raw_actor_loss'],  
    #     mean_format=' 5.3f',
    #     std_format='5.3f',
    #     min_value_format=None,
    #     max_value_format=None,
    # )
    entropy_coef_loss = None if 'final_entropy_coef_loss' not in info else format_summary_statics(
        info['final_entropy_coef_loss'], 
        mean_format='5.3f',
#         std_format='5.3f',
        std_format=None,
        min_value_format=None,
        max_value_format=None,
    )
    critic_loss = format_summary_statics(
        info['final_critic_loss'], 
        mean_format='5.3f',
#         std_format='5.3f',
        std_format=None,
        min_value_format=None,
        max_value_format=None,
    )
    entropy_coef = format_summary_statics(
        info['entropy_coef'],
        mean_format='5.3f',
#         std_format='5.3f',
        std_format=None,
        min_value_format=None,
        max_value_format=None,
    )
    # resets = format_summary_statics(
    #     rl.buffer.dones.astype(int).sum(axis=0), 
    #     mean_format='.2f',
    #     std_format=None,
    #     min_value_format='1d',
    #     max_value_format=None,
    # )
    # kl_div = info['actor_kl_divergence'][-1]
    # grad_norm = format_summary_statics(
    #     info['grad_norm'], 
    #     mean_format=' 6.3f',
    #     std_format='.1f',
    #     min_value_format=' 7.3f',
    #     max_value_format='6.3f',
    # )
    action_stds = info['rollout'].get('action_stds')
    if action_stds is not None:
        rollout_action_stds = format_summary_statics(
            action_stds,
            mean_format='5.3f',
            std_format='5.3f',
            min_value_format=None,
            max_value_format=None,
        )
    else:
        rollout_action_stds = 'N/A'
    action_magnitude = format_summary_statics(
        np.abs(rl.buffer.actions[tail_indices]),
        mean_format='5.3f',
        std_format='5.3f',
        min_value_format=None,
        max_value_format=None,
    )
    # ppo_epochs = info['nr_ppo_epochs']
    # ppo_updates = info['nr_ppo_updates']
    # expl_var = rl.buffer.compute_critic_explained_variance()
    print(f"{step = : >7}, "
          f"{num_env_steps = : >7}, "
          f"{scores = :s}, "
          # f"{scores2 = :s}, "
          f'score_ema = {score_moving_average: 6.3f}, '
          # f"{advantages = :s}, "
          f"{actor_loss = :s}, "
          # f"{actor_loss_raw = :s}, "
          f"{critic_loss = :s}, "
          +(f"{entropy_coef_loss = :s}, " if entropy_coef_loss is not None else '')+
          f"{entropy_coef = :s}, "
          f"rollout_stds = {rollout_action_stds:s}, "
          f"{action_magnitude = :s}, "
          # f"{expl_var = :.3f}, "
          # f"{kl_div = :.4f}, "
          # f"{ppo_epochs = }, "
          # f"{ppo_updates = }, "
          # f"{grad_norm = :s}, "
          f"n_updates = {rl.gradient_steps_performed}, "
          # f"{resets = :s}, "
          f"time = {step_time:4.1f}, "
          f"total_time = {total_time:4.1f} \n"
          )
    logger.add_item({
        'step': step,
        'num_env_steps': num_env_steps,
        'scores': maybe_compute_summary_statistics(episode_scores),
        'actor_loss': maybe_compute_summary_statistics(info['final_actor_loss']),
        'entropy_coef_loss': maybe_compute_summary_statistics(info.get('final_entropy_coef_loss')),
        'critic_loss': maybe_compute_summary_statistics(info['final_critic_loss']),
        'entropy_coef': maybe_compute_summary_statistics(info['entropy_coef']),
        'action_stds': maybe_compute_summary_statistics(action_stds),
        'action_magnitude': maybe_compute_summary_statistics(np.abs(rl.buffer.actions[tail_indices])),
        'num_gradient_steps': rl.gradient_steps_performed,
        'step_time': step_time,
        'total_time': total_time
    })
    if step % 10000 == 0:
        logger.save_experiment_log()
        print()
    print()
    
    # if episode_scores is not None and len(episode_scores) > 0 and episode_scores.mean().item() < -500:
    #     logger.save_experiment_log()
    #     raise ValueError('Score too low, policy probably fucked :(')

device = torch.device("cuda:0") if True else torch.device('cpu')
print(f'using device {device}')

def create_env(render_mode: str | None):
    return gym.make(env_name, render_mode=render_mode, **env_kwargs)

wrap_env_source_code_source = inspect.getsource(wrap_env)
init_policy_source = inspect.getsource(init_policy)

env_name = 'HalfCheetah-v4'
# env_kwargs = {'forward_reward_weight': 1.25, 'healthy_reward': 0.5, 'ctrl_cost_weight': 0.001 }
# env_kwargs = {'forward_reward_weight': 1.25, 'ctrl_cost_weight': 0.1 }
# env_kwargs = {'forward_reward_weight': 1.25, 'ctrl_cost_weight': 0.05 }
env_kwargs = {}
num_envs = 1
    
# policy_db = TinyModelDB[MitosisPolicyInfo](base_path=f'saved_models/rl/{env_name}')
policy_db = DummyModelDB[MitosisPolicyInfo]()
print(f'{policy_db = }')

parent_policy_id=None  # '2024-04-28_20.57.23'

# TODO
# env = parallelize_env_async(lambda: create_env(render_mode=None), num_envs)
env = create_env(render_mode=None)

logger = ExperimentLogger(f'experiment_logs/{env_name}/sac/')

try:
    policy_id, policy, optimizer, wrapped_env, steps_trained = get_policy(create_new_if_exists=False)
    print(f'{count_parameters(policy) = }')
    print(f'{env = }, {num_envs = }')
        
    with ((torch.autograd.set_detect_anomaly(False))):
        algo = SAC(
            env=wrapped_env,
            policy=policy,
            actor_optimizer_provider=lambda params: optim.Adam(params, lr=3e-4),  # (params, lr=3e-4, betas=(0.5, 0.999)),
            critic_optimizer_provider=lambda params: optim.Adam(params, lr=3e-4),  # (params, lr=3e-4, betas=(0.5, 0.999)),
            # weigh_and_reduce_actor_loss=lambda l: 1 * l.mean(),
            # weigh_critic_loss=lambda l: 1 * l,
            buffer_size=1_000_000,
            reward_scale=1,
            gamma=0.99,
            tau=0.005,
            entropy_coef_optimizer_provider=lambda params: optim.Adam(params, lr=3e-4),
            entropy_coef=1.0,
            rollout_steps=1,
            gradient_steps=1,
            warmup_steps=10_000,
            optimization_batch_size=256,
            target_update_interval=1,
            # sde_noise_sample_freq=50,
            callback=Callback(
                on_rollout_done=on_rollout_done,
                rollout_schedulers={},
                on_optimization_done=on_optimization_done,
                optimization_schedulers={},
            ),
            logging_config=SACLoggingConfig(log_rollout_infos=True, log_rollout_action_stds=True,
                                            log_last_obs=True, log_entropy_coef=True,
                                            entropy_coef_loss=LossLoggingConfig(log_final=True),
                                            actor_loss=LossLoggingConfig(log_final=True, log_raw=True),
                                            critic_loss=LossLoggingConfig(log_final=True)),
            torch_device=device,
        )
        total_stopwatch.reset()
        with log_experiment(
            logger,
            experiment_tags=algo.collect_tags(),
            hyper_parameters=algo.collect_hyper_parameters(),
            setup=get_setup(),
        ) as x:
            logger.save_experiment_log()
            print('\nStarting Training\n\n')
            # import cProfile
            # pr = cProfile.Profile()
            # pr.enable()
            algo.learn(5_000_000)
            # pr.disable()  
            # pr.dump_stats('profile_stats.pstat')
except KeyboardInterrupt:
    print('keyboard interrupt')
finally:
    print('closing envs')
    time.sleep(0.5)
    env.close()
    print('envs closed')
    policy_db.close()
    print('model db closed')
    

print('done')
# Out:
# using device cuda:0
# policy_db = DummyModelDB()
# No policy in RAM, creating a new one
# New policy 2024-10-11 12:23:25.093747 created
# Using policy 2024-10-11 12:23:25.093747 with parent policy None
# count_parameters(policy) = 217870
# env = <TimeLimit<OrderEnforcing<PassiveEnvChecker<HalfCheetahEnv<HalfCheetah-v4>>>>>, num_envs = 1
# Grabbing system information... done!
# saved experiment log 2024-10-11_12-23-25_512841~zjtzBB at experiment_logs/HalfCheetah-v4/sac/2024-10-11_12-23-25_512841~zjtzBB.json
#
# Starting Training
#
# step =   11000, num_env_steps =   11000, scores = -214.477 (n= 1), score_ema = -281.336, actor_loss = -17.919, critic_loss = 0.883, entropy_coef_loss = -3.005, entropy_coef = 0.741, rollout_stds = 0.930 ± 0.034, action_magnitude = 0.520 ± 0.288, n_updates = 1000, time = 12.8, total_time = 12.4
#
# step =   12000, num_env_steps =   12000, scores = -188.843 (n= 1), score_ema = -258.212, actor_loss = -25.479, critic_loss = 1.208, entropy_coef_loss = -5.937, entropy_coef = 0.549, rollout_stds = 0.914 ± 0.025, action_magnitude = 0.537 ± 0.289, n_updates = 2000, time =  8.7, total_time = 21.1
#
# step =   13000, num_env_steps =   13000, scores = -141.044 (n= 1), score_ema = -228.920, actor_loss = -30.126, critic_loss = 1.565, entropy_coef_loss = -8.859, entropy_coef = 0.407, rollout_stds = 0.903 ± 0.027, action_magnitude = 0.535 ± 0.289, n_updates = 3000, time =  8.7, total_time = 29.8
#
# step =   14000, num_env_steps =   14000, scores = -89.078 (n= 1), score_ema = -193.960, actor_loss = -32.831, critic_loss = 1.684, entropy_coef_loss = -11.498, entropy_coef = 0.303, rollout_stds = 0.948 ± 0.037, action_magnitude = 0.542 ± 0.288, n_updates = 4000, time =  9.6, total_time = 39.4
#
# step =   15000, num_env_steps =   15000, scores = -174.742 (n= 1), score_ema = -189.155, actor_loss = -34.281, critic_loss = 1.667, entropy_coef_loss = -13.576, entropy_coef = 0.226, rollout_stds = 0.941 ± 0.069, action_magnitude = 0.554 ± 0.290, n_updates = 5000, time =  9.9, total_time = 49.4
#
# step =   16000, num_env_steps =   16000, scores = -286.854 (n= 1), score_ema = -213.580, actor_loss = -34.087, critic_loss = 1.647, entropy_coef_loss = -15.081, entropy_coef = 0.170, rollout_stds = 0.843 ± 0.051, action_magnitude = 0.561 ± 0.294, n_updates = 6000, time =  9.8, total_time = 59.2
#
# step =   17000, num_env_steps =   17000, scores = -264.211 (n= 1), score_ema = -226.238, actor_loss = -34.535, critic_loss = 1.648, entropy_coef_loss = -17.024, entropy_coef = 0.128, rollout_stds = 0.835 ± 0.058, action_magnitude = 0.572 ± 0.291, n_updates = 7000, time =  9.3, total_time = 68.5
#
# step =   18000, num_env_steps =   18000, scores = -163.525 (n= 1), score_ema = -210.559, actor_loss = -33.640, critic_loss = 1.402, entropy_coef_loss = -15.798, entropy_coef = 0.098, rollout_stds = 0.830 ± 0.076, action_magnitude = 0.585 ± 0.296, n_updates = 8000, time = 10.7, total_time = 79.2
#
# step =   19000, num_env_steps =   19000, scores = -156.054 (n= 1), score_ema = -196.933, actor_loss = -33.049, critic_loss = 1.552, entropy_coef_loss = -15.327, entropy_coef = 0.075, rollout_stds = 0.841 ± 0.056, action_magnitude = 0.595 ± 0.293, n_updates = 9000, time = 12.1, total_time = 91.3
#
# step =   20000, num_env_steps =   20000, scores = -213.271 (n= 1), score_ema = -201.017, actor_loss = -32.043, critic_loss = 1.198, entropy_coef_loss = -15.339, entropy_coef = 0.058, rollout_stds = 0.797 ± 0.053, action_magnitude = 0.599 ± 0.296, n_updates = 10000, time = 11.3, total_time = 102.6
#
# saved experiment log 2024-10-11_12-23-25_512841~zjtzBB at experiment_logs/HalfCheetah-v4/sac/2024-10-11_12-23-25_512841~zjtzBB.json
#
# step =   21000, num_env_steps =   21000, scores = -308.726 (n= 1), score_ema = -227.945, actor_loss = -31.610, critic_loss = 1.534, entropy_coef_loss = -15.233, entropy_coef = 0.044, rollout_stds = 0.738 ± 0.091, action_magnitude = 0.623 ± 0.299, n_updates = 11000, time = 10.9, total_time = 113.4
#
# step =   22000, num_env_steps =   22000, scores = -153.213 (n= 1), score_ema = -209.262, actor_loss = -30.166, critic_loss = 1.286, entropy_coef_loss = -14.309, entropy_coef = 0.034, rollout_stds = 0.617 ± 0.085, action_magnitude = 0.619 ± 0.297, n_updates = 12000, time = 10.7, total_time = 124.1
#
# step =   23000, num_env_steps =   23000, scores = -49.839 (n= 1), score_ema = -169.406, actor_loss = -29.263, critic_loss = 1.835, entropy_coef_loss = -13.795, entropy_coef = 0.026, rollout_stds = 0.673 ± 0.089, action_magnitude = 0.627 ± 0.301, n_updates = 13000, time = 10.7, total_time = 134.9
#
# step =   24000, num_env_steps =   24000, scores = -195.027 (n= 1), score_ema = -175.811, actor_loss = -27.847, critic_loss = 1.443, entropy_coef_loss = -12.548, entropy_coef = 0.021, rollout_stds = 0.633 ± 0.049, action_magnitude = 0.643 ± 0.298, n_updates = 14000, time = 10.7, total_time = 145.6
#
# step =   25000, num_env_steps =   25000, scores = -133.811 (n= 1), score_ema = -165.311, actor_loss = -24.628, critic_loss = 1.505, entropy_coef_loss = -9.537, entropy_coef = 0.017, rollout_stds = 0.590 ± 0.132, action_magnitude = 0.652 ± 0.298, n_updates = 15000, time = 10.7, total_time = 156.3
#
# step =   26000, num_env_steps =   26000, scores = -123.253 (n= 1), score_ema = -154.797, actor_loss = -25.388, critic_loss = 1.704, entropy_coef_loss = -6.496, entropy_coef = 0.013, rollout_stds = 0.437 ± 0.100, action_magnitude = 0.628 ± 0.300, n_updates = 16000, time = 10.8, total_time = 167.1
#
# step =   27000, num_env_steps =   27000, scores = -77.343 (n= 1), score_ema = -135.433, actor_loss = -23.619, critic_loss = 1.894, entropy_coef_loss = -4.052, entropy_coef = 0.011, rollout_stds = 0.571 ± 0.112, action_magnitude = 0.660 ± 0.301, n_updates = 17000, time = 11.0, total_time = 178.1
#
# step =   28000, num_env_steps =   28000, scores = -56.852 (n= 1), score_ema = -115.788, actor_loss = -23.649, critic_loss = 1.350, entropy_coef_loss = -1.531, entropy_coef = 0.009, rollout_stds = 0.457 ± 0.092, action_magnitude = 0.654 ± 0.300, n_updates = 18000, time = 11.9, total_time = 189.9
#
# step =   29000, num_env_steps =   29000, scores =  59.061 (n= 1), score_ema = -72.076, actor_loss = -20.940, critic_loss = 1.290, entropy_coef_loss = -3.007, entropy_coef = 0.008, rollout_stds = 0.418 ± 0.072, action_magnitude = 0.655 ± 0.306, n_updates = 19000, time = 11.3, total_time = 201.2
#
# step =   30000, num_env_steps =   30000, scores =  841.433 (n= 1), score_ema =  156.301, actor_loss = -20.978, critic_loss = 1.418, entropy_coef_loss = -3.338, entropy_coef = 0.008, rollout_stds = 0.250 ± 0.122, action_magnitude = 0.718 ± 0.292, n_updates = 20000, time = 11.1, total_time = 212.3
#
# saved experiment log 2024-10-11_12-23-25_512841~zjtzBB at experiment_logs/HalfCheetah-v4/sac/2024-10-11_12-23-25_512841~zjtzBB.json
#
# step =   31000, num_env_steps =   31000, scores =  757.627 (n= 1), score_ema =  306.633, actor_loss = -22.775, critic_loss = 1.718, entropy_coef_loss = -3.446, entropy_coef = 0.008, rollout_stds = 0.176 ± 0.052, action_magnitude = 0.664 ± 0.301, n_updates = 21000, time = 10.7, total_time = 223.0
#
# step =   32000, num_env_steps =   32000, scores =  1231.140 (n= 1), score_ema =  537.759, actor_loss = -22.917, critic_loss = 1.832, entropy_coef_loss = -0.802, entropy_coef = 0.008, rollout_stds = 0.141 ± 0.068, action_magnitude = 0.685 ± 0.299, n_updates = 22000, time = 11.4, total_time = 234.4
#
# step =   33000, num_env_steps =   33000, scores =  1517.017 (n= 1), score_ema =  782.574, actor_loss = -27.662, critic_loss = 1.860, entropy_coef_loss = 2.721, entropy_coef = 0.009, rollout_stds = 0.268 ± 0.088, action_magnitude = 0.692 ± 0.301, n_updates = 23000, time = 11.6, total_time = 246.0
#
# step =   34000, num_env_steps =   34000, scores =  1494.432 (n= 1), score_ema =  960.538, actor_loss = -24.118, critic_loss = 2.267, entropy_coef_loss = 0.098, entropy_coef = 0.010, rollout_stds = 0.238 ± 0.070, action_magnitude = 0.718 ± 0.290, n_updates = 24000, time = 11.8, total_time = 257.8
#
# step =   35000, num_env_steps =   35000, scores =  1684.497 (n= 1), score_ema =  1141.528, actor_loss = -24.266, critic_loss = 2.437, entropy_coef_loss = -0.845, entropy_coef = 0.011, rollout_stds = 0.266 ± 0.096, action_magnitude = 0.726 ± 0.293, n_updates = 25000, time = 11.6, total_time = 269.3
#
# step =   36000, num_env_steps =   36000, scores =  188.980 (n= 1), score_ema =  903.391, actor_loss = -30.317, critic_loss = 2.324, entropy_coef_loss = 0.123, entropy_coef = 0.012, rollout_stds = 0.423 ± 0.077, action_magnitude = 0.677 ± 0.298, n_updates = 26000, time = 11.2, total_time = 280.5
#
# step =   37000, num_env_steps =   37000, scores =  1677.698 (n= 1), score_ema =  1096.968, actor_loss = -31.427, critic_loss = 2.659, entropy_coef_loss = 0.479, entropy_coef = 0.013, rollout_stds = 0.302 ± 0.096, action_magnitude = 0.734 ± 0.290, n_updates = 27000, time = 11.1, total_time = 291.6
#
# step =   38000, num_env_steps =   38000, scores =  1886.407 (n= 1), score_ema =  1294.328, actor_loss = -33.058, critic_loss = 2.359, entropy_coef_loss = 2.577, entropy_coef = 0.015, rollout_stds = 0.378 ± 0.166, action_magnitude = 0.733 ± 0.291, n_updates = 28000, time = 11.0, total_time = 302.6
#
# step =   39000, num_env_steps =   39000, scores =  1880.853 (n= 1), score_ema =  1440.959, actor_loss = -36.493, critic_loss = 2.538, entropy_coef_loss = -0.948, entropy_coef = 0.016, rollout_stds = 0.312 ± 0.131, action_magnitude = 0.737 ± 0.288, n_updates = 29000, time = 11.4, total_time = 314.0
#
# step =   40000, num_env_steps =   40000, scores =  1914.031 (n= 1), score_ema =  1559.227, actor_loss = -37.766, critic_loss = 3.106, entropy_coef_loss = -1.010, entropy_coef = 0.019, rollout_stds = 0.363 ± 0.131, action_magnitude = 0.717 ± 0.294, n_updates = 30000, time = 11.6, total_time = 325.6
#
# saved experiment log 2024-10-11_12-23-25_512841~zjtzBB at experiment_logs/HalfCheetah-v4/sac/2024-10-11_12-23-25_512841~zjtzBB.json
#
# step =   41000, num_env_steps =   41000, scores =  2156.953 (n= 1), score_ema =  1708.658, actor_loss = -39.492, critic_loss = 3.053, entropy_coef_loss = 0.388, entropy_coef = 0.021, rollout_stds = 0.414 ± 0.098, action_magnitude = 0.722 ± 0.291, n_updates = 31000, time = 11.3, total_time = 336.9
#
# step =   42000, num_env_steps =   42000, scores =  2250.490 (n= 1), score_ema =  1844.116, actor_loss = -39.355, critic_loss = 2.558, entropy_coef_loss = -1.952, entropy_coef = 0.023, rollout_stds = 0.290 ± 0.065, action_magnitude = 0.720 ± 0.295, n_updates = 32000, time = 12.2, total_time = 349.1
#
# step =   43000, num_env_steps =   43000, scores =  2304.038 (n= 1), score_ema =  1959.097, actor_loss = -44.956, critic_loss = 3.330, entropy_coef_loss = 0.715, entropy_coef = 0.025, rollout_stds = 0.357 ± 0.082, action_magnitude = 0.718 ± 0.294, n_updates = 33000, time = 11.6, total_time = 360.6
#
# step =   44000, num_env_steps =   44000, scores =  2267.719 (n= 1), score_ema =  2036.252, actor_loss = -48.633, critic_loss = 4.376, entropy_coef_loss = 0.920, entropy_coef = 0.027, rollout_stds = 0.372 ± 0.134, action_magnitude = 0.730 ± 0.291, n_updates = 34000, time = 11.3, total_time = 372.0
#
# step =   45000, num_env_steps =   45000, scores =  2340.664 (n= 1), score_ema =  2112.355, actor_loss = -51.617, critic_loss = 4.101, entropy_coef_loss = -0.082, entropy_coef = 0.029, rollout_stds = 0.438 ± 0.060, action_magnitude = 0.730 ± 0.292, n_updates = 35000, time = 11.2, total_time = 383.2
#
# step =   46000, num_env_steps =   46000, scores =  2519.387 (n= 1), score_ema =  2214.113, actor_loss = -54.071, critic_loss = 3.443, entropy_coef_loss = 0.726, entropy_coef = 0.030, rollout_stds = 0.489 ± 0.097, action_magnitude = 0.736 ± 0.290, n_updates = 36000, time = 12.0, total_time = 395.2
#
# step =   47000, num_env_steps =   47000, scores =  2691.214 (n= 1), score_ema =  2333.389, actor_loss = -58.276, critic_loss = 4.015, entropy_coef_loss = -1.465, entropy_coef = 0.031, rollout_stds = 0.444 ± 0.105, action_magnitude = 0.737 ± 0.288, n_updates = 37000, time = 11.7, total_time = 406.9
#
# step =   48000, num_env_steps =   48000, scores =  2850.183 (n= 1), score_ema =  2462.587, actor_loss = -67.296, critic_loss = 4.331, entropy_coef_loss = -1.690, entropy_coef = 0.032, rollout_stds = 0.588 ± 0.171, action_magnitude = 0.753 ± 0.282, n_updates = 38000, time = 11.5, total_time = 418.5
#
# step =   49000, num_env_steps =   49000, scores =  2380.854 (n= 1), score_ema =  2442.154, actor_loss = -67.880, critic_loss = 3.863, entropy_coef_loss = 0.553, entropy_coef = 0.032, rollout_stds = 0.421 ± 0.116, action_magnitude = 0.757 ± 0.281, n_updates = 39000, time = 12.0, total_time = 430.4
#
# step =   50000, num_env_steps =   50000, scores =  2507.774 (n= 1), score_ema =  2458.559, actor_loss = -67.213, critic_loss = 4.595, entropy_coef_loss = -2.595, entropy_coef = 0.033, rollout_stds = 0.353 ± 0.076, action_magnitude = 0.737 ± 0.291, n_updates = 40000, time = 12.0, total_time = 442.4
#
# saved experiment log 2024-10-11_12-23-25_512841~zjtzBB at experiment_logs/HalfCheetah-v4/sac/2024-10-11_12-23-25_512841~zjtzBB.json
#
# step =   51000, num_env_steps =   51000, scores =  2755.685 (n= 1), score_ema =  2532.841, actor_loss = -70.687, critic_loss = 5.281, entropy_coef_loss = 0.883, entropy_coef = 0.033, rollout_stds = 0.406 ± 0.108, action_magnitude = 0.746 ± 0.284, n_updates = 41000, time = 11.6, total_time = 454.1
#
# step =   52000, num_env_steps =   52000, scores =  1529.738 (n= 1), score_ema =  2282.065, actor_loss = -74.648, critic_loss = 5.130, entropy_coef_loss = 0.302, entropy_coef = 0.033, rollout_stds = 0.708 ± 0.107, action_magnitude = 0.730 ± 0.293, n_updates = 42000, time = 11.7, total_time = 465.7
#
# step =   53000, num_env_steps =   53000, scores =  2546.195 (n= 1), score_ema =  2348.097, actor_loss = -77.036, critic_loss = 5.078, entropy_coef_loss = -0.832, entropy_coef = 0.034, rollout_stds = 0.444 ± 0.223, action_magnitude = 0.747 ± 0.279, n_updates = 43000, time = 12.0, total_time = 477.7
#
# step =   54000, num_env_steps =   54000, scores =  599.491 (n= 1), score_ema =  1910.946, actor_loss = -76.424, critic_loss = 6.477, entropy_coef_loss = 0.577, entropy_coef = 0.033, rollout_stds = 0.486 ± 0.048, action_magnitude = 0.712 ± 0.295, n_updates = 44000, time = 12.3, total_time = 490.0
#
# step =   55000, num_env_steps =   55000, scores =  2744.394 (n= 1), score_ema =  2119.308, actor_loss = -83.290, critic_loss = 6.733, entropy_coef_loss = 2.904, entropy_coef = 0.033, rollout_stds = 0.345 ± 0.072, action_magnitude = 0.722 ± 0.294, n_updates = 45000, time = 11.7, total_time = 501.7
#
# step =   56000, num_env_steps =   56000, scores =  2783.286 (n= 1), score_ema =  2285.302, actor_loss = -89.841, critic_loss = 7.087, entropy_coef_loss = 0.171, entropy_coef = 0.033, rollout_stds = 0.385 ± 0.099, action_magnitude = 0.727 ± 0.288, n_updates = 46000, time = 11.1, total_time = 512.7
#
# step =   57000, num_env_steps =   57000, scores =  2725.698 (n= 1), score_ema =  2395.401, actor_loss = -93.917, critic_loss = 6.275, entropy_coef_loss = 1.078, entropy_coef = 0.034, rollout_stds = 0.388 ± 0.117, action_magnitude = 0.734 ± 0.286, n_updates = 47000, time = 12.1, total_time = 524.8
#
# step =   58000, num_env_steps =   58000, scores =  2740.949 (n= 1), score_ema =  2481.788, actor_loss = -93.587, critic_loss = 8.159, entropy_coef_loss = 1.736, entropy_coef = 0.034, rollout_stds = 0.540 ± 0.123, action_magnitude = 0.733 ± 0.289, n_updates = 48000, time = 11.8, total_time = 536.6
#
# step =   59000, num_env_steps =   59000, scores =  2893.583 (n= 1), score_ema =  2584.737, actor_loss = -93.671, critic_loss = 6.605, entropy_coef_loss = -1.334, entropy_coef = 0.034, rollout_stds = 0.393 ± 0.100, action_magnitude = 0.740 ± 0.286, n_updates = 49000, time = 12.1, total_time = 548.7
#
# step =   60000, num_env_steps =   60000, scores =  2902.119 (n= 1), score_ema =  2664.082, actor_loss = -101.513, critic_loss = 5.339, entropy_coef_loss = 0.131, entropy_coef = 0.036, rollout_stds = 0.295 ± 0.058, action_magnitude = 0.735 ± 0.285, n_updates = 50000, time = 12.8, total_time = 561.5
#
# saved experiment log 2024-10-11_12-23-25_512841~zjtzBB at experiment_logs/HalfCheetah-v4/sac/2024-10-11_12-23-25_512841~zjtzBB.json
#
# step =   61000, num_env_steps =   61000, scores =  3261.586 (n= 1), score_ema =  2813.458, actor_loss = -96.220, critic_loss = 6.494, entropy_coef_loss = -0.416, entropy_coef = 0.036, rollout_stds = 0.369 ± 0.085, action_magnitude = 0.751 ± 0.283, n_updates = 51000, time = 11.3, total_time = 572.8
#
# step =   62000, num_env_steps =   62000, scores =  3017.333 (n= 1), score_ema =  2864.427, actor_loss = -99.232, critic_loss = 5.870, entropy_coef_loss = 0.451, entropy_coef = 0.036, rollout_stds = 0.433 ± 0.182, action_magnitude = 0.733 ± 0.287, n_updates = 52000, time = 11.4, total_time = 584.2
#
# step =   63000, num_env_steps =   63000, scores =  3012.802 (n= 1), score_ema =  2901.521, actor_loss = -103.879, critic_loss = 6.842, entropy_coef_loss = 1.022, entropy_coef = 0.037, rollout_stds = 0.408 ± 0.112, action_magnitude = 0.740 ± 0.283, n_updates = 53000, time = 11.5, total_time = 595.7
#
# step =   64000, num_env_steps =   64000, scores =  3247.735 (n= 1), score_ema =  2988.074, actor_loss = -111.559, critic_loss = 6.821, entropy_coef_loss = 2.016, entropy_coef = 0.037, rollout_stds = 0.352 ± 0.099, action_magnitude = 0.741 ± 0.281, n_updates = 54000, time = 12.0, total_time = 607.7
#
# step =   65000, num_env_steps =   65000, scores =  3531.781 (n= 1), score_ema =  3124.001, actor_loss = -113.454, critic_loss = 6.565, entropy_coef_loss = 0.359, entropy_coef = 0.038, rollout_stds = 0.352 ± 0.092, action_magnitude = 0.740 ± 0.286, n_updates = 55000, time = 13.2, total_time = 620.9
#
# step =   66000, num_env_steps =   66000, scores =  3335.837 (n= 1), score_ema =  3176.960, actor_loss = -119.241, critic_loss = 8.724, entropy_coef_loss = 1.580, entropy_coef = 0.039, rollout_stds = 0.366 ± 0.111, action_magnitude = 0.741 ± 0.283, n_updates = 56000, time = 13.1, total_time = 634.0
#
# step =   67000, num_env_steps =   67000, scores =  3592.556 (n= 1), score_ema =  3280.859, actor_loss = -123.917, critic_loss = 7.191, entropy_coef_loss = 0.182, entropy_coef = 0.040, rollout_stds = 0.340 ± 0.111, action_magnitude = 0.759 ± 0.276, n_updates = 57000, time = 13.3, total_time = 647.3
#
# step =   68000, num_env_steps =   68000, scores =  3378.789 (n= 1), score_ema =  3305.341, actor_loss = -120.493, critic_loss = 7.803, entropy_coef_loss = -0.401, entropy_coef = 0.040, rollout_stds = 0.478 ± 0.100, action_magnitude = 0.742 ± 0.285, n_updates = 58000, time = 14.0, total_time = 661.3
#
# step =   69000, num_env_steps =   69000, scores =  3505.987 (n= 1), score_ema =  3355.503, actor_loss = -127.280, critic_loss = 8.048, entropy_coef_loss = 0.453, entropy_coef = 0.041, rollout_stds = 0.390 ± 0.150, action_magnitude = 0.738 ± 0.285, n_updates = 59000, time = 13.3, total_time = 674.6
#
# step =   70000, num_env_steps =   70000, scores =  3125.881 (n= 1), score_ema =  3298.097, actor_loss = -131.230, critic_loss = 10.399, entropy_coef_loss = 1.267, entropy_coef = 0.043, rollout_stds = 0.554 ± 0.056, action_magnitude = 0.738 ± 0.285, n_updates = 60000, time = 13.2, total_time = 687.8
#
# saved experiment log 2024-10-11_12-23-25_512841~zjtzBB at experiment_logs/HalfCheetah-v4/sac/2024-10-11_12-23-25_512841~zjtzBB.json
#
# step =   71000, num_env_steps =   71000, scores =  3520.958 (n= 1), score_ema =  3353.812, actor_loss = -126.894, critic_loss = 9.037, entropy_coef_loss = -0.779, entropy_coef = 0.043, rollout_stds = 0.384 ± 0.140, action_magnitude = 0.738 ± 0.286, n_updates = 61000, time = 13.4, total_time = 701.2
#
# step =   72000, num_env_steps =   72000, scores =  3738.245 (n= 1), score_ema =  3449.921, actor_loss = -133.948, critic_loss = 7.427, entropy_coef_loss = 0.661, entropy_coef = 0.044, rollout_stds = 0.367 ± 0.148, action_magnitude = 0.753 ± 0.277, n_updates = 62000, time = 13.3, total_time = 714.4
#
# step =   73000, num_env_steps =   73000, scores =  3676.096 (n= 1), score_ema =  3506.465, actor_loss = -143.202, critic_loss = 9.335, entropy_coef_loss = 0.321, entropy_coef = 0.044, rollout_stds = 0.349 ± 0.094, action_magnitude = 0.751 ± 0.281, n_updates = 63000, time = 14.5, total_time = 728.9
#
# step =   74000, num_env_steps =   74000, scores =  3634.574 (n= 1), score_ema =  3538.492, actor_loss = -150.429, critic_loss = 9.795, entropy_coef_loss = 1.498, entropy_coef = 0.046, rollout_stds = 0.389 ± 0.145, action_magnitude = 0.744 ± 0.285, n_updates = 64000, time = 13.5, total_time = 742.4
#
# step =   75000, num_env_steps =   75000, scores =  3756.951 (n= 1), score_ema =  3593.107, actor_loss = -134.303, critic_loss = 6.817, entropy_coef_loss = 0.064, entropy_coef = 0.048, rollout_stds = 0.407 ± 0.137, action_magnitude = 0.749 ± 0.284, n_updates = 65000, time = 13.9, total_time = 756.3
#
# step =   76000, num_env_steps =   76000, scores =  3995.461 (n= 1), score_ema =  3693.695, actor_loss = -146.385, critic_loss = 7.168, entropy_coef_loss = 0.505, entropy_coef = 0.048, rollout_stds = 0.373 ± 0.113, action_magnitude = 0.765 ± 0.272, n_updates = 66000, time = 13.5, total_time = 769.8
#
# step =   77000, num_env_steps =   77000, scores =  3860.811 (n= 1), score_ema =  3735.474, actor_loss = -146.651, critic_loss = 9.644, entropy_coef_loss = 2.653, entropy_coef = 0.048, rollout_stds = 0.350 ± 0.106, action_magnitude = 0.758 ± 0.276, n_updates = 67000, time = 14.0, total_time = 783.9
#
# step =   78000, num_env_steps =   78000, scores =  3909.565 (n= 1), score_ema =  3778.997, actor_loss = -139.721, critic_loss = 8.490, entropy_coef_loss = -1.788, entropy_coef = 0.050, rollout_stds = 0.431 ± 0.113, action_magnitude = 0.753 ± 0.278, n_updates = 68000, time = 13.6, total_time = 797.5
#
# step =   79000, num_env_steps =   79000, scores =  3907.085 (n= 1), score_ema =  3811.019, actor_loss = -153.808, critic_loss = 10.172, entropy_coef_loss = -1.495, entropy_coef = 0.051, rollout_stds = 0.375 ± 0.096, action_magnitude = 0.760 ± 0.277, n_updates = 69000, time = 13.5, total_time = 810.9
#
# step =   80000, num_env_steps =   80000, scores =  867.010 (n= 1), score_ema =  3075.017, actor_loss = -163.739, critic_loss = 9.364, entropy_coef_loss = 2.780, entropy_coef = 0.052, rollout_stds = 0.567 ± 0.080, action_magnitude = 0.629 ± 0.299, n_updates = 70000, time = 13.4, total_time = 824.3
#
# saved experiment log 2024-10-11_12-23-25_512841~zjtzBB at experiment_logs/HalfCheetah-v4/sac/2024-10-11_12-23-25_512841~zjtzBB.json
#
# step =   81000, num_env_steps =   81000, scores =  4251.254 (n= 1), score_ema =  3369.076, actor_loss = -160.692, critic_loss = 9.074, entropy_coef_loss = -2.382, entropy_coef = 0.052, rollout_stds = 0.360 ± 0.125, action_magnitude = 0.765 ± 0.271, n_updates = 71000, time = 13.2, total_time = 837.5
#
# step =   82000, num_env_steps =   82000, scores =  3948.190 (n= 1), score_ema =  3513.855, actor_loss = -166.378, critic_loss = 9.315, entropy_coef_loss = -1.109, entropy_coef = 0.052, rollout_stds = 0.302 ± 0.080, action_magnitude = 0.749 ± 0.283, n_updates = 72000, time = 13.2, total_time = 850.7
#
# step =   83000, num_env_steps =   83000, scores =  4194.152 (n= 1), score_ema =  3683.929, actor_loss = -170.499, critic_loss = 8.626, entropy_coef_loss = -1.124, entropy_coef = 0.054, rollout_stds = 0.344 ± 0.090, action_magnitude = 0.760 ± 0.275, n_updates = 73000, time = 13.4, total_time = 864.1
#
# step =   84000, num_env_steps =   84000, scores =  4458.947 (n= 1), score_ema =  3877.683, actor_loss = -165.395, critic_loss = 9.716, entropy_coef_loss = -1.780, entropy_coef = 0.055, rollout_stds = 0.401 ± 0.161, action_magnitude = 0.761 ± 0.275, n_updates = 74000, time = 13.4, total_time = 877.6
#
# step =   85000, num_env_steps =   85000, scores =  4081.106 (n= 1), score_ema =  3928.539, actor_loss = -165.991, critic_loss = 10.505, entropy_coef_loss = 1.351, entropy_coef = 0.056, rollout_stds = 0.384 ± 0.138, action_magnitude = 0.748 ± 0.280, n_updates = 75000, time = 13.5, total_time = 891.1
#
# step =   86000, num_env_steps =   86000, scores =  4158.828 (n= 1), score_ema =  3986.111, actor_loss = -175.841, critic_loss = 8.026, entropy_coef_loss = 0.589, entropy_coef = 0.057, rollout_stds = 0.419 ± 0.112, action_magnitude = 0.751 ± 0.279, n_updates = 76000, time = 13.2, total_time = 904.2
#
# step =   87000, num_env_steps =   87000, scores =  4131.892 (n= 1), score_ema =  4022.556, actor_loss = -164.906, critic_loss = 9.538, entropy_coef_loss = -1.229, entropy_coef = 0.057, rollout_stds = 0.398 ± 0.117, action_magnitude = 0.744 ± 0.284, n_updates = 77000, time = 13.1, total_time = 917.3
#
# step =   88000, num_env_steps =   88000, scores =  4446.804 (n= 1), score_ema =  4128.618, actor_loss = -180.427, critic_loss = 8.829, entropy_coef_loss = 1.540, entropy_coef = 0.059, rollout_stds = 0.451 ± 0.175, action_magnitude = 0.757 ± 0.273, n_updates = 78000, time = 13.1, total_time = 930.4
#
# step =   89000, num_env_steps =   89000, scores =  4621.334 (n= 1), score_ema =  4251.797, actor_loss = -194.676, critic_loss = 9.259, entropy_coef_loss = 1.267, entropy_coef = 0.058, rollout_stds = 0.407 ± 0.103, action_magnitude = 0.749 ± 0.283, n_updates = 79000, time = 13.1, total_time = 943.4
#
# step =   90000, num_env_steps =   90000, scores =  4476.575 (n= 1), score_ema =  4307.992, actor_loss = -198.358, critic_loss = 10.607, entropy_coef_loss = 0.228, entropy_coef = 0.060, rollout_stds = 0.405 ± 0.111, action_magnitude = 0.738 ± 0.282, n_updates = 80000, time = 13.0, total_time = 956.4
#
# saved experiment log 2024-10-11_12-23-25_512841~zjtzBB at experiment_logs/HalfCheetah-v4/sac/2024-10-11_12-23-25_512841~zjtzBB.json
#
# step =   91000, num_env_steps =   91000, scores =  4475.302 (n= 1), score_ema =  4349.819, actor_loss = -194.372, critic_loss = 12.590, entropy_coef_loss = 0.515, entropy_coef = 0.061, rollout_stds = 0.356 ± 0.122, action_magnitude = 0.740 ± 0.284, n_updates = 81000, time = 13.1, total_time = 969.5
#
# step =   92000, num_env_steps =   92000, scores =  4659.301 (n= 1), score_ema =  4427.190, actor_loss = -197.671, critic_loss = 10.499, entropy_coef_loss = 0.879, entropy_coef = 0.062, rollout_stds = 0.389 ± 0.160, action_magnitude = 0.752 ± 0.279, n_updates = 82000, time = 13.1, total_time = 982.5
#
# step =   93000, num_env_steps =   93000, scores =  4436.721 (n= 1), score_ema =  4429.573, actor_loss = -185.792, critic_loss = 12.640, entropy_coef_loss = -0.094, entropy_coef = 0.063, rollout_stds = 0.414 ± 0.090, action_magnitude = 0.745 ± 0.282, n_updates = 83000, time = 13.0, total_time = 995.6
#
# step =   94000, num_env_steps =   94000, scores =  4686.144 (n= 1), score_ema =  4493.715, actor_loss = -204.115, critic_loss = 10.744, entropy_coef_loss = -0.006, entropy_coef = 0.064, rollout_stds = 0.274 ± 0.084, action_magnitude = 0.745 ± 0.281, n_updates = 84000, time = 13.1, total_time = 1008.6
#
# step =   95000, num_env_steps =   95000, scores =  4596.836 (n= 1), score_ema =  4519.496, actor_loss = -195.369, critic_loss = 9.403, entropy_coef_loss = -0.082, entropy_coef = 0.065, rollout_stds = 0.499 ± 0.074, action_magnitude = 0.753 ± 0.277, n_updates = 85000, time = 13.0, total_time = 1021.7
#
# step =   96000, num_env_steps =   96000, scores =  5052.740 (n= 1), score_ema =  4652.807, actor_loss = -200.997, critic_loss = 14.053, entropy_coef_loss = -0.970, entropy_coef = 0.066, rollout_stds = 0.475 ± 0.177, action_magnitude = 0.752 ± 0.277, n_updates = 86000, time = 13.0, total_time = 1034.7
#
# step =   97000, num_env_steps =   97000, scores =  4676.894 (n= 1), score_ema =  4658.829, actor_loss = -223.279, critic_loss = 10.296, entropy_coef_loss = 0.934, entropy_coef = 0.068, rollout_stds = 0.355 ± 0.126, action_magnitude = 0.754 ± 0.277, n_updates = 87000, time = 13.0, total_time = 1047.7
#
# step =   98000, num_env_steps =   98000, scores =  5111.119 (n= 1), score_ema =  4771.901, actor_loss = -207.276, critic_loss = 12.110, entropy_coef_loss = -0.358, entropy_coef = 0.068, rollout_stds = 0.453 ± 0.101, action_magnitude = 0.753 ± 0.281, n_updates = 88000, time = 13.1, total_time = 1060.8
#
# step =   99000, num_env_steps =   99000, scores =  4880.417 (n= 1), score_ema =  4799.030, actor_loss = -228.557, critic_loss = 11.349, entropy_coef_loss = -0.024, entropy_coef = 0.069, rollout_stds = 0.373 ± 0.172, action_magnitude = 0.745 ± 0.282, n_updates = 89000, time = 13.1, total_time = 1073.8
#
# step =  100000, num_env_steps =  100000, scores =  4776.550 (n= 1), score_ema =  4793.410, actor_loss = -203.211, critic_loss = 12.118, entropy_coef_loss = -0.179, entropy_coef = 0.069, rollout_stds = 0.388 ± 0.112, action_magnitude = 0.747 ± 0.281, n_updates = 90000, time = 13.0, total_time = 1086.9
#
# saved experiment log 2024-10-11_12-23-25_512841~zjtzBB at experiment_logs/HalfCheetah-v4/sac/2024-10-11_12-23-25_512841~zjtzBB.json
#
# step =  101000, num_env_steps =  101000, scores =  4883.193 (n= 1), score_ema =  4815.856, actor_loss = -210.257, critic_loss = 11.679, entropy_coef_loss = 0.428, entropy_coef = 0.070, rollout_stds = 0.430 ± 0.112, action_magnitude = 0.753 ± 0.276, n_updates = 91000, time = 13.1, total_time = 1099.9
#
# step =  102000, num_env_steps =  102000, scores =  4845.758 (n= 1), score_ema =  4823.331, actor_loss = -233.212, critic_loss = 10.776, entropy_coef_loss = 0.071, entropy_coef = 0.073, rollout_stds = 0.406 ± 0.161, action_magnitude = 0.752 ± 0.278, n_updates = 92000, time = 13.0, total_time = 1113.0
#
# step =  103000, num_env_steps =  103000, scores =  4773.837 (n= 1), score_ema =  4810.958, actor_loss = -223.373, critic_loss = 16.291, entropy_coef_loss = -0.387, entropy_coef = 0.073, rollout_stds = 0.392 ± 0.069, action_magnitude = 0.754 ± 0.274, n_updates = 93000, time = 13.1, total_time = 1126.0
#
# step =  104000, num_env_steps =  104000, scores =  4887.240 (n= 1), score_ema =  4830.028, actor_loss = -230.149, critic_loss = 11.898, entropy_coef_loss = -0.052, entropy_coef = 0.075, rollout_stds = 0.432 ± 0.090, action_magnitude = 0.754 ± 0.277, n_updates = 94000, time = 13.1, total_time = 1139.1
#
# step =  105000, num_env_steps =  105000, scores =  4986.491 (n= 1), score_ema =  4869.144, actor_loss = -227.394, critic_loss = 14.136, entropy_coef_loss = -0.527, entropy_coef = 0.076, rollout_stds = 0.395 ± 0.106, action_magnitude = 0.756 ± 0.275, n_updates = 95000, time = 13.9, total_time = 1153.0
#
# step =  106000, num_env_steps =  106000, scores =  4988.228 (n= 1), score_ema =  4898.915, actor_loss = -219.558, critic_loss = 15.131, entropy_coef_loss = -3.492, entropy_coef = 0.077, rollout_stds = 0.402 ± 0.144, action_magnitude = 0.760 ± 0.270, n_updates = 96000, time = 13.2, total_time = 1166.2
#
# step =  107000, num_env_steps =  107000, scores =  4823.477 (n= 1), score_ema =  4880.055, actor_loss = -242.772, critic_loss = 10.290, entropy_coef_loss = 0.328, entropy_coef = 0.078, rollout_stds = 0.380 ± 0.133, action_magnitude = 0.758 ± 0.276, n_updates = 97000, time = 13.1, total_time = 1179.3
#
# step =  108000, num_env_steps =  108000, scores =  5143.409 (n= 1), score_ema =  4945.894, actor_loss = -232.221, critic_loss = 11.565, entropy_coef_loss = -0.179, entropy_coef = 0.079, rollout_stds = 0.670 ± 0.228, action_magnitude = 0.766 ± 0.269, n_updates = 98000, time = 13.2, total_time = 1192.5
#
# step =  109000, num_env_steps =  109000, scores =  5037.868 (n= 1), score_ema =  4968.887, actor_loss = -238.226, critic_loss = 9.935, entropy_coef_loss = -0.731, entropy_coef = 0.083, rollout_stds = 0.383 ± 0.147, action_magnitude = 0.751 ± 0.282, n_updates = 99000, time = 13.2, total_time = 1205.8
#
# step =  110000, num_env_steps =  110000, scores =  4887.717 (n= 1), score_ema =  4948.595, actor_loss = -239.107, critic_loss = 13.201, entropy_coef_loss = -1.018, entropy_coef = 0.081, rollout_stds = 0.411 ± 0.162, action_magnitude = 0.757 ± 0.277, n_updates = 100000, time = 13.2, total_time = 1219.0
#
# saved experiment log 2024-10-11_12-23-25_512841~zjtzBB at experiment_logs/HalfCheetah-v4/sac/2024-10-11_12-23-25_512841~zjtzBB.json
#
# step =  111000, num_env_steps =  111000, scores =  5311.384 (n= 1), score_ema =  5039.292, actor_loss = -236.269, critic_loss = 12.201, entropy_coef_loss = -1.597, entropy_coef = 0.082, rollout_stds = 0.418 ± 0.136, action_magnitude = 0.763 ± 0.277, n_updates = 101000, time = 13.2, total_time = 1232.2
#
# step =  112000, num_env_steps =  112000, scores =  5132.674 (n= 1), score_ema =  5062.638, actor_loss = -251.573, critic_loss = 11.731, entropy_coef_loss = -0.588, entropy_coef = 0.084, rollout_stds = 0.483 ± 0.124, action_magnitude = 0.750 ± 0.282, n_updates = 102000, time = 13.2, total_time = 1245.4
#
# step =  113000, num_env_steps =  113000, scores =  5209.805 (n= 1), score_ema =  5099.430, actor_loss = -254.764, critic_loss = 12.204, entropy_coef_loss = -0.749, entropy_coef = 0.086, rollout_stds = 0.453 ± 0.068, action_magnitude = 0.759 ± 0.277, n_updates = 103000, time = 13.2, total_time = 1258.6
#
# step =  114000, num_env_steps =  114000, scores =  5245.504 (n= 1), score_ema =  5135.948, actor_loss = -257.400, critic_loss = 10.897, entropy_coef_loss = 0.940, entropy_coef = 0.086, rollout_stds = 0.397 ± 0.124, action_magnitude = 0.768 ± 0.268, n_updates = 104000, time = 13.2, total_time = 1271.8
#
# step =  115000, num_env_steps =  115000, scores =  5430.800 (n= 1), score_ema =  5209.661, actor_loss = -259.487, critic_loss = 14.311, entropy_coef_loss = 1.053, entropy_coef = 0.088, rollout_stds = 0.464 ± 0.126, action_magnitude = 0.756 ± 0.280, n_updates = 105000, time = 13.2, total_time = 1285.1
#
# step =  116000, num_env_steps =  116000, scores =  5302.402 (n= 1), score_ema =  5232.846, actor_loss = -267.207, critic_loss = 18.014, entropy_coef_loss = 1.301, entropy_coef = 0.089, rollout_stds = 0.450 ± 0.105, action_magnitude = 0.763 ± 0.272, n_updates = 106000, time = 13.2, total_time = 1298.2
#
# step =  117000, num_env_steps =  117000, scores =  5421.709 (n= 1), score_ema =  5280.062, actor_loss = -260.880, critic_loss = 10.476, entropy_coef_loss = -0.098, entropy_coef = 0.091, rollout_stds = 0.428 ± 0.098, action_magnitude = 0.769 ± 0.270, n_updates = 107000, time = 13.2, total_time = 1311.4
#
# step =  118000, num_env_steps =  118000, scores =  5447.236 (n= 1), score_ema =  5321.855, actor_loss = -257.450, critic_loss = 12.450, entropy_coef_loss = -0.997, entropy_coef = 0.090, rollout_stds = 0.466 ± 0.030, action_magnitude = 0.765 ± 0.274, n_updates = 108000, time = 13.2, total_time = 1324.6
#
# step =  119000, num_env_steps =  119000, scores =  5571.820 (n= 1), score_ema =  5384.347, actor_loss = -266.981, critic_loss = 20.476, entropy_coef_loss = 0.886, entropy_coef = 0.091, rollout_stds = 0.453 ± 0.115, action_magnitude = 0.764 ± 0.275, n_updates = 109000, time = 13.1, total_time = 1337.7
#
# step =  120000, num_env_steps =  120000, scores =  5355.418 (n= 1), score_ema =  5377.115, actor_loss = -271.582, critic_loss = 12.528, entropy_coef_loss = 0.263, entropy_coef = 0.093, rollout_stds = 0.361 ± 0.087, action_magnitude = 0.762 ± 0.275, n_updates = 110000, time = 13.1, total_time = 1350.8
#
# saved experiment log 2024-10-11_12-23-25_512841~zjtzBB at experiment_logs/HalfCheetah-v4/sac/2024-10-11_12-23-25_512841~zjtzBB.json
#
# step =  121000, num_env_steps =  121000, scores =  5168.909 (n= 1), score_ema =  5325.063, actor_loss = -276.538, critic_loss = 14.596, entropy_coef_loss = 0.496, entropy_coef = 0.095, rollout_stds = 0.436 ± 0.165, action_magnitude = 0.757 ± 0.277, n_updates = 111000, time = 13.1, total_time = 1363.9
#
# step =  122000, num_env_steps =  122000, scores =  5708.920 (n= 1), score_ema =  5421.027, actor_loss = -274.279, critic_loss = 13.805, entropy_coef_loss = 0.068, entropy_coef = 0.096, rollout_stds = 0.356 ± 0.144, action_magnitude = 0.765 ± 0.273, n_updates = 112000, time = 13.3, total_time = 1377.2
#
# step =  123000, num_env_steps =  123000, scores =  5777.721 (n= 1), score_ema =  5510.201, actor_loss = -274.552, critic_loss = 11.261, entropy_coef_loss = -0.225, entropy_coef = 0.096, rollout_stds = 0.432 ± 0.177, action_magnitude = 0.772 ± 0.267, n_updates = 113000, time = 13.3, total_time = 1390.5
#
# step =  124000, num_env_steps =  124000, scores =  5803.437 (n= 1), score_ema =  5583.510, actor_loss = -274.166, critic_loss = 15.352, entropy_coef_loss = -0.450, entropy_coef = 0.096, rollout_stds = 0.397 ± 0.149, action_magnitude = 0.764 ± 0.276, n_updates = 114000, time = 13.3, total_time = 1403.8
#
# step =  125000, num_env_steps =  125000, scores =  2768.934 (n= 1), score_ema =  4879.866, actor_loss = -277.898, critic_loss = 15.138, entropy_coef_loss = -0.426, entropy_coef = 0.096, rollout_stds = 0.628 ± 0.105, action_magnitude = 0.673 ± 0.297, n_updates = 115000, time = 13.5, total_time = 1417.3
#
# step =  126000, num_env_steps =  126000, scores =  5581.794 (n= 1), score_ema =  5055.348, actor_loss = -289.536, critic_loss = 23.879, entropy_coef_loss = -0.274, entropy_coef = 0.099, rollout_stds = 0.446 ± 0.193, action_magnitude = 0.761 ± 0.277, n_updates = 116000, time = 13.6, total_time = 1430.8
#
# step =  127000, num_env_steps =  127000, scores =  5727.505 (n= 1), score_ema =  5223.387, actor_loss = -276.012, critic_loss = 14.664, entropy_coef_loss = 0.908, entropy_coef = 0.099, rollout_stds = 0.575 ± 0.119, action_magnitude = 0.764 ± 0.275, n_updates = 117000, time = 13.5, total_time = 1444.4
#
# step =  128000, num_env_steps =  128000, scores =  5785.688 (n= 1), score_ema =  5363.962, actor_loss = -294.200, critic_loss = 12.936, entropy_coef_loss = 0.152, entropy_coef = 0.099, rollout_stds = 0.398 ± 0.110, action_magnitude = 0.762 ± 0.278, n_updates = 118000, time = 13.5, total_time = 1457.8
#
# step =  129000, num_env_steps =  129000, scores =  5575.105 (n= 1), score_ema =  5416.748, actor_loss = -298.832, critic_loss = 14.272, entropy_coef_loss = 0.642, entropy_coef = 0.099, rollout_stds = 0.455 ± 0.144, action_magnitude = 0.763 ± 0.274, n_updates = 119000, time = 13.5, total_time = 1471.3
#
# step =  130000, num_env_steps =  130000, scores =  5792.760 (n= 1), score_ema =  5510.751, actor_loss = -293.302, critic_loss = 12.161, entropy_coef_loss = -0.003, entropy_coef = 0.103, rollout_stds = 0.400 ± 0.166, action_magnitude = 0.761 ± 0.279, n_updates = 120000, time = 13.2, total_time = 1484.6
#
# saved experiment log 2024-10-11_12-23-25_512841~zjtzBB at experiment_logs/HalfCheetah-v4/sac/2024-10-11_12-23-25_512841~zjtzBB.json
#
# step =  131000, num_env_steps =  131000, scores =  5713.597 (n= 1), score_ema =  5561.463, actor_loss = -290.506, critic_loss = 10.562, entropy_coef_loss = -0.758, entropy_coef = 0.105, rollout_stds = 0.432 ± 0.122, action_magnitude = 0.761 ± 0.279, n_updates = 121000, time = 13.1, total_time = 1497.7
#
# step =  132000, num_env_steps =  132000, scores =  5742.785 (n= 1), score_ema =  5606.793, actor_loss = -294.851, critic_loss = 15.096, entropy_coef_loss = 0.497, entropy_coef = 0.104, rollout_stds = 0.459 ± 0.072, action_magnitude = 0.761 ± 0.274, n_updates = 122000, time = 13.1, total_time = 1510.8
#
# step =  133000, num_env_steps =  133000, scores =  5755.026 (n= 1), score_ema =  5643.851, actor_loss = -304.193, critic_loss = 12.488, entropy_coef_loss = -0.690, entropy_coef = 0.107, rollout_stds = 0.482 ± 0.067, action_magnitude = 0.766 ± 0.273, n_updates = 123000, time = 13.1, total_time = 1523.9
#
# step =  134000, num_env_steps =  134000, scores =  6105.268 (n= 1), score_ema =  5759.206, actor_loss = -298.561, critic_loss = 16.173, entropy_coef_loss = 1.809, entropy_coef = 0.106, rollout_stds = 0.370 ± 0.100, action_magnitude = 0.773 ± 0.270, n_updates = 124000, time = 13.1, total_time = 1537.0
#
# step =  135000, num_env_steps =  135000, scores =  5917.286 (n= 1), score_ema =  5798.726, actor_loss = -307.182, critic_loss = 27.131, entropy_coef_loss = -0.055, entropy_coef = 0.109, rollout_stds = 0.372 ± 0.152, action_magnitude = 0.766 ± 0.274, n_updates = 125000, time = 13.1, total_time = 1550.1
#
# step =  136000, num_env_steps =  136000, scores =  6270.617 (n= 1), score_ema =  5916.699, actor_loss = -312.844, critic_loss = 14.505, entropy_coef_loss = 2.286, entropy_coef = 0.109, rollout_stds = 0.451 ± 0.162, action_magnitude = 0.780 ± 0.263, n_updates = 126000, time = 13.1, total_time = 1563.1
#
# step =  137000, num_env_steps =  137000, scores =  6092.512 (n= 1), score_ema =  5960.652, actor_loss = -313.870, critic_loss = 14.759, entropy_coef_loss = 0.497, entropy_coef = 0.108, rollout_stds = 0.331 ± 0.130, action_magnitude = 0.770 ± 0.272, n_updates = 127000, time = 13.1, total_time = 1576.2
#
# step =  138000, num_env_steps =  138000, scores =  5965.373 (n= 1), score_ema =  5961.832, actor_loss = -319.303, critic_loss = 14.847, entropy_coef_loss = 0.322, entropy_coef = 0.110, rollout_stds = 0.395 ± 0.083, action_magnitude = 0.768 ± 0.271, n_updates = 128000, time = 13.1, total_time = 1589.3
#
# step =  139000, num_env_steps =  139000, scores =  6308.288 (n= 1), score_ema =  6048.446, actor_loss = -301.008, critic_loss = 12.147, entropy_coef_loss = -0.630, entropy_coef = 0.110, rollout_stds = 0.450 ± 0.187, action_magnitude = 0.771 ± 0.271, n_updates = 129000, time = 13.1, total_time = 1602.4
#
# step =  140000, num_env_steps =  140000, scores =  6244.162 (n= 1), score_ema =  6097.375, actor_loss = -314.147, critic_loss = 15.668, entropy_coef_loss = 1.281, entropy_coef = 0.111, rollout_stds = 0.315 ± 0.113, action_magnitude = 0.768 ± 0.269, n_updates = 130000, time = 13.1, total_time = 1615.5
#
# saved experiment log 2024-10-11_12-23-25_512841~zjtzBB at experiment_logs/HalfCheetah-v4/sac/2024-10-11_12-23-25_512841~zjtzBB.json
#
# step =  141000, num_env_steps =  141000, scores =  6128.202 (n= 1), score_ema =  6105.082, actor_loss = -323.821, critic_loss = 12.714, entropy_coef_loss = 0.247, entropy_coef = 0.112, rollout_stds = 0.461 ± 0.087, action_magnitude = 0.773 ± 0.268, n_updates = 131000, time = 13.1, total_time = 1628.6
#
# step =  142000, num_env_steps =  142000, scores =  6303.538 (n= 1), score_ema =  6154.696, actor_loss = -302.308, critic_loss = 15.924, entropy_coef_loss = -0.858, entropy_coef = 0.114, rollout_stds = 0.357 ± 0.094, action_magnitude = 0.773 ± 0.270, n_updates = 132000, time = 13.1, total_time = 1641.6
#
# step =  143000, num_env_steps =  143000, scores =  6266.000 (n= 1), score_ema =  6182.522, actor_loss = -315.455, critic_loss = 22.882, entropy_coef_loss = 0.386, entropy_coef = 0.115, rollout_stds = 0.396 ± 0.173, action_magnitude = 0.772 ± 0.272, n_updates = 133000, time = 13.1, total_time = 1654.7
#
# step =  144000, num_env_steps =  144000, scores =  6140.696 (n= 1), score_ema =  6172.065, actor_loss = -326.945, critic_loss = 16.621, entropy_coef_loss = 0.011, entropy_coef = 0.116, rollout_stds = 0.354 ± 0.137, action_magnitude = 0.773 ± 0.273, n_updates = 134000, time = 13.1, total_time = 1667.8
#
# step =  145000, num_env_steps =  145000, scores =  6073.812 (n= 1), score_ema =  6147.502, actor_loss = -326.247, critic_loss = 14.319, entropy_coef_loss = 1.165, entropy_coef = 0.118, rollout_stds = 0.336 ± 0.140, action_magnitude = 0.771 ± 0.266, n_updates = 135000, time = 13.1, total_time = 1680.9
#
# step =  146000, num_env_steps =  146000, scores =  6321.327 (n= 1), score_ema =  6190.958, actor_loss = -327.097, critic_loss = 16.894, entropy_coef_loss = 0.536, entropy_coef = 0.119, rollout_stds = 0.442 ± 0.111, action_magnitude = 0.773 ± 0.274, n_updates = 136000, time = 13.1, total_time = 1694.0
#
# step =  147000, num_env_steps =  147000, scores =  1411.536 (n= 1), score_ema =  4996.103, actor_loss = -338.196, critic_loss = 17.301, entropy_coef_loss = -0.246, entropy_coef = 0.117, rollout_stds = 0.712 ± 0.135, action_magnitude = 0.600 ± 0.303, n_updates = 137000, time = 13.1, total_time = 1707.1
#
# step =  148000, num_env_steps =  148000, scores =  6049.388 (n= 1), score_ema =  5259.424, actor_loss = -321.118, critic_loss = 15.033, entropy_coef_loss = -1.895, entropy_coef = 0.119, rollout_stds = 0.456 ± 0.110, action_magnitude = 0.770 ± 0.273, n_updates = 138000, time = 13.1, total_time = 1720.2
#
# step =  149000, num_env_steps =  149000, scores =  6559.092 (n= 1), score_ema =  5584.341, actor_loss = -317.816, critic_loss = 20.755, entropy_coef_loss = -0.949, entropy_coef = 0.121, rollout_stds = 0.373 ± 0.142, action_magnitude = 0.769 ± 0.274, n_updates = 139000, time = 13.1, total_time = 1733.2
#
# step =  150000, num_env_steps =  150000, scores =  6483.410 (n= 1), score_ema =  5809.108, actor_loss = -333.687, critic_loss = 18.892, entropy_coef_loss = -0.102, entropy_coef = 0.119, rollout_stds = 0.329 ± 0.138, action_magnitude = 0.775 ± 0.268, n_updates = 140000, time = 13.4, total_time = 1746.6
#
# saved experiment log 2024-10-11_12-23-25_512841~zjtzBB at experiment_logs/HalfCheetah-v4/sac/2024-10-11_12-23-25_512841~zjtzBB.json
#
# step =  151000, num_env_steps =  151000, scores =  6413.433 (n= 1), score_ema =  5960.189, actor_loss = -338.900, critic_loss = 12.267, entropy_coef_loss = -1.098, entropy_coef = 0.121, rollout_stds = 0.387 ± 0.166, action_magnitude = 0.775 ± 0.267, n_updates = 141000, time = 13.1, total_time = 1759.7
#
# step =  152000, num_env_steps =  152000, scores =  6456.249 (n= 1), score_ema =  6084.204, actor_loss = -321.013, critic_loss = 19.246, entropy_coef_loss = -0.148, entropy_coef = 0.121, rollout_stds = 0.387 ± 0.154, action_magnitude = 0.778 ± 0.269, n_updates = 142000, time = 13.1, total_time = 1772.8
#
# step =  153000, num_env_steps =  153000, scores =  6546.564 (n= 1), score_ema =  6199.794, actor_loss = -346.216, critic_loss = 14.366, entropy_coef_loss = 0.242, entropy_coef = 0.124, rollout_stds = 0.461 ± 0.111, action_magnitude = 0.767 ± 0.274, n_updates = 143000, time = 13.1, total_time = 1785.8
#
# step =  154000, num_env_steps =  154000, scores =  6514.128 (n= 1), score_ema =  6278.378, actor_loss = -329.528, critic_loss = 12.189, entropy_coef_loss = -1.231, entropy_coef = 0.124, rollout_stds = 0.441 ± 0.092, action_magnitude = 0.768 ± 0.273, n_updates = 144000, time = 13.1, total_time = 1798.9
#
# step =  155000, num_env_steps =  155000, scores =  6669.587 (n= 1), score_ema =  6376.180, actor_loss = -362.724, critic_loss = 14.055, entropy_coef_loss = 0.786, entropy_coef = 0.125, rollout_stds = 0.380 ± 0.115, action_magnitude = 0.780 ± 0.265, n_updates = 145000, time = 13.1, total_time = 1812.0
#
# step =  156000, num_env_steps =  156000, scores =  6441.216 (n= 1), score_ema =  6392.439, actor_loss = -336.800, critic_loss = 20.020, entropy_coef_loss = -0.863, entropy_coef = 0.126, rollout_stds = 0.524 ± 0.084, action_magnitude = 0.777 ± 0.269, n_updates = 146000, time = 13.1, total_time = 1825.1
#
# step =  157000, num_env_steps =  157000, scores =  6626.917 (n= 1), score_ema =  6451.058, actor_loss = -353.749, critic_loss = 13.810, entropy_coef_loss = -0.017, entropy_coef = 0.128, rollout_stds = 0.435 ± 0.182, action_magnitude = 0.776 ± 0.268, n_updates = 147000, time = 13.1, total_time = 1838.1
#
# step =  158000, num_env_steps =  158000, scores =  6520.585 (n= 1), score_ema =  6468.440, actor_loss = -363.833, critic_loss = 24.202, entropy_coef_loss = 0.384, entropy_coef = 0.127, rollout_stds = 0.424 ± 0.119, action_magnitude = 0.777 ± 0.266, n_updates = 148000, time = 13.1, total_time = 1851.2
#
# step =  159000, num_env_steps =  159000, scores =  6438.259 (n= 1), score_ema =  6460.895, actor_loss = -334.553, critic_loss = 16.541, entropy_coef_loss = -1.020, entropy_coef = 0.130, rollout_stds = 0.397 ± 0.165, action_magnitude = 0.775 ± 0.270, n_updates = 149000, time = 13.1, total_time = 1864.3
#
# step =  160000, num_env_steps =  160000, scores =  6660.665 (n= 1), score_ema =  6510.837, actor_loss = -364.146, critic_loss = 18.086, entropy_coef_loss = 0.375, entropy_coef = 0.127, rollout_stds = 0.311 ± 0.140, action_magnitude = 0.779 ± 0.268, n_updates = 150000, time = 13.1, total_time = 1877.3
#
# saved experiment log 2024-10-11_12-23-25_512841~zjtzBB at experiment_logs/HalfCheetah-v4/sac/2024-10-11_12-23-25_512841~zjtzBB.json
#
# ...
#
#
# step = 3630000, num_env_steps = 3630000, scores =  14491.452 (n= 1), score_ema =  14541.448, actor_loss = -1120.558, critic_loss = 63.540, entropy_coef_loss = -0.018, entropy_coef = 0.467, rollout_stds = 0.358 ± 0.175, action_magnitude = 0.722 ± 0.269, n_updates = 3620000, time = 13.2, total_time = 48190.5
#
# saved experiment log 2024-10-11_12-23-25_512841~zjtzBB at experiment_logs/HalfCheetah-v4/sac/2024-10-11_12-23-25_512841~zjtzBB.json
#
#
# step = 3631000, num_env_steps = 3631000, scores =  2760.025 (n= 1), score_ema =  11596.092, actor_loss = -1122.619, critic_loss = 55.697, entropy_coef_loss = -0.130, entropy_coef = 0.469, rollout_stds = 0.870 ± 0.109, action_magnitude = 0.572 ± 0.295, n_updates = 3621000, time = 13.6, total_time = 48204.1
#
#
# step = 3632000, num_env_steps = 3632000, scores =  14406.953 (n= 1), score_ema =  12298.807, actor_loss = -1093.031, critic_loss = 63.743, entropy_coef_loss = 0.412, entropy_coef = 0.482, rollout_stds = 0.402 ± 0.171, action_magnitude = 0.729 ± 0.269, n_updates = 3622000, time = 13.2, total_time = 48217.4
#
#
# step = 3633000, num_env_steps = 3633000, scores =  11225.490 (n= 1), score_ema =  12030.478, actor_loss = -1110.678, critic_loss = 115.131, entropy_coef_loss = -0.239, entropy_coef = 0.472, rollout_stds = 0.669 ± 0.074, action_magnitude = 0.682 ± 0.289, n_updates = 3623000, time = 13.3, total_time = 48230.6
#
#
# step = 3634000, num_env_steps = 3634000, scores =  14702.613 (n= 1), score_ema =  12698.512, actor_loss = -1098.697, critic_loss = 44.579, entropy_coef_loss = -0.311, entropy_coef = 0.464, rollout_stds = 0.397 ± 0.175, action_magnitude = 0.719 ± 0.270, n_updates = 3624000, time = 13.2, total_time = 48243.8
#
#
# step = 3635000, num_env_steps = 3635000, scores =  14884.397 (n= 1), score_ema =  13244.983, actor_loss = -1091.338, critic_loss = 40.812, entropy_coef_loss = -0.084, entropy_coef = 0.468, rollout_stds = 0.516 ± 0.041, action_magnitude = 0.723 ± 0.269, n_updates = 3625000, time = 13.2, total_time = 48257.1
#
#
# step = 3636000, num_env_steps = 3636000, scores =  14480.651 (n= 1), score_ema =  13553.900, actor_loss = -1074.151, critic_loss = 200.936, entropy_coef_loss = 0.688, entropy_coef = 0.467, rollout_stds = 0.491 ± 0.045, action_magnitude = 0.719 ± 0.272, n_updates = 3626000, time = 13.2, total_time = 48270.3
#
#
# step = 3637000, num_env_steps = 3637000, scores =  14596.545 (n= 1), score_ema =  13814.561, actor_loss = -1093.225, critic_loss = 366.811, entropy_coef_loss = 0.495, entropy_coef = 0.485, rollout_stds = 0.362 ± 0.156, action_magnitude = 0.725 ± 0.269, n_updates = 3627000, time = 13.2, total_time = 48283.5
#
#
# step = 3638000, num_env_steps = 3638000, scores =  14728.568 (n= 1), score_ema =  14043.063, actor_loss = -1143.995, critic_loss = 132.914, entropy_coef_loss = 0.010, entropy_coef = 0.474, rollout_stds = 0.388 ± 0.146, action_magnitude = 0.721 ± 0.273, n_updates = 3628000, time = 13.2, total_time = 48296.7
#
#
# step = 3639000, num_env_steps = 3639000, scores =  14322.802 (n= 1), score_ema =  14112.998, actor_loss = -1132.807, critic_loss = 56.810, entropy_coef_loss = 0.013, entropy_coef = 0.484, rollout_stds = 0.380 ± 0.146, action_magnitude = 0.721 ± 0.269, n_updates = 3629000, time = 13.2, total_time = 48310.0
#
#
# step = 3640000, num_env_steps = 3640000, scores =  14230.057 (n= 1), score_ema =  14142.262, actor_loss = -1130.364, critic_loss = 25.804, entropy_coef_loss = -0.234, entropy_coef = 0.479, rollout_stds = 0.338 ± 0.159, action_magnitude = 0.716 ± 0.274, n_updates = 3630000, time = 13.2, total_time = 48323.1
#
# saved experiment log 2024-10-11_12-23-25_512841~zjtzBB at experiment_logs/HalfCheetah-v4/sac/2024-10-11_12-23-25_512841~zjtzBB.json
#
#
# step = 3641000, num_env_steps = 3641000, scores =  14426.049 (n= 1), score_ema =  14213.209, actor_loss = -1126.330, critic_loss = 86.867, entropy_coef_loss = -0.173, entropy_coef = 0.470, rollout_stds = 0.445 ± 0.178, action_magnitude = 0.717 ± 0.275, n_updates = 3631000, time = 13.6, total_time = 48336.8
#
#
# step = 3642000, num_env_steps = 3642000, scores =  14554.345 (n= 1), score_ema =  14298.493, actor_loss = -1124.513, critic_loss = 86.758, entropy_coef_loss = -0.166, entropy_coef = 0.465, rollout_stds = 0.516 ± 0.050, action_magnitude = 0.720 ± 0.272, n_updates = 3632000, time = 13.3, total_time = 48350.0
#
#
# step = 3643000, num_env_steps = 3643000, scores =  14648.265 (n= 1), score_ema =  14385.936, actor_loss = -1113.869, critic_loss = 45.169, entropy_coef_loss = -0.153, entropy_coef = 0.450, rollout_stds = 0.474 ± 0.069, action_magnitude = 0.720 ± 0.273, n_updates = 3633000, time = 13.3, total_time = 48363.3
#
#
# step = 3644000, num_env_steps = 3644000, scores =  14393.549 (n= 1), score_ema =  14387.839, actor_loss = -1135.135, critic_loss = 49.893, entropy_coef_loss = 0.065, entropy_coef = 0.451, rollout_stds = 0.442 ± 0.018, action_magnitude = 0.718 ± 0.273, n_updates = 3634000, time = 13.2, total_time = 48376.5
#
#
# step = 3645000, num_env_steps = 3645000, scores =  14625.064 (n= 1), score_ema =  14447.145, actor_loss = -1114.950, critic_loss = 104.719, entropy_coef_loss = -0.184, entropy_coef = 0.453, rollout_stds = 0.363 ± 0.213, action_magnitude = 0.719 ± 0.271, n_updates = 3635000, time = 13.2, total_time = 48389.8
#
#
# step = 3646000, num_env_steps = 3646000, scores =  14854.222 (n= 1), score_ema =  14548.914, actor_loss = -1087.164, critic_loss = 72.883, entropy_coef_loss = 0.179, entropy_coef = 0.455, rollout_stds = 0.389 ± 0.142, action_magnitude = 0.723 ± 0.268, n_updates = 3636000, time = 13.2, total_time = 48403.0
#
#
# step = 3647000, num_env_steps = 3647000, scores =  14624.263 (n= 1), score_ema =  14567.751, actor_loss = -1149.664, critic_loss = 36.919, entropy_coef_loss = -0.003, entropy_coef = 0.459, rollout_stds = 0.363 ± 0.199, action_magnitude = 0.723 ± 0.269, n_updates = 3637000, time = 13.2, total_time = 48416.2
#
#
# step = 3648000, num_env_steps = 3648000, scores =  14742.974 (n= 1), score_ema =  14611.557, actor_loss = -1091.677, critic_loss = 99.578, entropy_coef_loss = 0.113, entropy_coef = 0.453, rollout_stds = 0.359 ± 0.192, action_magnitude = 0.723 ± 0.268, n_updates = 3638000, time = 13.2, total_time = 48429.4
#
#
# step = 3649000, num_env_steps = 3649000, scores =  14294.234 (n= 1), score_ema =  14532.226, actor_loss = -1114.973, critic_loss = 36.051, entropy_coef_loss = -0.419, entropy_coef = 0.467, rollout_stds = 0.486 ± 0.041, action_magnitude = 0.720 ± 0.272, n_updates = 3639000, time = 13.2, total_time = 48442.7
#
#
# step = 3650000, num_env_steps = 3650000, scores =  14816.485 (n= 1), score_ema =  14603.291, actor_loss = -1120.042, critic_loss = 63.851, entropy_coef_loss = 0.193, entropy_coef = 0.465, rollout_stds = 0.409 ± 0.158, action_magnitude = 0.720 ± 0.270, n_updates = 3640000, time = 13.2, total_time = 48455.9
#
# saved experiment log 2024-10-11_12-23-25_512841~zjtzBB at experiment_logs/HalfCheetah-v4/sac/2024-10-11_12-23-25_512841~zjtzBB.json
#
#
# step = 3651000, num_env_steps = 3651000, scores =  14621.508 (n= 1), score_ema =  14607.845, actor_loss = -1123.646, critic_loss = 44.313, entropy_coef_loss = -0.359, entropy_coef = 0.468, rollout_stds = 0.298 ± 0.211, action_magnitude = 0.719 ± 0.275, n_updates = 3641000, time = 13.6, total_time = 48469.5
#
#
# step = 3652000, num_env_steps = 3652000, scores =  14649.541 (n= 1), score_ema =  14618.269, actor_loss = -1138.788, critic_loss = 37.811, entropy_coef_loss = -0.219, entropy_coef = 0.461, rollout_stds = 0.453 ± 0.183, action_magnitude = 0.717 ± 0.276, n_updates = 3642000, time = 13.3, total_time = 48482.7
#
#
# step = 3653000, num_env_steps = 3653000, scores =  14507.023 (n= 1), score_ema =  14590.458, actor_loss = -1086.317, critic_loss = 51.943, entropy_coef_loss = 0.385, entropy_coef = 0.470, rollout_stds = 0.547 ± 0.105, action_magnitude = 0.722 ± 0.268, n_updates = 3643000, time = 13.2, total_time = 48496.0
#
#
# step = 3654000, num_env_steps = 3654000, scores =  14338.628 (n= 1), score_ema =  14527.500, actor_loss = -1113.204, critic_loss = 45.673, entropy_coef_loss = -0.045, entropy_coef = 0.471, rollout_stds = 0.434 ± 0.162, action_magnitude = 0.722 ± 0.272, n_updates = 3644000, time = 13.2, total_time = 48509.2
#
#
# step = 3655000, num_env_steps = 3655000, scores =  14455.021 (n= 1), score_ema =  14509.380, actor_loss = -1126.556, critic_loss = 830.086, entropy_coef_loss = -0.000, entropy_coef = 0.460, rollout_stds = 0.455 ± 0.058, action_magnitude = 0.718 ± 0.271, n_updates = 3645000, time = 13.2, total_time = 48522.5
#
#
# step = 3656000, num_env_steps = 3656000, scores =  14096.088 (n= 1), score_ema =  14406.057, actor_loss = -1115.082, critic_loss = 48.826, entropy_coef_loss = 0.280, entropy_coef = 0.460, rollout_stds = 0.327 ± 0.195, action_magnitude = 0.717 ± 0.273, n_updates = 3646000, time = 13.3, total_time = 48535.7
#
#
# step = 3657000, num_env_steps = 3657000, scores =  14152.421 (n= 1), score_ema =  14342.648, actor_loss = -1094.596, critic_loss = 58.016, entropy_coef_loss = -0.066, entropy_coef = 0.470, rollout_stds = 0.501 ± 0.061, action_magnitude = 0.723 ± 0.269, n_updates = 3647000, time = 13.2, total_time = 48548.9
#
#
# step = 3658000, num_env_steps = 3658000, scores =  14814.067 (n= 1), score_ema =  14460.503, actor_loss = -1107.182, critic_loss = 46.077, entropy_coef_loss = -0.035, entropy_coef = 0.460, rollout_stds = 0.420 ± 0.149, action_magnitude = 0.721 ± 0.270, n_updates = 3648000, time = 13.2, total_time = 48562.1
#
#
# step = 3659000, num_env_steps = 3659000, scores =  14611.455 (n= 1), score_ema =  14498.241, actor_loss = -1128.449, critic_loss = 321.495, entropy_coef_loss = -0.054, entropy_coef = 0.457, rollout_stds = 0.367 ± 0.156, action_magnitude = 0.723 ± 0.267, n_updates = 3649000, time = 13.3, total_time = 48575.4
#
#
# step = 3660000, num_env_steps = 3660000, scores =  14404.069 (n= 1), score_ema =  14474.698, actor_loss = -1102.346, critic_loss = 63.559, entropy_coef_loss = 0.230, entropy_coef = 0.455, rollout_stds = 0.501 ± 0.042, action_magnitude = 0.720 ± 0.273, n_updates = 3650000, time = 13.2, total_time = 48588.6
#
# saved experiment log 2024-10-11_12-23-25_512841~zjtzBB at experiment_logs/HalfCheetah-v4/sac/2024-10-11_12-23-25_512841~zjtzBB.json
#
#
# step = 3661000, num_env_steps = 3661000, scores =  2079.799 (n= 1), score_ema =  11375.973, actor_loss = -1071.476, critic_loss = 42.400, entropy_coef_loss = -0.076, entropy_coef = 0.455, rollout_stds = 0.688 ± 0.048, action_magnitude = 0.523 ± 0.294, n_updates = 3651000, time = 13.6, total_time = 48602.2
#
#
# step = 3662000, num_env_steps = 3662000, scores =  14750.576 (n= 1), score_ema =  12219.624, actor_loss = -1073.212, critic_loss = 35.483, entropy_coef_loss = 0.028, entropy_coef = 0.461, rollout_stds = 0.470 ± 0.103, action_magnitude = 0.725 ± 0.273, n_updates = 3652000, time = 13.2, total_time = 48615.4
#
#
# step = 3663000, num_env_steps = 3663000, scores =  14766.724 (n= 1), score_ema =  12856.399, actor_loss = -1104.509, critic_loss = 45.501, entropy_coef_loss = 0.380, entropy_coef = 0.458, rollout_stds = 0.385 ± 0.136, action_magnitude = 0.723 ± 0.266, n_updates = 3653000, time = 13.2, total_time = 48628.7
#
#
# step = 3664000, num_env_steps = 3664000, scores =  14695.901 (n= 1), score_ema =  13316.275, actor_loss = -1123.121, critic_loss = 91.294, entropy_coef_loss = 0.114, entropy_coef = 0.457, rollout_stds = 0.440 ± 0.092, action_magnitude = 0.720 ± 0.268, n_updates = 3654000, time = 13.2, total_time = 48641.9
#
#
# step = 3665000, num_env_steps = 3665000, scores =  14797.929 (n= 1), score_ema =  13686.688, actor_loss = -1142.591, critic_loss = 63.157, entropy_coef_loss = -0.046, entropy_coef = 0.458, rollout_stds = 0.481 ± 0.072, action_magnitude = 0.719 ± 0.269, n_updates = 3655000, time = 13.2, total_time = 48655.1
#
#
# step = 3666000, num_env_steps = 3666000, scores =  14874.413 (n= 1), score_ema =  13983.619, actor_loss = -1095.197, critic_loss = 89.617, entropy_coef_loss = 0.265, entropy_coef = 0.466, rollout_stds = 0.389 ± 0.134, action_magnitude = 0.727 ± 0.265, n_updates = 3656000, time = 13.2, total_time = 48668.4
#
#
# step = 3667000, num_env_steps = 3667000, scores =  14465.833 (n= 1), score_ema =  14104.173, actor_loss = -1121.801, critic_loss = 372.931, entropy_coef_loss = -0.044, entropy_coef = 0.466, rollout_stds = 0.383 ± 0.140, action_magnitude = 0.721 ± 0.270, n_updates = 3657000, time = 13.2, total_time = 48681.5
#
#
# step = 3668000, num_env_steps = 3668000, scores =  14081.969 (n= 1), score_ema =  14098.622, actor_loss = -1134.320, critic_loss = 42.798, entropy_coef_loss = -0.311, entropy_coef = 0.477, rollout_stds = 0.354 ± 0.218, action_magnitude = 0.717 ± 0.272, n_updates = 3658000, time = 13.3, total_time = 48694.8
#
#
# step = 3669000, num_env_steps = 3669000, scores =  14274.478 (n= 1), score_ema =  14142.586, actor_loss = -1129.900, critic_loss = 95.660, entropy_coef_loss = 0.321, entropy_coef = 0.470, rollout_stds = 0.404 ± 0.168, action_magnitude = 0.720 ± 0.274, n_updates = 3659000, time = 13.3, total_time = 48708.0
#
#
# step = 3670000, num_env_steps = 3670000, scores =  14642.720 (n= 1), score_ema =  14267.619, actor_loss = -1126.665, critic_loss = 54.429, entropy_coef_loss = 0.190, entropy_coef = 0.459, rollout_stds = 0.321 ± 0.207, action_magnitude = 0.719 ± 0.271, n_updates = 3660000, time = 13.2, total_time = 48721.2
#
# saved experiment log 2024-10-11_12-23-25_512841~zjtzBB at experiment_logs/HalfCheetah-v4/sac/2024-10-11_12-23-25_512841~zjtzBB.json
#
#
# step = 3671000, num_env_steps = 3671000, scores =  14600.685 (n= 1), score_ema =  14350.886, actor_loss = -1133.074, critic_loss = 508.926, entropy_coef_loss = -0.247, entropy_coef = 0.448, rollout_stds = 0.396 ± 0.176, action_magnitude = 0.721 ± 0.267, n_updates = 3661000, time = 13.6, total_time = 48734.9
#
#
# step = 3672000, num_env_steps = 3672000, scores =  14667.808 (n= 1), score_ema =  14430.116, actor_loss = -1140.040, critic_loss = 47.368, entropy_coef_loss = 0.068, entropy_coef = 0.462, rollout_stds = 0.329 ± 0.104, action_magnitude = 0.716 ± 0.277, n_updates = 3662000, time = 13.2, total_time = 48748.1
#
#
# step = 3673000, num_env_steps = 3673000, scores =  14765.332 (n= 1), score_ema =  14513.920, actor_loss = -1116.957, critic_loss = 70.816, entropy_coef_loss = -0.083, entropy_coef = 0.461, rollout_stds = 0.393 ± 0.125, action_magnitude = 0.720 ± 0.271, n_updates = 3663000, time = 13.3, total_time = 48761.4
#
#
# step = 3674000, num_env_steps = 3674000, scores =  14415.834 (n= 1), score_ema =  14489.399, actor_loss = -1138.758, critic_loss = 33.766, entropy_coef_loss = -0.089, entropy_coef = 0.461, rollout_stds = 0.362 ± 0.203, action_magnitude = 0.718 ± 0.273, n_updates = 3664000, time = 13.2, total_time = 48774.6
#
#
# step = 3675000, num_env_steps = 3675000, scores =  14655.330 (n= 1), score_ema =  14530.882, actor_loss = -1127.206, critic_loss = 47.303, entropy_coef_loss = -0.008, entropy_coef = 0.461, rollout_stds = 0.423 ± 0.153, action_magnitude = 0.717 ± 0.273, n_updates = 3665000, time = 13.2, total_time = 48787.8
#
#
# step = 3676000, num_env_steps = 3676000, scores =  14142.768 (n= 1), score_ema =  14433.853, actor_loss = -1168.969, critic_loss = 34.664, entropy_coef_loss = -0.220, entropy_coef = 0.462, rollout_stds = 0.406 ± 0.148, action_magnitude = 0.721 ± 0.270, n_updates = 3666000, time = 13.3, total_time = 48801.1
#
#
# step = 3677000, num_env_steps = 3677000, scores =  14417.881 (n= 1), score_ema =  14429.860, actor_loss = -1134.662, critic_loss = 53.374, entropy_coef_loss = 0.101, entropy_coef = 0.462, rollout_stds = 0.330 ± 0.217, action_magnitude = 0.727 ± 0.269, n_updates = 3667000, time = 14.0, total_time = 48815.1
#
# saved experiment log 2024-10-11_12-23-25_512841~zjtzBB at experiment_logs/HalfCheetah-v4/sac/2024-10-11_12-23-25_512841~zjtzBB.json
# keyboard interrupt
# closing envs
# envs closed
# model db closed
# done

# %%
algo.policy
