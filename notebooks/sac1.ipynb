# %%
import time
from typing import Any

import gymnasium as gym
import numpy as np
import torch
from torch import optim, nn

from src.experiment_logging.experiment_log import ExperimentLogItem
from src.experiment_logging.experiment_logger import ExperimentLogger, log_experiment
from src.module_analysis import count_parameters
from src.reinforcement_learning.algorithms.sac.sac import SAC, SACInfoStashConfig
from src.reinforcement_learning.algorithms.sac.sac_policy import SACPolicy
from src.reinforcement_learning.core.action_selectors.predicted_std_action_selector import PredictedStdActionSelector
from src.reinforcement_learning.core.buffers.replay.ring_with_reservoir_replay_buffer import \
    RingWithReservoirReplayBuffer
from src.reinforcement_learning.core.callback import Callback
from src.reinforcement_learning.core.loss_config import LossInfoStashConfig
from src.reinforcement_learning.core.policies.components.actor import Actor
from src.reinforcement_learning.core.policies.components.q_critic import QCritic
from src.reinforcement_learning.gym.parallelize_env import parallelize_env_async
from src.stopwatch import Stopwatch
from src.summary_statistics import maybe_compute_summary_statistics

# %load_ext autoreload
# %autoreload 2
# Out:
# pygame 2.5.2 (SDL 2.28.3, Python 3.11.7)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
def get_setup() -> dict[str, str]:
    return {
        'notebook': _ih[1] + '\n\n' + _ih[-1], # first and last cell input (imports and this cell)
    }

step_stopwatch = Stopwatch()
total_stopwatch = Stopwatch()
best_iteration_score = -1e6

def save_experiment_state():
    experiment_id = logger.experiment_log['experiment_id']
    algo.save(
        folder_location=f'models/{env_name}/{experiment_id}', 
        name=experiment_id, 
        latest_log_item=logger.get_latest_log_item()
    )
    

def on_rollout_done(rl: SAC, step: int, info: dict[str, Any], scheduler_values: dict[str, Any]):
    if step % 1000 != 0:
        return
    
    episode_scores = rl.buffer.compute_most_recent_episode_scores(rl.num_envs, consider_truncated_as_done=True)
    
    if len(episode_scores) > 0:
    
        global best_iteration_score
        iteration_score = episode_scores.mean()
        if iteration_score >= best_iteration_score:
            pass
    
    info['episode_scores'] = episode_scores
        
def on_optimization_done(rl: SAC, step: int, info: dict[str, Any], scheduler_values: dict[str, Any]):    
    if step % 1000 != 0:
        return
    
    num_env_steps = step * rl.num_envs
    
    step_time = step_stopwatch.reset()
    total_time = total_stopwatch.time_passed()
    
    tail_indices = rl.buffer.tail_indices(1000)
    
    episode_scores = info.get('episode_scores')
    
    log_item: ExperimentLogItem = {
        'step': step,
        'num_env_steps': num_env_steps,
        'scores': maybe_compute_summary_statistics(episode_scores),
        'actor_loss': maybe_compute_summary_statistics(info['final_actor_loss']),
        'entropy_coef_loss': maybe_compute_summary_statistics(info.get('final_entropy_coef_loss')),
        'critic_loss': maybe_compute_summary_statistics(info['final_critic_loss']),
        'entropy_coef': maybe_compute_summary_statistics(info['entropy_coef']),
        'action_stds': maybe_compute_summary_statistics(info['rollout'].get('action_stds')),
        'action_magnitude': maybe_compute_summary_statistics(np.abs(rl.buffer.actions[tail_indices])),
        'num_gradient_steps': rl.gradient_steps_performed,
        'step_time': step_time,
        'total_time': total_time
    }
    print(logger.format_log_item(log_item, mean_format='5.3f', std_format='5.3f', step_time='.2f', total_time='.2f'), end='\n\n')
    logger.add_item(log_item)
    if step % 10000 == 0:
        logger.save_experiment_log()
        
        print()
    print()

device = torch.device("cuda:0") if True else torch.device('cpu')
print(f'using device {device}')

env_name = 'HalfCheetah-v4'
# env_kwargs = {'forward_reward_weight': 1.25, 'healthy_reward': 0.5, 'ctrl_cost_weight': 0.001 }
env_kwargs = {}
num_envs = 1

def create_env(render_mode: str | None):
    make_single_env = lambda: gym.make(env_name, render_mode=render_mode, **env_kwargs)
    
    if num_envs == 1:
        return make_single_env()
        
    return parallelize_env_async(make_single_env, num_envs)


def create_policy():
    in_size = 17
    action_size = 6
    
    actor_net = nn.Sequential(
        nn.Linear(in_size, 256),
        nn.ReLU(),
        nn.Linear(256, 256),
        nn.ReLU(),
    )

    critic = QCritic(
        n_critics=2,
        create_q_network=lambda: nn.Sequential(
            nn.Linear(in_size + action_size, 256),
            nn.ReLU(),
            # BatchRenorm(256),
            nn.Linear(256, 256),
            nn.ReLU(),
            # BatchRenorm(256),
            nn.Linear(256, 1)
        )
    )

    return SACPolicy(
        actor=Actor(actor_net, PredictedStdActionSelector(
            latent_dim=256,
            action_dim=action_size,
            base_std=1.0,
            squash_output=True,
        )),
        critic=critic
    )


env = create_env(render_mode=None)
policy = create_policy()
logger = ExperimentLogger(f'experiment_logs/{env_name}/sac/')

try:
    print(f'{count_parameters(policy) = }')
    print(f'{env = }, {num_envs = }')
        
    with ((torch.autograd.set_detect_anomaly(False))):
        algo = SAC(
            env=env,
            policy=policy,
            actor_optimizer_provider=lambda params: optim.Adam(params, lr=3e-4),  # (params, lr=3e-4, betas=(0.5, 0.999)),
            critic_optimizer_provider=lambda params: optim.Adam(params, lr=3e-4),  # (params, lr=3e-4, betas=(0.5, 0.999)),
            buffer_type=RingWithReservoirReplayBuffer,
            buffer_step_size=300_000,
            buffer_kwargs={
                'reservoir_total_size': 700_000,
            },
            reward_scale=1,
            gamma=0.99,
            tau=0.005,
            entropy_coef_optimizer_provider=lambda params: optim.Adam(params, lr=3e-4),
            entropy_coef=1.0,
            rollout_steps=1,
            gradient_steps=1,
            warmup_steps=10_000,
            optimization_batch_size=256,
            target_update_interval=1,
            callback=Callback(
                on_rollout_done=on_rollout_done,
                rollout_schedulers={},
                on_optimization_done=on_optimization_done,
                optimization_schedulers={},
            ),
            stash_config=SACInfoStashConfig(stash_rollout_infos=True, stash_rollout_action_stds=True,
                                            stash_entropy_coef=True,
                                            entropy_coef_loss=LossInfoStashConfig(stash_final=True),
                                            actor_loss=LossInfoStashConfig(stash_final=True),
                                            critic_loss=LossInfoStashConfig(stash_final=True)),
            torch_device=device,
        )
        total_stopwatch.reset()
        with log_experiment(
            logger,
            experiment_tags=algo.collect_tags(),
            hyper_parameters=algo.collect_hyper_parameters(),
            setup=get_setup(),
        ) as x:
            logger.save_experiment_log()
            print('\nStarting Training\n\n')
            # import cProfile
            # pr = cProfile.Profile()
            # pr.enable()
            algo.learn(3_500_000)
            # pr.disable()  
            # pr.dump_stats('profile_stats.pstat')
except KeyboardInterrupt as ki:
    print('keyboard interrupt')
    raise ki
finally:
    print('closing envs')
    time.sleep(0.5)
    env.close()
    print('envs closed')
    

print('done')
# Out:
# using device cuda:0
# count_parameters(policy) = 217870
# env = <TimeLimit<OrderEnforcing<PassiveEnvChecker<HalfCheetahEnv<HalfCheetah-v4>>>>>, num_envs = 1
# Grabbing system information... done!
# saved experiment log 2024-11-05_11-51-26_600853~Orhj1J at experiment_logs/HalfCheetah-v4/sac/2024-11-05_11-51-26_600853~Orhj1J.json
#
# Starting Training
#
# step = 11000, num_env_steps = 11000, scores = -299.503, actor_loss = -17.761, entropy_coef_loss = -3.000, critic_loss = 0.896, entropy_coef = 0.741, action_stds = 0.928 ± 0.036, action_magnitude = 0.523 ± 0.290, num_gradient_steps = 1000, step_time = 13.27, total_time = 12.82
#
# step = 12000, num_env_steps = 12000, scores = -270.497, actor_loss = -25.452, entropy_coef_loss = -5.950, critic_loss = 1.092, entropy_coef = 0.549, action_stds = 0.898 ± 0.068, action_magnitude = 0.538 ± 0.287, num_gradient_steps = 2000, step_time = 9.44, total_time = 22.26
#
# step = 13000, num_env_steps = 13000, scores = -247.855, actor_loss = -30.246, entropy_coef_loss = -8.870, critic_loss = 1.379, entropy_coef = 0.407, action_stds = 0.894 ± 0.018, action_magnitude = 0.533 ± 0.288, num_gradient_steps = 3000, step_time = 9.41, total_time = 31.67
#
# step = 14000, num_env_steps = 14000, scores = -271.055, actor_loss = -32.352, entropy_coef_loss = -11.551, critic_loss = 1.442, entropy_coef = 0.303, action_stds = 0.871 ± 0.070, action_magnitude = 0.536 ± 0.288, num_gradient_steps = 4000, step_time = 10.86, total_time = 42.53
#
# step = 15000, num_env_steps = 15000, scores = -287.137, actor_loss = -33.937, entropy_coef_loss = -13.469, critic_loss = 1.304, entropy_coef = 0.226, action_stds = 0.854 ± 0.044, action_magnitude = 0.542 ± 0.287, num_gradient_steps = 5000, step_time = 10.96, total_time = 53.49
#
# step = 16000, num_env_steps = 16000, scores = -290.194, actor_loss = -33.814, entropy_coef_loss = -15.658, critic_loss = 1.649, entropy_coef = 0.170, action_stds = 0.865 ± 0.104, action_magnitude = 0.564 ± 0.294, num_gradient_steps = 6000, step_time = 11.04, total_time = 64.53
#
# step = 17000, num_env_steps = 17000, scores = -221.266, actor_loss = -33.569, entropy_coef_loss = -17.423, critic_loss = 1.552, entropy_coef = 0.128, action_stds = 0.838 ± 0.059, action_magnitude = 0.554 ± 0.292, num_gradient_steps = 7000, step_time = 11.26, total_time = 75.79
#
# step = 18000, num_env_steps = 18000, scores = -256.332, actor_loss = -31.898, entropy_coef_loss = -17.563, critic_loss = 1.192, entropy_coef = 0.097, action_stds = 0.795 ± 0.071, action_magnitude = 0.563 ± 0.293, num_gradient_steps = 8000, step_time = 11.04, total_time = 86.84
#
# step = 19000, num_env_steps = 19000, scores = -309.671, actor_loss = -30.987, entropy_coef_loss = -18.591, critic_loss = 1.674, entropy_coef = 0.073, action_stds = 0.741 ± 0.086, action_magnitude = 0.572 ± 0.295, num_gradient_steps = 9000, step_time = 10.64, total_time = 97.47
#
# step = 20000, num_env_steps = 20000, scores = -415.505, actor_loss = -29.600, entropy_coef_loss = -18.144, critic_loss = 1.415, entropy_coef = 0.056, action_stds = 0.701 ± 0.087, action_magnitude = 0.586 ± 0.295, num_gradient_steps = 10000, step_time = 10.59, total_time = 108.07
#
# saved experiment log 2024-11-05_11-51-26_600853~Orhj1J at experiment_logs/HalfCheetah-v4/sac/2024-11-05_11-51-26_600853~Orhj1J.json
#
# step = 21000, num_env_steps = 21000, scores = -188.366, actor_loss = -28.339, entropy_coef_loss = -18.353, critic_loss = 1.415, entropy_coef = 0.042, action_stds = 0.649 ± 0.077, action_magnitude = 0.566 ± 0.293, num_gradient_steps = 11000, step_time = 10.64, total_time = 118.71
#
# step = 22000, num_env_steps = 22000, scores = -78.460, actor_loss = -26.876, entropy_coef_loss = -15.827, critic_loss = 1.620, entropy_coef = 0.033, action_stds = 0.493 ± 0.083, action_magnitude = 0.544 ± 0.288, num_gradient_steps = 12000, step_time = 10.59, total_time = 129.29
#
# step = 23000, num_env_steps = 23000, scores = -56.970, actor_loss = -25.074, entropy_coef_loss = -15.540, critic_loss = 1.541, entropy_coef = 0.025, action_stds = 0.468 ± 0.106, action_magnitude = 0.526 ± 0.291, num_gradient_steps = 13000, step_time = 10.57, total_time = 139.87
#
# step = 24000, num_env_steps = 24000, scores = -6.517, actor_loss = -25.159, entropy_coef_loss = -12.283, critic_loss = 1.711, entropy_coef = 0.020, action_stds = 0.462 ± 0.096, action_magnitude = 0.619 ± 0.304, num_gradient_steps = 14000, step_time = 10.61, total_time = 150.48
#
# step = 25000, num_env_steps = 25000, scores = -42.277, actor_loss = -24.186, entropy_coef_loss = -10.935, critic_loss = 1.183, entropy_coef = 0.016, action_stds = 0.498 ± 0.106, action_magnitude = 0.614 ± 0.300, num_gradient_steps = 15000, step_time = 10.61, total_time = 161.09
#
# step = 26000, num_env_steps = 26000, scores = -146.666, actor_loss = -23.119, entropy_coef_loss = -10.371, critic_loss = 1.038, entropy_coef = 0.012, action_stds = 0.392 ± 0.086, action_magnitude = 0.598 ± 0.300, num_gradient_steps = 16000, step_time = 10.62, total_time = 171.71
#
# step = 27000, num_env_steps = 27000, scores = 15.755, actor_loss = -22.201, entropy_coef_loss = -6.747, critic_loss = 1.209, entropy_coef = 0.010, action_stds = 0.441 ± 0.114, action_magnitude = 0.599 ± 0.299, num_gradient_steps = 17000, step_time = 10.70, total_time = 182.41
#
# step = 28000, num_env_steps = 28000, scores = -4.602, actor_loss = -20.460, entropy_coef_loss = -4.257, critic_loss = 1.079, entropy_coef = 0.008, action_stds = 0.429 ± 0.097, action_magnitude = 0.599 ± 0.297, num_gradient_steps = 18000, step_time = 10.62, total_time = 193.03
#
# step = 29000, num_env_steps = 29000, scores = 400.216, actor_loss = -20.839, entropy_coef_loss = -1.860, critic_loss = 1.139, entropy_coef = 0.007, action_stds = 0.374 ± 0.071, action_magnitude = 0.609 ± 0.301, num_gradient_steps = 19000, step_time = 10.64, total_time = 203.67
#
# step = 30000, num_env_steps = 30000, scores = 118.743, actor_loss = -18.270, entropy_coef_loss = -0.219, critic_loss = 1.021, entropy_coef = 0.007, action_stds = 0.392 ± 0.037, action_magnitude = 0.606 ± 0.299, num_gradient_steps = 20000, step_time = 10.67, total_time = 214.34
#
# saved experiment log 2024-11-05_11-51-26_600853~Orhj1J at experiment_logs/HalfCheetah-v4/sac/2024-11-05_11-51-26_600853~Orhj1J.json
#
# step = 31000, num_env_steps = 31000, scores = 11.320, actor_loss = -20.469, entropy_coef_loss = 0.446, critic_loss = 0.994, entropy_coef = 0.007, action_stds = 0.408 ± 0.046, action_magnitude = 0.617 ± 0.301, num_gradient_steps = 21000, step_time = 10.69, total_time = 225.03
#
# step = 32000, num_env_steps = 32000, scores = -78.905, actor_loss = -18.314, entropy_coef_loss = -1.254, critic_loss = 1.265, entropy_coef = 0.007, action_stds = 0.449 ± 0.045, action_magnitude = 0.594 ± 0.301, num_gradient_steps = 22000, step_time = 10.63, total_time = 235.66
#
# step = 33000, num_env_steps = 33000, scores = 374.191, actor_loss = -18.317, entropy_coef_loss = 0.148, critic_loss = 1.222, entropy_coef = 0.007, action_stds = 0.413 ± 0.046, action_magnitude = 0.610 ± 0.299, num_gradient_steps = 23000, step_time = 10.66, total_time = 246.32
#
# step = 34000, num_env_steps = 34000, scores = 157.568, actor_loss = -17.139, entropy_coef_loss = -4.300, critic_loss = 1.095, entropy_coef = 0.008, action_stds = 0.352 ± 0.076, action_magnitude = 0.606 ± 0.303, num_gradient_steps = 24000, step_time = 10.63, total_time = 256.96
#
# step = 35000, num_env_steps = 35000, scores = 1456.250, actor_loss = -21.273, entropy_coef_loss = 1.291, critic_loss = 1.700, entropy_coef = 0.009, action_stds = 0.194 ± 0.063, action_magnitude = 0.665 ± 0.306, num_gradient_steps = 25000, step_time = 10.62, total_time = 267.58
#
# step = 36000, num_env_steps = 36000, scores = 1467.193, actor_loss = -22.190, entropy_coef_loss = 3.222, critic_loss = 1.414, entropy_coef = 0.010, action_stds = 0.384 ± 0.094, action_magnitude = 0.665 ± 0.308, num_gradient_steps = 26000, step_time = 10.64, total_time = 278.22
#
# step = 37000, num_env_steps = 37000, scores = 669.781, actor_loss = -20.446, entropy_coef_loss = -0.459, critic_loss = 1.734, entropy_coef = 0.011, action_stds = 0.360 ± 0.044, action_magnitude = 0.640 ± 0.306, num_gradient_steps = 27000, step_time = 10.62, total_time = 288.84
#
# step = 38000, num_env_steps = 38000, scores = 1733.025, actor_loss = -24.287, entropy_coef_loss = -2.418, critic_loss = 1.765, entropy_coef = 0.012, action_stds = 0.334 ± 0.159, action_magnitude = 0.698 ± 0.303, num_gradient_steps = 28000, step_time = 10.64, total_time = 299.48
#
# step = 39000, num_env_steps = 39000, scores = 1842.058, actor_loss = -26.566, entropy_coef_loss = 2.593, critic_loss = 1.874, entropy_coef = 0.014, action_stds = 0.266 ± 0.110, action_magnitude = 0.710 ± 0.296, num_gradient_steps = 29000, step_time = 10.70, total_time = 310.17
#
# step = 40000, num_env_steps = 40000, scores = 1163.040, actor_loss = -28.514, entropy_coef_loss = 1.889, critic_loss = 2.539, entropy_coef = 0.015, action_stds = 0.385 ± 0.095, action_magnitude = 0.670 ± 0.304, num_gradient_steps = 30000, step_time = 10.66, total_time = 320.83
#
# saved experiment log 2024-11-05_11-51-26_600853~Orhj1J at experiment_logs/HalfCheetah-v4/sac/2024-11-05_11-51-26_600853~Orhj1J.json
#
# step = 41000, num_env_steps = 41000, scores = 813.089, actor_loss = -28.375, entropy_coef_loss = -0.966, critic_loss = 2.442, entropy_coef = 0.016, action_stds = 0.366 ± 0.088, action_magnitude = 0.659 ± 0.301, num_gradient_steps = 31000, step_time = 10.66, total_time = 331.49
#
# step = 42000, num_env_steps = 42000, scores = 53.385, actor_loss = -29.365, entropy_coef_loss = -0.064, critic_loss = 2.213, entropy_coef = 0.016, action_stds = 0.463 ± 0.101, action_magnitude = 0.620 ± 0.299, num_gradient_steps = 32000, step_time = 10.67, total_time = 342.16
#
# step = 43000, num_env_steps = 43000, scores = 2307.182, actor_loss = -30.785, entropy_coef_loss = -3.301, critic_loss = 2.409, entropy_coef = 0.017, action_stds = 0.207 ± 0.076, action_magnitude = 0.730 ± 0.295, num_gradient_steps = 33000, step_time = 10.60, total_time = 352.76
#
# step = 44000, num_env_steps = 44000, scores = 2758.808, actor_loss = -37.086, entropy_coef_loss = 1.867, critic_loss = 3.224, entropy_coef = 0.019, action_stds = 0.366 ± 0.181, action_magnitude = 0.754 ± 0.286, num_gradient_steps = 34000, step_time = 10.61, total_time = 363.37
#
# step = 45000, num_env_steps = 45000, scores = 2398.448, actor_loss = -35.401, entropy_coef_loss = -1.057, critic_loss = 4.489, entropy_coef = 0.020, action_stds = 0.429 ± 0.079, action_magnitude = 0.762 ± 0.283, num_gradient_steps = 35000, step_time = 10.66, total_time = 374.03
#
# step = 46000, num_env_steps = 46000, scores = 2441.352, actor_loss = -44.703, entropy_coef_loss = 2.319, critic_loss = 4.098, entropy_coef = 0.022, action_stds = 0.433 ± 0.208, action_magnitude = 0.775 ± 0.280, num_gradient_steps = 36000, step_time = 10.60, total_time = 384.63
#
# step = 47000, num_env_steps = 47000, scores = 474.198, actor_loss = -42.126, entropy_coef_loss = -1.690, critic_loss = 3.761, entropy_coef = 0.023, action_stds = 0.441 ± 0.066, action_magnitude = 0.659 ± 0.299, num_gradient_steps = 37000, step_time = 10.62, total_time = 395.25
#
# step = 48000, num_env_steps = 48000, scores = 526.954, actor_loss = -44.658, entropy_coef_loss = -1.008, critic_loss = 4.317, entropy_coef = 0.023, action_stds = 0.488 ± 0.081, action_magnitude = 0.641 ± 0.304, num_gradient_steps = 38000, step_time = 10.65, total_time = 405.90
#
# step = 49000, num_env_steps = 49000, scores = 2483.557, actor_loss = -46.839, entropy_coef_loss = -0.885, critic_loss = 3.908, entropy_coef = 0.025, action_stds = 0.351 ± 0.118, action_magnitude = 0.763 ± 0.284, num_gradient_steps = 39000, step_time = 10.65, total_time = 416.54
#
# step = 50000, num_env_steps = 50000, scores = 2894.254, actor_loss = -44.369, entropy_coef_loss = -2.063, critic_loss = 4.291, entropy_coef = 0.026, action_stds = 0.450 ± 0.133, action_magnitude = 0.761 ± 0.285, num_gradient_steps = 40000, step_time = 10.63, total_time = 427.17
#
# saved experiment log 2024-11-05_11-51-26_600853~Orhj1J at experiment_logs/HalfCheetah-v4/sac/2024-11-05_11-51-26_600853~Orhj1J.json
#
# step = 51000, num_env_steps = 51000, scores = 2604.541, actor_loss = -52.316, entropy_coef_loss = -1.081, critic_loss = 4.951, entropy_coef = 0.028, action_stds = 0.262 ± 0.092, action_magnitude = 0.754 ± 0.288, num_gradient_steps = 41000, step_time = 10.66, total_time = 437.83
#
# step = 52000, num_env_steps = 52000, scores = 2684.108, actor_loss = -58.577, entropy_coef_loss = -1.107, critic_loss = 4.945, entropy_coef = 0.029, action_stds = 0.361 ± 0.120, action_magnitude = 0.763 ± 0.282, num_gradient_steps = 42000, step_time = 10.60, total_time = 448.42
#
# step = 53000, num_env_steps = 53000, scores = 1788.116, actor_loss = -56.245, entropy_coef_loss = -0.369, critic_loss = 6.192, entropy_coef = 0.030, action_stds = 0.543 ± 0.071, action_magnitude = 0.707 ± 0.300, num_gradient_steps = 43000, step_time = 10.59, total_time = 459.02
#
# step = 54000, num_env_steps = 54000, scores = 2462.966, actor_loss = -60.946, entropy_coef_loss = -1.591, critic_loss = 8.431, entropy_coef = 0.031, action_stds = 0.435 ± 0.193, action_magnitude = 0.755 ± 0.284, num_gradient_steps = 44000, step_time = 10.63, total_time = 469.65
#
# step = 55000, num_env_steps = 55000, scores = 2794.981, actor_loss = -65.765, entropy_coef_loss = 1.012, critic_loss = 6.829, entropy_coef = 0.031, action_stds = 0.463 ± 0.152, action_magnitude = 0.750 ± 0.284, num_gradient_steps = 45000, step_time = 10.61, total_time = 480.26
#
# step = 56000, num_env_steps = 56000, scores = 2794.365, actor_loss = -71.394, entropy_coef_loss = -0.257, critic_loss = 6.287, entropy_coef = 0.033, action_stds = 0.386 ± 0.155, action_magnitude = 0.761 ± 0.278, num_gradient_steps = 46000, step_time = 10.62, total_time = 490.88
#
# step = 57000, num_env_steps = 57000, scores = 2659.922, actor_loss = -70.020, entropy_coef_loss = 0.975, critic_loss = 5.240, entropy_coef = 0.034, action_stds = 0.349 ± 0.112, action_magnitude = 0.752 ± 0.285, num_gradient_steps = 47000, step_time = 10.63, total_time = 501.51
#
# step = 58000, num_env_steps = 58000, scores = 3021.264, actor_loss = -71.034, entropy_coef_loss = -0.552, critic_loss = 8.767, entropy_coef = 0.034, action_stds = 0.341 ± 0.106, action_magnitude = 0.749 ± 0.282, num_gradient_steps = 48000, step_time = 10.61, total_time = 512.12
#
# step = 59000, num_env_steps = 59000, scores = 3134.077, actor_loss = -83.331, entropy_coef_loss = 0.614, critic_loss = 6.015, entropy_coef = 0.036, action_stds = 0.400 ± 0.155, action_magnitude = 0.758 ± 0.281, num_gradient_steps = 49000, step_time = 10.60, total_time = 522.72
#
# step = 60000, num_env_steps = 60000, scores = 3194.770, actor_loss = -81.650, entropy_coef_loss = 0.308, critic_loss = 6.072, entropy_coef = 0.037, action_stds = 0.447 ± 0.142, action_magnitude = 0.758 ± 0.281, num_gradient_steps = 50000, step_time = 10.61, total_time = 533.33
#
# saved experiment log 2024-11-05_11-51-26_600853~Orhj1J at experiment_logs/HalfCheetah-v4/sac/2024-11-05_11-51-26_600853~Orhj1J.json
#
# step = 61000, num_env_steps = 61000, scores = 3325.843, actor_loss = -94.629, entropy_coef_loss = 1.697, critic_loss = 5.731, entropy_coef = 0.039, action_stds = 0.379 ± 0.172, action_magnitude = 0.754 ± 0.281, num_gradient_steps = 51000, step_time = 10.60, total_time = 543.93
#
# step = 62000, num_env_steps = 62000, scores = 3438.133, actor_loss = -85.109, entropy_coef_loss = -0.164, critic_loss = 9.752, entropy_coef = 0.040, action_stds = 0.361 ± 0.099, action_magnitude = 0.770 ± 0.275, num_gradient_steps = 52000, step_time = 10.59, total_time = 554.52
#
# step = 63000, num_env_steps = 63000, scores = 3740.190, actor_loss = -99.211, entropy_coef_loss = 1.505, critic_loss = 7.829, entropy_coef = 0.040, action_stds = 0.441 ± 0.114, action_magnitude = 0.774 ± 0.271, num_gradient_steps = 53000, step_time = 10.63, total_time = 565.15
#
# step = 64000, num_env_steps = 64000, scores = 3456.323, actor_loss = -100.498, entropy_coef_loss = 0.704, critic_loss = 7.929, entropy_coef = 0.042, action_stds = 0.454 ± 0.104, action_magnitude = 0.773 ± 0.274, num_gradient_steps = 54000, step_time = 10.60, total_time = 575.76
#
# step = 65000, num_env_steps = 65000, scores = 3612.969, actor_loss = -106.543, entropy_coef_loss = 1.045, critic_loss = 7.688, entropy_coef = 0.044, action_stds = 0.483 ± 0.095, action_magnitude = 0.773 ± 0.271, num_gradient_steps = 55000, step_time = 10.60, total_time = 586.35
#
# step = 66000, num_env_steps = 66000, scores = 3625.354, actor_loss = -106.458, entropy_coef_loss = -2.056, critic_loss = 11.480, entropy_coef = 0.044, action_stds = 0.356 ± 0.139, action_magnitude = 0.779 ± 0.267, num_gradient_steps = 56000, step_time = 10.62, total_time = 596.98
#
# step = 67000, num_env_steps = 67000, scores = 3584.595, actor_loss = -114.943, entropy_coef_loss = 0.258, critic_loss = 7.708, entropy_coef = 0.047, action_stds = 0.524 ± 0.146, action_magnitude = 0.769 ± 0.272, num_gradient_steps = 57000, step_time = 10.62, total_time = 607.59
#
# step = 68000, num_env_steps = 68000, scores = 3812.280, actor_loss = -119.008, entropy_coef_loss = 1.095, critic_loss = 12.310, entropy_coef = 0.049, action_stds = 0.329 ± 0.137, action_magnitude = 0.774 ± 0.269, num_gradient_steps = 58000, step_time = 10.63, total_time = 618.23
#
# step = 69000, num_env_steps = 69000, scores = 3448.886, actor_loss = -126.238, entropy_coef_loss = 2.785, critic_loss = 8.890, entropy_coef = 0.050, action_stds = 0.410 ± 0.129, action_magnitude = 0.768 ± 0.275, num_gradient_steps = 59000, step_time = 10.64, total_time = 628.87
#
# step = 70000, num_env_steps = 70000, scores = 3816.275, actor_loss = -123.128, entropy_coef_loss = -1.119, critic_loss = 7.592, entropy_coef = 0.052, action_stds = 0.398 ± 0.106, action_magnitude = 0.784 ± 0.266, num_gradient_steps = 60000, step_time = 10.63, total_time = 639.50
#
# saved experiment log 2024-11-05_11-51-26_600853~Orhj1J at experiment_logs/HalfCheetah-v4/sac/2024-11-05_11-51-26_600853~Orhj1J.json
#
# step = 71000, num_env_steps = 71000, scores = 3838.724, actor_loss = -111.473, entropy_coef_loss = -1.382, critic_loss = 11.559, entropy_coef = 0.053, action_stds = 0.419 ± 0.060, action_magnitude = 0.780 ± 0.267, num_gradient_steps = 61000, step_time = 10.65, total_time = 650.15
#
# step = 72000, num_env_steps = 72000, scores = 3718.913, actor_loss = -134.439, entropy_coef_loss = 1.021, critic_loss = 9.409, entropy_coef = 0.054, action_stds = 0.542 ± 0.101, action_magnitude = 0.770 ± 0.272, num_gradient_steps = 62000, step_time = 10.61, total_time = 660.76
#
# step = 73000, num_env_steps = 73000, scores = 4298.057, actor_loss = -130.979, entropy_coef_loss = -1.538, critic_loss = 11.259, entropy_coef = 0.055, action_stds = 0.409 ± 0.120, action_magnitude = 0.789 ± 0.264, num_gradient_steps = 63000, step_time = 10.63, total_time = 671.39
#
# step = 74000, num_env_steps = 74000, scores = 4213.240, actor_loss = -135.478, entropy_coef_loss = 2.444, critic_loss = 11.963, entropy_coef = 0.057, action_stds = 0.314 ± 0.162, action_magnitude = 0.787 ± 0.264, num_gradient_steps = 64000, step_time = 10.62, total_time = 682.01
#
# step = 75000, num_env_steps = 75000, scores = 4582.150, actor_loss = -135.935, entropy_coef_loss = 1.148, critic_loss = 8.065, entropy_coef = 0.059, action_stds = 0.420 ± 0.109, action_magnitude = 0.787 ± 0.262, num_gradient_steps = 65000, step_time = 10.63, total_time = 692.64
#
# step = 76000, num_env_steps = 76000, scores = 4250.479, actor_loss = -141.140, entropy_coef_loss = 0.224, critic_loss = 11.854, entropy_coef = 0.060, action_stds = 0.317 ± 0.097, action_magnitude = 0.781 ± 0.266, num_gradient_steps = 66000, step_time = 10.58, total_time = 703.23
#
# step = 77000, num_env_steps = 77000, scores = 4296.134, actor_loss = -151.346, entropy_coef_loss = -0.365, critic_loss = 12.244, entropy_coef = 0.063, action_stds = 0.364 ± 0.110, action_magnitude = 0.791 ± 0.257, num_gradient_steps = 67000, step_time = 10.66, total_time = 713.88
#
# step = 78000, num_env_steps = 78000, scores = 3948.970, actor_loss = -143.475, entropy_coef_loss = 0.852, critic_loss = 12.230, entropy_coef = 0.064, action_stds = 0.369 ± 0.169, action_magnitude = 0.779 ± 0.267, num_gradient_steps = 68000, step_time = 10.64, total_time = 724.53
#
# step = 79000, num_env_steps = 79000, scores = 4488.123, actor_loss = -157.810, entropy_coef_loss = 0.753, critic_loss = 11.569, entropy_coef = 0.066, action_stds = 0.425 ± 0.090, action_magnitude = 0.796 ± 0.257, num_gradient_steps = 69000, step_time = 10.62, total_time = 735.15
#
# step = 80000, num_env_steps = 80000, scores = 4325.024, actor_loss = -161.936, entropy_coef_loss = -0.714, critic_loss = 12.026, entropy_coef = 0.068, action_stds = 0.361 ± 0.136, action_magnitude = 0.797 ± 0.257, num_gradient_steps = 70000, step_time = 10.64, total_time = 745.79
#
# saved experiment log 2024-11-05_11-51-26_600853~Orhj1J at experiment_logs/HalfCheetah-v4/sac/2024-11-05_11-51-26_600853~Orhj1J.json
#
# step = 81000, num_env_steps = 81000, scores = 4257.252, actor_loss = -154.865, entropy_coef_loss = -0.748, critic_loss = 12.037, entropy_coef = 0.069, action_stds = 0.370 ± 0.076, action_magnitude = 0.792 ± 0.260, num_gradient_steps = 71000, step_time = 10.63, total_time = 756.42
#
# step = 82000, num_env_steps = 82000, scores = 4469.735, actor_loss = -155.888, entropy_coef_loss = -1.376, critic_loss = 14.076, entropy_coef = 0.070, action_stds = 0.349 ± 0.110, action_magnitude = 0.797 ± 0.257, num_gradient_steps = 72000, step_time = 10.61, total_time = 767.03
#
# step = 83000, num_env_steps = 83000, scores = 4692.501, actor_loss = -168.451, entropy_coef_loss = -0.822, critic_loss = 17.134, entropy_coef = 0.073, action_stds = 0.451 ± 0.079, action_magnitude = 0.799 ± 0.260, num_gradient_steps = 73000, step_time = 10.64, total_time = 777.67
#
# step = 84000, num_env_steps = 84000, scores = 4778.164, actor_loss = -160.761, entropy_coef_loss = -0.868, critic_loss = 10.412, entropy_coef = 0.073, action_stds = 0.430 ± 0.087, action_magnitude = 0.810 ± 0.250, num_gradient_steps = 74000, step_time = 10.63, total_time = 788.30
#
# step = 85000, num_env_steps = 85000, scores = 4610.689, actor_loss = -163.328, entropy_coef_loss = -0.396, critic_loss = 12.680, entropy_coef = 0.074, action_stds = 0.318 ± 0.085, action_magnitude = 0.808 ± 0.254, num_gradient_steps = 75000, step_time = 10.61, total_time = 798.91
#
# step = 86000, num_env_steps = 86000, scores = 4590.477, actor_loss = -173.613, entropy_coef_loss = -0.902, critic_loss = 11.675, entropy_coef = 0.076, action_stds = 0.498 ± 0.075, action_magnitude = 0.814 ± 0.247, num_gradient_steps = 76000, step_time = 10.65, total_time = 809.55
#
# step = 87000, num_env_steps = 87000, scores = 4899.336, actor_loss = -183.515, entropy_coef_loss = 1.596, critic_loss = 11.184, entropy_coef = 0.079, action_stds = 0.334 ± 0.109, action_magnitude = 0.816 ± 0.245, num_gradient_steps = 77000, step_time = 10.60, total_time = 820.15
#
# step = 88000, num_env_steps = 88000, scores = 4573.353, actor_loss = -195.161, entropy_coef_loss = -0.021, critic_loss = 14.847, entropy_coef = 0.081, action_stds = 0.468 ± 0.051, action_magnitude = 0.807 ± 0.250, num_gradient_steps = 78000, step_time = 10.61, total_time = 830.76
#
# step = 89000, num_env_steps = 89000, scores = 4669.946, actor_loss = -189.729, entropy_coef_loss = -0.030, critic_loss = 13.786, entropy_coef = 0.083, action_stds = 0.452 ± 0.071, action_magnitude = 0.817 ± 0.246, num_gradient_steps = 79000, step_time = 10.65, total_time = 841.41
#
# step = 90000, num_env_steps = 90000, scores = 4770.748, actor_loss = -204.759, entropy_coef_loss = 0.735, critic_loss = 15.212, entropy_coef = 0.085, action_stds = 0.482 ± 0.141, action_magnitude = 0.819 ± 0.247, num_gradient_steps = 80000, step_time = 10.62, total_time = 852.04
#
# saved experiment log 2024-11-05_11-51-26_600853~Orhj1J at experiment_logs/HalfCheetah-v4/sac/2024-11-05_11-51-26_600853~Orhj1J.json
#
# step = 91000, num_env_steps = 91000, scores = 4522.976, actor_loss = -188.318, entropy_coef_loss = -0.274, critic_loss = 22.988, entropy_coef = 0.084, action_stds = 0.371 ± 0.112, action_magnitude = 0.805 ± 0.254, num_gradient_steps = 81000, step_time = 10.62, total_time = 862.65
#
# step = 92000, num_env_steps = 92000, scores = 4590.051, actor_loss = -191.099, entropy_coef_loss = -0.176, critic_loss = 12.153, entropy_coef = 0.086, action_stds = 0.517 ± 0.121, action_magnitude = 0.809 ± 0.250, num_gradient_steps = 82000, step_time = 10.65, total_time = 873.31
#
# step = 93000, num_env_steps = 93000, scores = 4724.981, actor_loss = -193.648, entropy_coef_loss = -0.104, critic_loss = 15.661, entropy_coef = 0.087, action_stds = 0.443 ± 0.096, action_magnitude = 0.813 ± 0.247, num_gradient_steps = 83000, step_time = 10.61, total_time = 883.91
#
# step = 94000, num_env_steps = 94000, scores = 4687.139, actor_loss = -207.309, entropy_coef_loss = -0.050, critic_loss = 12.755, entropy_coef = 0.088, action_stds = 0.430 ± 0.089, action_magnitude = 0.812 ± 0.247, num_gradient_steps = 84000, step_time = 10.62, total_time = 894.54
#
# step = 95000, num_env_steps = 95000, scores = 4924.889, actor_loss = -203.321, entropy_coef_loss = 0.126, critic_loss = 11.936, entropy_coef = 0.089, action_stds = 0.410 ± 0.092, action_magnitude = 0.811 ± 0.250, num_gradient_steps = 85000, step_time = 10.68, total_time = 905.22
#
# step = 96000, num_env_steps = 96000, scores = 5210.230, actor_loss = -218.982, entropy_coef_loss = 0.518, critic_loss = 20.509, entropy_coef = 0.090, action_stds = 0.378 ± 0.103, action_magnitude = 0.814 ± 0.249, num_gradient_steps = 86000, step_time = 10.61, total_time = 915.84
#
# step = 97000, num_env_steps = 97000, scores = 5016.284, actor_loss = -195.977, entropy_coef_loss = -1.512, critic_loss = 13.673, entropy_coef = 0.091, action_stds = 0.386 ± 0.142, action_magnitude = 0.811 ± 0.248, num_gradient_steps = 87000, step_time = 10.59, total_time = 926.43
#
# step = 98000, num_env_steps = 98000, scores = 4704.910, actor_loss = -208.701, entropy_coef_loss = 0.678, critic_loss = 15.549, entropy_coef = 0.092, action_stds = 0.484 ± 0.079, action_magnitude = 0.806 ± 0.251, num_gradient_steps = 88000, step_time = 10.70, total_time = 937.13
#
# step = 99000, num_env_steps = 99000, scores = 4735.479, actor_loss = -223.380, entropy_coef_loss = -0.485, critic_loss = 13.714, entropy_coef = 0.092, action_stds = 0.383 ± 0.097, action_magnitude = 0.801 ± 0.255, num_gradient_steps = 89000, step_time = 10.88, total_time = 948.01
#
# step = 100000, num_env_steps = 100000, scores = 4630.155, actor_loss = -214.141, entropy_coef_loss = -0.780, critic_loss = 12.973, entropy_coef = 0.092, action_stds = 0.457 ± 0.099, action_magnitude = 0.803 ± 0.251, num_gradient_steps = 90000, step_time = 10.86, total_time = 958.87
#
# saved experiment log 2024-11-05_11-51-26_600853~Orhj1J at experiment_logs/HalfCheetah-v4/sac/2024-11-05_11-51-26_600853~Orhj1J.json
#
# step = 101000, num_env_steps = 101000, scores = 4915.227, actor_loss = -216.100, entropy_coef_loss = -1.596, critic_loss = 14.489, entropy_coef = 0.094, action_stds = 0.437 ± 0.113, action_magnitude = 0.812 ± 0.245, num_gradient_steps = 91000, step_time = 10.96, total_time = 969.83
#
# step = 102000, num_env_steps = 102000, scores = 4723.175, actor_loss = -220.023, entropy_coef_loss = -1.738, critic_loss = 13.360, entropy_coef = 0.097, action_stds = 0.390 ± 0.093, action_magnitude = 0.810 ± 0.247, num_gradient_steps = 92000, step_time = 10.92, total_time = 980.75
#
# step = 103000, num_env_steps = 103000, scores = 5264.512, actor_loss = -217.845, entropy_coef_loss = -1.115, critic_loss = 14.344, entropy_coef = 0.097, action_stds = 0.462 ± 0.065, action_magnitude = 0.815 ± 0.243, num_gradient_steps = 93000, step_time = 10.62, total_time = 991.36
#
# step = 104000, num_env_steps = 104000, scores = 4646.059, actor_loss = -217.255, entropy_coef_loss = -2.143, critic_loss = 19.105, entropy_coef = 0.099, action_stds = 0.502 ± 0.105, action_magnitude = 0.804 ± 0.250, num_gradient_steps = 94000, step_time = 10.65, total_time = 1002.02
#
# step = 105000, num_env_steps = 105000, scores = 5348.549, actor_loss = -226.975, entropy_coef_loss = 0.683, critic_loss = 14.345, entropy_coef = 0.099, action_stds = 0.421 ± 0.096, action_magnitude = 0.813 ± 0.246, num_gradient_steps = 95000, step_time = 10.61, total_time = 1012.62
#
# step = 106000, num_env_steps = 106000, scores = 5045.168, actor_loss = -237.888, entropy_coef_loss = 1.400, critic_loss = 19.540, entropy_coef = 0.101, action_stds = 0.399 ± 0.137, action_magnitude = 0.811 ± 0.243, num_gradient_steps = 96000, step_time = 10.63, total_time = 1023.25
#
# step = 107000, num_env_steps = 107000, scores = 5236.072, actor_loss = -234.923, entropy_coef_loss = 0.654, critic_loss = 14.383, entropy_coef = 0.102, action_stds = 0.359 ± 0.103, action_magnitude = 0.819 ± 0.240, num_gradient_steps = 97000, step_time = 10.65, total_time = 1033.90
#
# step = 108000, num_env_steps = 108000, scores = 5173.060, actor_loss = -244.175, entropy_coef_loss = 0.988, critic_loss = 18.121, entropy_coef = 0.103, action_stds = 0.419 ± 0.089, action_magnitude = 0.817 ± 0.239, num_gradient_steps = 98000, step_time = 10.60, total_time = 1044.50
#
# step = 109000, num_env_steps = 109000, scores = 5155.266, actor_loss = -242.222, entropy_coef_loss = -0.588, critic_loss = 12.670, entropy_coef = 0.106, action_stds = 0.337 ± 0.123, action_magnitude = 0.813 ± 0.243, num_gradient_steps = 99000, step_time = 10.62, total_time = 1055.12
#
# step = 110000, num_env_steps = 110000, scores = 5285.986, actor_loss = -243.018, entropy_coef_loss = -1.128, critic_loss = 11.051, entropy_coef = 0.104, action_stds = 0.375 ± 0.086, action_magnitude = 0.812 ± 0.243, num_gradient_steps = 100000, step_time = 10.65, total_time = 1065.77
#
# saved experiment log 2024-11-05_11-51-26_600853~Orhj1J at experiment_logs/HalfCheetah-v4/sac/2024-11-05_11-51-26_600853~Orhj1J.json
#
# step = 111000, num_env_steps = 111000, scores = 5396.012, actor_loss = -246.998, entropy_coef_loss = 1.209, critic_loss = 15.047, entropy_coef = 0.105, action_stds = 0.347 ± 0.069, action_magnitude = 0.808 ± 0.248, num_gradient_steps = 101000, step_time = 10.65, total_time = 1076.42
#
# step = 112000, num_env_steps = 112000, scores = 4975.880, actor_loss = -242.505, entropy_coef_loss = 0.025, critic_loss = 16.490, entropy_coef = 0.106, action_stds = 0.653 ± 0.085, action_magnitude = 0.798 ± 0.252, num_gradient_steps = 102000, step_time = 10.66, total_time = 1087.09
#
# step = 113000, num_env_steps = 113000, scores = 5495.478, actor_loss = -255.922, entropy_coef_loss = 0.449, critic_loss = 18.293, entropy_coef = 0.108, action_stds = 0.360 ± 0.135, action_magnitude = 0.817 ± 0.240, num_gradient_steps = 103000, step_time = 10.64, total_time = 1097.73
#
# step = 114000, num_env_steps = 114000, scores = 5322.656, actor_loss = -247.567, entropy_coef_loss = 0.590, critic_loss = 14.296, entropy_coef = 0.109, action_stds = 0.442 ± 0.146, action_magnitude = 0.809 ± 0.245, num_gradient_steps = 104000, step_time = 10.58, total_time = 1108.30
#
# step = 115000, num_env_steps = 115000, scores = 5392.635, actor_loss = -254.337, entropy_coef_loss = 0.231, critic_loss = 13.918, entropy_coef = 0.110, action_stds = 0.484 ± 0.093, action_magnitude = 0.810 ± 0.243, num_gradient_steps = 105000, step_time = 10.66, total_time = 1118.97
#
# step = 116000, num_env_steps = 116000, scores = 5445.116, actor_loss = -253.845, entropy_coef_loss = 0.078, critic_loss = 13.007, entropy_coef = 0.111, action_stds = 0.434 ± 0.089, action_magnitude = 0.806 ± 0.250, num_gradient_steps = 106000, step_time = 10.63, total_time = 1129.60
#
# step = 117000, num_env_steps = 117000, scores = 5257.538, actor_loss = -249.712, entropy_coef_loss = 0.290, critic_loss = 15.461, entropy_coef = 0.111, action_stds = 0.462 ± 0.091, action_magnitude = 0.800 ± 0.250, num_gradient_steps = 107000, step_time = 10.64, total_time = 1140.24
#
# step = 118000, num_env_steps = 118000, scores = 5191.034, actor_loss = -252.511, entropy_coef_loss = -0.587, critic_loss = 14.513, entropy_coef = 0.110, action_stds = 0.538 ± 0.092, action_magnitude = 0.794 ± 0.255, num_gradient_steps = 108000, step_time = 10.68, total_time = 1150.92
#
# step = 119000, num_env_steps = 119000, scores = 5344.014, actor_loss = -256.515, entropy_coef_loss = -1.050, critic_loss = 14.172, entropy_coef = 0.110, action_stds = 0.457 ± 0.105, action_magnitude = 0.800 ± 0.250, num_gradient_steps = 109000, step_time = 10.63, total_time = 1161.55
#
# step = 120000, num_env_steps = 120000, scores = 1419.499, actor_loss = -267.644, entropy_coef_loss = 0.089, critic_loss = 20.220, entropy_coef = 0.112, action_stds = 0.551 ± 0.079, action_magnitude = 0.636 ± 0.301, num_gradient_steps = 110000, step_time = 10.63, total_time = 1172.18
#
# saved experiment log 2024-11-05_11-51-26_600853~Orhj1J at experiment_logs/HalfCheetah-v4/sac/2024-11-05_11-51-26_600853~Orhj1J.json
#
# step = 121000, num_env_steps = 121000, scores = 5444.845, actor_loss = -274.021, entropy_coef_loss = -0.581, critic_loss = 14.071, entropy_coef = 0.112, action_stds = 0.485 ± 0.121, action_magnitude = 0.808 ± 0.246, num_gradient_steps = 111000, step_time = 10.64, total_time = 1182.82
#
# step = 122000, num_env_steps = 122000, scores = 5531.942, actor_loss = -268.370, entropy_coef_loss = 0.489, critic_loss = 14.572, entropy_coef = 0.114, action_stds = 0.429 ± 0.080, action_magnitude = 0.807 ± 0.245, num_gradient_steps = 112000, step_time = 10.62, total_time = 1193.44
#
# step = 123000, num_env_steps = 123000, scores = 5360.261, actor_loss = -263.520, entropy_coef_loss = -1.533, critic_loss = 12.632, entropy_coef = 0.117, action_stds = 0.459 ± 0.120, action_magnitude = 0.802 ± 0.251, num_gradient_steps = 113000, step_time = 10.64, total_time = 1204.08
#
# step = 124000, num_env_steps = 124000, scores = 5620.843, actor_loss = -260.847, entropy_coef_loss = 1.083, critic_loss = 18.176, entropy_coef = 0.116, action_stds = 0.342 ± 0.124, action_magnitude = 0.810 ± 0.247, num_gradient_steps = 114000, step_time = 10.68, total_time = 1214.76
#
# step = 125000, num_env_steps = 125000, scores = 2128.855, actor_loss = -274.496, entropy_coef_loss = -0.191, critic_loss = 14.108, entropy_coef = 0.116, action_stds = 0.650 ± 0.088, action_magnitude = 0.640 ± 0.305, num_gradient_steps = 115000, step_time = 10.62, total_time = 1225.38
#
# step = 126000, num_env_steps = 126000, scores = 4936.979, actor_loss = -266.122, entropy_coef_loss = -0.173, critic_loss = 16.113, entropy_coef = 0.117, action_stds = 0.416 ± 0.111, action_magnitude = 0.799 ± 0.252, num_gradient_steps = 116000, step_time = 10.62, total_time = 1236.00
#
# step = 127000, num_env_steps = 127000, scores = 5551.055, actor_loss = -274.013, entropy_coef_loss = -0.679, critic_loss = 12.877, entropy_coef = 0.117, action_stds = 0.385 ± 0.137, action_magnitude = 0.802 ± 0.251, num_gradient_steps = 117000, step_time = 10.65, total_time = 1246.65
#
# step = 128000, num_env_steps = 128000, scores = 5913.943, actor_loss = -286.500, entropy_coef_loss = 0.785, critic_loss = 14.582, entropy_coef = 0.122, action_stds = 0.375 ± 0.080, action_magnitude = 0.809 ± 0.246, num_gradient_steps = 118000, step_time = 10.64, total_time = 1257.29
#
# step = 129000, num_env_steps = 129000, scores = 5597.938, actor_loss = -284.539, entropy_coef_loss = 0.555, critic_loss = 20.082, entropy_coef = 0.121, action_stds = 0.495 ± 0.117, action_magnitude = 0.808 ± 0.248, num_gradient_steps = 119000, step_time = 10.63, total_time = 1267.92
#
# step = 130000, num_env_steps = 130000, scores = 5802.891, actor_loss = -294.899, entropy_coef_loss = 0.856, critic_loss = 14.450, entropy_coef = 0.120, action_stds = 0.498 ± 0.074, action_magnitude = 0.799 ± 0.252, num_gradient_steps = 120000, step_time = 10.63, total_time = 1278.56
#
# saved experiment log 2024-11-05_11-51-26_600853~Orhj1J at experiment_logs/HalfCheetah-v4/sac/2024-11-05_11-51-26_600853~Orhj1J.json
#
# step = 131000, num_env_steps = 131000, scores = 5682.485, actor_loss = -285.242, entropy_coef_loss = -0.058, critic_loss = 17.007, entropy_coef = 0.123, action_stds = 0.356 ± 0.112, action_magnitude = 0.803 ± 0.250, num_gradient_steps = 121000, step_time = 10.63, total_time = 1289.19
#
# step = 132000, num_env_steps = 132000, scores = 5331.446, actor_loss = -296.796, entropy_coef_loss = 1.631, critic_loss = 13.132, entropy_coef = 0.122, action_stds = 0.478 ± 0.089, action_magnitude = 0.793 ± 0.256, num_gradient_steps = 122000, step_time = 10.62, total_time = 1299.81
#
# step = 133000, num_env_steps = 133000, scores = 5698.724, actor_loss = -278.128, entropy_coef_loss = -0.336, critic_loss = 14.235, entropy_coef = 0.125, action_stds = 0.461 ± 0.133, action_magnitude = 0.796 ± 0.257, num_gradient_steps = 123000, step_time = 10.67, total_time = 1310.48
#
# step = 134000, num_env_steps = 134000, scores = 5971.201, actor_loss = -287.271, entropy_coef_loss = -0.082, critic_loss = 26.390, entropy_coef = 0.126, action_stds = 0.449 ± 0.080, action_magnitude = 0.806 ± 0.251, num_gradient_steps = 124000, step_time = 10.61, total_time = 1321.10
#
# step = 135000, num_env_steps = 135000, scores = 6159.857, actor_loss = -295.779, entropy_coef_loss = 0.791, critic_loss = 16.682, entropy_coef = 0.124, action_stds = 0.432 ± 0.059, action_magnitude = 0.800 ± 0.255, num_gradient_steps = 125000, step_time = 10.65, total_time = 1331.75
#
# step = 136000, num_env_steps = 136000, scores = 5933.028, actor_loss = -281.430, entropy_coef_loss = 0.313, critic_loss = 11.584, entropy_coef = 0.126, action_stds = 0.466 ± 0.067, action_magnitude = 0.806 ± 0.248, num_gradient_steps = 126000, step_time = 10.67, total_time = 1342.42
#
# step = 137000, num_env_steps = 137000, scores = 6043.097, actor_loss = -290.654, entropy_coef_loss = -0.401, critic_loss = 15.867, entropy_coef = 0.126, action_stds = 0.481 ± 0.052, action_magnitude = 0.802 ± 0.249, num_gradient_steps = 127000, step_time = 10.64, total_time = 1353.06
#
# step = 138000, num_env_steps = 138000, scores = 6163.880, actor_loss = -296.780, entropy_coef_loss = -0.039, critic_loss = 20.164, entropy_coef = 0.127, action_stds = 0.473 ± 0.131, action_magnitude = 0.805 ± 0.247, num_gradient_steps = 128000, step_time = 10.64, total_time = 1363.70
#
# step = 139000, num_env_steps = 139000, scores = 5943.896, actor_loss = -289.362, entropy_coef_loss = -0.107, critic_loss = 15.729, entropy_coef = 0.128, action_stds = 0.500 ± 0.055, action_magnitude = 0.805 ± 0.247, num_gradient_steps = 129000, step_time = 10.64, total_time = 1374.34
#
# step = 140000, num_env_steps = 140000, scores = 5941.687, actor_loss = -288.677, entropy_coef_loss = -0.383, critic_loss = 15.978, entropy_coef = 0.130, action_stds = 0.477 ± 0.122, action_magnitude = 0.798 ± 0.253, num_gradient_steps = 130000, step_time = 10.66, total_time = 1385.00
#
# saved experiment log 2024-11-05_11-51-26_600853~Orhj1J at experiment_logs/HalfCheetah-v4/sac/2024-11-05_11-51-26_600853~Orhj1J.json
#
# step = 141000, num_env_steps = 141000, scores = 5964.338, actor_loss = -305.741, entropy_coef_loss = 0.905, critic_loss = 15.843, entropy_coef = 0.130, action_stds = 0.424 ± 0.094, action_magnitude = 0.807 ± 0.245, num_gradient_steps = 131000, step_time = 10.64, total_time = 1395.65
#
# step = 142000, num_env_steps = 142000, scores = 5926.107, actor_loss = -295.336, entropy_coef_loss = 0.347, critic_loss = 17.452, entropy_coef = 0.132, action_stds = 0.388 ± 0.120, action_magnitude = 0.801 ± 0.250, num_gradient_steps = 132000, step_time = 10.67, total_time = 1406.32
#
# step = 143000, num_env_steps = 143000, scores = 5897.864, actor_loss = -300.485, entropy_coef_loss = -0.006, critic_loss = 10.788, entropy_coef = 0.131, action_stds = 0.442 ± 0.059, action_magnitude = 0.795 ± 0.252, num_gradient_steps = 133000, step_time = 10.64, total_time = 1416.95
#
# step = 144000, num_env_steps = 144000, scores = 5962.961, actor_loss = -311.537, entropy_coef_loss = 0.514, critic_loss = 22.818, entropy_coef = 0.133, action_stds = 0.438 ± 0.140, action_magnitude = 0.805 ± 0.248, num_gradient_steps = 134000, step_time = 10.65, total_time = 1427.60
#
# step = 145000, num_env_steps = 145000, scores = 5761.907, actor_loss = -317.431, entropy_coef_loss = 0.497, critic_loss = 17.690, entropy_coef = 0.134, action_stds = 0.397 ± 0.165, action_magnitude = 0.801 ± 0.249, num_gradient_steps = 135000, step_time = 10.68, total_time = 1438.28
#
# step = 146000, num_env_steps = 146000, scores = 6011.822, actor_loss = -285.973, entropy_coef_loss = -0.779, critic_loss = 16.359, entropy_coef = 0.133, action_stds = 0.488 ± 0.088, action_magnitude = 0.804 ± 0.247, num_gradient_steps = 136000, step_time = 10.66, total_time = 1448.94
#
# step = 147000, num_env_steps = 147000, scores = 6153.509, actor_loss = -315.001, entropy_coef_loss = 0.885, critic_loss = 18.847, entropy_coef = 0.135, action_stds = 0.398 ± 0.128, action_magnitude = 0.810 ± 0.242, num_gradient_steps = 137000, step_time = 10.63, total_time = 1459.57
#
# step = 148000, num_env_steps = 148000, scores = 6197.129, actor_loss = -317.977, entropy_coef_loss = 0.746, critic_loss = 17.643, entropy_coef = 0.136, action_stds = 0.505 ± 0.048, action_magnitude = 0.808 ± 0.245, num_gradient_steps = 138000, step_time = 10.68, total_time = 1470.25
#
# step = 149000, num_env_steps = 149000, scores = 6342.260, actor_loss = -324.854, entropy_coef_loss = 1.137, critic_loss = 14.874, entropy_coef = 0.137, action_stds = 0.498 ± 0.122, action_magnitude = 0.801 ± 0.249, num_gradient_steps = 139000, step_time = 10.65, total_time = 1480.91
#
# step = 150000, num_env_steps = 150000, scores = 6408.114, actor_loss = -327.826, entropy_coef_loss = 0.131, critic_loss = 17.814, entropy_coef = 0.138, action_stds = 0.470 ± 0.084, action_magnitude = 0.808 ± 0.243, num_gradient_steps = 140000, step_time = 10.59, total_time = 1491.50
#
# saved experiment log 2024-11-05_11-51-26_600853~Orhj1J at experiment_logs/HalfCheetah-v4/sac/2024-11-05_11-51-26_600853~Orhj1J.json
#
# step = 151000, num_env_steps = 151000, scores = 6108.792, actor_loss = -309.038, entropy_coef_loss = 0.091, critic_loss = 12.327, entropy_coef = 0.137, action_stds = 0.461 ± 0.110, action_magnitude = 0.802 ± 0.246, num_gradient_steps = 141000, step_time = 10.67, total_time = 1502.17
#
# step = 152000, num_env_steps = 152000, scores = 6328.807, actor_loss = -335.845, entropy_coef_loss = 0.707, critic_loss = 19.056, entropy_coef = 0.140, action_stds = 0.322 ± 0.150, action_magnitude = 0.804 ± 0.245, num_gradient_steps = 142000, step_time = 10.63, total_time = 1512.79
#
# step = 153000, num_env_steps = 153000, scores = 6398.492, actor_loss = -322.960, entropy_coef_loss = 0.331, critic_loss = 14.563, entropy_coef = 0.141, action_stds = 0.444 ± 0.122, action_magnitude = 0.798 ± 0.250, num_gradient_steps = 143000, step_time = 10.63, total_time = 1523.43
#
# step = 154000, num_env_steps = 154000, scores = 6512.468, actor_loss = -320.010, entropy_coef_loss = -0.704, critic_loss = 13.895, entropy_coef = 0.140, action_stds = 0.450 ± 0.062, action_magnitude = 0.796 ± 0.249, num_gradient_steps = 144000, step_time = 10.66, total_time = 1534.09
#
# step = 155000, num_env_steps = 155000, scores = 6368.342, actor_loss = -330.832, entropy_coef_loss = 0.305, critic_loss = 12.159, entropy_coef = 0.142, action_stds = 0.470 ± 0.087, action_magnitude = 0.797 ± 0.248, num_gradient_steps = 145000, step_time = 10.62, total_time = 1544.71
#
# step = 156000, num_env_steps = 156000, scores = 6248.497, actor_loss = -317.766, entropy_coef_loss = -0.365, critic_loss = 12.652, entropy_coef = 0.140, action_stds = 0.423 ± 0.066, action_magnitude = 0.802 ± 0.244, num_gradient_steps = 146000, step_time = 10.62, total_time = 1555.33
#
# step = 157000, num_env_steps = 157000, scores = 6335.095, actor_loss = -334.537, entropy_coef_loss = -0.285, critic_loss = 16.346, entropy_coef = 0.142, action_stds = 0.439 ± 0.114, action_magnitude = 0.804 ± 0.243, num_gradient_steps = 147000, step_time = 10.65, total_time = 1565.98
#
# step = 158000, num_env_steps = 158000, scores = 6505.788, actor_loss = -331.776, entropy_coef_loss = 0.382, critic_loss = 20.234, entropy_coef = 0.144, action_stds = 0.315 ± 0.129, action_magnitude = 0.805 ± 0.241, num_gradient_steps = 148000, step_time = 10.62, total_time = 1576.61
#
# step = 159000, num_env_steps = 159000, scores = 6474.157, actor_loss = -322.951, entropy_coef_loss = -0.145, critic_loss = 11.668, entropy_coef = 0.143, action_stds = 0.441 ± 0.126, action_magnitude = 0.802 ± 0.243, num_gradient_steps = 149000, step_time = 10.67, total_time = 1587.27
#
# step = 160000, num_env_steps = 160000, scores = 6260.997, actor_loss = -339.664, entropy_coef_loss = -0.288, critic_loss = 16.182, entropy_coef = 0.145, action_stds = 0.322 ± 0.167, action_magnitude = 0.795 ± 0.249, num_gradient_steps = 150000, step_time = 10.67, total_time = 1597.94
#
# saved experiment log 2024-11-05_11-51-26_600853~Orhj1J at experiment_logs/HalfCheetah-v4/sac/2024-11-05_11-51-26_600853~Orhj1J.json
#
# step = 161000, num_env_steps = 161000, scores = 6463.825, actor_loss = -338.223, entropy_coef_loss = 0.784, critic_loss = 18.773, entropy_coef = 0.147, action_stds = 0.450 ± 0.111, action_magnitude = 0.802 ± 0.242, num_gradient_steps = 151000, step_time = 10.63, total_time = 1608.57
#
# step = 162000, num_env_steps = 162000, scores = 6597.172, actor_loss = -341.132, entropy_coef_loss = -0.046, critic_loss = 16.106, entropy_coef = 0.145, action_stds = 0.528 ± 0.100, action_magnitude = 0.798 ± 0.248, num_gradient_steps = 152000, step_time = 10.67, total_time = 1619.24
#
# step = 163000, num_env_steps = 163000, scores = 6386.197, actor_loss = -342.239, entropy_coef_loss = 0.055, critic_loss = 13.901, entropy_coef = 0.145, action_stds = 0.363 ± 0.139, action_magnitude = 0.801 ± 0.245, num_gradient_steps = 153000, step_time = 10.61, total_time = 1629.85
#
# step = 164000, num_env_steps = 164000, scores = 6410.677, actor_loss = -336.629, entropy_coef_loss = 0.077, critic_loss = 13.857, entropy_coef = 0.150, action_stds = 0.403 ± 0.077, action_magnitude = 0.802 ± 0.244, num_gradient_steps = 154000, step_time = 10.64, total_time = 1640.48
#
# step = 165000, num_env_steps = 165000, scores = 6454.132, actor_loss = -334.995, entropy_coef_loss = -0.052, critic_loss = 13.015, entropy_coef = 0.149, action_stds = 0.443 ± 0.106, action_magnitude = 0.800 ± 0.245, num_gradient_steps = 155000, step_time = 10.67, total_time = 1651.16
#
# step = 166000, num_env_steps = 166000, scores = 6574.000, actor_loss = -327.455, entropy_coef_loss = -0.734, critic_loss = 16.135, entropy_coef = 0.148, action_stds = 0.428 ± 0.081, action_magnitude = 0.801 ± 0.246, num_gradient_steps = 156000, step_time = 10.62, total_time = 1661.77
#
# step = 167000, num_env_steps = 167000, scores = 6586.214, actor_loss = -337.784, entropy_coef_loss = -0.355, critic_loss = 18.501, entropy_coef = 0.150, action_stds = 0.328 ± 0.147, action_magnitude = 0.800 ± 0.247, num_gradient_steps = 157000, step_time = 10.60, total_time = 1672.37
#
# step = 168000, num_env_steps = 168000, scores = 6537.454, actor_loss = -333.168, entropy_coef_loss = -0.554, critic_loss = 21.970, entropy_coef = 0.152, action_stds = 0.409 ± 0.053, action_magnitude = 0.795 ± 0.252, num_gradient_steps = 158000, step_time = 10.64, total_time = 1683.01
#
# step = 169000, num_env_steps = 169000, scores = 6272.631, actor_loss = -340.423, entropy_coef_loss = 0.681, critic_loss = 13.120, entropy_coef = 0.152, action_stds = 0.429 ± 0.122, action_magnitude = 0.796 ± 0.249, num_gradient_steps = 159000, step_time = 10.64, total_time = 1693.65
#
# step = 170000, num_env_steps = 170000, scores = 6578.719, actor_loss = -362.493, entropy_coef_loss = 0.396, critic_loss = 14.227, entropy_coef = 0.154, action_stds = 0.353 ± 0.139, action_magnitude = 0.792 ± 0.256, num_gradient_steps = 160000, step_time = 10.64, total_time = 1704.29
#
# saved experiment log 2024-11-05_11-51-26_600853~Orhj1J at experiment_logs/HalfCheetah-v4/sac/2024-11-05_11-51-26_600853~Orhj1J.json
#
# step = 171000, num_env_steps = 171000, scores = 6687.717, actor_loss = -355.902, entropy_coef_loss = -0.025, critic_loss = 18.201, entropy_coef = 0.154, action_stds = 0.438 ± 0.086, action_magnitude = 0.798 ± 0.249, num_gradient_steps = 161000, step_time = 10.69, total_time = 1714.98
#
# ...
#
# step = 3450000, num_env_steps = 3450000, scores = 14256.499, actor_loss = -1049.341, entropy_coef_loss = -0.030, critic_loss = 35.647, entropy_coef = 0.431, action_stds = 0.488 ± 0.057, action_magnitude = 0.730 ± 0.267, num_gradient_steps = 3440000, step_time = 11.55, total_time = 39416.44
# saved experiment log 2024-11-05_11-51-26_600853~Orhj1J at experiment_logs/HalfCheetah-v4/sac/2024-11-05_11-51-26_600853~Orhj1J.json
#
# step = 3451000, num_env_steps = 3451000, scores = 14359.334, actor_loss = -1069.589, entropy_coef_loss = 0.280, critic_loss = 79.186, entropy_coef = 0.425, action_stds = 0.401 ± 0.162, action_magnitude = 0.730 ± 0.268, num_gradient_steps = 3441000, step_time = 11.88, total_time = 39428.32
#
# step = 3452000, num_env_steps = 3452000, scores = 14317.199, actor_loss = -1066.197, entropy_coef_loss = 0.622, critic_loss = 60.075, entropy_coef = 0.429, action_stds = 0.404 ± 0.156, action_magnitude = 0.729 ± 0.268, num_gradient_steps = 3442000, step_time = 11.52, total_time = 39439.84
#
# step = 3453000, num_env_steps = 3453000, scores = 14312.603, actor_loss = -1072.061, entropy_coef_loss = 0.062, critic_loss = 60.190, entropy_coef = 0.426, action_stds = 0.417 ± 0.180, action_magnitude = 0.733 ± 0.267, num_gradient_steps = 3443000, step_time = 11.55, total_time = 39451.39
#
# step = 3454000, num_env_steps = 3454000, scores = 14412.911, actor_loss = -1064.320, entropy_coef_loss = 0.076, critic_loss = 80.779, entropy_coef = 0.433, action_stds = 0.328 ± 0.185, action_magnitude = 0.730 ± 0.268, num_gradient_steps = 3444000, step_time = 11.52, total_time = 39462.91
#
# step = 3455000, num_env_steps = 3455000, scores = 14160.566, actor_loss = -1064.192, entropy_coef_loss = -0.456, critic_loss = 87.253, entropy_coef = 0.433, action_stds = 0.524 ± 0.046, action_magnitude = 0.728 ± 0.272, num_gradient_steps = 3445000, step_time = 11.55, total_time = 39474.46
#
# step = 3456000, num_env_steps = 3456000, scores = 14235.087, actor_loss = -1077.846, entropy_coef_loss = -0.124, critic_loss = 50.732, entropy_coef = 0.427, action_stds = 0.368 ± 0.202, action_magnitude = 0.723 ± 0.271, num_gradient_steps = 3446000, step_time = 11.52, total_time = 39485.98
#
# step = 3457000, num_env_steps = 3457000, scores = 14481.507, actor_loss = -1047.250, entropy_coef_loss = -0.568, critic_loss = 60.115, entropy_coef = 0.433, action_stds = 0.324 ± 0.199, action_magnitude = 0.729 ± 0.270, num_gradient_steps = 3447000, step_time = 11.53, total_time = 39497.52
#
# step = 3458000, num_env_steps = 3458000, scores = 14514.242, actor_loss = -1062.955, entropy_coef_loss = -0.183, critic_loss = 52.445, entropy_coef = 0.441, action_stds = 0.447 ± 0.082, action_magnitude = 0.728 ± 0.270, num_gradient_steps = 3448000, step_time = 11.55, total_time = 39509.07
#
# step = 3459000, num_env_steps = 3459000, scores = 14176.995, actor_loss = -1055.061, entropy_coef_loss = 0.055, critic_loss = 44.155, entropy_coef = 0.422, action_stds = 0.381 ± 0.154, action_magnitude = 0.728 ± 0.268, num_gradient_steps = 3449000, step_time = 11.58, total_time = 39520.64
#
# step = 3460000, num_env_steps = 3460000, scores = 14407.206, actor_loss = -1077.840, entropy_coef_loss = -0.145, critic_loss = 39.794, entropy_coef = 0.431, action_stds = 0.393 ± 0.150, action_magnitude = 0.734 ± 0.266, num_gradient_steps = 3450000, step_time = 11.57, total_time = 39532.21
# saved experiment log 2024-11-05_11-51-26_600853~Orhj1J at experiment_logs/HalfCheetah-v4/sac/2024-11-05_11-51-26_600853~Orhj1J.json
#
# step = 3461000, num_env_steps = 3461000, scores = 14423.335, actor_loss = -1079.433, entropy_coef_loss = 0.105, critic_loss = 89.803, entropy_coef = 0.435, action_stds = 0.382 ± 0.193, action_magnitude = 0.736 ± 0.263, num_gradient_steps = 3451000, step_time = 11.85, total_time = 39544.07
#
# step = 3462000, num_env_steps = 3462000, scores = 14600.997, actor_loss = -1071.181, entropy_coef_loss = -0.026, critic_loss = 36.217, entropy_coef = 0.425, action_stds = 0.418 ± 0.104, action_magnitude = 0.734 ± 0.263, num_gradient_steps = 3452000, step_time = 11.62, total_time = 39555.68
#
# step = 3463000, num_env_steps = 3463000, scores = 14302.336, actor_loss = -1080.711, entropy_coef_loss = 0.033, critic_loss = 85.847, entropy_coef = 0.430, action_stds = 0.390 ± 0.202, action_magnitude = 0.732 ± 0.267, num_gradient_steps = 3453000, step_time = 11.56, total_time = 39567.25
#
# step = 3464000, num_env_steps = 3464000, scores = 14425.279, actor_loss = -1042.824, entropy_coef_loss = -0.076, critic_loss = 60.602, entropy_coef = 0.435, action_stds = 0.387 ± 0.154, action_magnitude = 0.728 ± 0.272, num_gradient_steps = 3454000, step_time = 11.53, total_time = 39578.77
#
# step = 3465000, num_env_steps = 3465000, scores = 14246.282, actor_loss = -1092.256, entropy_coef_loss = -0.199, critic_loss = 47.389, entropy_coef = 0.432, action_stds = 0.380 ± 0.217, action_magnitude = 0.727 ± 0.270, num_gradient_steps = 3455000, step_time = 11.56, total_time = 39590.33
#
# step = 3466000, num_env_steps = 3466000, scores = 14539.360, actor_loss = -1066.241, entropy_coef_loss = 0.150, critic_loss = 127.588, entropy_coef = 0.433, action_stds = 0.390 ± 0.146, action_magnitude = 0.726 ± 0.269, num_gradient_steps = 3456000, step_time = 11.52, total_time = 39601.85
#
# step = 3467000, num_env_steps = 3467000, scores = 14284.132, actor_loss = -1067.538, entropy_coef_loss = -0.323, critic_loss = 43.261, entropy_coef = 0.428, action_stds = 0.433 ± 0.167, action_magnitude = 0.733 ± 0.269, num_gradient_steps = 3457000, step_time = 11.57, total_time = 39613.43
#
# step = 3468000, num_env_steps = 3468000, scores = 14604.432, actor_loss = -1088.574, entropy_coef_loss = -0.090, critic_loss = 73.389, entropy_coef = 0.430, action_stds = 0.506 ± 0.047, action_magnitude = 0.730 ± 0.267, num_gradient_steps = 3458000, step_time = 11.56, total_time = 39624.99
#
# step = 3469000, num_env_steps = 3469000, scores = 14622.183, actor_loss = -1068.890, entropy_coef_loss = -0.063, critic_loss = 41.791, entropy_coef = 0.434, action_stds = 0.386 ± 0.200, action_magnitude = 0.728 ± 0.270, num_gradient_steps = 3459000, step_time = 11.55, total_time = 39636.54
#
# step = 3470000, num_env_steps = 3470000, scores = 14392.847, actor_loss = -1071.126, entropy_coef_loss = 0.128, critic_loss = 76.248, entropy_coef = 0.432, action_stds = 0.386 ± 0.158, action_magnitude = 0.732 ± 0.265, num_gradient_steps = 3460000, step_time = 11.58, total_time = 39648.11
# saved experiment log 2024-11-05_11-51-26_600853~Orhj1J at experiment_logs/HalfCheetah-v4/sac/2024-11-05_11-51-26_600853~Orhj1J.json
#
# step = 3471000, num_env_steps = 3471000, scores = 13875.985, actor_loss = -1074.803, entropy_coef_loss = -0.114, critic_loss = 35.399, entropy_coef = 0.429, action_stds = 0.330 ± 0.195, action_magnitude = 0.732 ± 0.271, num_gradient_steps = 3461000, step_time = 11.88, total_time = 39660.00
#
# step = 3472000, num_env_steps = 3472000, scores = 14381.666, actor_loss = -1068.787, entropy_coef_loss = -0.045, critic_loss = 107.636, entropy_coef = 0.429, action_stds = 0.389 ± 0.137, action_magnitude = 0.730 ± 0.269, num_gradient_steps = 3462000, step_time = 11.59, total_time = 39671.58
#
# step = 3473000, num_env_steps = 3473000, scores = 14446.719, actor_loss = -1079.163, entropy_coef_loss = 0.036, critic_loss = 42.329, entropy_coef = 0.438, action_stds = 0.321 ± 0.202, action_magnitude = 0.729 ± 0.267, num_gradient_steps = 3463000, step_time = 11.56, total_time = 39683.15
#
# step = 3474000, num_env_steps = 3474000, scores = 14420.867, actor_loss = -1071.496, entropy_coef_loss = 0.161, critic_loss = 33.782, entropy_coef = 0.437, action_stds = 0.323 ± 0.191, action_magnitude = 0.726 ± 0.269, num_gradient_steps = 3464000, step_time = 11.47, total_time = 39694.61
#
# step = 3475000, num_env_steps = 3475000, scores = 14549.368, actor_loss = -1047.599, entropy_coef_loss = -0.406, critic_loss = 36.738, entropy_coef = 0.431, action_stds = 0.317 ± 0.193, action_magnitude = 0.733 ± 0.264, num_gradient_steps = 3465000, step_time = 11.58, total_time = 39706.19
#
# step = 3476000, num_env_steps = 3476000, scores = 14350.045, actor_loss = -1046.914, entropy_coef_loss = -0.257, critic_loss = 74.008, entropy_coef = 0.437, action_stds = 0.475 ± 0.058, action_magnitude = 0.729 ± 0.268, num_gradient_steps = 3466000, step_time = 11.55, total_time = 39717.73
#
# step = 3477000, num_env_steps = 3477000, scores = 14629.017, actor_loss = -1087.385, entropy_coef_loss = -0.159, critic_loss = 50.351, entropy_coef = 0.434, action_stds = 0.414 ± 0.129, action_magnitude = 0.729 ± 0.267, num_gradient_steps = 3467000, step_time = 11.60, total_time = 39729.34
#
# step = 3478000, num_env_steps = 3478000, scores = 13920.809, actor_loss = -1064.840, entropy_coef_loss = -0.321, critic_loss = 48.746, entropy_coef = 0.435, action_stds = 0.456 ± 0.123, action_magnitude = 0.735 ± 0.267, num_gradient_steps = 3468000, step_time = 11.64, total_time = 39740.98
#
# step = 3479000, num_env_steps = 3479000, scores = 14371.404, actor_loss = -1081.078, entropy_coef_loss = 0.371, critic_loss = 52.862, entropy_coef = 0.439, action_stds = 0.506 ± 0.056, action_magnitude = 0.731 ± 0.266, num_gradient_steps = 3469000, step_time = 11.61, total_time = 39752.58
#
# step = 3480000, num_env_steps = 3480000, scores = 13947.441, actor_loss = -1059.143, entropy_coef_loss = -0.306, critic_loss = 44.123, entropy_coef = 0.440, action_stds = 0.364 ± 0.170, action_magnitude = 0.730 ± 0.268, num_gradient_steps = 3470000, step_time = 11.58, total_time = 39764.17
# saved experiment log 2024-11-05_11-51-26_600853~Orhj1J at experiment_logs/HalfCheetah-v4/sac/2024-11-05_11-51-26_600853~Orhj1J.json
#
# step = 3481000, num_env_steps = 3481000, scores = 14391.397, actor_loss = -1068.170, entropy_coef_loss = -0.250, critic_loss = 37.323, entropy_coef = 0.437, action_stds = 0.474 ± 0.070, action_magnitude = 0.736 ± 0.264, num_gradient_steps = 3471000, step_time = 11.90, total_time = 39776.07
#
# step = 3482000, num_env_steps = 3482000, scores = 14642.701, actor_loss = -1084.970, entropy_coef_loss = -0.176, critic_loss = 42.248, entropy_coef = 0.429, action_stds = 0.326 ± 0.207, action_magnitude = 0.730 ± 0.268, num_gradient_steps = 3472000, step_time = 11.52, total_time = 39787.59
#
# step = 3483000, num_env_steps = 3483000, scores = 14577.842, actor_loss = -1080.287, entropy_coef_loss = 0.149, critic_loss = 599.179, entropy_coef = 0.440, action_stds = 0.462 ± 0.067, action_magnitude = 0.737 ± 0.265, num_gradient_steps = 3473000, step_time = 11.59, total_time = 39799.18
#
# step = 3484000, num_env_steps = 3484000, scores = 14335.663, actor_loss = -1067.876, entropy_coef_loss = -0.052, critic_loss = 43.897, entropy_coef = 0.434, action_stds = 0.349 ± 0.230, action_magnitude = 0.733 ± 0.269, num_gradient_steps = 3474000, step_time = 11.41, total_time = 39810.59
#
# step = 3485000, num_env_steps = 3485000, scores = 14590.825, actor_loss = -1068.163, entropy_coef_loss = -0.027, critic_loss = 42.361, entropy_coef = 0.430, action_stds = 0.487 ± 0.059, action_magnitude = 0.724 ± 0.270, num_gradient_steps = 3475000, step_time = 11.58, total_time = 39822.16
#
# step = 3486000, num_env_steps = 3486000, scores = 14430.440, actor_loss = -1089.138, entropy_coef_loss = 0.282, critic_loss = 68.188, entropy_coef = 0.428, action_stds = 0.391 ± 0.163, action_magnitude = 0.734 ± 0.268, num_gradient_steps = 3476000, step_time = 11.56, total_time = 39833.73
#
# step = 3487000, num_env_steps = 3487000, scores = 14513.055, actor_loss = -1069.831, entropy_coef_loss = 0.086, critic_loss = 42.482, entropy_coef = 0.427, action_stds = 0.524 ± 0.050, action_magnitude = 0.729 ± 0.269, num_gradient_steps = 3477000, step_time = 11.55, total_time = 39845.28
#
# step = 3488000, num_env_steps = 3488000, scores = 14659.785, actor_loss = -1059.838, entropy_coef_loss = -0.131, critic_loss = 71.491, entropy_coef = 0.443, action_stds = 0.369 ± 0.177, action_magnitude = 0.732 ± 0.268, num_gradient_steps = 3478000, step_time = 11.53, total_time = 39856.81
#
# step = 3489000, num_env_steps = 3489000, scores = 14334.015, actor_loss = -1078.162, entropy_coef_loss = 0.343, critic_loss = 67.479, entropy_coef = 0.441, action_stds = 0.439 ± 0.075, action_magnitude = 0.734 ± 0.261, num_gradient_steps = 3479000, step_time = 11.57, total_time = 39868.38
#
# step = 3490000, num_env_steps = 3490000, scores = 14603.131, actor_loss = -1058.714, entropy_coef_loss = 0.025, critic_loss = 59.452, entropy_coef = 0.434, action_stds = 0.387 ± 0.151, action_magnitude = 0.728 ± 0.267, num_gradient_steps = 3480000, step_time = 11.56, total_time = 39879.94
# saved experiment log 2024-11-05_11-51-26_600853~Orhj1J at experiment_logs/HalfCheetah-v4/sac/2024-11-05_11-51-26_600853~Orhj1J.json
#
# step = 3491000, num_env_steps = 3491000, scores = 14440.428, actor_loss = -1084.230, entropy_coef_loss = -0.141, critic_loss = 53.192, entropy_coef = 0.440, action_stds = 0.411 ± 0.161, action_magnitude = 0.731 ± 0.270, num_gradient_steps = 3481000, step_time = 11.91, total_time = 39891.85
#
# step = 3492000, num_env_steps = 3492000, scores = 14347.626, actor_loss = -1099.306, entropy_coef_loss = 0.123, critic_loss = 72.293, entropy_coef = 0.437, action_stds = 0.472 ± 0.063, action_magnitude = 0.731 ± 0.268, num_gradient_steps = 3482000, step_time = 11.53, total_time = 39903.38
#
# step = 3493000, num_env_steps = 3493000, scores = 14345.247, actor_loss = -1088.249, entropy_coef_loss = 0.122, critic_loss = 43.327, entropy_coef = 0.435, action_stds = 0.294 ± 0.153, action_magnitude = 0.727 ± 0.270, num_gradient_steps = 3483000, step_time = 11.55, total_time = 39914.93
#
# step = 3494000, num_env_steps = 3494000, scores = 14504.835, actor_loss = -1075.688, entropy_coef_loss = -0.127, critic_loss = 51.173, entropy_coef = 0.445, action_stds = 0.400 ± 0.160, action_magnitude = 0.729 ± 0.269, num_gradient_steps = 3484000, step_time = 11.49, total_time = 39926.42
#
# step = 3495000, num_env_steps = 3495000, scores = 14573.447, actor_loss = -1067.691, entropy_coef_loss = 0.224, critic_loss = 56.406, entropy_coef = 0.435, action_stds = 0.317 ± 0.194, action_magnitude = 0.735 ± 0.267, num_gradient_steps = 3485000, step_time = 11.55, total_time = 39937.96
#
# step = 3496000, num_env_steps = 3496000, scores = 14716.383, actor_loss = -1080.506, entropy_coef_loss = -0.382, critic_loss = 29.825, entropy_coef = 0.430, action_stds = 0.414 ± 0.163, action_magnitude = 0.731 ± 0.271, num_gradient_steps = 3486000, step_time = 11.53, total_time = 39949.49
#
# step = 3497000, num_env_steps = 3497000, scores = 14361.938, actor_loss = -1064.645, entropy_coef_loss = 0.290, critic_loss = 73.046, entropy_coef = 0.430, action_stds = 0.397 ± 0.139, action_magnitude = 0.731 ± 0.272, num_gradient_steps = 3487000, step_time = 11.57, total_time = 39961.06
#
# step = 3498000, num_env_steps = 3498000, scores = 7511.186, actor_loss = -1080.381, entropy_coef_loss = -0.171, critic_loss = 71.163, entropy_coef = 0.444, action_stds = 0.736 ± 0.091, action_magnitude = 0.634 ± 0.298, num_gradient_steps = 3488000, step_time = 11.53, total_time = 39972.59
#
# step = 3499000, num_env_steps = 3499000, scores = 13988.860, actor_loss = -1075.622, entropy_coef_loss = -0.313, critic_loss = 46.295, entropy_coef = 0.442, action_stds = 0.314 ± 0.194, action_magnitude = 0.738 ± 0.266, num_gradient_steps = 3489000, step_time = 11.57, total_time = 39984.16
#
# step = 3500000, num_env_steps = 3500000, scores = 14629.373, actor_loss = -1056.190, entropy_coef_loss = -0.269, critic_loss = 46.785, entropy_coef = 0.433, action_stds = 0.381 ± 0.179, action_magnitude = 0.731 ± 0.270, num_gradient_steps = 3490000, step_time = 11.58, total_time = 39995.74
# saved experiment log 2024-11-05_11-51-26_600853~Orhj1J at experiment_logs/HalfCheetah-v4/sac/2024-11-05_11-51-26_600853~Orhj1J.json
#
# saved experiment log 2024-11-05_11-51-26_600853~Orhj1J at experiment_logs/HalfCheetah-v4/sac/2024-11-05_11-51-26_600853~Orhj1J.json
# closing envs
# envs closed
# done
