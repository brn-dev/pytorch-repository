# %%
import inspect
import os
import time
from pathlib import Path

import gymnasium
from gymnasium import Env
from gymnasium.vector import VectorEnv

from sac import init_action_selector, init_policy, init_optimizer, wrap_env, policy_construction_hyper_parameter
from src.datetime import get_current_timestamp
from src.experiment_logging.experiment_logger import ExperimentLogger, log_experiment
from src.model_db.model_db import ModelDB
from src.model_db.dummy_model_db import DummyModelDB
from src.np_functions import inv_symmetric_log
from src.reinforcement_learning.algorithms.policy_mitosis.mitosis_policy_info import MitosisPolicyInfo
from src.model_db.tiny_model_db import TinyModelDB
from src.module_analysis import count_parameters, get_gradients_per_parameter
from src.moving_averages import ExponentialMovingAverage
from src.reinforcement_learning.core.action_selectors.action_selector import ActionSelector
from src.reinforcement_learning.core.action_selectors.predicted_std_action_selector import PredictedStdActionSelector
from src.reinforcement_learning.core.action_selectors.state_dependent_noise_action_selector import \
    StateDependentNoiseActionSelector
from src.reinforcement_learning.core.generalized_advantage_estimate import compute_episode_returns, compute_returns
from src.reinforcement_learning.core.policies.base_policy import BasePolicy
from src.reinforcement_learning.core.policy_construction import InitActionSelectorFunction, PolicyConstruction
from src.reinforcement_learning.gym.envs.test_env import TestEnv
from src.schedulers import FixedValueScheduler, OneStepRecursiveScheduler
from src.stopwatch import Stopwatch
from src.summary_statistics import format_summary_statics
from src.reinforcement_learning.core.policies.actor_critic_policy import ActorCriticPolicy
from typing import Any, SupportsFloat, Optional
from gymnasium.wrappers import RecordVideo, AutoResetWrapper, NormalizeReward, TransformReward, TransformObservation, ClipAction
from src.reinforcement_learning.core.callback import Callback
from src.reinforcement_learning.algorithms.sac.sac import SAC, SAC_DEFAULT_OPTIMIZER_PROVIDER
from src.reinforcement_learning.algorithms.ppo.ppo import PPO, PPOLoggingConfig
from src.reinforcement_learning.core.normalization import NormalizationType
from src.torch_device import set_default_torch_device, optimizer_to_device
from src.reinforcement_learning.gym.parallelize_env import parallelize_env_async
from torch.distributions import Normal, Categorical

import torch
from torch import optim, nn
import torch.distributions as dist
import gymnasium as gym
import numpy as np

from src.torch_functions import antisymmetric_power

# %load_ext autoreload
# %autoreload 2
# Out:
# pygame 2.5.2 (SDL 2.28.3, Python 3.11.7)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
from src.summary_statistics import maybe_compute_summary_statistics
from src.reinforcement_learning.core.loss_config import LossLoggingConfig
from src.reinforcement_learning.algorithms.sac.sac import SAC, SACLoggingConfig
def get_setup() -> dict[str, str]:
    import inspect
    import sac
    return {
        'sac.py': inspect.getsource(sac),
        'notebook': _ih[1] + '\n\n' + _ih[-1], # first and last cell input (imports and this cell)
    }

policy_id: str
policy: BasePolicy
optimizer: optim.Optimizer
wrapped_env: Env
steps_trained: int
def get_policy(create_new_if_exists: bool):
    
    global policy_id, policy, optimizer, wrapped_env, steps_trained
    
    policy_in_ram = 'policy' in globals()
    if not policy_in_ram or create_new_if_exists:
        if not policy_in_ram:
            print('No policy in RAM, creating a new one')
        
        policy_id = get_current_timestamp()
        policy, optimizer, wrapped_env = PolicyConstruction.init_from_info(
            env=env,
            info=PolicyConstruction.create_policy_initialization_info(
                init_action_selector=init_action_selector,
                init_policy=init_policy,
                init_optimizer=init_optimizer,
                wrap_env=wrap_env,
                hyper_parameters=policy_construction_hyper_parameter,
            ),
        )
        steps_trained = 0
        print(f'New policy {policy_id} created')
    
    if parent_policy_id is not None:
        model_entry = policy_db.load_model_state_dict(policy, parent_policy_id)
        steps_trained = model_entry['model_info']['steps_trained']
        print(f'Loading state dict from policy {parent_policy_id}')
    
    print(f'Using policy {policy_id} with parent policy {parent_policy_id}')
    return policy_id, policy, optimizer, wrapped_env, steps_trained

score_mean_ema = ExponentialMovingAverage(alpha=0.25)
step_stopwatch = Stopwatch()
total_stopwatch = Stopwatch()
best_iteration_score = -1e6

def on_rollout_done(rl: SAC, step: int, info: dict[str, Any], scheduler_values: dict[str, Any]):
    
    if step % 1000 != 0:
        return
    
    tail_indices = rl.buffer.tail_indices(1000)
    
    # rewards = rl.buffer.rewards[tail_indices]
    # if 'raw_rewards' in info['rollout']:
    #     rewards = info['rollout']['raw_rewards']
    
    # episode_scores = compute_episode_returns(
    #     rewards=rewards,
    #     episode_starts=np.repeat(np.arange(len(tail_indices)).reshape(-1, 1), num_envs, axis=1) % 1000 == 0,
    #     last_episode_starts=info['last_episode_starts'],
    #     gamma=1.0,
    #     gae_lambda=1.0,
    #     normalize_rewards=None,
    #     remove_unfinished_episodes=True,
    # )
    
    episode_scores = rl.buffer.compute_most_recent_episode_scores(rl.num_envs)
    
    if len(episode_scores) > 0:
    
        global best_iteration_score
        iteration_score = episode_scores.mean()
        score_moving_average = score_mean_ema.update(iteration_score)
        if iteration_score >= best_iteration_score:
            best_iteration_score = iteration_score
            policy_db.save_model_state_dict(
                model_id=policy_id,
                parent_model_id=parent_policy_id,
                model_info={
                    'score': iteration_score.item(),
                    'steps_trained': steps_trained,
                    'wrap_env_source_code': wrap_env_source_code_source,
                    'init_policy_source_code': init_policy_source
                },
                model=policy,
                optimizer=optimizer,
            )
        info['score_moving_average'] = score_moving_average
    
    info['episode_scores'] = episode_scores
        
def on_optimization_done(rl: SAC, step: int, info: dict[str, Any], scheduler_values: dict[str, Any]):
    # global steps_trained
    # steps_trained += rl.buffer.pos
    
    if step % 1000 != 0:
        return
    num_env_steps = step * rl.num_envs
    
    step_time = step_stopwatch.reset()
    total_time = total_stopwatch.time_passed()
    
    tail_indices = rl.buffer.tail_indices(1000)
    
    episode_scores = info.get('episode_scores')
    score_moving_average = info.get('score_moving_average') or 0.0
    
    scores = format_summary_statics(
        episode_scores, 
        mean_format=' 6.3f',
        std_format='4.3f',
        min_value_format=' 6.3f',
        max_value_format='5.3f',
        n_format='>2'
    )
    # scores2 = format_summary_statics(
    #     rl.buffer.compute_most_recent_episode_scores(rl.num_envs, lambda r: 1 * r), 
    #     mean_format=' 6.3f',
    #     std_format='4.3f',
    #     min_value_format=' 6.3f',
    #     max_value_format='5.3f',
    #     n_format='>2'
    # )
    # advantages = format_summary_statics(
    #     rl.buffer.advantages, 
    #     mean_format=' 6.3f',
    #     std_format='.1f',
    #     min_value_format=' 7.3f',
    #     max_value_format='6.3f',
    # )
    actor_loss = format_summary_statics(
        info['final_actor_loss'],  
        mean_format=' 5.3f',
        # std_format='5.3f',
        std_format=None,
        min_value_format=None,
        max_value_format=None,
    )
    # actor_loss_raw = format_summary_statics(
    #     info['raw_actor_loss'],  
    #     mean_format=' 5.3f',
    #     std_format='5.3f',
    #     min_value_format=None,
    #     max_value_format=None,
    # )
    entropy_coef_loss = None if 'final_entropy_coef_loss' not in info else format_summary_statics(
        info['final_entropy_coef_loss'], 
        mean_format='5.3f',
#         std_format='5.3f',
        std_format=None,
        min_value_format=None,
        max_value_format=None,
    )
    critic_loss = format_summary_statics(
        info['final_critic_loss'], 
        mean_format='5.3f',
#         std_format='5.3f',
        std_format=None,
        min_value_format=None,
        max_value_format=None,
    )
    entropy_coef = format_summary_statics(
        info['entropy_coef'],
        mean_format='5.3f',
#         std_format='5.3f',
        std_format=None,
        min_value_format=None,
        max_value_format=None,
    )
    # resets = format_summary_statics(
    #     rl.buffer.dones.astype(int).sum(axis=0), 
    #     mean_format='.2f',
    #     std_format=None,
    #     min_value_format='1d',
    #     max_value_format=None,
    # )
    # kl_div = info['actor_kl_divergence'][-1]
    # grad_norm = format_summary_statics(
    #     info['grad_norm'], 
    #     mean_format=' 6.3f',
    #     std_format='.1f',
    #     min_value_format=' 7.3f',
    #     max_value_format='6.3f',
    # )
    action_stds = info['rollout'].get('action_stds')
    if action_stds is not None:
        rollout_action_stds = format_summary_statics(
            action_stds,
            mean_format='5.3f',
            std_format='5.3f',
            min_value_format=None,
            max_value_format=None,
        )
    else:
        rollout_action_stds = 'N/A'
    action_magnitude = format_summary_statics(
        np.abs(rl.buffer.actions[tail_indices]),
        mean_format='5.3f',
        std_format='5.3f',
        min_value_format=None,
        max_value_format=None,
    )
    # ppo_epochs = info['nr_ppo_epochs']
    # ppo_updates = info['nr_ppo_updates']
    # expl_var = rl.buffer.compute_critic_explained_variance()
    print(f"{step = : >7}, "
          f"{num_env_steps = : >7}, "
          f"{scores = :s}, "
          # f"{scores2 = :s}, "
          f'score_ema = {score_moving_average: 6.3f}, '
          # f"{advantages = :s}, "
          f"{actor_loss = :s}, "
          # f"{actor_loss_raw = :s}, "
          f"{critic_loss = :s}, "
          +(f"{entropy_coef_loss = :s}, " if entropy_coef_loss is not None else '')+
          f"{entropy_coef = :s}, "
          f"rollout_stds = {rollout_action_stds:s}, "
          f"{action_magnitude = :s}, "
          # f"{expl_var = :.3f}, "
          # f"{kl_div = :.4f}, "
          # f"{ppo_epochs = }, "
          # f"{ppo_updates = }, "
          # f"{grad_norm = :s}, "
          f"n_updates = {rl.gradient_steps_performed}, "
          # f"{resets = :s}, "
          f"time = {step_time:4.1f}, "
          f"total_time = {total_time:4.1f} \n"
          )
    logger.add_item({
        'step': step,
        'num_env_steps': num_env_steps,
        'scores': maybe_compute_summary_statistics(episode_scores),
        'actor_loss': maybe_compute_summary_statistics(info['final_actor_loss']),
        'entropy_coef_loss': maybe_compute_summary_statistics(info.get('final_entropy_coef_loss')),
        'critic_loss': maybe_compute_summary_statistics(info['final_critic_loss']),
        'entropy_coef': maybe_compute_summary_statistics(info['entropy_coef']),
        'action_stds': maybe_compute_summary_statistics(action_stds),
        'action_magnitude': maybe_compute_summary_statistics(np.abs(rl.buffer.actions[tail_indices])),
        'num_gradient_steps': rl.gradient_steps_performed,
        'step_time': step_time,
        'total_time': total_time
    })
    if step % 10000 == 0:
        logger.save_experiment_log()
        print()
    print()
    
    # if episode_scores is not None and len(episode_scores) > 0 and episode_scores.mean().item() < -500:
    #     logger.save_experiment_log()
    #     raise ValueError('Score too low, policy probably fucked :(')

device = torch.device("cuda:0") if True else torch.device('cpu')
print(f'using device {device}')

def create_env(render_mode: str | None):
    return gym.make(env_name, render_mode=render_mode, **env_kwargs)

wrap_env_source_code_source = inspect.getsource(wrap_env)
init_policy_source = inspect.getsource(init_policy)

env_name = 'HalfCheetah-v4'
# env_kwargs = {'forward_reward_weight': 1.25, 'healthy_reward': 0.5, 'ctrl_cost_weight': 0.001 }
# env_kwargs = {'forward_reward_weight': 1.25, 'ctrl_cost_weight': 0.1 }
# env_kwargs = {'forward_reward_weight': 1.25, 'ctrl_cost_weight': 0.05 }
env_kwargs = {}
num_envs = 1
    
# policy_db = TinyModelDB[MitosisPolicyInfo](base_path=f'saved_models/rl/{env_name}')
policy_db = DummyModelDB[MitosisPolicyInfo]()
print(f'{policy_db = }')

parent_policy_id=None  # '2024-04-28_20.57.23'

# TODO
# env = parallelize_env_async(lambda: create_env(render_mode=None), num_envs)
env = create_env(render_mode=None)

logger = ExperimentLogger(f'experiment_logs/{env_name}/sac/')

try:
    policy_id, policy, optimizer, wrapped_env, steps_trained = get_policy(create_new_if_exists=False)
    print(f'{count_parameters(policy) = }')
    print(f'{env = }, {num_envs = }')
        
    with ((torch.autograd.set_detect_anomaly(False))):
        algo = SAC(
            env=wrapped_env,
            policy=policy,
            actor_optimizer_provider=lambda params: optim.Adam(params, lr=3e-4),  # (params, lr=3e-4, betas=(0.5, 0.999)),
            critic_optimizer_provider=lambda params: optim.Adam(params, lr=3e-4),  # (params, lr=3e-4, betas=(0.5, 0.999)),
            # weigh_and_reduce_actor_loss=lambda l: 1 * l.mean(),
            # weigh_critic_loss=lambda l: 1 * l,
            buffer_size=1_000_000,
            reward_scale=1,
            gamma=0.99,
            tau=0.005,
            entropy_coef_optimizer_provider=lambda params: optim.Adam(params, lr=3e-4),
            entropy_coef=1.0,
            rollout_steps=1,
            gradient_steps=1,
            warmup_steps=10_000,
            optimization_batch_size=256,
            target_update_interval=1,
            # sde_noise_sample_freq=50,
            callback=Callback(
                on_rollout_done=on_rollout_done,
                rollout_schedulers={},
                on_optimization_done=on_optimization_done,
                optimization_schedulers={},
            ),
            logging_config=SACLoggingConfig(log_rollout_infos=True, log_rollout_action_stds=True,
                                            log_last_obs=True, log_entropy_coef=True,
                                            entropy_coef_loss=LossLoggingConfig(log_final=True),
                                            actor_loss=LossLoggingConfig(log_final=True, log_raw=True),
                                            critic_loss=LossLoggingConfig(log_final=True)),
            torch_device=device,
        )
        total_stopwatch.reset()
        with log_experiment(
            logger,
            experiment_tags=algo.collect_tags(),
            hyper_parameters=algo.collect_hyper_parameters(),
            setup=get_setup(),
        ) as x:
            logger.save_experiment_log()
            print('\nStarting Training\n\n')
            # import cProfile
            # pr = cProfile.Profile()
            # pr.enable()
            algo.learn(5_000_000)
            # pr.disable()  
            # pr.dump_stats('profile_stats.pstat')
except KeyboardInterrupt:
    print('keyboard interrupt')
finally:
    print('closing envs')
    time.sleep(0.5)
    env.close()
    print('envs closed')
    policy_db.close()
    print('model db closed')
    

print('done')
# Out:
# using device cuda:0
# policy_db = DummyModelDB()
# No policy in RAM, creating a new one
# New policy 2024-10-10 19:36:32.078213 created
# Using policy 2024-10-10 19:36:32.078213 with parent policy None
# count_parameters(policy) = 217870
# env = <TimeLimit<OrderEnforcing<PassiveEnvChecker<HalfCheetahEnv<HalfCheetah-v4>>>>>, num_envs = 1
# Grabbing system information... done!
# saved experiment log 2024-10-10_19-36-32_501308~7W3lI0 at experiment_logs/HalfCheetah-v4/sac/2024-10-10_19-36-32_501308~7W3lI0.json
#
# Starting Training
#
# step =   11000, num_env_steps =   11000, scores = -96.378 (n= 1), score_ema = -228.581, actor_loss = -18.034, critic_loss = 0.867, entropy_coef_loss = -2.981, entropy_coef = 0.741, rollout_stds = 0.937 ± 0.031, action_magnitude = 0.529 ± 0.289, n_updates = 1000, time = 13.9, total_time = 13.5
#
# step =   12000, num_env_steps =   12000, scores = -248.042 (n= 1), score_ema = -233.446, actor_loss = -25.821, critic_loss = 1.132, entropy_coef_loss = -6.025, entropy_coef = 0.549, rollout_stds = 0.953 ± 0.027, action_magnitude = 0.536 ± 0.291, n_updates = 2000, time = 10.5, total_time = 24.0
#
# step =   13000, num_env_steps =   13000, scores = -234.491 (n= 1), score_ema = -233.707, actor_loss = -30.076, critic_loss = 1.139, entropy_coef_loss = -8.893, entropy_coef = 0.407, rollout_stds = 0.920 ± 0.039, action_magnitude = 0.534 ± 0.289, n_updates = 3000, time = 12.5, total_time = 36.5
#
# step =   14000, num_env_steps =   14000, scores = -191.423 (n= 1), score_ema = -223.136, actor_loss = -33.323, critic_loss = 1.090, entropy_coef_loss = -11.479, entropy_coef = 0.302, rollout_stds = 0.917 ± 0.027, action_magnitude = 0.547 ± 0.290, n_updates = 4000, time = 13.4, total_time = 49.9
#
# step =   15000, num_env_steps =   15000, scores = -254.037 (n= 1), score_ema = -230.861, actor_loss = -34.575, critic_loss = 1.296, entropy_coef_loss = -13.988, entropy_coef = 0.226, rollout_stds = 0.900 ± 0.048, action_magnitude = 0.557 ± 0.290, n_updates = 5000, time = 11.5, total_time = 61.4
#
# step =   16000, num_env_steps =   16000, scores = -161.005 (n= 1), score_ema = -213.397, actor_loss = -34.302, critic_loss = 1.255, entropy_coef_loss = -15.704, entropy_coef = 0.169, rollout_stds = 0.909 ± 0.032, action_magnitude = 0.552 ± 0.292, n_updates = 6000, time = 11.0, total_time = 72.3
#
# step =   17000, num_env_steps =   17000, scores = -163.625 (n= 1), score_ema = -200.954, actor_loss = -34.064, critic_loss = 1.197, entropy_coef_loss = -16.435, entropy_coef = 0.128, rollout_stds = 0.897 ± 0.095, action_magnitude = 0.566 ± 0.294, n_updates = 7000, time = 13.8, total_time = 86.2
#
# step =   18000, num_env_steps =   18000, scores = -273.264 (n= 1), score_ema = -219.032, actor_loss = -33.538, critic_loss = 1.130, entropy_coef_loss = -17.115, entropy_coef = 0.097, rollout_stds = 0.841 ± 0.080, action_magnitude = 0.579 ± 0.294, n_updates = 8000, time = 12.4, total_time = 98.5
#
# step =   19000, num_env_steps =   19000, scores = -294.091 (n= 1), score_ema = -237.797, actor_loss = -32.762, critic_loss = 1.930, entropy_coef_loss = -17.366, entropy_coef = 0.074, rollout_stds = 0.826 ± 0.111, action_magnitude = 0.607 ± 0.296, n_updates = 9000, time = 12.6, total_time = 111.2
#
# step =   20000, num_env_steps =   20000, scores = -507.208 (n= 1), score_ema = -305.149, actor_loss = -31.270, critic_loss = 1.402, entropy_coef_loss = -18.486, entropy_coef = 0.056, rollout_stds = 0.663 ± 0.089, action_magnitude = 0.607 ± 0.294, n_updates = 10000, time = 12.8, total_time = 124.0
#
# saved experiment log 2024-10-10_19-36-32_501308~7W3lI0 at experiment_logs/HalfCheetah-v4/sac/2024-10-10_19-36-32_501308~7W3lI0.json
#
# step =   21000, num_env_steps =   21000, scores = -269.435 (n= 1), score_ema = -296.221, actor_loss = -29.183, critic_loss = 1.563, entropy_coef_loss = -18.647, entropy_coef = 0.043, rollout_stds = 0.618 ± 0.082, action_magnitude = 0.587 ± 0.295, n_updates = 11000, time = 11.8, total_time = 135.8
#
# step =   22000, num_env_steps =   22000, scores = -205.704 (n= 1), score_ema = -273.592, actor_loss = -28.805, critic_loss = 1.606, entropy_coef_loss = -15.965, entropy_coef = 0.033, rollout_stds = 0.596 ± 0.112, action_magnitude = 0.578 ± 0.299, n_updates = 12000, time = 11.5, total_time = 147.3
#
# step =   23000, num_env_steps =   23000, scores = -87.279 (n= 1), score_ema = -227.013, actor_loss = -26.457, critic_loss = 1.526, entropy_coef_loss = -14.973, entropy_coef = 0.025, rollout_stds = 0.616 ± 0.087, action_magnitude = 0.610 ± 0.301, n_updates = 13000, time = 11.8, total_time = 159.1
#
# step =   24000, num_env_steps =   24000, scores = -18.692 (n= 1), score_ema = -174.933, actor_loss = -25.252, critic_loss = 1.326, entropy_coef_loss = -14.040, entropy_coef = 0.020, rollout_stds = 0.512 ± 0.091, action_magnitude = 0.605 ± 0.298, n_updates = 14000, time = 12.5, total_time = 171.6
#
# step =   25000, num_env_steps =   25000, scores =  237.938 (n= 1), score_ema = -71.715, actor_loss = -25.354, critic_loss = 1.206, entropy_coef_loss = -11.947, entropy_coef = 0.016, rollout_stds = 0.450 ± 0.122, action_magnitude = 0.620 ± 0.301, n_updates = 15000, time = 11.7, total_time = 183.3
#
# step =   26000, num_env_steps =   26000, scores =  134.378 (n= 1), score_ema = -20.192, actor_loss = -24.141, critic_loss = 1.125, entropy_coef_loss = -9.787, entropy_coef = 0.013, rollout_stds = 0.457 ± 0.102, action_magnitude = 0.623 ± 0.300, n_updates = 16000, time = 12.2, total_time = 195.4
#
# step =   27000, num_env_steps =   27000, scores =  473.982 (n= 1), score_ema =  103.351, actor_loss = -23.709, critic_loss = 1.180, entropy_coef_loss = -4.881, entropy_coef = 0.010, rollout_stds = 0.451 ± 0.134, action_magnitude = 0.656 ± 0.300, n_updates = 17000, time = 11.1, total_time = 206.5
#
# step =   28000, num_env_steps =   28000, scores =  91.946 (n= 1), score_ema =  100.500, actor_loss = -23.702, critic_loss = 1.242, entropy_coef_loss = -0.125, entropy_coef = 0.009, rollout_stds = 0.502 ± 0.115, action_magnitude = 0.646 ± 0.301, n_updates = 18000, time = 11.3, total_time = 217.8
#
# step =   29000, num_env_steps =   29000, scores =  860.539 (n= 1), score_ema =  290.510, actor_loss = -21.642, critic_loss = 1.027, entropy_coef_loss = -0.079, entropy_coef = 0.009, rollout_stds = 0.310 ± 0.099, action_magnitude = 0.698 ± 0.300, n_updates = 19000, time = 10.0, total_time = 227.8
#
# step =   30000, num_env_steps =   30000, scores =  1611.907 (n= 1), score_ema =  620.859, actor_loss = -24.391, critic_loss = 1.498, entropy_coef_loss = 3.276, entropy_coef = 0.010, rollout_stds = 0.293 ± 0.131, action_magnitude = 0.770 ± 0.287, n_updates = 20000, time = 10.3, total_time = 238.1
#
# saved experiment log 2024-10-10_19-36-32_501308~7W3lI0 at experiment_logs/HalfCheetah-v4/sac/2024-10-10_19-36-32_501308~7W3lI0.json
#
# step =   31000, num_env_steps =   31000, scores =  1449.605 (n= 1), score_ema =  828.045, actor_loss = -24.167, critic_loss = 1.342, entropy_coef_loss = -2.659, entropy_coef = 0.012, rollout_stds = 0.403 ± 0.131, action_magnitude = 0.775 ± 0.282, n_updates = 21000, time = 12.4, total_time = 250.4
#
# step =   32000, num_env_steps =   32000, scores =  1421.797 (n= 1), score_ema =  976.483, actor_loss = -27.006, critic_loss = 1.555, entropy_coef_loss = 0.338, entropy_coef = 0.014, rollout_stds = 0.292 ± 0.118, action_magnitude = 0.775 ± 0.280, n_updates = 22000, time = 12.1, total_time = 262.5
#
# step =   33000, num_env_steps =   33000, scores =  1368.203 (n= 1), score_ema =  1074.413, actor_loss = -28.947, critic_loss = 2.446, entropy_coef_loss = -0.016, entropy_coef = 0.015, rollout_stds = 0.339 ± 0.103, action_magnitude = 0.754 ± 0.288, n_updates = 23000, time = 12.6, total_time = 275.1
#
# step =   34000, num_env_steps =   34000, scores =  1662.474 (n= 1), score_ema =  1221.429, actor_loss = -32.296, critic_loss = 2.913, entropy_coef_loss = 3.473, entropy_coef = 0.016, rollout_stds = 0.393 ± 0.081, action_magnitude = 0.755 ± 0.289, n_updates = 24000, time = 12.4, total_time = 287.5
#
# step =   35000, num_env_steps =   35000, scores =  603.860 (n= 1), score_ema =  1067.037, actor_loss = -31.267, critic_loss = 3.633, entropy_coef_loss = 1.033, entropy_coef = 0.018, rollout_stds = 0.379 ± 0.096, action_magnitude = 0.719 ± 0.295, n_updates = 25000, time = 11.3, total_time = 298.9
#
# step =   36000, num_env_steps =   36000, scores =  607.039 (n= 1), score_ema =  952.037, actor_loss = -32.124, critic_loss = 2.296, entropy_coef_loss = -1.926, entropy_coef = 0.019, rollout_stds = 0.443 ± 0.105, action_magnitude = 0.703 ± 0.294, n_updates = 26000, time = 11.6, total_time = 310.5
#
# step =   37000, num_env_steps =   37000, scores =  1637.446 (n= 1), score_ema =  1123.389, actor_loss = -36.936, critic_loss = 4.016, entropy_coef_loss = 1.030, entropy_coef = 0.019, rollout_stds = 0.331 ± 0.104, action_magnitude = 0.749 ± 0.287, n_updates = 27000, time = 12.9, total_time = 323.4
#
# step =   38000, num_env_steps =   38000, scores =  1965.289 (n= 1), score_ema =  1333.864, actor_loss = -38.449, critic_loss = 2.629, entropy_coef_loss = 1.058, entropy_coef = 0.021, rollout_stds = 0.508 ± 0.220, action_magnitude = 0.747 ± 0.287, n_updates = 28000, time = 12.2, total_time = 335.6
#
# step =   39000, num_env_steps =   39000, scores =  2164.891 (n= 1), score_ema =  1541.621, actor_loss = -39.248, critic_loss = 3.476, entropy_coef_loss = -0.285, entropy_coef = 0.022, rollout_stds = 0.311 ± 0.062, action_magnitude = 0.759 ± 0.285, n_updates = 29000, time = 12.7, total_time = 348.2
#
# step =   40000, num_env_steps =   40000, scores =  2215.003 (n= 1), score_ema =  1709.966, actor_loss = -44.312, critic_loss = 4.733, entropy_coef_loss = 2.821, entropy_coef = 0.024, rollout_stds = 0.447 ± 0.171, action_magnitude = 0.758 ± 0.286, n_updates = 30000, time = 11.3, total_time = 359.6
#
# saved experiment log 2024-10-10_19-36-32_501308~7W3lI0 at experiment_logs/HalfCheetah-v4/sac/2024-10-10_19-36-32_501308~7W3lI0.json
#
# step =   41000, num_env_steps =   41000, scores =  382.429 (n= 1), score_ema =  1378.082, actor_loss = -46.425, critic_loss = 3.463, entropy_coef_loss = 0.697, entropy_coef = 0.025, rollout_stds = 0.514 ± 0.056, action_magnitude = 0.665 ± 0.302, n_updates = 31000, time = 11.9, total_time = 371.5
#
# step =   42000, num_env_steps =   42000, scores =  2126.991 (n= 1), score_ema =  1565.309, actor_loss = -46.107, critic_loss = 3.090, entropy_coef_loss = -1.682, entropy_coef = 0.025, rollout_stds = 0.477 ± 0.160, action_magnitude = 0.756 ± 0.285, n_updates = 32000, time = 11.7, total_time = 383.2
#
# step =   43000, num_env_steps =   43000, scores =  2363.093 (n= 1), score_ema =  1764.755, actor_loss = -45.924, critic_loss = 3.964, entropy_coef_loss = 0.060, entropy_coef = 0.026, rollout_stds = 0.442 ± 0.143, action_magnitude = 0.756 ± 0.284, n_updates = 33000, time = 12.6, total_time = 395.8
#
# step =   44000, num_env_steps =   44000, scores =  2363.234 (n= 1), score_ema =  1914.375, actor_loss = -56.662, critic_loss = 4.354, entropy_coef_loss = 0.963, entropy_coef = 0.028, rollout_stds = 0.325 ± 0.140, action_magnitude = 0.763 ± 0.281, n_updates = 34000, time = 11.9, total_time = 407.7
#
# step =   45000, num_env_steps =   45000, scores =  2619.680 (n= 1), score_ema =  2090.701, actor_loss = -57.550, critic_loss = 4.717, entropy_coef_loss = 0.067, entropy_coef = 0.029, rollout_stds = 0.397 ± 0.168, action_magnitude = 0.767 ± 0.279, n_updates = 35000, time = 12.5, total_time = 420.2
#
# step =   46000, num_env_steps =   46000, scores =  2675.426 (n= 1), score_ema =  2236.882, actor_loss = -55.771, critic_loss = 4.383, entropy_coef_loss = -0.842, entropy_coef = 0.032, rollout_stds = 0.339 ± 0.107, action_magnitude = 0.767 ± 0.276, n_updates = 36000, time = 12.7, total_time = 432.9
#
# step =   47000, num_env_steps =   47000, scores =  1121.761 (n= 1), score_ema =  1958.102, actor_loss = -65.866, critic_loss = 5.137, entropy_coef_loss = 1.006, entropy_coef = 0.032, rollout_stds = 0.639 ± 0.170, action_magnitude = 0.708 ± 0.294, n_updates = 37000, time = 11.1, total_time = 444.0
#
# step =   48000, num_env_steps =   48000, scores =  2647.006 (n= 1), score_ema =  2130.328, actor_loss = -61.631, critic_loss = 8.607, entropy_coef_loss = 1.593, entropy_coef = 0.033, rollout_stds = 0.367 ± 0.127, action_magnitude = 0.764 ± 0.279, n_updates = 38000, time = 11.1, total_time = 455.1
#
# step =   49000, num_env_steps =   49000, scores =  2810.743 (n= 1), score_ema =  2300.432, actor_loss = -63.772, critic_loss = 4.037, entropy_coef_loss = -0.950, entropy_coef = 0.034, rollout_stds = 0.405 ± 0.116, action_magnitude = 0.770 ± 0.276, n_updates = 39000, time = 11.2, total_time = 466.3
#
# step =   50000, num_env_steps =   50000, scores =  2948.069 (n= 1), score_ema =  2462.341, actor_loss = -66.043, critic_loss = 4.838, entropy_coef_loss = -1.453, entropy_coef = 0.036, rollout_stds = 0.330 ± 0.134, action_magnitude = 0.764 ± 0.280, n_updates = 40000, time = 11.0, total_time = 477.3
#
# saved experiment log 2024-10-10_19-36-32_501308~7W3lI0 at experiment_logs/HalfCheetah-v4/sac/2024-10-10_19-36-32_501308~7W3lI0.json
#
# step =   51000, num_env_steps =   51000, scores =  2968.991 (n= 1), score_ema =  2589.004, actor_loss = -71.563, critic_loss = 5.422, entropy_coef_loss = -1.520, entropy_coef = 0.038, rollout_stds = 0.394 ± 0.132, action_magnitude = 0.770 ± 0.278, n_updates = 41000, time = 11.1, total_time = 488.4
#
# step =   52000, num_env_steps =   52000, scores =  2802.700 (n= 1), score_ema =  2642.428, actor_loss = -77.554, critic_loss = 5.858, entropy_coef_loss = 0.672, entropy_coef = 0.039, rollout_stds = 0.450 ± 0.108, action_magnitude = 0.773 ± 0.273, n_updates = 42000, time = 11.0, total_time = 499.4
#
# step =   53000, num_env_steps =   53000, scores =  3287.915 (n= 1), score_ema =  2803.800, actor_loss = -88.092, critic_loss = 6.669, entropy_coef_loss = 1.327, entropy_coef = 0.040, rollout_stds = 0.387 ± 0.131, action_magnitude = 0.774 ± 0.274, n_updates = 43000, time = 11.0, total_time = 510.5
#
# step =   54000, num_env_steps =   54000, scores =  3305.639 (n= 1), score_ema =  2929.259, actor_loss = -87.554, critic_loss = 4.090, entropy_coef_loss = 1.115, entropy_coef = 0.042, rollout_stds = 0.385 ± 0.090, action_magnitude = 0.775 ± 0.270, n_updates = 44000, time = 11.0, total_time = 521.5
#
# step =   55000, num_env_steps =   55000, scores =  2916.929 (n= 1), score_ema =  2926.177, actor_loss = -87.548, critic_loss = 7.029, entropy_coef_loss = 0.413, entropy_coef = 0.044, rollout_stds = 0.432 ± 0.172, action_magnitude = 0.775 ± 0.271, n_updates = 45000, time = 11.1, total_time = 532.6
#
# step =   56000, num_env_steps =   56000, scores =  3232.955 (n= 1), score_ema =  3002.871, actor_loss = -89.715, critic_loss = 7.043, entropy_coef_loss = -0.155, entropy_coef = 0.045, rollout_stds = 0.380 ± 0.121, action_magnitude = 0.777 ± 0.270, n_updates = 46000, time = 11.0, total_time = 543.6
#
# step =   57000, num_env_steps =   57000, scores =  3217.601 (n= 1), score_ema =  3056.554, actor_loss = -93.001, critic_loss = 7.171, entropy_coef_loss = -0.616, entropy_coef = 0.046, rollout_stds = 0.335 ± 0.100, action_magnitude = 0.783 ± 0.266, n_updates = 47000, time = 11.0, total_time = 554.6
#
# step =   58000, num_env_steps =   58000, scores =  3549.151 (n= 1), score_ema =  3179.703, actor_loss = -97.185, critic_loss = 4.704, entropy_coef_loss = -1.032, entropy_coef = 0.047, rollout_stds = 0.389 ± 0.093, action_magnitude = 0.779 ± 0.268, n_updates = 48000, time = 11.1, total_time = 565.7
#
# step =   59000, num_env_steps =   59000, scores =  3699.505 (n= 1), score_ema =  3309.654, actor_loss = -96.166, critic_loss = 5.402, entropy_coef_loss = -1.129, entropy_coef = 0.049, rollout_stds = 0.371 ± 0.104, action_magnitude = 0.778 ± 0.267, n_updates = 49000, time = 11.0, total_time = 576.7
#
# step =   60000, num_env_steps =   60000, scores =  3703.205 (n= 1), score_ema =  3408.041, actor_loss = -109.434, critic_loss = 6.289, entropy_coef_loss = 0.081, entropy_coef = 0.050, rollout_stds = 0.364 ± 0.136, action_magnitude = 0.782 ± 0.264, n_updates = 50000, time = 11.0, total_time = 587.7
#
# saved experiment log 2024-10-10_19-36-32_501308~7W3lI0 at experiment_logs/HalfCheetah-v4/sac/2024-10-10_19-36-32_501308~7W3lI0.json
#
# step =   61000, num_env_steps =   61000, scores =  1819.644 (n= 1), score_ema =  3010.942, actor_loss = -105.498, critic_loss = 6.998, entropy_coef_loss = -1.280, entropy_coef = 0.053, rollout_stds = 0.614 ± 0.069, action_magnitude = 0.738 ± 0.285, n_updates = 51000, time = 11.0, total_time = 598.7
#
# step =   62000, num_env_steps =   62000, scores =  3831.674 (n= 1), score_ema =  3216.125, actor_loss = -106.600, critic_loss = 6.175, entropy_coef_loss = 1.149, entropy_coef = 0.053, rollout_stds = 0.362 ± 0.091, action_magnitude = 0.783 ± 0.264, n_updates = 52000, time = 11.0, total_time = 609.7
#
# step =   63000, num_env_steps =   63000, scores =  2589.324 (n= 1), score_ema =  3059.425, actor_loss = -116.245, critic_loss = 8.391, entropy_coef_loss = -1.319, entropy_coef = 0.054, rollout_stds = 0.675 ± 0.111, action_magnitude = 0.759 ± 0.278, n_updates = 53000, time = 11.0, total_time = 620.7
#
# step =   64000, num_env_steps =   64000, scores =  3606.879 (n= 1), score_ema =  3196.288, actor_loss = -117.240, critic_loss = 6.898, entropy_coef_loss = 1.323, entropy_coef = 0.055, rollout_stds = 0.354 ± 0.093, action_magnitude = 0.788 ± 0.263, n_updates = 54000, time = 11.0, total_time = 631.7
#
# step =   65000, num_env_steps =   65000, scores =  667.152 (n= 1), score_ema =  2564.004, actor_loss = -119.719, critic_loss = 8.365, entropy_coef_loss = -0.328, entropy_coef = 0.055, rollout_stds = 0.613 ± 0.099, action_magnitude = 0.678 ± 0.298, n_updates = 55000, time = 11.0, total_time = 642.8
#
# step =   66000, num_env_steps =   66000, scores =  3723.154 (n= 1), score_ema =  2853.792, actor_loss = -113.878, critic_loss = 6.614, entropy_coef_loss = -0.999, entropy_coef = 0.056, rollout_stds = 0.464 ± 0.136, action_magnitude = 0.794 ± 0.260, n_updates = 56000, time = 11.0, total_time = 653.8
#
# step =   67000, num_env_steps =   67000, scores =  3938.781 (n= 1), score_ema =  3125.039, actor_loss = -118.356, critic_loss = 6.385, entropy_coef_loss = -1.016, entropy_coef = 0.056, rollout_stds = 0.420 ± 0.157, action_magnitude = 0.793 ± 0.260, n_updates = 57000, time = 11.0, total_time = 664.7
#
# step =   68000, num_env_steps =   68000, scores =  3787.004 (n= 1), score_ema =  3290.530, actor_loss = -121.453, critic_loss = 7.011, entropy_coef_loss = -0.726, entropy_coef = 0.057, rollout_stds = 0.410 ± 0.086, action_magnitude = 0.781 ± 0.269, n_updates = 58000, time = 11.0, total_time = 675.8
#
# step =   69000, num_env_steps =   69000, scores =  3902.495 (n= 1), score_ema =  3443.521, actor_loss = -139.137, critic_loss = 9.718, entropy_coef_loss = 1.470, entropy_coef = 0.059, rollout_stds = 0.420 ± 0.159, action_magnitude = 0.780 ± 0.267, n_updates = 59000, time = 11.1, total_time = 686.8
#
# step =   70000, num_env_steps =   70000, scores =  3960.724 (n= 1), score_ema =  3572.822, actor_loss = -131.091, critic_loss = 7.687, entropy_coef_loss = -1.268, entropy_coef = 0.061, rollout_stds = 0.520 ± 0.141, action_magnitude = 0.784 ± 0.266, n_updates = 60000, time = 11.1, total_time = 697.9
#
# saved experiment log 2024-10-10_19-36-32_501308~7W3lI0 at experiment_logs/HalfCheetah-v4/sac/2024-10-10_19-36-32_501308~7W3lI0.json
#
# step =   71000, num_env_steps =   71000, scores =  3981.661 (n= 1), score_ema =  3675.032, actor_loss = -140.820, critic_loss = 12.251, entropy_coef_loss = 0.778, entropy_coef = 0.062, rollout_stds = 0.479 ± 0.114, action_magnitude = 0.790 ± 0.259, n_updates = 61000, time = 11.2, total_time = 709.1
#
# step =   72000, num_env_steps =   72000, scores =  3960.641 (n= 1), score_ema =  3746.434, actor_loss = -148.464, critic_loss = 7.583, entropy_coef_loss = -0.216, entropy_coef = 0.061, rollout_stds = 0.411 ± 0.100, action_magnitude = 0.784 ± 0.265, n_updates = 62000, time = 11.0, total_time = 720.1
#
# step =   73000, num_env_steps =   73000, scores =  3802.261 (n= 1), score_ema =  3760.391, actor_loss = -150.754, critic_loss = 8.949, entropy_coef_loss = 0.187, entropy_coef = 0.063, rollout_stds = 0.454 ± 0.107, action_magnitude = 0.785 ± 0.266, n_updates = 63000, time = 11.0, total_time = 731.1
#
# step =   74000, num_env_steps =   74000, scores =  4106.805 (n= 1), score_ema =  3846.994, actor_loss = -147.110, critic_loss = 11.224, entropy_coef_loss = -0.423, entropy_coef = 0.065, rollout_stds = 0.397 ± 0.105, action_magnitude = 0.787 ± 0.264, n_updates = 64000, time = 11.1, total_time = 742.2
#
# step =   75000, num_env_steps =   75000, scores =  4129.228 (n= 1), score_ema =  3917.553, actor_loss = -156.104, critic_loss = 9.217, entropy_coef_loss = 0.473, entropy_coef = 0.066, rollout_stds = 0.330 ± 0.100, action_magnitude = 0.785 ± 0.264, n_updates = 65000, time = 11.1, total_time = 753.3
#
# step =   76000, num_env_steps =   76000, scores =  4190.059 (n= 1), score_ema =  3985.679, actor_loss = -156.851, critic_loss = 10.959, entropy_coef_loss = 1.543, entropy_coef = 0.067, rollout_stds = 0.404 ± 0.149, action_magnitude = 0.786 ± 0.268, n_updates = 66000, time = 11.0, total_time = 764.3
#
# step =   77000, num_env_steps =   77000, scores =  4198.532 (n= 1), score_ema =  4038.892, actor_loss = -166.895, critic_loss = 9.081, entropy_coef_loss = 0.698, entropy_coef = 0.068, rollout_stds = 0.383 ± 0.104, action_magnitude = 0.793 ± 0.260, n_updates = 67000, time = 11.0, total_time = 775.3
#
# step =   78000, num_env_steps =   78000, scores =  4025.097 (n= 1), score_ema =  4035.444, actor_loss = -154.413, critic_loss = 10.554, entropy_coef_loss = -0.791, entropy_coef = 0.069, rollout_stds = 0.462 ± 0.140, action_magnitude = 0.778 ± 0.270, n_updates = 68000, time = 11.1, total_time = 786.4
#
# step =   79000, num_env_steps =   79000, scores =  4182.241 (n= 1), score_ema =  4072.143, actor_loss = -153.806, critic_loss = 7.563, entropy_coef_loss = -1.484, entropy_coef = 0.070, rollout_stds = 0.423 ± 0.105, action_magnitude = 0.777 ± 0.271, n_updates = 69000, time = 11.0, total_time = 797.4
#
# step =   80000, num_env_steps =   80000, scores =  4136.383 (n= 1), score_ema =  4088.203, actor_loss = -164.947, critic_loss = 9.365, entropy_coef_loss = -1.039, entropy_coef = 0.073, rollout_stds = 0.456 ± 0.072, action_magnitude = 0.780 ± 0.270, n_updates = 70000, time = 11.1, total_time = 808.5
#
# saved experiment log 2024-10-10_19-36-32_501308~7W3lI0 at experiment_logs/HalfCheetah-v4/sac/2024-10-10_19-36-32_501308~7W3lI0.json
#
# step =   81000, num_env_steps =   81000, scores =  4411.752 (n= 1), score_ema =  4169.090, actor_loss = -167.363, critic_loss = 7.470, entropy_coef_loss = 0.636, entropy_coef = 0.073, rollout_stds = 0.380 ± 0.129, action_magnitude = 0.781 ± 0.269, n_updates = 71000, time = 11.1, total_time = 819.5
#
# step =   82000, num_env_steps =   82000, scores =  4139.395 (n= 1), score_ema =  4161.666, actor_loss = -183.303, critic_loss = 8.213, entropy_coef_loss = 0.223, entropy_coef = 0.075, rollout_stds = 0.365 ± 0.101, action_magnitude = 0.780 ± 0.267, n_updates = 72000, time = 11.0, total_time = 830.6
#
# step =   83000, num_env_steps =   83000, scores =  4129.380 (n= 1), score_ema =  4153.595, actor_loss = -184.885, critic_loss = 11.215, entropy_coef_loss = 1.863, entropy_coef = 0.076, rollout_stds = 0.418 ± 0.115, action_magnitude = 0.781 ± 0.267, n_updates = 73000, time = 11.0, total_time = 841.6
#
# step =   84000, num_env_steps =   84000, scores =  4379.284 (n= 1), score_ema =  4210.017, actor_loss = -182.308, critic_loss = 9.630, entropy_coef_loss = 0.097, entropy_coef = 0.078, rollout_stds = 0.436 ± 0.076, action_magnitude = 0.786 ± 0.264, n_updates = 74000, time = 11.0, total_time = 852.6
#
# step =   85000, num_env_steps =   85000, scores =  4320.338 (n= 1), score_ema =  4237.597, actor_loss = -168.685, critic_loss = 8.693, entropy_coef_loss = -2.012, entropy_coef = 0.078, rollout_stds = 0.429 ± 0.157, action_magnitude = 0.781 ± 0.272, n_updates = 75000, time = 11.0, total_time = 863.6
#
# step =   86000, num_env_steps =   86000, scores =  4311.800 (n= 1), score_ema =  4256.148, actor_loss = -187.482, critic_loss = 9.895, entropy_coef_loss = 0.706, entropy_coef = 0.077, rollout_stds = 0.402 ± 0.145, action_magnitude = 0.777 ± 0.274, n_updates = 76000, time = 11.1, total_time = 874.7
#
# step =   87000, num_env_steps =   87000, scores =  4459.030 (n= 1), score_ema =  4306.868, actor_loss = -181.591, critic_loss = 7.307, entropy_coef_loss = 0.171, entropy_coef = 0.080, rollout_stds = 0.398 ± 0.080, action_magnitude = 0.789 ± 0.264, n_updates = 77000, time = 11.0, total_time = 885.7
#
# step =   88000, num_env_steps =   88000, scores =  4486.456 (n= 1), score_ema =  4351.765, actor_loss = -193.954, critic_loss = 8.642, entropy_coef_loss = 0.886, entropy_coef = 0.080, rollout_stds = 0.385 ± 0.087, action_magnitude = 0.782 ± 0.265, n_updates = 78000, time = 11.1, total_time = 896.8
#
# step =   89000, num_env_steps =   89000, scores =  4438.966 (n= 1), score_ema =  4373.566, actor_loss = -201.332, critic_loss = 10.573, entropy_coef_loss = 0.264, entropy_coef = 0.079, rollout_stds = 0.399 ± 0.108, action_magnitude = 0.775 ± 0.271, n_updates = 79000, time = 11.0, total_time = 907.8
#
# step =   90000, num_env_steps =   90000, scores =  4503.552 (n= 1), score_ema =  4406.062, actor_loss = -198.994, critic_loss = 9.153, entropy_coef_loss = 0.005, entropy_coef = 0.081, rollout_stds = 0.495 ± 0.133, action_magnitude = 0.773 ± 0.272, n_updates = 80000, time = 11.1, total_time = 918.9
#
# saved experiment log 2024-10-10_19-36-32_501308~7W3lI0 at experiment_logs/HalfCheetah-v4/sac/2024-10-10_19-36-32_501308~7W3lI0.json
#
# step =   91000, num_env_steps =   91000, scores =  4604.581 (n= 1), score_ema =  4455.692, actor_loss = -199.536, critic_loss = 7.849, entropy_coef_loss = -0.082, entropy_coef = 0.084, rollout_stds = 0.434 ± 0.156, action_magnitude = 0.780 ± 0.270, n_updates = 81000, time = 12.3, total_time = 931.2
#
# step =   92000, num_env_steps =   92000, scores =  4386.160 (n= 1), score_ema =  4438.309, actor_loss = -209.906, critic_loss = 10.698, entropy_coef_loss = 0.615, entropy_coef = 0.084, rollout_stds = 0.423 ± 0.105, action_magnitude = 0.786 ± 0.265, n_updates = 82000, time = 11.5, total_time = 942.7
#
# step =   93000, num_env_steps =   93000, scores =  4576.845 (n= 1), score_ema =  4472.943, actor_loss = -204.452, critic_loss = 11.129, entropy_coef_loss = 0.094, entropy_coef = 0.084, rollout_stds = 0.398 ± 0.161, action_magnitude = 0.780 ± 0.266, n_updates = 83000, time = 12.2, total_time = 954.9
#
# step =   94000, num_env_steps =   94000, scores =  4246.819 (n= 1), score_ema =  4416.412, actor_loss = -207.134, critic_loss = 9.480, entropy_coef_loss = -0.239, entropy_coef = 0.085, rollout_stds = 0.453 ± 0.113, action_magnitude = 0.775 ± 0.270, n_updates = 84000, time = 11.6, total_time = 966.5
#
# step =   95000, num_env_steps =   95000, scores =  4669.693 (n= 1), score_ema =  4479.732, actor_loss = -203.326, critic_loss = 10.895, entropy_coef_loss = -1.122, entropy_coef = 0.086, rollout_stds = 0.416 ± 0.152, action_magnitude = 0.781 ± 0.267, n_updates = 85000, time = 11.3, total_time = 977.8
#
# step =   96000, num_env_steps =   96000, scores =  4854.759 (n= 1), score_ema =  4573.489, actor_loss = -207.229, critic_loss = 8.820, entropy_coef_loss = 1.157, entropy_coef = 0.087, rollout_stds = 0.397 ± 0.114, action_magnitude = 0.784 ± 0.268, n_updates = 86000, time = 11.3, total_time = 989.0
#
# step =   97000, num_env_steps =   97000, scores =  4733.569 (n= 1), score_ema =  4613.509, actor_loss = -215.843, critic_loss = 9.835, entropy_coef_loss = 0.009, entropy_coef = 0.087, rollout_stds = 0.382 ± 0.103, action_magnitude = 0.779 ± 0.270, n_updates = 87000, time = 11.1, total_time = 1000.1
#
# step =   98000, num_env_steps =   98000, scores =  4511.308 (n= 1), score_ema =  4587.959, actor_loss = -212.150, critic_loss = 7.429, entropy_coef_loss = 0.157, entropy_coef = 0.089, rollout_stds = 0.414 ± 0.157, action_magnitude = 0.773 ± 0.274, n_updates = 88000, time = 11.2, total_time = 1011.3
#
# step =   99000, num_env_steps =   99000, scores =  4864.442 (n= 1), score_ema =  4657.080, actor_loss = -216.770, critic_loss = 12.361, entropy_coef_loss = -0.306, entropy_coef = 0.090, rollout_stds = 0.432 ± 0.155, action_magnitude = 0.779 ± 0.271, n_updates = 89000, time = 11.2, total_time = 1022.5
#
# step =  100000, num_env_steps =  100000, scores =  4782.810 (n= 1), score_ema =  4688.512, actor_loss = -239.602, critic_loss = 7.645, entropy_coef_loss = 0.717, entropy_coef = 0.091, rollout_stds = 0.477 ± 0.115, action_magnitude = 0.775 ± 0.272, n_updates = 90000, time = 11.3, total_time = 1033.8
#
# saved experiment log 2024-10-10_19-36-32_501308~7W3lI0 at experiment_logs/HalfCheetah-v4/sac/2024-10-10_19-36-32_501308~7W3lI0.json
#
# step =  101000, num_env_steps =  101000, scores =  4667.303 (n= 1), score_ema =  4683.210, actor_loss = -216.793, critic_loss = 9.132, entropy_coef_loss = -0.076, entropy_coef = 0.093, rollout_stds = 0.445 ± 0.135, action_magnitude = 0.773 ± 0.272, n_updates = 91000, time = 11.3, total_time = 1045.2
#
# step =  102000, num_env_steps =  102000, scores =  4525.241 (n= 1), score_ema =  4643.718, actor_loss = -233.736, critic_loss = 12.086, entropy_coef_loss = 0.098, entropy_coef = 0.095, rollout_stds = 0.433 ± 0.109, action_magnitude = 0.768 ± 0.278, n_updates = 92000, time = 11.1, total_time = 1056.2
#
# step =  103000, num_env_steps =  103000, scores =  4948.366 (n= 1), score_ema =  4719.880, actor_loss = -234.889, critic_loss = 11.285, entropy_coef_loss = -0.232, entropy_coef = 0.095, rollout_stds = 0.396 ± 0.122, action_magnitude = 0.778 ± 0.268, n_updates = 93000, time = 11.2, total_time = 1067.4
#
# step =  104000, num_env_steps =  104000, scores =  4773.904 (n= 1), score_ema =  4733.386, actor_loss = -232.154, critic_loss = 7.559, entropy_coef_loss = -0.036, entropy_coef = 0.095, rollout_stds = 0.429 ± 0.124, action_magnitude = 0.768 ± 0.276, n_updates = 94000, time = 11.2, total_time = 1078.6
#
# step =  105000, num_env_steps =  105000, scores =  4935.995 (n= 1), score_ema =  4784.038, actor_loss = -218.745, critic_loss = 11.304, entropy_coef_loss = 0.429, entropy_coef = 0.098, rollout_stds = 0.439 ± 0.132, action_magnitude = 0.771 ± 0.272, n_updates = 95000, time = 11.2, total_time = 1089.8
#
# step =  106000, num_env_steps =  106000, scores =  5016.693 (n= 1), score_ema =  4842.202, actor_loss = -227.392, critic_loss = 9.326, entropy_coef_loss = -0.942, entropy_coef = 0.098, rollout_stds = 0.420 ± 0.130, action_magnitude = 0.781 ± 0.268, n_updates = 96000, time = 11.1, total_time = 1100.8
#
# step =  107000, num_env_steps =  107000, scores =  5090.502 (n= 1), score_ema =  4904.277, actor_loss = -226.152, critic_loss = 9.411, entropy_coef_loss = -1.259, entropy_coef = 0.100, rollout_stds = 0.422 ± 0.147, action_magnitude = 0.776 ± 0.273, n_updates = 97000, time = 11.2, total_time = 1112.0
#
# step =  108000, num_env_steps =  108000, scores =  4844.395 (n= 1), score_ema =  4889.306, actor_loss = -237.681, critic_loss = 9.917, entropy_coef_loss = -0.756, entropy_coef = 0.100, rollout_stds = 0.422 ± 0.110, action_magnitude = 0.769 ± 0.274, n_updates = 98000, time = 11.1, total_time = 1123.0
#
# step =  109000, num_env_steps =  109000, scores =  5018.424 (n= 1), score_ema =  4921.586, actor_loss = -250.048, critic_loss = 11.331, entropy_coef_loss = 0.263, entropy_coef = 0.101, rollout_stds = 0.403 ± 0.181, action_magnitude = 0.769 ± 0.275, n_updates = 99000, time = 11.1, total_time = 1134.1
#
# step =  110000, num_env_steps =  110000, scores =  4781.461 (n= 1), score_ema =  4886.555, actor_loss = -243.864, critic_loss = 10.275, entropy_coef_loss = 0.803, entropy_coef = 0.102, rollout_stds = 0.511 ± 0.165, action_magnitude = 0.767 ± 0.273, n_updates = 100000, time = 11.1, total_time = 1145.2
#
# saved experiment log 2024-10-10_19-36-32_501308~7W3lI0 at experiment_logs/HalfCheetah-v4/sac/2024-10-10_19-36-32_501308~7W3lI0.json
#
# step =  111000, num_env_steps =  111000, scores =  5175.783 (n= 1), score_ema =  4958.862, actor_loss = -245.446, critic_loss = 12.730, entropy_coef_loss = -0.017, entropy_coef = 0.102, rollout_stds = 0.456 ± 0.130, action_magnitude = 0.775 ± 0.272, n_updates = 101000, time = 11.1, total_time = 1156.4
#
# step =  112000, num_env_steps =  112000, scores =  5203.955 (n= 1), score_ema =  5020.135, actor_loss = -243.283, critic_loss = 9.166, entropy_coef_loss = -0.477, entropy_coef = 0.104, rollout_stds = 0.425 ± 0.183, action_magnitude = 0.775 ± 0.271, n_updates = 102000, time = 11.1, total_time = 1167.4
#
# step =  113000, num_env_steps =  113000, scores =  5138.184 (n= 1), score_ema =  5049.647, actor_loss = -255.285, critic_loss = 10.076, entropy_coef_loss = -0.232, entropy_coef = 0.105, rollout_stds = 0.424 ± 0.123, action_magnitude = 0.774 ± 0.274, n_updates = 103000, time = 11.1, total_time = 1178.5
#
# step =  114000, num_env_steps =  114000, scores =  5234.851 (n= 1), score_ema =  5095.948, actor_loss = -249.718, critic_loss = 20.083, entropy_coef_loss = -0.397, entropy_coef = 0.107, rollout_stds = 0.470 ± 0.103, action_magnitude = 0.771 ± 0.274, n_updates = 104000, time = 11.1, total_time = 1189.6
#
# step =  115000, num_env_steps =  115000, scores =  2082.586 (n= 1), score_ema =  4342.608, actor_loss = -257.174, critic_loss = 9.761, entropy_coef_loss = 1.277, entropy_coef = 0.107, rollout_stds = 0.686 ± 0.130, action_magnitude = 0.652 ± 0.304, n_updates = 105000, time = 11.1, total_time = 1200.7
#
# step =  116000, num_env_steps =  116000, scores =  5230.615 (n= 1), score_ema =  4564.609, actor_loss = -246.438, critic_loss = 10.376, entropy_coef_loss = 0.246, entropy_coef = 0.107, rollout_stds = 0.396 ± 0.142, action_magnitude = 0.771 ± 0.275, n_updates = 106000, time = 11.0, total_time = 1211.7
#
# step =  117000, num_env_steps =  117000, scores =  5386.895 (n= 1), score_ema =  4770.181, actor_loss = -247.002, critic_loss = 9.073, entropy_coef_loss = -0.050, entropy_coef = 0.108, rollout_stds = 0.425 ± 0.127, action_magnitude = 0.774 ± 0.276, n_updates = 107000, time = 11.1, total_time = 1222.8
#
# step =  118000, num_env_steps =  118000, scores =  5094.255 (n= 1), score_ema =  4851.199, actor_loss = -255.239, critic_loss = 11.950, entropy_coef_loss = 0.106, entropy_coef = 0.108, rollout_stds = 0.463 ± 0.142, action_magnitude = 0.763 ± 0.280, n_updates = 108000, time = 11.0, total_time = 1233.8
#
# step =  119000, num_env_steps =  119000, scores =  5291.532 (n= 1), score_ema =  4961.282, actor_loss = -273.026, critic_loss = 11.375, entropy_coef_loss = 1.279, entropy_coef = 0.110, rollout_stds = 0.475 ± 0.134, action_magnitude = 0.773 ± 0.274, n_updates = 109000, time = 11.0, total_time = 1244.9
#
# step =  120000, num_env_steps =  120000, scores =  5191.795 (n= 1), score_ema =  5018.911, actor_loss = -253.330, critic_loss = 13.554, entropy_coef_loss = 0.348, entropy_coef = 0.111, rollout_stds = 0.396 ± 0.126, action_magnitude = 0.779 ± 0.270, n_updates = 110000, time = 11.1, total_time = 1255.9
#
# saved experiment log 2024-10-10_19-36-32_501308~7W3lI0 at experiment_logs/HalfCheetah-v4/sac/2024-10-10_19-36-32_501308~7W3lI0.json
#
# step =  121000, num_env_steps =  121000, scores =  5155.166 (n= 1), score_ema =  5052.975, actor_loss = -257.184, critic_loss = 7.893, entropy_coef_loss = -0.118, entropy_coef = 0.111, rollout_stds = 0.413 ± 0.124, action_magnitude = 0.775 ± 0.272, n_updates = 111000, time = 11.0, total_time = 1267.0
#
# step =  122000, num_env_steps =  122000, scores =  5007.707 (n= 1), score_ema =  5041.658, actor_loss = -275.865, critic_loss = 10.345, entropy_coef_loss = 0.929, entropy_coef = 0.115, rollout_stds = 0.400 ± 0.144, action_magnitude = 0.772 ± 0.277, n_updates = 112000, time = 11.0, total_time = 1278.0
#
# step =  123000, num_env_steps =  123000, scores =  5284.388 (n= 1), score_ema =  5102.340, actor_loss = -256.148, critic_loss = 9.503, entropy_coef_loss = -0.091, entropy_coef = 0.114, rollout_stds = 0.406 ± 0.142, action_magnitude = 0.769 ± 0.278, n_updates = 113000, time = 11.0, total_time = 1289.0
#
# step =  124000, num_env_steps =  124000, scores =  5497.619 (n= 1), score_ema =  5201.160, actor_loss = -269.942, critic_loss = 10.152, entropy_coef_loss = 0.702, entropy_coef = 0.114, rollout_stds = 0.412 ± 0.130, action_magnitude = 0.770 ± 0.277, n_updates = 114000, time = 11.2, total_time = 1300.2
#
# step =  125000, num_env_steps =  125000, scores =  5238.631 (n= 1), score_ema =  5210.528, actor_loss = -283.422, critic_loss = 11.441, entropy_coef_loss = -0.066, entropy_coef = 0.113, rollout_stds = 0.462 ± 0.059, action_magnitude = 0.767 ± 0.278, n_updates = 115000, time = 11.6, total_time = 1311.8
#
# step =  126000, num_env_steps =  126000, scores =  5414.221 (n= 1), score_ema =  5261.451, actor_loss = -276.987, critic_loss = 9.648, entropy_coef_loss = 1.018, entropy_coef = 0.117, rollout_stds = 0.445 ± 0.134, action_magnitude = 0.775 ± 0.278, n_updates = 116000, time = 11.6, total_time = 1323.4
#
# step =  127000, num_env_steps =  127000, scores =  5226.332 (n= 1), score_ema =  5252.671, actor_loss = -275.278, critic_loss = 11.597, entropy_coef_loss = -0.030, entropy_coef = 0.116, rollout_stds = 0.445 ± 0.152, action_magnitude = 0.771 ± 0.274, n_updates = 117000, time = 11.7, total_time = 1335.0
#
# step =  128000, num_env_steps =  128000, scores =  5378.384 (n= 1), score_ema =  5284.099, actor_loss = -280.437, critic_loss = 9.801, entropy_coef_loss = 0.156, entropy_coef = 0.118, rollout_stds = 0.387 ± 0.120, action_magnitude = 0.773 ± 0.274, n_updates = 118000, time = 11.2, total_time = 1346.2
#
# step =  129000, num_env_steps =  129000, scores =  5259.760 (n= 1), score_ema =  5278.015, actor_loss = -274.129, critic_loss = 13.129, entropy_coef_loss = 0.023, entropy_coef = 0.118, rollout_stds = 0.469 ± 0.161, action_magnitude = 0.772 ± 0.274, n_updates = 119000, time = 11.1, total_time = 1357.4
#
# step =  130000, num_env_steps =  130000, scores =  5466.604 (n= 1), score_ema =  5325.162, actor_loss = -292.124, critic_loss = 8.255, entropy_coef_loss = 0.575, entropy_coef = 0.120, rollout_stds = 0.428 ± 0.120, action_magnitude = 0.776 ± 0.271, n_updates = 120000, time = 11.4, total_time = 1368.8
#
# saved experiment log 2024-10-10_19-36-32_501308~7W3lI0 at experiment_logs/HalfCheetah-v4/sac/2024-10-10_19-36-32_501308~7W3lI0.json
#
# step =  131000, num_env_steps =  131000, scores =  5432.996 (n= 1), score_ema =  5352.120, actor_loss = -275.359, critic_loss = 6.901, entropy_coef_loss = -0.402, entropy_coef = 0.119, rollout_stds = 0.407 ± 0.138, action_magnitude = 0.776 ± 0.271, n_updates = 121000, time = 11.2, total_time = 1380.0
#
# step =  132000, num_env_steps =  132000, scores =  5370.383 (n= 1), score_ema =  5356.686, actor_loss = -273.480, critic_loss = 11.596, entropy_coef_loss = 0.238, entropy_coef = 0.118, rollout_stds = 0.418 ± 0.111, action_magnitude = 0.768 ± 0.277, n_updates = 122000, time = 11.2, total_time = 1391.2
#
# step =  133000, num_env_steps =  133000, scores =  5489.629 (n= 1), score_ema =  5389.922, actor_loss = -300.410, critic_loss = 10.967, entropy_coef_loss = 1.764, entropy_coef = 0.121, rollout_stds = 0.417 ± 0.120, action_magnitude = 0.775 ± 0.272, n_updates = 123000, time = 11.3, total_time = 1402.5
#
# step =  134000, num_env_steps =  134000, scores =  5395.701 (n= 1), score_ema =  5391.367, actor_loss = -283.869, critic_loss = 12.490, entropy_coef_loss = 0.057, entropy_coef = 0.120, rollout_stds = 0.465 ± 0.092, action_magnitude = 0.771 ± 0.272, n_updates = 124000, time = 11.7, total_time = 1414.2
#
# step =  135000, num_env_steps =  135000, scores =  5447.914 (n= 1), score_ema =  5405.504, actor_loss = -290.526, critic_loss = 8.982, entropy_coef_loss = -0.495, entropy_coef = 0.123, rollout_stds = 0.455 ± 0.134, action_magnitude = 0.776 ± 0.271, n_updates = 125000, time = 13.0, total_time = 1427.2
#
# step =  136000, num_env_steps =  136000, scores =  5486.718 (n= 1), score_ema =  5425.807, actor_loss = -290.235, critic_loss = 9.464, entropy_coef_loss = -0.543, entropy_coef = 0.123, rollout_stds = 0.436 ± 0.134, action_magnitude = 0.774 ± 0.273, n_updates = 126000, time = 11.8, total_time = 1439.0
#
# step =  137000, num_env_steps =  137000, scores =  5582.241 (n= 1), score_ema =  5464.916, actor_loss = -289.649, critic_loss = 10.374, entropy_coef_loss = 0.385, entropy_coef = 0.125, rollout_stds = 0.408 ± 0.141, action_magnitude = 0.775 ± 0.273, n_updates = 127000, time = 12.0, total_time = 1451.1
#
# step =  138000, num_env_steps =  138000, scores =  5459.126 (n= 1), score_ema =  5463.468, actor_loss = -285.828, critic_loss = 9.953, entropy_coef_loss = -0.283, entropy_coef = 0.123, rollout_stds = 0.404 ± 0.119, action_magnitude = 0.765 ± 0.276, n_updates = 128000, time = 11.5, total_time = 1462.5
#
# step =  139000, num_env_steps =  139000, scores =  5667.450 (n= 1), score_ema =  5514.464, actor_loss = -307.915, critic_loss = 8.666, entropy_coef_loss = 0.328, entropy_coef = 0.124, rollout_stds = 0.466 ± 0.106, action_magnitude = 0.775 ± 0.269, n_updates = 129000, time = 12.0, total_time = 1474.5
#
# step =  140000, num_env_steps =  140000, scores =  5493.102 (n= 1), score_ema =  5509.123, actor_loss = -302.693, critic_loss = 8.218, entropy_coef_loss = 0.341, entropy_coef = 0.126, rollout_stds = 0.385 ± 0.145, action_magnitude = 0.772 ± 0.274, n_updates = 130000, time = 12.1, total_time = 1486.7
#
# saved experiment log 2024-10-10_19-36-32_501308~7W3lI0 at experiment_logs/HalfCheetah-v4/sac/2024-10-10_19-36-32_501308~7W3lI0.json
#
# step =  141000, num_env_steps =  141000, scores =  5685.208 (n= 1), score_ema =  5553.145, actor_loss = -297.258, critic_loss = 10.527, entropy_coef_loss = -0.497, entropy_coef = 0.127, rollout_stds = 0.416 ± 0.128, action_magnitude = 0.772 ± 0.271, n_updates = 131000, time = 11.3, total_time = 1498.0
#
# step =  142000, num_env_steps =  142000, scores =  5473.902 (n= 1), score_ema =  5533.334, actor_loss = -299.790, critic_loss = 10.231, entropy_coef_loss = -0.322, entropy_coef = 0.126, rollout_stds = 0.452 ± 0.154, action_magnitude = 0.773 ± 0.270, n_updates = 132000, time = 11.1, total_time = 1509.1
#
# step =  143000, num_env_steps =  143000, scores =  5831.638 (n= 1), score_ema =  5607.910, actor_loss = -306.784, critic_loss = 10.750, entropy_coef_loss = 0.458, entropy_coef = 0.129, rollout_stds = 0.394 ± 0.123, action_magnitude = 0.779 ± 0.269, n_updates = 133000, time = 11.1, total_time = 1520.2
#
# step =  144000, num_env_steps =  144000, scores =  5854.631 (n= 1), score_ema =  5669.590, actor_loss = -300.673, critic_loss = 9.250, entropy_coef_loss = -0.068, entropy_coef = 0.128, rollout_stds = 0.441 ± 0.124, action_magnitude = 0.767 ± 0.276, n_updates = 134000, time = 11.1, total_time = 1531.4
#
# step =  145000, num_env_steps =  145000, scores =  5755.473 (n= 1), score_ema =  5691.061, actor_loss = -296.264, critic_loss = 14.991, entropy_coef_loss = -0.946, entropy_coef = 0.130, rollout_stds = 0.397 ± 0.119, action_magnitude = 0.769 ± 0.277, n_updates = 135000, time = 11.1, total_time = 1542.5
#
# step =  146000, num_env_steps =  146000, scores =  5589.328 (n= 1), score_ema =  5665.628, actor_loss = -304.451, critic_loss = 11.218, entropy_coef_loss = 1.177, entropy_coef = 0.130, rollout_stds = 0.374 ± 0.142, action_magnitude = 0.776 ± 0.268, n_updates = 136000, time = 11.0, total_time = 1553.5
#
# step =  147000, num_env_steps =  147000, scores =  5880.172 (n= 1), score_ema =  5719.264, actor_loss = -311.183, critic_loss = 8.735, entropy_coef_loss = 0.172, entropy_coef = 0.130, rollout_stds = 0.405 ± 0.134, action_magnitude = 0.775 ± 0.270, n_updates = 137000, time = 11.0, total_time = 1564.5
#
# step =  148000, num_env_steps =  148000, scores =  5993.041 (n= 1), score_ema =  5787.708, actor_loss = -287.448, critic_loss = 8.244, entropy_coef_loss = -1.593, entropy_coef = 0.132, rollout_stds = 0.368 ± 0.132, action_magnitude = 0.773 ± 0.270, n_updates = 138000, time = 11.6, total_time = 1576.1
#
# step =  149000, num_env_steps =  149000, scores =  5618.032 (n= 1), score_ema =  5745.289, actor_loss = -304.884, critic_loss = 8.632, entropy_coef_loss = -0.073, entropy_coef = 0.133, rollout_stds = 0.360 ± 0.138, action_magnitude = 0.767 ± 0.274, n_updates = 139000, time = 11.2, total_time = 1587.2
#
# step =  150000, num_env_steps =  150000, scores =  6003.182 (n= 1), score_ema =  5809.762, actor_loss = -310.387, critic_loss = 8.532, entropy_coef_loss = -0.188, entropy_coef = 0.131, rollout_stds = 0.397 ± 0.143, action_magnitude = 0.772 ± 0.271, n_updates = 140000, time = 11.3, total_time = 1598.5
#
# saved experiment log 2024-10-10_19-36-32_501308~7W3lI0 at experiment_logs/HalfCheetah-v4/sac/2024-10-10_19-36-32_501308~7W3lI0.json
#
# step =  151000, num_env_steps =  151000, scores =  5779.687 (n= 1), score_ema =  5802.243, actor_loss = -310.579, critic_loss = 11.951, entropy_coef_loss = 0.306, entropy_coef = 0.133, rollout_stds = 0.443 ± 0.114, action_magnitude = 0.768 ± 0.273, n_updates = 141000, time = 11.1, total_time = 1609.6
#
# step =  152000, num_env_steps =  152000, scores =  5948.274 (n= 1), score_ema =  5838.751, actor_loss = -311.953, critic_loss = 11.320, entropy_coef_loss = -0.300, entropy_coef = 0.133, rollout_stds = 0.469 ± 0.137, action_magnitude = 0.773 ± 0.269, n_updates = 142000, time = 11.0, total_time = 1620.6
#
# step =  153000, num_env_steps =  153000, scores =  5949.748 (n= 1), score_ema =  5866.500, actor_loss = -317.690, critic_loss = 12.409, entropy_coef_loss = -0.040, entropy_coef = 0.133, rollout_stds = 0.423 ± 0.122, action_magnitude = 0.770 ± 0.277, n_updates = 143000, time = 11.0, total_time = 1631.7
#
# step =  154000, num_env_steps =  154000, scores =  5872.108 (n= 1), score_ema =  5867.902, actor_loss = -315.496, critic_loss = 12.070, entropy_coef_loss = 0.798, entropy_coef = 0.134, rollout_stds = 0.440 ± 0.124, action_magnitude = 0.765 ± 0.276, n_updates = 144000, time = 11.0, total_time = 1642.7
#
# step =  155000, num_env_steps =  155000, scores =  5840.053 (n= 1), score_ema =  5860.940, actor_loss = -328.247, critic_loss = 12.874, entropy_coef_loss = 0.343, entropy_coef = 0.136, rollout_stds = 0.467 ± 0.128, action_magnitude = 0.763 ± 0.276, n_updates = 145000, time = 11.1, total_time = 1653.7
#
# step =  156000, num_env_steps =  156000, scores =  5743.807 (n= 1), score_ema =  5831.657, actor_loss = -314.870, critic_loss = 12.841, entropy_coef_loss = -0.492, entropy_coef = 0.136, rollout_stds = 0.381 ± 0.129, action_magnitude = 0.757 ± 0.278, n_updates = 146000, time = 11.1, total_time = 1664.8
#
# step =  157000, num_env_steps =  157000, scores =  6005.521 (n= 1), score_ema =  5875.123, actor_loss = -330.599, critic_loss = 12.291, entropy_coef_loss = 0.777, entropy_coef = 0.136, rollout_stds = 0.410 ± 0.127, action_magnitude = 0.756 ± 0.280, n_updates = 147000, time = 12.0, total_time = 1676.9
#
# step =  158000, num_env_steps =  158000, scores =  5649.992 (n= 1), score_ema =  5818.840, actor_loss = -327.531, critic_loss = 9.357, entropy_coef_loss = 0.482, entropy_coef = 0.135, rollout_stds = 0.452 ± 0.125, action_magnitude = 0.758 ± 0.277, n_updates = 148000, time = 11.0, total_time = 1687.9
#
# step =  159000, num_env_steps =  159000, scores =  6125.176 (n= 1), score_ema =  5895.424, actor_loss = -338.152, critic_loss = 13.230, entropy_coef_loss = 1.591, entropy_coef = 0.138, rollout_stds = 0.434 ± 0.131, action_magnitude = 0.764 ± 0.277, n_updates = 149000, time = 11.2, total_time = 1699.1
#
# step =  160000, num_env_steps =  160000, scores =  6080.255 (n= 1), score_ema =  5941.632, actor_loss = -308.915, critic_loss = 12.567, entropy_coef_loss = -0.771, entropy_coef = 0.138, rollout_stds = 0.432 ± 0.126, action_magnitude = 0.759 ± 0.278, n_updates = 150000, time = 11.0, total_time = 1710.1
#
# saved experiment log 2024-10-10_19-36-32_501308~7W3lI0 at experiment_logs/HalfCheetah-v4/sac/2024-10-10_19-36-32_501308~7W3lI0.json
#
# ...
#
# step = 2047000, num_env_steps = 2047000, scores =  12631.945 (n= 1), score_ema =  12637.261, actor_loss = -1040.361, critic_loss = 25.011, entropy_coef_loss = 0.236, entropy_coef = 0.326, rollout_stds = 0.393 ± 0.184, action_magnitude = 0.730 ± 0.269, n_updates = 2037000, time = 10.9, total_time = 22949.9
#
# step = 2048000, num_env_steps = 2048000, scores =  12669.757 (n= 1), score_ema =  12645.385, actor_loss = -1024.603, critic_loss = 25.233, entropy_coef_loss = 0.201, entropy_coef = 0.323, rollout_stds = 0.409 ± 0.092, action_magnitude = 0.738 ± 0.267, n_updates = 2038000, time = 10.9, total_time = 22960.7
#
# step = 2049000, num_env_steps = 2049000, scores =  12756.148 (n= 1), score_ema =  12673.076, actor_loss = -1021.876, critic_loss = 23.517, entropy_coef_loss = 0.491, entropy_coef = 0.327, rollout_stds = 0.545 ± 0.103, action_magnitude = 0.731 ± 0.272, n_updates = 2039000, time = 10.9, total_time = 22971.6
#
# step = 2050000, num_env_steps = 2050000, scores =  12593.051 (n= 1), score_ema =  12653.070, actor_loss = -1023.094, critic_loss = 29.939, entropy_coef_loss = -0.076, entropy_coef = 0.322, rollout_stds = 0.453 ± 0.109, action_magnitude = 0.734 ± 0.266, n_updates = 2040000, time = 10.9, total_time = 22982.5
# saved experiment log 2024-10-10_19-36-32_501308~7W3lI0 at experiment_logs/HalfCheetah-v4/sac/2024-10-10_19-36-32_501308~7W3lI0.json
#
# step = 2051000, num_env_steps = 2051000, scores =  12485.257 (n= 1), score_ema =  12611.117, actor_loss = -1029.204, critic_loss = 43.022, entropy_coef_loss = 0.173, entropy_coef = 0.324, rollout_stds = 0.470 ± 0.158, action_magnitude = 0.731 ± 0.277, n_updates = 2041000, time = 11.1, total_time = 22993.6
#
# step = 2052000, num_env_steps = 2052000, scores =  4326.094 (n= 1), score_ema =  10539.861, actor_loss = -1017.326, critic_loss = 84.302, entropy_coef_loss = 0.444, entropy_coef = 0.320, rollout_stds = 0.462 ± 0.095, action_magnitude = 0.609 ± 0.299, n_updates = 2042000, time = 11.2, total_time = 23004.8
#
# step = 2053000, num_env_steps = 2053000, scores =  12785.584 (n= 1), score_ema =  11101.292, actor_loss = -1016.737, critic_loss = 22.577, entropy_coef_loss = 0.525, entropy_coef = 0.316, rollout_stds = 0.417 ± 0.086, action_magnitude = 0.734 ± 0.269, n_updates = 2043000, time = 10.9, total_time = 23015.7
#
# step = 2054000, num_env_steps = 2054000, scores =  12777.171 (n= 1), score_ema =  11520.262, actor_loss = -1028.795, critic_loss = 25.149, entropy_coef_loss = -0.008, entropy_coef = 0.328, rollout_stds = 0.411 ± 0.166, action_magnitude = 0.729 ± 0.272, n_updates = 2044000, time = 10.8, total_time = 23026.5
#
# step = 2055000, num_env_steps = 2055000, scores =  12235.986 (n= 1), score_ema =  11699.193, actor_loss = -1030.604, critic_loss = 30.006, entropy_coef_loss = 0.128, entropy_coef = 0.317, rollout_stds = 0.301 ± 0.140, action_magnitude = 0.725 ± 0.275, n_updates = 2045000, time = 10.9, total_time = 23037.4
#
# step = 2056000, num_env_steps = 2056000, scores =  12767.791 (n= 1), score_ema =  11966.342, actor_loss = -1025.427, critic_loss = 48.920, entropy_coef_loss = -0.411, entropy_coef = 0.318, rollout_stds = 0.370 ± 0.185, action_magnitude = 0.731 ± 0.269, n_updates = 2046000, time = 10.9, total_time = 23048.2
#
# step = 2057000, num_env_steps = 2057000, scores =  12604.766 (n= 1), score_ema =  12125.948, actor_loss = -1026.814, critic_loss = 20.190, entropy_coef_loss = 0.057, entropy_coef = 0.324, rollout_stds = 0.286 ± 0.198, action_magnitude = 0.730 ± 0.273, n_updates = 2047000, time = 10.8, total_time = 23059.1
#
# step = 2058000, num_env_steps = 2058000, scores =  12928.868 (n= 1), score_ema =  12326.678, actor_loss = -1018.148, critic_loss = 18.338, entropy_coef_loss = -0.069, entropy_coef = 0.318, rollout_stds = 0.405 ± 0.158, action_magnitude = 0.735 ± 0.267, n_updates = 2048000, time = 10.8, total_time = 23069.9
#
# step = 2059000, num_env_steps = 2059000, scores =  11754.709 (n= 1), score_ema =  12183.686, actor_loss = -1025.338, critic_loss = 28.319, entropy_coef_loss = -0.034, entropy_coef = 0.320, rollout_stds = 0.262 ± 0.192, action_magnitude = 0.724 ± 0.274, n_updates = 2049000, time = 10.8, total_time = 23080.7
#
# step = 2060000, num_env_steps = 2060000, scores =  12396.649 (n= 1), score_ema =  12236.927, actor_loss = -1023.216, critic_loss = 20.590, entropy_coef_loss = 0.208, entropy_coef = 0.311, rollout_stds = 0.321 ± 0.169, action_magnitude = 0.728 ± 0.271, n_updates = 2050000, time = 10.9, total_time = 23091.6
#
# saved experiment log 2024-10-10_19-36-32_501308~7W3lI0 at experiment_logs/HalfCheetah-v4/sac/2024-10-10_19-36-32_501308~7W3lI0.json
#
# step = 2061000, num_env_steps = 2061000, scores =  12696.539 (n= 1), score_ema =  12351.830, actor_loss = -1019.218, critic_loss = 49.882, entropy_coef_loss = 0.215, entropy_coef = 0.311, rollout_stds = 0.462 ± 0.106, action_magnitude = 0.729 ± 0.272, n_updates = 2051000, time = 11.0, total_time = 23102.6
#
# step = 2062000, num_env_steps = 2062000, scores =  12722.795 (n= 1), score_ema =  12444.571, actor_loss = -1011.127, critic_loss = 47.173, entropy_coef_loss = -0.297, entropy_coef = 0.315, rollout_stds = 0.440 ± 0.084, action_magnitude = 0.729 ± 0.271, n_updates = 2052000, time = 10.8, total_time = 23113.5
#
# step = 2063000, num_env_steps = 2063000, scores =  12637.818 (n= 1), score_ema =  12492.883, actor_loss = -1027.488, critic_loss = 12.568, entropy_coef_loss = -0.183, entropy_coef = 0.317, rollout_stds = 0.489 ± 0.176, action_magnitude = 0.735 ± 0.265, n_updates = 2053000, time = 10.9, total_time = 23124.4
#
# step = 2064000, num_env_steps = 2064000, scores =  12420.793 (n= 1), score_ema =  12474.860, actor_loss = -1027.307, critic_loss = 21.223, entropy_coef_loss = 0.668, entropy_coef = 0.316, rollout_stds = 0.320 ± 0.167, action_magnitude = 0.732 ± 0.265, n_updates = 2054000, time = 10.8, total_time = 23135.2
#
# step = 2065000, num_env_steps = 2065000, scores =  12678.116 (n= 1), score_ema =  12525.674, actor_loss = -1029.693, critic_loss = 21.552, entropy_coef_loss = 0.417, entropy_coef = 0.321, rollout_stds = 0.479 ± 0.199, action_magnitude = 0.731 ± 0.267, n_updates = 2055000, time = 10.9, total_time = 23146.1
#
# step = 2066000, num_env_steps = 2066000, scores =  12589.161 (n= 1), score_ema =  12541.546, actor_loss = -1033.938, critic_loss = 155.801, entropy_coef_loss = -0.086, entropy_coef = 0.318, rollout_stds = 0.294 ± 0.219, action_magnitude = 0.731 ± 0.268, n_updates = 2056000, time = 10.9, total_time = 23157.0
#
# step = 2067000, num_env_steps = 2067000, scores =  12594.154 (n= 1), score_ema =  12554.698, actor_loss = -1023.186, critic_loss = 19.682, entropy_coef_loss = 0.018, entropy_coef = 0.321, rollout_stds = 0.453 ± 0.102, action_magnitude = 0.738 ± 0.267, n_updates = 2057000, time = 10.8, total_time = 23167.8
#
# step = 2068000, num_env_steps = 2068000, scores =  12467.115 (n= 1), score_ema =  12532.802, actor_loss = -1028.136, critic_loss = 36.777, entropy_coef_loss = 0.178, entropy_coef = 0.321, rollout_stds = 0.380 ± 0.178, action_magnitude = 0.727 ± 0.272, n_updates = 2058000, time = 10.9, total_time = 23178.7
#
# step = 2069000, num_env_steps = 2069000, scores =  12422.079 (n= 1), score_ema =  12505.121, actor_loss = -1033.796, critic_loss = 33.736, entropy_coef_loss = 0.002, entropy_coef = 0.320, rollout_stds = 0.324 ± 0.166, action_magnitude = 0.733 ± 0.273, n_updates = 2059000, time = 10.9, total_time = 23189.6
#
# step = 2070000, num_env_steps = 2070000, scores =  12659.616 (n= 1), score_ema =  12543.745, actor_loss = -1027.053, critic_loss = 34.010, entropy_coef_loss = 0.678, entropy_coef = 0.326, rollout_stds = 0.357 ± 0.165, action_magnitude = 0.736 ± 0.266, n_updates = 2060000, time = 10.9, total_time = 23200.4
# saved experiment log 2024-10-10_19-36-32_501308~7W3lI0 at experiment_logs/HalfCheetah-v4/sac/2024-10-10_19-36-32_501308~7W3lI0.json
#
# step = 2071000, num_env_steps = 2071000, scores =  12545.878 (n= 1), score_ema =  12544.278, actor_loss = -1044.633, critic_loss = 27.842, entropy_coef_loss = 0.085, entropy_coef = 0.323, rollout_stds = 0.484 ± 0.162, action_magnitude = 0.727 ± 0.276, n_updates = 2061000, time = 11.1, total_time = 23211.5
#
# step = 2072000, num_env_steps = 2072000, scores =  12523.822 (n= 1), score_ema =  12539.164, actor_loss = -1030.688, critic_loss = 36.251, entropy_coef_loss = 0.510, entropy_coef = 0.315, rollout_stds = 0.443 ± 0.172, action_magnitude = 0.730 ± 0.272, n_updates = 2062000, time = 10.9, total_time = 23222.4
#
# step = 2073000, num_env_steps = 2073000, scores =  12655.193 (n= 1), score_ema =  12568.171, actor_loss = -1026.151, critic_loss = 23.776, entropy_coef_loss = -0.362, entropy_coef = 0.323, rollout_stds = 0.554 ± 0.122, action_magnitude = 0.729 ± 0.268, n_updates = 2063000, time = 10.9, total_time = 23233.3
#
# step = 2074000, num_env_steps = 2074000, scores =  7851.235 (n= 1), score_ema =  11388.937, actor_loss = -1025.221, critic_loss = 22.488, entropy_coef_loss = 0.055, entropy_coef = 0.319, rollout_stds = 0.455 ± 0.172, action_magnitude = 0.638 ± 0.301, n_updates = 2064000, time = 10.8, total_time = 23244.1
#
# step = 2075000, num_env_steps = 2075000, scores =  12353.117 (n= 1), score_ema =  11629.982, actor_loss = -1018.429, critic_loss = 16.873, entropy_coef_loss = -0.028, entropy_coef = 0.321, rollout_stds = 0.299 ± 0.212, action_magnitude = 0.729 ± 0.274, n_updates = 2065000, time = 10.9, total_time = 23255.0
#
# step = 2076000, num_env_steps = 2076000, scores =  12577.952 (n= 1), score_ema =  11866.975, actor_loss = -1024.359, critic_loss = 15.567, entropy_coef_loss = -0.007, entropy_coef = 0.318, rollout_stds = 0.332 ± 0.141, action_magnitude = 0.723 ± 0.276, n_updates = 2066000, time = 10.8, total_time = 23265.8
#
# step = 2077000, num_env_steps = 2077000, scores =  12725.526 (n= 1), score_ema =  12081.612, actor_loss = -1038.489, critic_loss = 33.923, entropy_coef_loss = 0.469, entropy_coef = 0.316, rollout_stds = 0.449 ± 0.062, action_magnitude = 0.728 ± 0.271, n_updates = 2067000, time = 10.9, total_time = 23276.7
#
# step = 2078000, num_env_steps = 2078000, scores =  12283.572 (n= 1), score_ema =  12132.102, actor_loss = -1028.188, critic_loss = 32.483, entropy_coef_loss = 0.081, entropy_coef = 0.318, rollout_stds = 0.390 ± 0.170, action_magnitude = 0.724 ± 0.273, n_updates = 2068000, time = 10.9, total_time = 23287.6
#
# step = 2079000, num_env_steps = 2079000, scores =  12849.896 (n= 1), score_ema =  12311.551, actor_loss = -1029.078, critic_loss = 41.688, entropy_coef_loss = 0.047, entropy_coef = 0.327, rollout_stds = 0.481 ± 0.075, action_magnitude = 0.728 ± 0.274, n_updates = 2069000, time = 10.8, total_time = 23298.4
#
# step = 2080000, num_env_steps = 2080000, scores =  12628.972 (n= 1), score_ema =  12390.906, actor_loss = -1036.997, critic_loss = 23.367, entropy_coef_loss = 0.450, entropy_coef = 0.317, rollout_stds = 0.399 ± 0.164, action_magnitude = 0.727 ± 0.273, n_updates = 2070000, time = 10.9, total_time = 23309.3
# saved experiment log 2024-10-10_19-36-32_501308~7W3lI0 at experiment_logs/HalfCheetah-v4/sac/2024-10-10_19-36-32_501308~7W3lI0.json
#
# step = 2081000, num_env_steps = 2081000, scores =  12671.319 (n= 1), score_ema =  12461.009, actor_loss = -1036.064, critic_loss = 22.311, entropy_coef_loss = -0.341, entropy_coef = 0.322, rollout_stds = 0.467 ± 0.163, action_magnitude = 0.728 ± 0.271, n_updates = 2071000, time = 11.1, total_time = 23320.4
#
# step = 2082000, num_env_steps = 2082000, scores =  12791.043 (n= 1), score_ema =  12543.518, actor_loss = -1036.787, critic_loss = 19.979, entropy_coef_loss = 0.342, entropy_coef = 0.320, rollout_stds = 0.458 ± 0.148, action_magnitude = 0.736 ± 0.267, n_updates = 2072000, time = 10.9, total_time = 23331.3
#
# step = 2083000, num_env_steps = 2083000, scores =  12284.546 (n= 1), score_ema =  12478.775, actor_loss = -1029.219, critic_loss = 22.163, entropy_coef_loss = -0.009, entropy_coef = 0.310, rollout_stds = 0.491 ± 0.175, action_magnitude = 0.726 ± 0.270, n_updates = 2073000, time = 10.9, total_time = 23342.1
#
# step = 2084000, num_env_steps = 2084000, scores =  12712.997 (n= 1), score_ema =  12537.330, actor_loss = -1019.202, critic_loss = 19.722, entropy_coef_loss = 0.494, entropy_coef = 0.311, rollout_stds = 0.379 ± 0.172, action_magnitude = 0.731 ± 0.268, n_updates = 2074000, time = 10.9, total_time = 23353.0
#
# step = 2085000, num_env_steps = 2085000, scores =  12721.095 (n= 1), score_ema =  12583.271, actor_loss = -1033.190, critic_loss = 15.323, entropy_coef_loss = 0.240, entropy_coef = 0.319, rollout_stds = 0.480 ± 0.058, action_magnitude = 0.725 ± 0.273, n_updates = 2075000, time = 10.8, total_time = 23363.8
#
# step = 2086000, num_env_steps = 2086000, scores =  12663.359 (n= 1), score_ema =  12603.293, actor_loss = -1018.939, critic_loss = 15.773, entropy_coef_loss = -0.668, entropy_coef = 0.318, rollout_stds = 0.375 ± 0.152, action_magnitude = 0.738 ± 0.266, n_updates = 2076000, time = 10.8, total_time = 23374.7
#
# step = 2087000, num_env_steps = 2087000, scores =  12803.625 (n= 1), score_ema =  12653.376, actor_loss = -1010.137, critic_loss = 42.964, entropy_coef_loss = -0.240, entropy_coef = 0.318, rollout_stds = 0.438 ± 0.179, action_magnitude = 0.733 ± 0.268, n_updates = 2077000, time = 10.9, total_time = 23385.5
#
# step = 2088000, num_env_steps = 2088000, scores =  12499.794 (n= 1), score_ema =  12614.981, actor_loss = -1018.753, critic_loss = 16.486, entropy_coef_loss = -0.217, entropy_coef = 0.316, rollout_stds = 0.310 ± 0.155, action_magnitude = 0.729 ± 0.273, n_updates = 2078000, time = 10.9, total_time = 23396.4
#
# step = 2089000, num_env_steps = 2089000, scores =  12614.175 (n= 1), score_ema =  12614.779, actor_loss = -1019.781, critic_loss = 20.275, entropy_coef_loss = -0.079, entropy_coef = 0.320, rollout_stds = 0.428 ± 0.168, action_magnitude = 0.727 ± 0.270, n_updates = 2079000, time = 10.9, total_time = 23407.3
#
# step = 2090000, num_env_steps = 2090000, scores =  12698.733 (n= 1), score_ema =  12635.768, actor_loss = -1020.333, critic_loss = 15.132, entropy_coef_loss = 0.607, entropy_coef = 0.318, rollout_stds = 0.343 ± 0.186, action_magnitude = 0.723 ± 0.273, n_updates = 2080000, time = 10.9, total_time = 23418.1
# saved experiment log 2024-10-10_19-36-32_501308~7W3lI0 at experiment_logs/HalfCheetah-v4/sac/2024-10-10_19-36-32_501308~7W3lI0.json
#
# step = 2091000, num_env_steps = 2091000, scores =  12478.777 (n= 1), score_ema =  12596.520, actor_loss = -1028.271, critic_loss = 24.732, entropy_coef_loss = -0.469, entropy_coef = 0.318, rollout_stds = 0.469 ± 0.076, action_magnitude = 0.725 ± 0.277, n_updates = 2081000, time = 11.1, total_time = 23429.2
#
# step = 2092000, num_env_steps = 2092000, scores =  12690.926 (n= 1), score_ema =  12620.122, actor_loss = -1043.830, critic_loss = 20.716, entropy_coef_loss = -0.272, entropy_coef = 0.312, rollout_stds = 0.453 ± 0.137, action_magnitude = 0.728 ± 0.269, n_updates = 2082000, time = 10.9, total_time = 23440.1
#
# step = 2093000, num_env_steps = 2093000, scores =  12646.412 (n= 1), score_ema =  12626.694, actor_loss = -1021.771, critic_loss = 34.537, entropy_coef_loss = 0.123, entropy_coef = 0.325, rollout_stds = 0.545 ± 0.112, action_magnitude = 0.731 ± 0.272, n_updates = 2083000, time = 11.5, total_time = 23451.6
#
# step = 2094000, num_env_steps = 2094000, scores =  12773.205 (n= 1), score_ema =  12663.322, actor_loss = -1036.745, critic_loss = 18.790, entropy_coef_loss = 0.011, entropy_coef = 0.324, rollout_stds = 0.439 ± 0.132, action_magnitude = 0.736 ± 0.266, n_updates = 2084000, time = 11.3, total_time = 23462.8
#
# saved experiment log 2024-10-10_19-36-32_501308~7W3lI0 at experiment_logs/HalfCheetah-v4/sac/2024-10-10_19-36-32_501308~7W3lI0.json
# keyboard interrupt
# closing envs
# envs closed
# model db closed
# done

# %%
algo.policy
