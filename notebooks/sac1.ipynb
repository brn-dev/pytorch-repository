# %%
import inspect
import os
import time
from pathlib import Path

import gymnasium
from gymnasium import Env
from gymnasium.vector import VectorEnv

from sac import init_action_selector, init_policy, init_optimizer, wrap_env, policy_construction_hyper_parameter
from src.datetime import get_current_timestamp
from src.experiment_logging.experiment_logger import ExperimentLogger, log_experiment
from src.model_db.model_db import ModelDB
from src.model_db.dummy_model_db import DummyModelDB
from src.np_functions import inv_symmetric_log
from src.reinforcement_learning.algorithms.policy_mitosis.mitosis_policy_info import MitosisPolicyInfo
from src.model_db.tiny_model_db import TinyModelDB
from src.module_analysis import count_parameters, get_gradients_per_parameter
from src.moving_averages import ExponentialMovingAverage
from src.reinforcement_learning.core.action_selectors.action_selector import ActionSelector
from src.reinforcement_learning.core.action_selectors.predicted_std_action_selector import PredictedStdActionSelector
from src.reinforcement_learning.core.action_selectors.state_dependent_noise_action_selector import \
    StateDependentNoiseActionSelector
from src.reinforcement_learning.core.generalized_advantage_estimate import compute_episode_returns, compute_returns
from src.reinforcement_learning.core.policies.base_policy import BasePolicy
from src.reinforcement_learning.core.policy_construction import InitActionSelectorFunction, PolicyConstruction
from src.reinforcement_learning.gym.envs.test_env import TestEnv
from src.schedulers import FixedValueScheduler, OneStepRecursiveScheduler
from src.stopwatch import Stopwatch
from src.summary_statistics import format_summary_statics
from src.reinforcement_learning.core.policies.actor_critic_policy import ActorCriticPolicy
from typing import Any, SupportsFloat, Optional
from gymnasium.wrappers import RecordVideo, AutoResetWrapper, NormalizeReward, TransformReward, TransformObservation, ClipAction
from src.reinforcement_learning.core.callback import Callback
from src.reinforcement_learning.algorithms.sac.sac import SAC, SAC_DEFAULT_OPTIMIZER_PROVIDER
from src.reinforcement_learning.algorithms.ppo.ppo import PPO, PPOLoggingConfig
from src.reinforcement_learning.core.normalization import NormalizationType
from src.torch_device import set_default_torch_device, optimizer_to_device
from src.reinforcement_learning.gym.parallelize_env import parallelize_env_async
from torch.distributions import Normal, Categorical

import torch
from torch import optim, nn
import torch.distributions as dist
import gymnasium as gym
import numpy as np

from src.torch_functions import antisymmetric_power

# %load_ext autoreload
# %autoreload 2
# Out:
# pygame 2.5.2 (SDL 2.28.3, Python 3.11.7)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
from src.summary_statistics import maybe_compute_summary_statistics
from src.reinforcement_learning.core.loss_config import LossLoggingConfig
from src.reinforcement_learning.algorithms.sac.sac import SAC, SACLoggingConfig
def get_setup() -> dict[str, str]:
    import inspect
    import sac
    return {
        'sac.py': inspect.getsource(sac),
        'notebook': _ih[1] + '\n\n' + _ih[-1], # first and last cell input (imports and this cell)
    }

policy_id: str
policy: BasePolicy
optimizer: optim.Optimizer
wrapped_env: Env
steps_trained: int
def get_policy(create_new_if_exists: bool):
    
    global policy_id, policy, optimizer, wrapped_env, steps_trained
    
    policy_in_ram = 'policy' in globals()
    if not policy_in_ram or create_new_if_exists:
        if not policy_in_ram:
            print('No policy in RAM, creating a new one')
        
        policy_id = get_current_timestamp()
        policy, optimizer, wrapped_env = PolicyConstruction.init_from_info(
            env=env,
            info=PolicyConstruction.create_policy_initialization_info(
                init_action_selector=init_action_selector,
                init_policy=init_policy,
                init_optimizer=init_optimizer,
                wrap_env=wrap_env,
                hyper_parameters=policy_construction_hyper_parameter,
            ),
        )
        steps_trained = 0
        print(f'New policy {policy_id} created')
    
    if parent_policy_id is not None:
        model_entry = policy_db.load_model_state_dict(policy, parent_policy_id)
        steps_trained = model_entry['model_info']['steps_trained']
        print(f'Loading state dict from policy {parent_policy_id}')
    
    print(f'Using policy {policy_id} with parent policy {parent_policy_id}')
    return policy_id, policy, optimizer, wrapped_env, steps_trained

score_mean_ema = ExponentialMovingAverage(alpha=0.25)
step_stopwatch = Stopwatch()
total_stopwatch = Stopwatch()
best_iteration_score = -1e6

def on_rollout_done(rl: SAC, step: int, info: dict[str, Any], scheduler_values: dict[str, Any]):
    
    if step % 1000 != 0:
        return
    
    tail_indices = rl.buffer.tail_indices(1000)
    
    # rewards = rl.buffer.rewards[tail_indices]
    # if 'raw_rewards' in info['rollout']:
    #     rewards = info['rollout']['raw_rewards']
    
    # episode_scores = compute_episode_returns(
    #     rewards=rewards,
    #     episode_starts=np.repeat(np.arange(len(tail_indices)).reshape(-1, 1), num_envs, axis=1) % 1000 == 0,
    #     last_episode_starts=info['last_episode_starts'],
    #     gamma=1.0,
    #     gae_lambda=1.0,
    #     normalize_rewards=None,
    #     remove_unfinished_episodes=True,
    # )
    
    episode_scores = rl.buffer.compute_most_recent_episode_scores(rl.num_envs)
    
    if len(episode_scores) > 0:
    
        global best_iteration_score
        iteration_score = episode_scores.mean()
        score_moving_average = score_mean_ema.update(iteration_score)
        if iteration_score >= best_iteration_score:
            best_iteration_score = iteration_score
            policy_db.save_model_state_dict(
                model_id=policy_id,
                parent_model_id=parent_policy_id,
                model_info={
                    'score': iteration_score.item(),
                    'steps_trained': steps_trained,
                    'wrap_env_source_code': wrap_env_source_code_source,
                    'init_policy_source_code': init_policy_source
                },
                model=policy,
                optimizer=optimizer,
            )
        info['score_moving_average'] = score_moving_average
    
    info['episode_scores'] = episode_scores
        
def on_optimization_done(rl: SAC, step: int, info: dict[str, Any], scheduler_values: dict[str, Any]):
    # global steps_trained
    # steps_trained += rl.buffer.pos
    
    if step % 1000 != 0:
        return
    num_env_steps = step * rl.num_envs
    
    step_time = step_stopwatch.reset()
    total_time = total_stopwatch.time_passed()
    
    tail_indices = rl.buffer.tail_indices(1000)
    
    episode_scores = info.get('episode_scores')
    score_moving_average = info.get('score_moving_average') or 0.0
    
    scores = format_summary_statics(
        episode_scores, 
        mean_format=' 6.3f',
        std_format='4.3f',
        min_value_format=' 6.3f',
        max_value_format='5.3f',
        n_format='>2'
    )
    # scores2 = format_summary_statics(
    #     rl.buffer.compute_most_recent_episode_scores(rl.num_envs, lambda r: 1 * r), 
    #     mean_format=' 6.3f',
    #     std_format='4.3f',
    #     min_value_format=' 6.3f',
    #     max_value_format='5.3f',
    #     n_format='>2'
    # )
    # advantages = format_summary_statics(
    #     rl.buffer.advantages, 
    #     mean_format=' 6.3f',
    #     std_format='.1f',
    #     min_value_format=' 7.3f',
    #     max_value_format='6.3f',
    # )
    actor_loss = format_summary_statics(
        info['final_actor_loss'],  
        mean_format=' 5.3f',
        # std_format='5.3f',
        std_format=None,
        min_value_format=None,
        max_value_format=None,
    )
    # actor_loss_raw = format_summary_statics(
    #     info['raw_actor_loss'],  
    #     mean_format=' 5.3f',
    #     std_format='5.3f',
    #     min_value_format=None,
    #     max_value_format=None,
    # )
    entropy_coef_loss = None if 'final_entropy_coef_loss' not in info else format_summary_statics(
        info['final_entropy_coef_loss'], 
        mean_format='5.3f',
#         std_format='5.3f',
        std_format=None,
        min_value_format=None,
        max_value_format=None,
    )
    critic_loss = format_summary_statics(
        info['final_critic_loss'], 
        mean_format='5.3f',
#         std_format='5.3f',
        std_format=None,
        min_value_format=None,
        max_value_format=None,
    )
    entropy_coef = format_summary_statics(
        info['entropy_coef'],
        mean_format='5.3f',
#         std_format='5.3f',
        std_format=None,
        min_value_format=None,
        max_value_format=None,
    )
    # resets = format_summary_statics(
    #     rl.buffer.dones.astype(int).sum(axis=0), 
    #     mean_format='.2f',
    #     std_format=None,
    #     min_value_format='1d',
    #     max_value_format=None,
    # )
    # kl_div = info['actor_kl_divergence'][-1]
    # grad_norm = format_summary_statics(
    #     info['grad_norm'], 
    #     mean_format=' 6.3f',
    #     std_format='.1f',
    #     min_value_format=' 7.3f',
    #     max_value_format='6.3f',
    # )
    action_stds = info['rollout'].get('action_stds')
    if action_stds is not None:
        rollout_action_stds = format_summary_statics(
            action_stds,
            mean_format='5.3f',
            std_format='5.3f',
            min_value_format=None,
            max_value_format=None,
        )
    else:
        rollout_action_stds = 'N/A'
    action_magnitude = format_summary_statics(
        np.abs(rl.buffer.actions[tail_indices]),
        mean_format='5.3f',
        std_format='5.3f',
        min_value_format=None,
        max_value_format=None,
    )
    # ppo_epochs = info['nr_ppo_epochs']
    # ppo_updates = info['nr_ppo_updates']
    # expl_var = rl.buffer.compute_critic_explained_variance()
    print(f"{step = : >7}, "
          f"{num_env_steps = : >7}, "
          f"{scores = :s}, "
          # f"{scores2 = :s}, "
          f'score_ema = {score_moving_average: 6.3f}, '
          # f"{advantages = :s}, "
          f"{actor_loss = :s}, "
          # f"{actor_loss_raw = :s}, "
          +(f"{entropy_coef_loss = :s}, " if entropy_coef_loss is not None else '')+
          f"{critic_loss = :s}, "
          f"{entropy_coef = :s}, "
          f"rollout_stds = {rollout_action_stds:s}, "
          f"{action_magnitude = :s}, "
          # f"{expl_var = :.3f}, "
          # f"{kl_div = :.4f}, "
          # f"{ppo_epochs = }, "
          # f"{ppo_updates = }, "
          # f"{grad_norm = :s}, "
          f"n_updates = {rl.gradient_steps_performed}, "
          # f"{resets = :s}, "
          f"time = {step_time:4.1f}, "
          f"total_time = {total_time:4.1f} \n"
          )
    logger.add_item({
        'step': step,
        'num_env_steps': num_env_steps,
        'scores': maybe_compute_summary_statistics(episode_scores),
        'actor_loss': maybe_compute_summary_statistics(info['final_actor_loss']),
        'entropy_coef_loss': maybe_compute_summary_statistics(info.get('final_entropy_coef_loss')),
        'critic_loss': maybe_compute_summary_statistics(info['final_critic_loss']),
        'entropy_coef': maybe_compute_summary_statistics(info['entropy_coef']),
        'action_stds': maybe_compute_summary_statistics(action_stds),
        'action_magnitude': maybe_compute_summary_statistics(np.abs(rl.buffer.actions[tail_indices])),
        'num_gradient_steps': rl.gradient_steps_performed,
        'step_time': step_time,
        'total_time': total_time
    })
    if step % 10000 == 0:
        logger.save_experiment_log()
        print()
    print()
    
    # if episode_scores is not None and len(episode_scores) > 0 and episode_scores.mean().item() < -500:
    #     logger.save_experiment_log()
    #     raise ValueError('Score too low, policy probably fucked :(')

device = torch.device("cuda:0") if True else torch.device('cpu')
print(f'using device {device}')

def create_env(render_mode: str | None):
    return gym.make(env_name, render_mode=render_mode, **env_kwargs)

wrap_env_source_code_source = inspect.getsource(wrap_env)
init_policy_source = inspect.getsource(init_policy)

env_name = 'HalfCheetah-v4'
# env_kwargs = {'forward_reward_weight': 1.25, 'healthy_reward': 0.5, 'ctrl_cost_weight': 0.001 }
# env_kwargs = {'forward_reward_weight': 1.25, 'ctrl_cost_weight': 0.1 }
# env_kwargs = {'forward_reward_weight': 1.25, 'ctrl_cost_weight': 0.05 }
env_kwargs = {}
num_envs = 1
    
# policy_db = TinyModelDB[MitosisPolicyInfo](base_path=f'saved_models/rl/{env_name}')
policy_db = DummyModelDB[MitosisPolicyInfo]()
print(f'{policy_db = }')

parent_policy_id=None  # '2024-04-28_20.57.23'

# TODO
# env = parallelize_env_async(lambda: create_env(render_mode=None), num_envs)
env = create_env(render_mode=None)

logger = ExperimentLogger(f'experiment_logs/{env_name}/sac/')

try:
    policy_id, policy, optimizer, wrapped_env, steps_trained = get_policy(create_new_if_exists=False)
    print(f'{count_parameters(policy) = }')
    print(f'{env = }, {num_envs = }')
        
    with ((torch.autograd.set_detect_anomaly(False))):
        algo = SAC(
            env=wrapped_env,
            policy=policy,
            actor_optimizer_provider=lambda params: optim.Adam(params, lr=3e-4),  # (params, lr=3e-4, betas=(0.5, 0.999)),
            critic_optimizer_provider=lambda params: optim.Adam(params, lr=3e-4),  # (params, lr=3e-4, betas=(0.5, 0.999)),
            # weigh_and_reduce_actor_loss=lambda l: 1 * l.mean(),
            # weigh_critic_loss=lambda l: 1 * l,
            buffer_size=1_000_000,
            reward_scale=5,
            gamma=0.99,
            tau=0.005,
            entropy_coef_optimizer_provider=lambda params: optim.Adam(params, lr=3e-4),
            entropy_coef=1.0,
            rollout_steps=1,
            gradient_steps=1,
            warmup_steps=10_000,
            optimization_batch_size=256,
            target_update_interval=1,
            # sde_noise_sample_freq=50,
            callback=Callback(
                on_rollout_done=on_rollout_done,
                rollout_schedulers={},
                on_optimization_done=on_optimization_done,
                optimization_schedulers={},
            ),
            logging_config=SACLoggingConfig(log_rollout_infos=True, log_rollout_action_stds=True,
                                            log_last_obs=True, log_entropy_coef=True,
                                            entropy_coef_loss=LossLoggingConfig(log_final=True),
                                            actor_loss=LossLoggingConfig(log_final=True, log_raw=True),
                                            critic_loss=LossLoggingConfig(log_final=True)),
            torch_device=device,
        )
        total_stopwatch.reset()
        with log_experiment(
            logger,
            experiment_tags=algo.collect_tags(),
            hyper_parameters=algo.collect_hyper_parameters(),
            setup=get_setup(),
        ) as x:
            logger.save_experiment_log()
            print('\nStarting Training\n\n')
            # import cProfile
            # pr = cProfile.Profile()
            # pr.enable()
            algo.learn(5_000_000)
            # pr.disable()  
            # pr.dump_stats('profile_stats.pstat')
except KeyboardInterrupt:
    print('keyboard interrupt')
finally:
    print('closing envs')
    time.sleep(0.5)
    env.close()
    print('envs closed')
    policy_db.close()
    print('model db closed')
    

print('done')
# Out:
# using device cuda:0
# policy_db = DummyModelDB()
# No policy in RAM, creating a new one
# New policy 2024-10-05 13:18:07.042509 created
# Using policy 2024-10-05 13:18:07.042509 with parent policy None
# count_parameters(policy) = 217870
# env = <TimeLimit<OrderEnforcing<PassiveEnvChecker<HalfCheetahEnv<HalfCheetah-v4>>>>>, num_envs = 1
# Grabbing system information... done!
# saved experiment log 2024-10-05_13-18-07_731665~48j0N7 at experiment_logs/HalfCheetah-v4/sac/2024-10-05_13-18-07_731665~48j0N7.json
#
# Starting Training
#
# step =   10000, num_env_steps =   10000, scores = -265.301 (n= 1), score_ema = -262.325, actor_loss = -2.978, entropy_coef_loss = 0.000, critic_loss = 18.399, entropy_coef = 1.000, rollout_stds = N/A, action_magnitude = 0.499 ± 0.291, n_updates = 1, time =  5.0, total_time =  4.2
#
# saved experiment log 2024-10-05_13-18-07_731665~48j0N7 at experiment_logs/HalfCheetah-v4/sac/2024-10-05_13-18-07_731665~48j0N7.json
#
# step =   11000, num_env_steps =   11000, scores = -137.146 (n= 1), score_ema = -231.030, actor_loss = -15.702, entropy_coef_loss = -2.583, critic_loss = 11.718, entropy_coef = 0.746, rollout_stds = 0.867 ± 0.063, action_magnitude = 0.538 ± 0.290, n_updates = 1001, time =  8.5, total_time = 12.7
#
# step =   12000, num_env_steps =   12000, scores = -185.195 (n= 1), score_ema = -219.572, actor_loss = -21.573, entropy_coef_loss = -5.152, critic_loss = 15.131, entropy_coef = 0.557, rollout_stds = 0.850 ± 0.041, action_magnitude = 0.575 ± 0.295, n_updates = 2001, time =  8.6, total_time = 21.4
#
# step =   13000, num_env_steps =   13000, scores = -256.215 (n= 1), score_ema = -228.732, actor_loss = -26.670, entropy_coef_loss = -6.898, critic_loss = 21.245, entropy_coef = 0.416, rollout_stds = 0.818 ± 0.047, action_magnitude = 0.535 ± 0.288, n_updates = 3001, time =  8.6, total_time = 30.0
#
# step =   14000, num_env_steps =   14000, scores = -253.848 (n= 1), score_ema = -235.011, actor_loss = -29.499, entropy_coef_loss = -7.770, critic_loss = 20.745, entropy_coef = 0.317, rollout_stds = 0.822 ± 0.051, action_magnitude = 0.547 ± 0.288, n_updates = 4001, time =  8.7, total_time = 38.7
#
# step =   15000, num_env_steps =   15000, scores = -225.766 (n= 1), score_ema = -232.700, actor_loss = -35.383, entropy_coef_loss = -8.430, critic_loss = 23.021, entropy_coef = 0.246, rollout_stds = 0.818 ± 0.048, action_magnitude = 0.564 ± 0.294, n_updates = 5001, time =  8.9, total_time = 47.6
#
# step =   16000, num_env_steps =   16000, scores = -233.532 (n= 1), score_ema = -232.908, actor_loss = -44.540, entropy_coef_loss = -5.832, critic_loss = 23.486, entropy_coef = 0.196, rollout_stds = 0.776 ± 0.081, action_magnitude = 0.590 ± 0.294, n_updates = 6001, time =  8.8, total_time = 56.4
#
# step =   17000, num_env_steps =   17000, scores = -268.972 (n= 1), score_ema = -241.924, actor_loss = -49.644, entropy_coef_loss = -5.151, critic_loss = 23.969, entropy_coef = 0.158, rollout_stds = 0.775 ± 0.120, action_magnitude = 0.619 ± 0.299, n_updates = 7001, time =  9.0, total_time = 65.4
#
# step =   18000, num_env_steps =   18000, scores = -52.823 (n= 1), score_ema = -194.649, actor_loss = -51.778, entropy_coef_loss = -4.078, critic_loss = 24.500, entropy_coef = 0.127, rollout_stds = 0.760 ± 0.082, action_magnitude = 0.662 ± 0.295, n_updates = 8001, time =  8.7, total_time = 74.1
#
# step =   19000, num_env_steps =   19000, scores = -27.089 (n= 1), score_ema = -152.759, actor_loss = -52.809, entropy_coef_loss = -4.146, critic_loss = 25.269, entropy_coef = 0.103, rollout_stds = 0.764 ± 0.073, action_magnitude = 0.689 ± 0.292, n_updates = 9001, time =  9.1, total_time = 83.2
#
# step =   20000, num_env_steps =   20000, scores = -194.306 (n= 1), score_ema = -163.146, actor_loss = -50.189, entropy_coef_loss = -3.938, critic_loss = 35.299, entropy_coef = 0.082, rollout_stds = 0.670 ± 0.078, action_magnitude = 0.692 ± 0.294, n_updates = 10001, time = 10.2, total_time = 93.4
#
# saved experiment log 2024-10-05_13-18-07_731665~48j0N7 at experiment_logs/HalfCheetah-v4/sac/2024-10-05_13-18-07_731665~48j0N7.json
#
# step =   21000, num_env_steps =   21000, scores = -242.509 (n= 1), score_ema = -182.987, actor_loss = -57.605, entropy_coef_loss = -3.094, critic_loss = 42.713, entropy_coef = 0.066, rollout_stds = 0.509 ± 0.055, action_magnitude = 0.719 ± 0.295, n_updates = 11001, time = 11.7, total_time = 105.0
#
# step =   22000, num_env_steps =   22000, scores =  90.065 (n= 1), score_ema = -114.724, actor_loss = -50.943, entropy_coef_loss = -3.782, critic_loss = 25.467, entropy_coef = 0.052, rollout_stds = 0.324 ± 0.105, action_magnitude = 0.711 ± 0.291, n_updates = 12001, time = 12.7, total_time = 117.7
#
# step =   23000, num_env_steps =   23000, scores =  656.331 (n= 1), score_ema =  78.040, actor_loss = -52.738, entropy_coef_loss = -2.246, critic_loss = 22.022, entropy_coef = 0.043, rollout_stds = 0.287 ± 0.121, action_magnitude = 0.652 ± 0.302, n_updates = 13001, time = 11.4, total_time = 129.1
#
# step =   24000, num_env_steps =   24000, scores =  845.386 (n= 1), score_ema =  269.876, actor_loss = -66.894, entropy_coef_loss = -0.429, critic_loss = 29.831, entropy_coef = 0.040, rollout_stds = 0.338 ± 0.130, action_magnitude = 0.652 ± 0.300, n_updates = 14001, time = 10.8, total_time = 139.8
#
# step =   25000, num_env_steps =   25000, scores =  1045.007 (n= 1), score_ema =  463.659, actor_loss = -68.039, entropy_coef_loss = -1.899, critic_loss = 32.271, entropy_coef = 0.043, rollout_stds = 0.253 ± 0.109, action_magnitude = 0.648 ± 0.302, n_updates = 15001, time = 11.0, total_time = 150.8
#
# step =   26000, num_env_steps =   26000, scores =  1047.603 (n= 1), score_ema =  609.645, actor_loss = -71.961, entropy_coef_loss = 0.219, critic_loss = 33.819, entropy_coef = 0.050, rollout_stds = 0.306 ± 0.103, action_magnitude = 0.674 ± 0.300, n_updates = 16001, time = 11.0, total_time = 161.8
#
# step =   27000, num_env_steps =   27000, scores =  1293.914 (n= 1), score_ema =  780.712, actor_loss = -72.824, entropy_coef_loss = -1.211, critic_loss = 38.041, entropy_coef = 0.056, rollout_stds = 0.294 ± 0.102, action_magnitude = 0.690 ± 0.296, n_updates = 17001, time = 12.6, total_time = 174.4
#
# step =   28000, num_env_steps =   28000, scores =  1370.004 (n= 1), score_ema =  928.035, actor_loss = -93.317, entropy_coef_loss = 2.772, critic_loss = 42.277, entropy_coef = 0.064, rollout_stds = 0.257 ± 0.081, action_magnitude = 0.701 ± 0.295, n_updates = 18001, time = 12.4, total_time = 186.9
#
# step =   29000, num_env_steps =   29000, scores =  1680.501 (n= 1), score_ema =  1116.152, actor_loss = -99.787, entropy_coef_loss = 0.761, critic_loss = 44.117, entropy_coef = 0.072, rollout_stds = 0.197 ± 0.070, action_magnitude = 0.708 ± 0.298, n_updates = 19001, time = 12.1, total_time = 199.0
#
# step =   30000, num_env_steps =   30000, scores =  1789.358 (n= 1), score_ema =  1284.453, actor_loss = -120.717, entropy_coef_loss = -0.414, critic_loss = 44.444, entropy_coef = 0.081, rollout_stds = 0.377 ± 0.066, action_magnitude = 0.727 ± 0.292, n_updates = 20001, time = 12.0, total_time = 211.0
#
# saved experiment log 2024-10-05_13-18-07_731665~48j0N7 at experiment_logs/HalfCheetah-v4/sac/2024-10-05_13-18-07_731665~48j0N7.json
#
# step =   31000, num_env_steps =   31000, scores =  1788.529 (n= 1), score_ema =  1410.472, actor_loss = -129.611, entropy_coef_loss = -1.331, critic_loss = 48.172, entropy_coef = 0.090, rollout_stds = 0.400 ± 0.081, action_magnitude = 0.748 ± 0.288, n_updates = 21001, time = 13.0, total_time = 224.0
#
# step =   32000, num_env_steps =   32000, scores =  1965.987 (n= 1), score_ema =  1549.351, actor_loss = -129.761, entropy_coef_loss = -0.221, critic_loss = 402.321, entropy_coef = 0.103, rollout_stds = 0.383 ± 0.106, action_magnitude = 0.751 ± 0.287, n_updates = 22001, time = 11.5, total_time = 235.4
#
# step =   33000, num_env_steps =   33000, scores =  2067.068 (n= 1), score_ema =  1678.780, actor_loss = -166.787, entropy_coef_loss = 2.095, critic_loss = 460.722, entropy_coef = 0.114, rollout_stds = 0.388 ± 0.108, action_magnitude = 0.756 ± 0.284, n_updates = 23001, time = 11.0, total_time = 246.4
#
# step =   34000, num_env_steps =   34000, scores =  2043.721 (n= 1), score_ema =  1770.015, actor_loss = -167.157, entropy_coef_loss = 0.215, critic_loss = 76.729, entropy_coef = 0.122, rollout_stds = 0.561 ± 0.130, action_magnitude = 0.748 ± 0.288, n_updates = 24001, time = 12.2, total_time = 258.6
#
# step =   35000, num_env_steps =   35000, scores =  2048.347 (n= 1), score_ema =  1839.598, actor_loss = -190.527, entropy_coef_loss = 0.328, critic_loss = 67.272, entropy_coef = 0.128, rollout_stds = 0.446 ± 0.142, action_magnitude = 0.755 ± 0.283, n_updates = 25001, time = 11.6, total_time = 270.3
#
# step =   36000, num_env_steps =   36000, scores =  2168.524 (n= 1), score_ema =  1921.830, actor_loss = -204.724, entropy_coef_loss = 0.425, critic_loss = 232.190, entropy_coef = 0.137, rollout_stds = 0.455 ± 0.100, action_magnitude = 0.752 ± 0.282, n_updates = 26001, time = 12.3, total_time = 282.6
#
# step =   37000, num_env_steps =   37000, scores =  2046.430 (n= 1), score_ema =  1952.980, actor_loss = -229.786, entropy_coef_loss = -0.834, critic_loss = 103.782, entropy_coef = 0.143, rollout_stds = 0.412 ± 0.124, action_magnitude = 0.742 ± 0.286, n_updates = 27001, time = 11.4, total_time = 294.0
#
# step =   38000, num_env_steps =   38000, scores =  2358.643 (n= 1), score_ema =  2054.395, actor_loss = -242.541, entropy_coef_loss = -0.625, critic_loss = 402.611, entropy_coef = 0.149, rollout_stds = 0.455 ± 0.171, action_magnitude = 0.742 ± 0.282, n_updates = 28001, time = 12.4, total_time = 306.4
#
# step =   39000, num_env_steps =   39000, scores = -424.352 (n= 1), score_ema =  1434.709, actor_loss = -240.879, entropy_coef_loss = -0.545, critic_loss = 137.415, entropy_coef = 0.150, rollout_stds = 0.710 ± 0.066, action_magnitude = 0.720 ± 0.295, n_updates = 29001, time = 11.9, total_time = 318.3
#
# step =   40000, num_env_steps =   40000, scores =  708.002 (n= 1), score_ema =  1253.032, actor_loss = -261.708, entropy_coef_loss = 0.005, critic_loss = 99.423, entropy_coef = 0.150, rollout_stds = 0.659 ± 0.104, action_magnitude = 0.719 ± 0.289, n_updates = 30001, time = 11.8, total_time = 330.1
#
# saved experiment log 2024-10-05_13-18-07_731665~48j0N7 at experiment_logs/HalfCheetah-v4/sac/2024-10-05_13-18-07_731665~48j0N7.json
#
# step =   41000, num_env_steps =   41000, scores =  2483.741 (n= 1), score_ema =  1560.709, actor_loss = -268.877, entropy_coef_loss = -0.415, critic_loss = 127.815, entropy_coef = 0.145, rollout_stds = 0.423 ± 0.150, action_magnitude = 0.741 ± 0.284, n_updates = 31001, time = 11.5, total_time = 341.6
#
# step =   42000, num_env_steps =   42000, scores =  2176.573 (n= 1), score_ema =  1714.675, actor_loss = -281.649, entropy_coef_loss = 0.340, critic_loss = 147.141, entropy_coef = 0.149, rollout_stds = 0.347 ± 0.091, action_magnitude = 0.736 ± 0.284, n_updates = 32001, time = 11.3, total_time = 352.8
#
# step =   43000, num_env_steps =   43000, scores =  2322.550 (n= 1), score_ema =  1866.644, actor_loss = -285.746, entropy_coef_loss = -0.301, critic_loss = 778.993, entropy_coef = 0.153, rollout_stds = 0.450 ± 0.063, action_magnitude = 0.731 ± 0.290, n_updates = 33001, time = 11.3, total_time = 364.1
#
# step =   44000, num_env_steps =   44000, scores =  1497.142 (n= 1), score_ema =  1774.268, actor_loss = -294.862, entropy_coef_loss = 0.313, critic_loss = 103.720, entropy_coef = 0.157, rollout_stds = 0.690 ± 0.040, action_magnitude = 0.711 ± 0.292, n_updates = 34001, time = 11.2, total_time = 375.3
#
# step =   45000, num_env_steps =   45000, scores =  2367.600 (n= 1), score_ema =  1922.601, actor_loss = -307.293, entropy_coef_loss = -0.419, critic_loss = 163.044, entropy_coef = 0.155, rollout_stds = 0.330 ± 0.088, action_magnitude = 0.728 ± 0.289, n_updates = 35001, time = 11.1, total_time = 386.4
#
# step =   46000, num_env_steps =   46000, scores =  2377.822 (n= 1), score_ema =  2036.407, actor_loss = -345.771, entropy_coef_loss = 0.862, critic_loss = 702.923, entropy_coef = 0.157, rollout_stds = 0.406 ± 0.105, action_magnitude = 0.730 ± 0.287, n_updates = 36001, time = 11.1, total_time = 397.5
#
# step =   47000, num_env_steps =   47000, scores =  2337.336 (n= 1), score_ema =  2111.639, actor_loss = -320.464, entropy_coef_loss = -0.937, critic_loss = 198.621, entropy_coef = 0.156, rollout_stds = 0.290 ± 0.065, action_magnitude = 0.733 ± 0.284, n_updates = 37001, time = 12.2, total_time = 409.7
#
# step =   48000, num_env_steps =   48000, scores =  2571.104 (n= 1), score_ema =  2226.505, actor_loss = -359.921, entropy_coef_loss = -0.451, critic_loss = 148.054, entropy_coef = 0.161, rollout_stds = 0.401 ± 0.140, action_magnitude = 0.725 ± 0.286, n_updates = 38001, time = 11.0, total_time = 420.6
#
# step =   49000, num_env_steps =   49000, scores =  2490.050 (n= 1), score_ema =  2292.391, actor_loss = -371.619, entropy_coef_loss = -0.175, critic_loss = 135.798, entropy_coef = 0.165, rollout_stds = 0.344 ± 0.067, action_magnitude = 0.729 ± 0.288, n_updates = 39001, time = 11.7, total_time = 432.3
#
# step =   50000, num_env_steps =   50000, scores =  2468.574 (n= 1), score_ema =  2336.437, actor_loss = -387.590, entropy_coef_loss = 0.414, critic_loss = 424.816, entropy_coef = 0.170, rollout_stds = 0.460 ± 0.117, action_magnitude = 0.730 ± 0.287, n_updates = 40001, time = 12.1, total_time = 444.4
#
# saved experiment log 2024-10-05_13-18-07_731665~48j0N7 at experiment_logs/HalfCheetah-v4/sac/2024-10-05_13-18-07_731665~48j0N7.json
#
# step =   51000, num_env_steps =   51000, scores =  2424.715 (n= 1), score_ema =  2358.507, actor_loss = -395.032, entropy_coef_loss = 0.304, critic_loss = 163.796, entropy_coef = 0.168, rollout_stds = 0.351 ± 0.111, action_magnitude = 0.732 ± 0.286, n_updates = 41001, time = 11.6, total_time = 456.0
#
# step =   52000, num_env_steps =   52000, scores =  2605.395 (n= 1), score_ema =  2420.229, actor_loss = -405.918, entropy_coef_loss = -0.598, critic_loss = 166.764, entropy_coef = 0.175, rollout_stds = 0.506 ± 0.072, action_magnitude = 0.732 ± 0.287, n_updates = 42001, time = 11.2, total_time = 467.2
#
# step =   53000, num_env_steps =   53000, scores =  2648.810 (n= 1), score_ema =  2477.374, actor_loss = -447.218, entropy_coef_loss = 0.538, critic_loss = 194.623, entropy_coef = 0.176, rollout_stds = 0.529 ± 0.143, action_magnitude = 0.740 ± 0.284, n_updates = 43001, time = 11.9, total_time = 479.1
#
# step =   54000, num_env_steps =   54000, scores =  2682.000 (n= 1), score_ema =  2528.530, actor_loss = -419.993, entropy_coef_loss = 0.038, critic_loss = 195.052, entropy_coef = 0.177, rollout_stds = 0.329 ± 0.062, action_magnitude = 0.736 ± 0.281, n_updates = 44001, time = 11.2, total_time = 490.3
#
# step =   55000, num_env_steps =   55000, scores =  2641.605 (n= 1), score_ema =  2556.799, actor_loss = -434.903, entropy_coef_loss = -0.248, critic_loss = 1126.975, entropy_coef = 0.186, rollout_stds = 0.455 ± 0.141, action_magnitude = 0.737 ± 0.286, n_updates = 45001, time = 11.9, total_time = 502.2
#
# step =   56000, num_env_steps =   56000, scores =  2575.766 (n= 1), score_ema =  2561.541, actor_loss = -462.482, entropy_coef_loss = 0.154, critic_loss = 156.727, entropy_coef = 0.189, rollout_stds = 0.541 ± 0.107, action_magnitude = 0.721 ± 0.294, n_updates = 46001, time = 11.1, total_time = 513.3
#
# step =   57000, num_env_steps =   57000, scores =  2786.427 (n= 1), score_ema =  2617.762, actor_loss = -475.623, entropy_coef_loss = -1.295, critic_loss = 156.662, entropy_coef = 0.189, rollout_stds = 0.432 ± 0.092, action_magnitude = 0.733 ± 0.289, n_updates = 47001, time = 11.1, total_time = 524.5
#
# step =   58000, num_env_steps =   58000, scores =  2621.788 (n= 1), score_ema =  2618.769, actor_loss = -467.406, entropy_coef_loss = -0.076, critic_loss = 183.875, entropy_coef = 0.196, rollout_stds = 0.549 ± 0.128, action_magnitude = 0.733 ± 0.289, n_updates = 48001, time = 10.9, total_time = 535.4
#
# step =   59000, num_env_steps =   59000, scores =  2561.726 (n= 1), score_ema =  2604.508, actor_loss = -485.700, entropy_coef_loss = -0.145, critic_loss = 175.916, entropy_coef = 0.195, rollout_stds = 0.350 ± 0.133, action_magnitude = 0.738 ± 0.284, n_updates = 49001, time = 12.1, total_time = 547.5
#
# step =   60000, num_env_steps =   60000, scores =  2839.266 (n= 1), score_ema =  2663.197, actor_loss = -524.861, entropy_coef_loss = -0.215, critic_loss = 228.552, entropy_coef = 0.196, rollout_stds = 0.379 ± 0.092, action_magnitude = 0.733 ± 0.288, n_updates = 50001, time = 12.3, total_time = 559.8
#
# saved experiment log 2024-10-05_13-18-07_731665~48j0N7 at experiment_logs/HalfCheetah-v4/sac/2024-10-05_13-18-07_731665~48j0N7.json
#
# step =   61000, num_env_steps =   61000, scores =  2837.969 (n= 1), score_ema =  2706.890, actor_loss = -511.178, entropy_coef_loss = -0.139, critic_loss = 215.702, entropy_coef = 0.203, rollout_stds = 0.480 ± 0.174, action_magnitude = 0.734 ± 0.288, n_updates = 51001, time = 11.7, total_time = 571.5
#
# step =   62000, num_env_steps =   62000, scores =  2708.846 (n= 1), score_ema =  2707.379, actor_loss = -539.621, entropy_coef_loss = -0.809, critic_loss = 205.160, entropy_coef = 0.207, rollout_stds = 0.483 ± 0.065, action_magnitude = 0.740 ± 0.285, n_updates = 52001, time = 11.6, total_time = 583.0
#
# step =   63000, num_env_steps =   63000, scores =  747.916 (n= 1), score_ema =  2217.513, actor_loss = -548.565, entropy_coef_loss = -0.127, critic_loss = 232.389, entropy_coef = 0.201, rollout_stds = 0.590 ± 0.136, action_magnitude = 0.689 ± 0.296, n_updates = 53001, time = 12.2, total_time = 595.3
#
# step =   64000, num_env_steps =   64000, scores =  2796.120 (n= 1), score_ema =  2362.165, actor_loss = -557.891, entropy_coef_loss = -0.500, critic_loss = 167.540, entropy_coef = 0.207, rollout_stds = 0.469 ± 0.132, action_magnitude = 0.730 ± 0.289, n_updates = 54001, time = 11.7, total_time = 606.9
#
# step =   65000, num_env_steps =   65000, scores =  1314.152 (n= 1), score_ema =  2100.162, actor_loss = -536.360, entropy_coef_loss = -0.316, critic_loss = 181.131, entropy_coef = 0.201, rollout_stds = 0.593 ± 0.073, action_magnitude = 0.699 ± 0.296, n_updates = 55001, time = 11.7, total_time = 618.6
#
# step =   66000, num_env_steps =   66000, scores =  1433.954 (n= 1), score_ema =  1933.610, actor_loss = -551.302, entropy_coef_loss = -0.417, critic_loss = 195.329, entropy_coef = 0.213, rollout_stds = 0.686 ± 0.090, action_magnitude = 0.710 ± 0.293, n_updates = 56001, time = 11.7, total_time = 630.3
#
# step =   67000, num_env_steps =   67000, scores =  2727.257 (n= 1), score_ema =  2132.022, actor_loss = -574.230, entropy_coef_loss = -0.403, critic_loss = 174.102, entropy_coef = 0.211, rollout_stds = 0.420 ± 0.093, action_magnitude = 0.729 ± 0.288, n_updates = 57001, time = 12.0, total_time = 642.3
#
# step =   68000, num_env_steps =   68000, scores =  2726.198 (n= 1), score_ema =  2280.566, actor_loss = -578.355, entropy_coef_loss = -0.195, critic_loss = 204.449, entropy_coef = 0.209, rollout_stds = 0.321 ± 0.056, action_magnitude = 0.731 ± 0.291, n_updates = 58001, time = 12.6, total_time = 655.0
#
# step =   69000, num_env_steps =   69000, scores =  2909.343 (n= 1), score_ema =  2437.760, actor_loss = -579.877, entropy_coef_loss = -0.544, critic_loss = 240.453, entropy_coef = 0.203, rollout_stds = 0.486 ± 0.098, action_magnitude = 0.730 ± 0.288, n_updates = 59001, time = 11.2, total_time = 666.1
#
# step =   70000, num_env_steps =   70000, scores =  2850.771 (n= 1), score_ema =  2541.013, actor_loss = -601.596, entropy_coef_loss = -0.209, critic_loss = 256.186, entropy_coef = 0.206, rollout_stds = 0.427 ± 0.071, action_magnitude = 0.719 ± 0.290, n_updates = 60001, time = 11.8, total_time = 678.0
#
# saved experiment log 2024-10-05_13-18-07_731665~48j0N7 at experiment_logs/HalfCheetah-v4/sac/2024-10-05_13-18-07_731665~48j0N7.json
#
# step =   71000, num_env_steps =   71000, scores =  2811.366 (n= 1), score_ema =  2608.601, actor_loss = -623.212, entropy_coef_loss = 0.864, critic_loss = 213.697, entropy_coef = 0.208, rollout_stds = 0.372 ± 0.038, action_magnitude = 0.730 ± 0.289, n_updates = 61001, time = 11.9, total_time = 689.9
#
# step =   72000, num_env_steps =   72000, scores =  2793.106 (n= 1), score_ema =  2654.727, actor_loss = -620.143, entropy_coef_loss = 0.077, critic_loss = 168.211, entropy_coef = 0.220, rollout_stds = 0.548 ± 0.142, action_magnitude = 0.735 ± 0.288, n_updates = 62001, time = 11.2, total_time = 701.1
#
# step =   73000, num_env_steps =   73000, scores =  2678.879 (n= 1), score_ema =  2660.765, actor_loss = -638.193, entropy_coef_loss = 0.413, critic_loss = 241.340, entropy_coef = 0.212, rollout_stds = 0.406 ± 0.113, action_magnitude = 0.744 ± 0.281, n_updates = 63001, time = 11.2, total_time = 712.4
#
# step =   74000, num_env_steps =   74000, scores =  2895.323 (n= 1), score_ema =  2719.405, actor_loss = -601.405, entropy_coef_loss = 0.252, critic_loss = 197.331, entropy_coef = 0.215, rollout_stds = 0.420 ± 0.112, action_magnitude = 0.743 ± 0.280, n_updates = 64001, time = 11.0, total_time = 723.4
#
# step =   75000, num_env_steps =   75000, scores =  2939.377 (n= 1), score_ema =  2774.398, actor_loss = -610.647, entropy_coef_loss = -0.164, critic_loss = 280.106, entropy_coef = 0.207, rollout_stds = 0.471 ± 0.080, action_magnitude = 0.736 ± 0.287, n_updates = 65001, time = 11.0, total_time = 734.3
#
# step =   76000, num_env_steps =   76000, scores =  2913.794 (n= 1), score_ema =  2809.247, actor_loss = -655.987, entropy_coef_loss = -0.627, critic_loss = 199.862, entropy_coef = 0.213, rollout_stds = 0.396 ± 0.071, action_magnitude = 0.732 ± 0.284, n_updates = 66001, time = 12.4, total_time = 746.8
#
# step =   77000, num_env_steps =   77000, scores =  1473.546 (n= 1), score_ema =  2475.322, actor_loss = -619.418, entropy_coef_loss = -0.465, critic_loss = 220.965, entropy_coef = 0.219, rollout_stds = 0.654 ± 0.047, action_magnitude = 0.685 ± 0.294, n_updates = 67001, time = 11.6, total_time = 758.3
#
# step =   78000, num_env_steps =   78000, scores =  2819.927 (n= 1), score_ema =  2561.473, actor_loss = -638.118, entropy_coef_loss = -0.465, critic_loss = 242.379, entropy_coef = 0.213, rollout_stds = 0.527 ± 0.086, action_magnitude = 0.721 ± 0.289, n_updates = 68001, time = 11.7, total_time = 770.0
#
# step =   79000, num_env_steps =   79000, scores =  3049.180 (n= 1), score_ema =  2683.400, actor_loss = -657.470, entropy_coef_loss = -0.382, critic_loss = 189.066, entropy_coef = 0.217, rollout_stds = 0.422 ± 0.077, action_magnitude = 0.735 ± 0.284, n_updates = 69001, time = 11.6, total_time = 781.6
#
# step =   80000, num_env_steps =   80000, scores =  2928.596 (n= 1), score_ema =  2744.699, actor_loss = -639.194, entropy_coef_loss = 0.223, critic_loss = 1285.846, entropy_coef = 0.217, rollout_stds = 0.346 ± 0.070, action_magnitude = 0.727 ± 0.285, n_updates = 70001, time = 11.5, total_time = 793.1
#
# saved experiment log 2024-10-05_13-18-07_731665~48j0N7 at experiment_logs/HalfCheetah-v4/sac/2024-10-05_13-18-07_731665~48j0N7.json
#
# step =   81000, num_env_steps =   81000, scores =  3048.695 (n= 1), score_ema =  2820.698, actor_loss = -678.602, entropy_coef_loss = 0.518, critic_loss = 244.872, entropy_coef = 0.220, rollout_stds = 0.332 ± 0.120, action_magnitude = 0.729 ± 0.286, n_updates = 71001, time = 11.6, total_time = 804.7
#
# step =   82000, num_env_steps =   82000, scores =  3154.396 (n= 1), score_ema =  2904.123, actor_loss = -698.024, entropy_coef_loss = -0.127, critic_loss = 210.786, entropy_coef = 0.220, rollout_stds = 0.354 ± 0.100, action_magnitude = 0.736 ± 0.282, n_updates = 72001, time = 11.1, total_time = 815.7
#
# step =   83000, num_env_steps =   83000, scores =  3358.767 (n= 1), score_ema =  3017.784, actor_loss = -694.673, entropy_coef_loss = -0.062, critic_loss = 246.971, entropy_coef = 0.219, rollout_stds = 0.371 ± 0.137, action_magnitude = 0.727 ± 0.287, n_updates = 73001, time = 11.2, total_time = 826.9
#
# step =   84000, num_env_steps =   84000, scores =  3137.126 (n= 1), score_ema =  3047.619, actor_loss = -701.517, entropy_coef_loss = -0.390, critic_loss = 215.491, entropy_coef = 0.226, rollout_stds = 0.441 ± 0.169, action_magnitude = 0.728 ± 0.287, n_updates = 74001, time = 11.3, total_time = 838.2
#
# step =   85000, num_env_steps =   85000, scores =  3294.672 (n= 1), score_ema =  3109.382, actor_loss = -661.280, entropy_coef_loss = 0.274, critic_loss = 2310.806, entropy_coef = 0.225, rollout_stds = 0.349 ± 0.072, action_magnitude = 0.729 ± 0.286, n_updates = 75001, time = 11.1, total_time = 849.4
#
# step =   86000, num_env_steps =   86000, scores =  3088.848 (n= 1), score_ema =  3104.249, actor_loss = -717.666, entropy_coef_loss = -0.597, critic_loss = 288.664, entropy_coef = 0.231, rollout_stds = 0.398 ± 0.079, action_magnitude = 0.719 ± 0.290, n_updates = 76001, time = 10.8, total_time = 860.2
#
# step =   87000, num_env_steps =   87000, scores =  3262.041 (n= 1), score_ema =  3143.697, actor_loss = -733.209, entropy_coef_loss = 0.770, critic_loss = 233.511, entropy_coef = 0.224, rollout_stds = 0.361 ± 0.149, action_magnitude = 0.726 ± 0.287, n_updates = 77001, time = 10.8, total_time = 871.0
#
# step =   88000, num_env_steps =   88000, scores =  3336.988 (n= 1), score_ema =  3192.020, actor_loss = -721.270, entropy_coef_loss = 0.739, critic_loss = 248.097, entropy_coef = 0.238, rollout_stds = 0.529 ± 0.113, action_magnitude = 0.732 ± 0.286, n_updates = 78001, time = 10.8, total_time = 881.8
#
# step =   89000, num_env_steps =   89000, scores =  3351.181 (n= 1), score_ema =  3231.810, actor_loss = -708.698, entropy_coef_loss = -0.203, critic_loss = 6822.238, entropy_coef = 0.246, rollout_stds = 0.306 ± 0.111, action_magnitude = 0.736 ± 0.286, n_updates = 79001, time = 10.8, total_time = 892.7
#
# step =   90000, num_env_steps =   90000, scores =  3352.249 (n= 1), score_ema =  3261.920, actor_loss = -751.542, entropy_coef_loss = -0.207, critic_loss = 206.559, entropy_coef = 0.246, rollout_stds = 0.535 ± 0.131, action_magnitude = 0.736 ± 0.282, n_updates = 80001, time = 10.9, total_time = 903.5
#
# saved experiment log 2024-10-05_13-18-07_731665~48j0N7 at experiment_logs/HalfCheetah-v4/sac/2024-10-05_13-18-07_731665~48j0N7.json
#
# step =   91000, num_env_steps =   91000, scores =  3228.783 (n= 1), score_ema =  3253.636, actor_loss = -715.478, entropy_coef_loss = -0.282, critic_loss = 3052.248, entropy_coef = 0.247, rollout_stds = 0.424 ± 0.120, action_magnitude = 0.741 ± 0.279, n_updates = 81001, time = 10.8, total_time = 914.4
#
# step =   92000, num_env_steps =   92000, scores =  3197.929 (n= 1), score_ema =  3239.709, actor_loss = -744.129, entropy_coef_loss = 0.051, critic_loss = 256.214, entropy_coef = 0.256, rollout_stds = 0.381 ± 0.133, action_magnitude = 0.730 ± 0.287, n_updates = 82001, time = 10.8, total_time = 925.2
#
# step =   93000, num_env_steps =   93000, scores =  3239.582 (n= 1), score_ema =  3239.677, actor_loss = -725.562, entropy_coef_loss = -0.362, critic_loss = 3359.918, entropy_coef = 0.254, rollout_stds = 0.319 ± 0.124, action_magnitude = 0.733 ± 0.286, n_updates = 83001, time = 10.9, total_time = 936.1
#
# step =   94000, num_env_steps =   94000, scores =  3490.394 (n= 1), score_ema =  3302.356, actor_loss = -789.788, entropy_coef_loss = 0.042, critic_loss = 262.622, entropy_coef = 0.256, rollout_stds = 0.367 ± 0.088, action_magnitude = 0.729 ± 0.288, n_updates = 84001, time = 10.8, total_time = 946.9
#
# step =   95000, num_env_steps =   95000, scores =  3191.437 (n= 1), score_ema =  3274.627, actor_loss = -754.928, entropy_coef_loss = -0.530, critic_loss = 232.380, entropy_coef = 0.265, rollout_stds = 0.351 ± 0.087, action_magnitude = 0.736 ± 0.284, n_updates = 85001, time = 10.8, total_time = 957.7
#
# step =   96000, num_env_steps =   96000, scores =  3448.449 (n= 1), score_ema =  3318.082, actor_loss = -738.691, entropy_coef_loss = -0.710, critic_loss = 246.214, entropy_coef = 0.268, rollout_stds = 0.360 ± 0.176, action_magnitude = 0.741 ± 0.284, n_updates = 86001, time = 10.8, total_time = 968.5
#
# step =   97000, num_env_steps =   97000, scores =  3374.898 (n= 1), score_ema =  3332.286, actor_loss = -795.530, entropy_coef_loss = 0.349, critic_loss = 246.629, entropy_coef = 0.259, rollout_stds = 0.363 ± 0.152, action_magnitude = 0.736 ± 0.281, n_updates = 87001, time = 10.8, total_time = 979.3
#
# step =   98000, num_env_steps =   98000, scores =  3339.798 (n= 1), score_ema =  3334.164, actor_loss = -783.387, entropy_coef_loss = 0.362, critic_loss = 293.362, entropy_coef = 0.259, rollout_stds = 0.385 ± 0.139, action_magnitude = 0.726 ± 0.290, n_updates = 88001, time = 10.8, total_time = 990.2
#
# step =   99000, num_env_steps =   99000, scores =  3279.033 (n= 1), score_ema =  3320.381, actor_loss = -795.387, entropy_coef_loss = -0.140, critic_loss = 219.680, entropy_coef = 0.267, rollout_stds = 0.529 ± 0.078, action_magnitude = 0.738 ± 0.279, n_updates = 89001, time = 10.9, total_time = 1001.0
#
# step =  100000, num_env_steps =  100000, scores =  3391.759 (n= 1), score_ema =  3338.226, actor_loss = -771.507, entropy_coef_loss = -0.255, critic_loss = 251.284, entropy_coef = 0.271, rollout_stds = 0.341 ± 0.086, action_magnitude = 0.740 ± 0.280, n_updates = 90001, time = 10.8, total_time = 1011.8
#
# saved experiment log 2024-10-05_13-18-07_731665~48j0N7 at experiment_logs/HalfCheetah-v4/sac/2024-10-05_13-18-07_731665~48j0N7.json
#
# step =  101000, num_env_steps =  101000, scores =  3351.866 (n= 1), score_ema =  3341.636, actor_loss = -881.383, entropy_coef_loss = 0.872, critic_loss = 288.377, entropy_coef = 0.274, rollout_stds = 0.372 ± 0.119, action_magnitude = 0.728 ± 0.285, n_updates = 91001, time = 10.8, total_time = 1022.7
#
# step =  102000, num_env_steps =  102000, scores =  3356.695 (n= 1), score_ema =  3345.401, actor_loss = -773.233, entropy_coef_loss = 0.421, critic_loss = 241.922, entropy_coef = 0.266, rollout_stds = 0.481 ± 0.099, action_magnitude = 0.731 ± 0.285, n_updates = 92001, time = 10.8, total_time = 1033.5
#
# step =  103000, num_env_steps =  103000, scores =  3477.234 (n= 1), score_ema =  3378.359, actor_loss = -797.188, entropy_coef_loss = -0.207, critic_loss = 285.515, entropy_coef = 0.282, rollout_stds = 0.373 ± 0.113, action_magnitude = 0.739 ± 0.283, n_updates = 93001, time = 10.8, total_time = 1044.3
#
# step =  104000, num_env_steps =  104000, scores =  3603.589 (n= 1), score_ema =  3434.666, actor_loss = -812.685, entropy_coef_loss = -0.929, critic_loss = 197.315, entropy_coef = 0.276, rollout_stds = 0.409 ± 0.144, action_magnitude = 0.738 ± 0.282, n_updates = 94001, time = 10.8, total_time = 1055.2
#
# step =  105000, num_env_steps =  105000, scores =  3490.212 (n= 1), score_ema =  3448.553, actor_loss = -814.837, entropy_coef_loss = -0.110, critic_loss = 250.323, entropy_coef = 0.280, rollout_stds = 0.325 ± 0.056, action_magnitude = 0.730 ± 0.283, n_updates = 95001, time = 10.8, total_time = 1066.0
#
# step =  106000, num_env_steps =  106000, scores =  3488.610 (n= 1), score_ema =  3458.567, actor_loss = -857.464, entropy_coef_loss = 0.259, critic_loss = 3765.577, entropy_coef = 0.288, rollout_stds = 0.400 ± 0.140, action_magnitude = 0.729 ± 0.289, n_updates = 96001, time = 10.8, total_time = 1076.8
#
# step =  107000, num_env_steps =  107000, scores =  3630.097 (n= 1), score_ema =  3501.449, actor_loss = -828.256, entropy_coef_loss = -0.064, critic_loss = 308.907, entropy_coef = 0.292, rollout_stds = 0.330 ± 0.073, action_magnitude = 0.732 ± 0.283, n_updates = 97001, time = 10.8, total_time = 1087.6
#
# step =  108000, num_env_steps =  108000, scores =  3676.213 (n= 1), score_ema =  3545.140, actor_loss = -845.125, entropy_coef_loss = -0.313, critic_loss = 328.356, entropy_coef = 0.292, rollout_stds = 0.383 ± 0.170, action_magnitude = 0.729 ± 0.284, n_updates = 98001, time = 11.9, total_time = 1099.5
#
# step =  109000, num_env_steps =  109000, scores =  3754.264 (n= 1), score_ema =  3597.421, actor_loss = -869.332, entropy_coef_loss = -0.442, critic_loss = 275.427, entropy_coef = 0.295, rollout_stds = 0.420 ± 0.083, action_magnitude = 0.750 ± 0.273, n_updates = 99001, time = 11.3, total_time = 1110.8
#
# step =  110000, num_env_steps =  110000, scores =  3453.247 (n= 1), score_ema =  3561.378, actor_loss = -888.596, entropy_coef_loss = 0.526, critic_loss = 306.442, entropy_coef = 0.302, rollout_stds = 0.522 ± 0.089, action_magnitude = 0.732 ± 0.284, n_updates = 100001, time = 11.5, total_time = 1122.3
#
# saved experiment log 2024-10-05_13-18-07_731665~48j0N7 at experiment_logs/HalfCheetah-v4/sac/2024-10-05_13-18-07_731665~48j0N7.json
#
# step =  111000, num_env_steps =  111000, scores =  3757.589 (n= 1), score_ema =  3610.431, actor_loss = -911.340, entropy_coef_loss = 0.112, critic_loss = 248.495, entropy_coef = 0.292, rollout_stds = 0.383 ± 0.059, action_magnitude = 0.748 ± 0.279, n_updates = 101001, time = 11.5, total_time = 1133.8
#
# step =  112000, num_env_steps =  112000, scores =  3646.942 (n= 1), score_ema =  3619.558, actor_loss = -913.626, entropy_coef_loss = 0.069, critic_loss = 182.412, entropy_coef = 0.294, rollout_stds = 0.391 ± 0.243, action_magnitude = 0.743 ± 0.279, n_updates = 102001, time = 11.4, total_time = 1145.2
#
# step =  113000, num_env_steps =  113000, scores =  3760.708 (n= 1), score_ema =  3654.846, actor_loss = -872.615, entropy_coef_loss = 0.110, critic_loss = 314.674, entropy_coef = 0.298, rollout_stds = 0.306 ± 0.129, action_magnitude = 0.744 ± 0.278, n_updates = 103001, time = 11.3, total_time = 1156.5
#
# step =  114000, num_env_steps =  114000, scores =  3830.299 (n= 1), score_ema =  3698.709, actor_loss = -852.844, entropy_coef_loss = -0.030, critic_loss = 272.817, entropy_coef = 0.305, rollout_stds = 0.402 ± 0.084, action_magnitude = 0.743 ± 0.279, n_updates = 104001, time = 11.3, total_time = 1167.8
#
# step =  115000, num_env_steps =  115000, scores =  3578.212 (n= 1), score_ema =  3668.585, actor_loss = -939.638, entropy_coef_loss = 0.779, critic_loss = 262.958, entropy_coef = 0.308, rollout_stds = 0.428 ± 0.085, action_magnitude = 0.731 ± 0.281, n_updates = 105001, time = 11.4, total_time = 1179.2
#
# step =  116000, num_env_steps =  116000, scores =  3828.672 (n= 1), score_ema =  3708.607, actor_loss = -927.087, entropy_coef_loss = 0.249, critic_loss = 271.862, entropy_coef = 0.308, rollout_stds = 0.306 ± 0.124, action_magnitude = 0.740 ± 0.281, n_updates = 106001, time = 11.2, total_time = 1190.5
#
# step =  117000, num_env_steps =  117000, scores =  3736.451 (n= 1), score_ema =  3715.568, actor_loss = -855.685, entropy_coef_loss = -0.317, critic_loss = 362.176, entropy_coef = 0.313, rollout_stds = 0.357 ± 0.096, action_magnitude = 0.744 ± 0.277, n_updates = 107001, time = 10.9, total_time = 1201.4
#
# step =  118000, num_env_steps =  118000, scores =  3729.161 (n= 1), score_ema =  3718.966, actor_loss = -900.059, entropy_coef_loss = 0.444, critic_loss = 376.160, entropy_coef = 0.317, rollout_stds = 0.294 ± 0.105, action_magnitude = 0.745 ± 0.276, n_updates = 108001, time = 10.8, total_time = 1212.2
#
# step =  119000, num_env_steps =  119000, scores =  3740.335 (n= 1), score_ema =  3724.308, actor_loss = -909.495, entropy_coef_loss = 0.253, critic_loss = 330.357, entropy_coef = 0.320, rollout_stds = 0.392 ± 0.141, action_magnitude = 0.746 ± 0.275, n_updates = 109001, time = 10.8, total_time = 1223.0
#
# step =  120000, num_env_steps =  120000, scores =  3675.346 (n= 1), score_ema =  3712.068, actor_loss = -902.282, entropy_coef_loss = -0.226, critic_loss = 5476.050, entropy_coef = 0.327, rollout_stds = 0.436 ± 0.120, action_magnitude = 0.747 ± 0.274, n_updates = 110001, time = 10.9, total_time = 1233.9
#
# saved experiment log 2024-10-05_13-18-07_731665~48j0N7 at experiment_logs/HalfCheetah-v4/sac/2024-10-05_13-18-07_731665~48j0N7.json
#
# step =  121000, num_env_steps =  121000, scores =  3716.446 (n= 1), score_ema =  3713.162, actor_loss = -930.591, entropy_coef_loss = 0.204, critic_loss = 321.367, entropy_coef = 0.327, rollout_stds = 0.406 ± 0.150, action_magnitude = 0.743 ± 0.277, n_updates = 111001, time = 10.9, total_time = 1244.8
#
# step =  122000, num_env_steps =  122000, scores =  3724.045 (n= 1), score_ema =  3715.883, actor_loss = -924.754, entropy_coef_loss = -0.535, critic_loss = 2447.900, entropy_coef = 0.344, rollout_stds = 0.371 ± 0.130, action_magnitude = 0.747 ± 0.274, n_updates = 112001, time = 10.8, total_time = 1255.6
#
# step =  123000, num_env_steps =  123000, scores =  3837.258 (n= 1), score_ema =  3746.227, actor_loss = -944.476, entropy_coef_loss = 0.455, critic_loss = 283.694, entropy_coef = 0.328, rollout_stds = 0.331 ± 0.076, action_magnitude = 0.739 ± 0.275, n_updates = 113001, time = 10.8, total_time = 1266.5
#
# step =  124000, num_env_steps =  124000, scores =  3822.450 (n= 1), score_ema =  3765.283, actor_loss = -954.172, entropy_coef_loss = 0.040, critic_loss = 316.517, entropy_coef = 0.330, rollout_stds = 0.412 ± 0.079, action_magnitude = 0.743 ± 0.273, n_updates = 114001, time = 10.9, total_time = 1277.3
#
# step =  125000, num_env_steps =  125000, scores =  3927.640 (n= 1), score_ema =  3805.872, actor_loss = -971.563, entropy_coef_loss = -0.040, critic_loss = 291.859, entropy_coef = 0.337, rollout_stds = 0.487 ± 0.157, action_magnitude = 0.748 ± 0.275, n_updates = 115001, time = 11.1, total_time = 1288.5
#
# step =  126000, num_env_steps =  126000, scores =  3862.866 (n= 1), score_ema =  3820.120, actor_loss = -950.600, entropy_coef_loss = 0.148, critic_loss = 321.290, entropy_coef = 0.355, rollout_stds = 0.386 ± 0.126, action_magnitude = 0.759 ± 0.271, n_updates = 116001, time = 11.1, total_time = 1299.6
#
# step =  127000, num_env_steps =  127000, scores =  3798.082 (n= 1), score_ema =  3814.611, actor_loss = -967.992, entropy_coef_loss = -0.190, critic_loss = 440.875, entropy_coef = 0.339, rollout_stds = 0.338 ± 0.164, action_magnitude = 0.739 ± 0.281, n_updates = 117001, time = 10.9, total_time = 1310.5
#
# step =  128000, num_env_steps =  128000, scores =  3878.211 (n= 1), score_ema =  3830.511, actor_loss = -963.603, entropy_coef_loss = -0.166, critic_loss = 4656.353, entropy_coef = 0.348, rollout_stds = 0.443 ± 0.130, action_magnitude = 0.745 ± 0.278, n_updates = 118001, time = 10.9, total_time = 1321.4
#
# step =  129000, num_env_steps =  129000, scores =  3674.130 (n= 1), score_ema =  3791.415, actor_loss = -956.785, entropy_coef_loss = 0.184, critic_loss = 276.667, entropy_coef = 0.354, rollout_stds = 0.339 ± 0.102, action_magnitude = 0.739 ± 0.277, n_updates = 119001, time = 10.8, total_time = 1332.2
#
# step =  130000, num_env_steps =  130000, scores =  3959.540 (n= 1), score_ema =  3833.447, actor_loss = -994.616, entropy_coef_loss = 0.027, critic_loss = 301.685, entropy_coef = 0.351, rollout_stds = 0.509 ± 0.064, action_magnitude = 0.752 ± 0.270, n_updates = 120001, time = 10.8, total_time = 1343.1
#
# saved experiment log 2024-10-05_13-18-07_731665~48j0N7 at experiment_logs/HalfCheetah-v4/sac/2024-10-05_13-18-07_731665~48j0N7.json
#
# step =  131000, num_env_steps =  131000, scores =  4017.972 (n= 1), score_ema =  3879.578, actor_loss = -965.700, entropy_coef_loss = 0.048, critic_loss = 6452.009, entropy_coef = 0.349, rollout_stds = 0.369 ± 0.121, action_magnitude = 0.749 ± 0.269, n_updates = 121001, time = 10.9, total_time = 1353.9
#
# step =  132000, num_env_steps =  132000, scores =  3992.743 (n= 1), score_ema =  3907.869, actor_loss = -985.957, entropy_coef_loss = 0.315, critic_loss = 307.426, entropy_coef = 0.347, rollout_stds = 0.456 ± 0.101, action_magnitude = 0.747 ± 0.271, n_updates = 122001, time = 10.8, total_time = 1364.8
#
# step =  133000, num_env_steps =  133000, scores =  4097.604 (n= 1), score_ema =  3955.303, actor_loss = -1003.341, entropy_coef_loss = -0.311, critic_loss = 310.038, entropy_coef = 0.357, rollout_stds = 0.403 ± 0.132, action_magnitude = 0.741 ± 0.275, n_updates = 123001, time = 10.8, total_time = 1375.6
#
# step =  134000, num_env_steps =  134000, scores =  3927.309 (n= 1), score_ema =  3948.304, actor_loss = -985.485, entropy_coef_loss = -0.133, critic_loss = 280.505, entropy_coef = 0.352, rollout_stds = 0.298 ± 0.096, action_magnitude = 0.741 ± 0.272, n_updates = 124001, time = 10.8, total_time = 1386.5
#
# step =  135000, num_env_steps =  135000, scores =  4055.695 (n= 1), score_ema =  3975.152, actor_loss = -997.306, entropy_coef_loss = -0.088, critic_loss = 284.044, entropy_coef = 0.361, rollout_stds = 0.297 ± 0.121, action_magnitude = 0.750 ± 0.275, n_updates = 125001, time = 10.8, total_time = 1397.3
#
# step =  136000, num_env_steps =  136000, scores =  3918.311 (n= 1), score_ema =  3960.942, actor_loss = -1008.334, entropy_coef_loss = 0.092, critic_loss = 287.016, entropy_coef = 0.349, rollout_stds = 0.327 ± 0.095, action_magnitude = 0.749 ± 0.272, n_updates = 126001, time = 10.9, total_time = 1408.2
#
# step =  137000, num_env_steps =  137000, scores =  4140.738 (n= 1), score_ema =  4005.891, actor_loss = -1021.594, entropy_coef_loss = 0.241, critic_loss = 5143.999, entropy_coef = 0.362, rollout_stds = 0.383 ± 0.162, action_magnitude = 0.743 ± 0.275, n_updates = 127001, time = 10.8, total_time = 1419.0
#
# step =  138000, num_env_steps =  138000, scores =  3980.784 (n= 1), score_ema =  3999.614, actor_loss = -1006.931, entropy_coef_loss = -0.366, critic_loss = 217.083, entropy_coef = 0.368, rollout_stds = 0.340 ± 0.123, action_magnitude = 0.750 ± 0.273, n_updates = 128001, time = 10.8, total_time = 1429.8
#
# step =  139000, num_env_steps =  139000, scores =  4077.325 (n= 1), score_ema =  4019.042, actor_loss = -1014.714, entropy_coef_loss = -0.096, critic_loss = 475.688, entropy_coef = 0.367, rollout_stds = 0.380 ± 0.110, action_magnitude = 0.751 ± 0.273, n_updates = 129001, time = 10.9, total_time = 1440.6
#
# step =  140000, num_env_steps =  140000, scores =  3984.853 (n= 1), score_ema =  4010.495, actor_loss = -1032.367, entropy_coef_loss = -0.169, critic_loss = 5180.399, entropy_coef = 0.365, rollout_stds = 0.388 ± 0.098, action_magnitude = 0.747 ± 0.274, n_updates = 130001, time = 11.0, total_time = 1451.6
#
# saved experiment log 2024-10-05_13-18-07_731665~48j0N7 at experiment_logs/HalfCheetah-v4/sac/2024-10-05_13-18-07_731665~48j0N7.json
#
# step =  141000, num_env_steps =  141000, scores =  4072.762 (n= 1), score_ema =  4026.061, actor_loss = -1052.025, entropy_coef_loss = 0.190, critic_loss = 6045.119, entropy_coef = 0.372, rollout_stds = 0.492 ± 0.206, action_magnitude = 0.749 ± 0.273, n_updates = 131001, time = 10.8, total_time = 1462.5
#
# step =  142000, num_env_steps =  142000, scores =  4046.220 (n= 1), score_ema =  4031.101, actor_loss = -1018.721, entropy_coef_loss = 0.351, critic_loss = 1528.260, entropy_coef = 0.377, rollout_stds = 0.427 ± 0.068, action_magnitude = 0.755 ± 0.268, n_updates = 132001, time = 10.9, total_time = 1473.3
#
# step =  143000, num_env_steps =  143000, scores =  4111.975 (n= 1), score_ema =  4051.319, actor_loss = -976.187, entropy_coef_loss = -0.701, critic_loss = 289.590, entropy_coef = 0.382, rollout_stds = 0.478 ± 0.053, action_magnitude = 0.751 ± 0.269, n_updates = 133001, time = 10.9, total_time = 1484.2
#
# step =  144000, num_env_steps =  144000, scores =  3891.925 (n= 1), score_ema =  4011.471, actor_loss = -1052.896, entropy_coef_loss = 0.111, critic_loss = 386.908, entropy_coef = 0.379, rollout_stds = 0.377 ± 0.153, action_magnitude = 0.744 ± 0.274, n_updates = 134001, time = 10.9, total_time = 1495.0
#
# step =  145000, num_env_steps =  145000, scores =  4015.210 (n= 1), score_ema =  4012.405, actor_loss = -1013.927, entropy_coef_loss = 0.025, critic_loss = 3698.444, entropy_coef = 0.389, rollout_stds = 0.338 ± 0.180, action_magnitude = 0.745 ± 0.275, n_updates = 135001, time = 10.8, total_time = 1505.9
#
# step =  146000, num_env_steps =  146000, scores =  4055.687 (n= 1), score_ema =  4023.226, actor_loss = -998.923, entropy_coef_loss = -0.468, critic_loss = 10986.062, entropy_coef = 0.396, rollout_stds = 0.386 ± 0.083, action_magnitude = 0.757 ± 0.270, n_updates = 136001, time = 10.8, total_time = 1516.7
#
# step =  147000, num_env_steps =  147000, scores =  3924.596 (n= 1), score_ema =  3998.568, actor_loss = -1079.832, entropy_coef_loss = -0.186, critic_loss = 318.676, entropy_coef = 0.388, rollout_stds = 0.377 ± 0.146, action_magnitude = 0.737 ± 0.279, n_updates = 137001, time = 10.9, total_time = 1527.6
#
# step =  148000, num_env_steps =  148000, scores =  3960.691 (n= 1), score_ema =  3989.099, actor_loss = -1058.487, entropy_coef_loss = -0.133, critic_loss = 247.017, entropy_coef = 0.402, rollout_stds = 0.376 ± 0.111, action_magnitude = 0.747 ± 0.270, n_updates = 138001, time = 10.9, total_time = 1538.4
#
# step =  149000, num_env_steps =  149000, scores =  4044.627 (n= 1), score_ema =  4002.981, actor_loss = -1093.440, entropy_coef_loss = 0.232, critic_loss = 5396.560, entropy_coef = 0.396, rollout_stds = 0.395 ± 0.160, action_magnitude = 0.745 ± 0.274, n_updates = 139001, time = 10.8, total_time = 1549.3
#
# step =  150000, num_env_steps =  150000, scores =  4017.553 (n= 1), score_ema =  4006.624, actor_loss = -1053.510, entropy_coef_loss = -0.474, critic_loss = 264.334, entropy_coef = 0.398, rollout_stds = 0.345 ± 0.153, action_magnitude = 0.743 ± 0.275, n_updates = 140001, time = 10.8, total_time = 1560.1
#
# saved experiment log 2024-10-05_13-18-07_731665~48j0N7 at experiment_logs/HalfCheetah-v4/sac/2024-10-05_13-18-07_731665~48j0N7.json
#
# step =  151000, num_env_steps =  151000, scores =  4000.912 (n= 1), score_ema =  4005.196, actor_loss = -1072.967, entropy_coef_loss = 0.148, critic_loss = 337.808, entropy_coef = 0.405, rollout_stds = 0.456 ± 0.092, action_magnitude = 0.749 ± 0.275, n_updates = 141001, time = 10.9, total_time = 1570.9
#
# step =  152000, num_env_steps =  152000, scores =  4083.839 (n= 1), score_ema =  4024.857, actor_loss = -1102.409, entropy_coef_loss = -0.216, critic_loss = 236.204, entropy_coef = 0.403, rollout_stds = 0.394 ± 0.101, action_magnitude = 0.751 ± 0.270, n_updates = 142001, time = 10.8, total_time = 1581.8
#
# step =  153000, num_env_steps =  153000, scores =  3903.775 (n= 1), score_ema =  3994.586, actor_loss = -1104.882, entropy_coef_loss = 0.058, critic_loss = 269.320, entropy_coef = 0.398, rollout_stds = 0.444 ± 0.156, action_magnitude = 0.742 ± 0.275, n_updates = 143001, time = 10.9, total_time = 1592.7
#
# step =  154000, num_env_steps =  154000, scores =  4105.626 (n= 1), score_ema =  4022.346, actor_loss = -1113.070, entropy_coef_loss = 0.021, critic_loss = 357.573, entropy_coef = 0.403, rollout_stds = 0.383 ± 0.114, action_magnitude = 0.748 ± 0.272, n_updates = 144001, time = 10.8, total_time = 1603.5
#
# step =  155000, num_env_steps =  155000, scores =  3995.845 (n= 1), score_ema =  4015.721, actor_loss = -1122.009, entropy_coef_loss = 0.399, critic_loss = 309.714, entropy_coef = 0.417, rollout_stds = 0.317 ± 0.095, action_magnitude = 0.746 ± 0.273, n_updates = 145001, time = 10.8, total_time = 1614.3
#
# step =  156000, num_env_steps =  156000, scores =  4196.057 (n= 1), score_ema =  4060.805, actor_loss = -1103.130, entropy_coef_loss = -0.034, critic_loss = 6027.184, entropy_coef = 0.424, rollout_stds = 0.405 ± 0.136, action_magnitude = 0.752 ± 0.267, n_updates = 146001, time = 10.8, total_time = 1625.2
#
# step =  157000, num_env_steps =  157000, scores =  3804.111 (n= 1), score_ema =  3996.632, actor_loss = -1092.220, entropy_coef_loss = 0.174, critic_loss = 2810.643, entropy_coef = 0.431, rollout_stds = 0.546 ± 0.072, action_magnitude = 0.748 ± 0.271, n_updates = 147001, time = 10.8, total_time = 1636.0
#
# step =  158000, num_env_steps =  158000, scores =  4425.555 (n= 1), score_ema =  4103.862, actor_loss = -1091.669, entropy_coef_loss = -0.060, critic_loss = 5804.674, entropy_coef = 0.428, rollout_stds = 0.351 ± 0.147, action_magnitude = 0.762 ± 0.261, n_updates = 148001, time = 10.8, total_time = 1646.8
#
# ...
#
#
# step = 3389000, num_env_steps = 3389000, scores =  9207.709 (n= 1), score_ema =  9160.718, actor_loss = -3197.126, entropy_coef_loss = -0.047, critic_loss = 367.134, entropy_coef = 1.532, rollout_stds = 0.324 ± 0.155, action_magnitude = 0.678 ± 0.288, n_updates = 3379001, time = 13.2, total_time = 44136.5
#
#
# step = 3390000, num_env_steps = 3390000, scores =  8822.720 (n= 1), score_ema =  9076.218, actor_loss = -3196.455, entropy_coef_loss = 0.030, critic_loss = 387.985, entropy_coef = 1.524, rollout_stds = 0.355 ± 0.151, action_magnitude = 0.680 ± 0.284, n_updates = 3380001, time = 13.2, total_time = 44149.7
#
# saved experiment log 2024-10-05_13-18-07_731665~48j0N7 at experiment_logs/HalfCheetah-v4/sac/2024-10-05_13-18-07_731665~48j0N7.json
#
#
# step = 3391000, num_env_steps = 3391000, scores =  9196.685 (n= 1), score_ema =  9106.335, actor_loss = -3195.812, entropy_coef_loss = -0.028, critic_loss = 325.553, entropy_coef = 1.508, rollout_stds = 0.441 ± 0.107, action_magnitude = 0.687 ± 0.285, n_updates = 3381001, time = 13.4, total_time = 44163.2
#
#
# step = 3392000, num_env_steps = 3392000, scores =  9288.020 (n= 1), score_ema =  9151.756, actor_loss = -3160.969, entropy_coef_loss = -0.012, critic_loss = 563.823, entropy_coef = 1.559, rollout_stds = 0.358 ± 0.099, action_magnitude = 0.695 ± 0.282, n_updates = 3382001, time = 13.1, total_time = 44176.3
#
#
# step = 3393000, num_env_steps = 3393000, scores =  9176.182 (n= 1), score_ema =  9157.862, actor_loss = -3211.125, entropy_coef_loss = -0.004, critic_loss = 42789.754, entropy_coef = 1.513, rollout_stds = 0.346 ± 0.114, action_magnitude = 0.695 ± 0.282, n_updates = 3383001, time = 13.2, total_time = 44189.5
#
#
# step = 3394000, num_env_steps = 3394000, scores =  8895.490 (n= 1), score_ema =  9092.269, actor_loss = -3185.131, entropy_coef_loss = -0.063, critic_loss = 372.279, entropy_coef = 1.495, rollout_stds = 0.406 ± 0.067, action_magnitude = 0.695 ± 0.285, n_updates = 3384001, time = 13.2, total_time = 44202.6
#
#
# step = 3395000, num_env_steps = 3395000, scores =  9160.977 (n= 1), score_ema =  9109.446, actor_loss = -3167.074, entropy_coef_loss = -0.038, critic_loss = 503.832, entropy_coef = 1.509, rollout_stds = 0.386 ± 0.138, action_magnitude = 0.688 ± 0.285, n_updates = 3385001, time = 13.1, total_time = 44215.8
#
#
# step = 3396000, num_env_steps = 3396000, scores =  9043.548 (n= 1), score_ema =  9092.972, actor_loss = -3187.398, entropy_coef_loss = -0.027, critic_loss = 386.085, entropy_coef = 1.521, rollout_stds = 0.428 ± 0.149, action_magnitude = 0.693 ± 0.278, n_updates = 3386001, time = 13.2, total_time = 44228.9
#
#
# step = 3397000, num_env_steps = 3397000, scores =  9225.198 (n= 1), score_ema =  9126.028, actor_loss = -3172.641, entropy_coef_loss = 0.009, critic_loss = 566.594, entropy_coef = 1.476, rollout_stds = 0.367 ± 0.145, action_magnitude = 0.685 ± 0.283, n_updates = 3387001, time = 13.2, total_time = 44242.1
#
#
# step = 3398000, num_env_steps = 3398000, scores =  9260.408 (n= 1), score_ema =  9159.623, actor_loss = -3214.717, entropy_coef_loss = 0.051, critic_loss = 348.560, entropy_coef = 1.521, rollout_stds = 0.333 ± 0.155, action_magnitude = 0.684 ± 0.287, n_updates = 3388001, time = 13.2, total_time = 44255.3
#
#
# step = 3399000, num_env_steps = 3399000, scores =  9151.194 (n= 1), score_ema =  9157.516, actor_loss = -3151.377, entropy_coef_loss = 0.006, critic_loss = 362.809, entropy_coef = 1.518, rollout_stds = 0.294 ± 0.109, action_magnitude = 0.688 ± 0.282, n_updates = 3389001, time = 13.1, total_time = 44268.4
#
#
# step = 3400000, num_env_steps = 3400000, scores =  9112.969 (n= 1), score_ema =  9146.379, actor_loss = -3209.924, entropy_coef_loss = 0.085, critic_loss = 413.948, entropy_coef = 1.492, rollout_stds = 0.250 ± 0.079, action_magnitude = 0.679 ± 0.293, n_updates = 3390001, time = 13.2, total_time = 44281.6
#
# saved experiment log 2024-10-05_13-18-07_731665~48j0N7 at experiment_logs/HalfCheetah-v4/sac/2024-10-05_13-18-07_731665~48j0N7.json
#
#
# step = 3401000, num_env_steps = 3401000, scores =  9225.633 (n= 1), score_ema =  9166.193, actor_loss = -3176.456, entropy_coef_loss = -0.104, critic_loss = 430.066, entropy_coef = 1.532, rollout_stds = 0.414 ± 0.128, action_magnitude = 0.693 ± 0.285, n_updates = 3391001, time = 13.5, total_time = 44295.1
#
#
# step = 3402000, num_env_steps = 3402000, scores =  9323.598 (n= 1), score_ema =  9205.544, actor_loss = -3205.349, entropy_coef_loss = -0.058, critic_loss = 535.364, entropy_coef = 1.532, rollout_stds = 0.305 ± 0.116, action_magnitude = 0.686 ± 0.287, n_updates = 3392001, time = 13.1, total_time = 44308.2
#
#
# step = 3403000, num_env_steps = 3403000, scores =  9080.812 (n= 1), score_ema =  9174.361, actor_loss = -3187.938, entropy_coef_loss = -0.003, critic_loss = 497.577, entropy_coef = 1.508, rollout_stds = 0.334 ± 0.169, action_magnitude = 0.677 ± 0.289, n_updates = 3393001, time = 13.2, total_time = 44321.4
#
#
# step = 3404000, num_env_steps = 3404000, scores =  9070.059 (n= 1), score_ema =  9148.286, actor_loss = -3169.844, entropy_coef_loss = 0.124, critic_loss = 317.122, entropy_coef = 1.458, rollout_stds = 0.355 ± 0.161, action_magnitude = 0.675 ± 0.291, n_updates = 3394001, time = 13.1, total_time = 44334.5
#
#
# step = 3405000, num_env_steps = 3405000, scores =  9113.270 (n= 1), score_ema =  9139.532, actor_loss = -3182.640, entropy_coef_loss = 0.103, critic_loss = 773.485, entropy_coef = 1.484, rollout_stds = 0.304 ± 0.162, action_magnitude = 0.694 ± 0.284, n_updates = 3395001, time = 13.1, total_time = 44347.6
#
#
# step = 3406000, num_env_steps = 3406000, scores =  9288.519 (n= 1), score_ema =  9176.778, actor_loss = -3177.674, entropy_coef_loss = 0.184, critic_loss = 379.096, entropy_coef = 1.492, rollout_stds = 0.312 ± 0.060, action_magnitude = 0.687 ± 0.284, n_updates = 3396001, time = 13.2, total_time = 44360.8
#
#
# step = 3407000, num_env_steps = 3407000, scores =  9338.257 (n= 1), score_ema =  9217.148, actor_loss = -3199.136, entropy_coef_loss = -0.083, critic_loss = 529.967, entropy_coef = 1.460, rollout_stds = 0.371 ± 0.153, action_magnitude = 0.682 ± 0.289, n_updates = 3397001, time = 13.1, total_time = 44373.9
#
#
# step = 3408000, num_env_steps = 3408000, scores =  9324.882 (n= 1), score_ema =  9244.081, actor_loss = -3206.563, entropy_coef_loss = -0.112, critic_loss = 73770.453, entropy_coef = 1.542, rollout_stds = 0.323 ± 0.174, action_magnitude = 0.691 ± 0.289, n_updates = 3398001, time = 13.1, total_time = 44387.1
#
#
# step = 3409000, num_env_steps = 3409000, scores =  9159.387 (n= 1), score_ema =  9222.908, actor_loss = -3182.828, entropy_coef_loss = -0.044, critic_loss = 413.871, entropy_coef = 1.526, rollout_stds = 0.319 ± 0.114, action_magnitude = 0.677 ± 0.290, n_updates = 3399001, time = 13.1, total_time = 44400.2
#
#
# step = 3410000, num_env_steps = 3410000, scores =  9205.200 (n= 1), score_ema =  9218.481, actor_loss = -3212.205, entropy_coef_loss = -0.073, critic_loss = 478.226, entropy_coef = 1.567, rollout_stds = 0.375 ± 0.129, action_magnitude = 0.682 ± 0.283, n_updates = 3400001, time = 13.2, total_time = 44413.4
#
# saved experiment log 2024-10-05_13-18-07_731665~48j0N7 at experiment_logs/HalfCheetah-v4/sac/2024-10-05_13-18-07_731665~48j0N7.json
#
#
# step = 3411000, num_env_steps = 3411000, scores =  8979.456 (n= 1), score_ema =  9158.725, actor_loss = -3181.245, entropy_coef_loss = -0.080, critic_loss = 654.958, entropy_coef = 1.541, rollout_stds = 0.418 ± 0.086, action_magnitude = 0.683 ± 0.284, n_updates = 3401001, time = 13.5, total_time = 44426.8
#
#
# step = 3412000, num_env_steps = 3412000, scores =  8871.043 (n= 1), score_ema =  9086.804, actor_loss = -3201.101, entropy_coef_loss = 0.056, critic_loss = 270.211, entropy_coef = 1.512, rollout_stds = 0.338 ± 0.089, action_magnitude = 0.687 ± 0.280, n_updates = 3402001, time = 13.2, total_time = 44440.0
#
#
# step = 3413000, num_env_steps = 3413000, scores =  9150.584 (n= 1), score_ema =  9102.749, actor_loss = -3219.018, entropy_coef_loss = 0.134, critic_loss = 299.435, entropy_coef = 1.531, rollout_stds = 0.310 ± 0.106, action_magnitude = 0.688 ± 0.286, n_updates = 3403001, time = 13.2, total_time = 44453.2
#
#
# step = 3414000, num_env_steps = 3414000, scores =  8958.408 (n= 1), score_ema =  9066.664, actor_loss = -3208.974, entropy_coef_loss = 0.071, critic_loss = 459.373, entropy_coef = 1.496, rollout_stds = 0.335 ± 0.120, action_magnitude = 0.675 ± 0.294, n_updates = 3404001, time = 13.2, total_time = 44466.3
#
#
# step = 3415000, num_env_steps = 3415000, scores =  9074.025 (n= 1), score_ema =  9068.504, actor_loss = -3211.807, entropy_coef_loss = -0.070, critic_loss = 321.777, entropy_coef = 1.515, rollout_stds = 0.375 ± 0.156, action_magnitude = 0.683 ± 0.284, n_updates = 3405001, time = 13.5, total_time = 44479.8
#
#
# step = 3416000, num_env_steps = 3416000, scores =  8983.322 (n= 1), score_ema =  9047.209, actor_loss = -3213.843, entropy_coef_loss = -0.056, critic_loss = 497.527, entropy_coef = 1.490, rollout_stds = 0.322 ± 0.078, action_magnitude = 0.674 ± 0.292, n_updates = 3406001, time = 13.2, total_time = 44493.0
#
#
# step = 3417000, num_env_steps = 3417000, scores =  9056.602 (n= 1), score_ema =  9049.557, actor_loss = -3148.325, entropy_coef_loss = 0.224, critic_loss = 429.559, entropy_coef = 1.489, rollout_stds = 0.273 ± 0.164, action_magnitude = 0.682 ± 0.285, n_updates = 3407001, time = 13.2, total_time = 44506.2
#
#
# step = 3418000, num_env_steps = 3418000, scores =  9300.702 (n= 1), score_ema =  9112.343, actor_loss = -3181.933, entropy_coef_loss = 0.032, critic_loss = 84328.844, entropy_coef = 1.505, rollout_stds = 0.311 ± 0.161, action_magnitude = 0.678 ± 0.289, n_updates = 3408001, time = 13.2, total_time = 44519.4
#
#
# step = 3419000, num_env_steps = 3419000, scores =  9003.416 (n= 1), score_ema =  9085.112, actor_loss = -3168.849, entropy_coef_loss = 0.057, critic_loss = 408.247, entropy_coef = 1.534, rollout_stds = 0.420 ± 0.200, action_magnitude = 0.683 ± 0.284, n_updates = 3409001, time = 13.2, total_time = 44532.6
#
#
# step = 3420000, num_env_steps = 3420000, scores =  8945.203 (n= 1), score_ema =  9050.134, actor_loss = -3160.217, entropy_coef_loss = 0.083, critic_loss = 278.013, entropy_coef = 1.546, rollout_stds = 0.315 ± 0.149, action_magnitude = 0.683 ± 0.289, n_updates = 3410001, time = 13.4, total_time = 44546.0
#
# saved experiment log 2024-10-05_13-18-07_731665~48j0N7 at experiment_logs/HalfCheetah-v4/sac/2024-10-05_13-18-07_731665~48j0N7.json
#
#
# step = 3421000, num_env_steps = 3421000, scores =  9025.309 (n= 1), score_ema =  9043.928, actor_loss = -3224.845, entropy_coef_loss = -0.032, critic_loss = 40389.797, entropy_coef = 1.563, rollout_stds = 0.254 ± 0.080, action_magnitude = 0.689 ± 0.285, n_updates = 3411001, time = 14.0, total_time = 44560.0
#
#
# step = 3422000, num_env_steps = 3422000, scores =  9072.196 (n= 1), score_ema =  9050.995, actor_loss = -3164.872, entropy_coef_loss = 0.030, critic_loss = 365.129, entropy_coef = 1.491, rollout_stds = 0.340 ± 0.105, action_magnitude = 0.676 ± 0.288, n_updates = 3412001, time = 13.5, total_time = 44573.5
#
#
# step = 3423000, num_env_steps = 3423000, scores =  8683.605 (n= 1), score_ema =  8959.148, actor_loss = -3226.838, entropy_coef_loss = -0.118, critic_loss = 460.888, entropy_coef = 1.521, rollout_stds = 0.294 ± 0.086, action_magnitude = 0.683 ± 0.288, n_updates = 3413001, time = 13.8, total_time = 44587.2
#
#
# step = 3424000, num_env_steps = 3424000, scores =  8957.729 (n= 1), score_ema =  8958.793, actor_loss = -3210.129, entropy_coef_loss = -0.037, critic_loss = 419.899, entropy_coef = 1.569, rollout_stds = 0.390 ± 0.151, action_magnitude = 0.694 ± 0.284, n_updates = 3414001, time = 14.2, total_time = 44601.4
#
#
# step = 3425000, num_env_steps = 3425000, scores =  8964.298 (n= 1), score_ema =  8960.169, actor_loss = -3200.429, entropy_coef_loss = 0.051, critic_loss = 476.749, entropy_coef = 1.575, rollout_stds = 0.414 ± 0.153, action_magnitude = 0.686 ± 0.286, n_updates = 3415001, time = 13.6, total_time = 44615.0
#
#
# step = 3426000, num_env_steps = 3426000, scores =  8620.191 (n= 1), score_ema =  8875.175, actor_loss = -3129.652, entropy_coef_loss = -0.035, critic_loss = 414.932, entropy_coef = 1.570, rollout_stds = 0.344 ± 0.169, action_magnitude = 0.678 ± 0.289, n_updates = 3416001, time = 14.2, total_time = 44629.2
#
#
# step = 3427000, num_env_steps = 3427000, scores =  9205.524 (n= 1), score_ema =  8957.762, actor_loss = -3183.449, entropy_coef_loss = 0.070, critic_loss = 338.574, entropy_coef = 1.560, rollout_stds = 0.398 ± 0.095, action_magnitude = 0.685 ± 0.287, n_updates = 3417001, time = 13.8, total_time = 44643.0
#
#
# step = 3428000, num_env_steps = 3428000, scores =  9280.286 (n= 1), score_ema =  9038.393, actor_loss = -3218.310, entropy_coef_loss = 0.051, critic_loss = 345.987, entropy_coef = 1.574, rollout_stds = 0.324 ± 0.138, action_magnitude = 0.691 ± 0.286, n_updates = 3418001, time = 13.6, total_time = 44656.6
#
#
# step = 3429000, num_env_steps = 3429000, scores =  8972.972 (n= 1), score_ema =  9022.038, actor_loss = -3201.416, entropy_coef_loss = 0.159, critic_loss = 42314.828, entropy_coef = 1.555, rollout_stds = 0.339 ± 0.121, action_magnitude = 0.687 ± 0.284, n_updates = 3419001, time = 13.3, total_time = 44669.9
#
#
# step = 3430000, num_env_steps = 3430000, scores =  9170.256 (n= 1), score_ema =  9059.093, actor_loss = -3191.822, entropy_coef_loss = 0.160, critic_loss = 296.803, entropy_coef = 1.626, rollout_stds = 0.331 ± 0.124, action_magnitude = 0.689 ± 0.284, n_updates = 3420001, time = 13.2, total_time = 44683.1
#
# saved experiment log 2024-10-05_13-18-07_731665~48j0N7 at experiment_logs/HalfCheetah-v4/sac/2024-10-05_13-18-07_731665~48j0N7.json
#
#
# step = 3431000, num_env_steps = 3431000, scores =  9277.289 (n= 1), score_ema =  9113.642, actor_loss = -3145.990, entropy_coef_loss = -0.026, critic_loss = 333.299, entropy_coef = 1.535, rollout_stds = 0.336 ± 0.112, action_magnitude = 0.690 ± 0.282, n_updates = 3421001, time = 14.3, total_time = 44697.3
#
#
# step = 3432000, num_env_steps = 3432000, scores =  9159.466 (n= 1), score_ema =  9125.098, actor_loss = -3195.984, entropy_coef_loss = -0.006, critic_loss = 41478.406, entropy_coef = 1.517, rollout_stds = 0.383 ± 0.167, action_magnitude = 0.690 ± 0.280, n_updates = 3422001, time = 13.3, total_time = 44710.6
#
#
# step = 3433000, num_env_steps = 3433000, scores =  9346.722 (n= 1), score_ema =  9180.504, actor_loss = -3190.705, entropy_coef_loss = 0.184, critic_loss = 353.094, entropy_coef = 1.558, rollout_stds = 0.449 ± 0.151, action_magnitude = 0.686 ± 0.284, n_updates = 3423001, time = 13.5, total_time = 44724.1
#
#
# step = 3434000, num_env_steps = 3434000, scores =  9029.577 (n= 1), score_ema =  9142.772, actor_loss = -3207.437, entropy_coef_loss = -0.059, critic_loss = 343.569, entropy_coef = 1.436, rollout_stds = 0.377 ± 0.172, action_magnitude = 0.684 ± 0.285, n_updates = 3424001, time = 14.2, total_time = 44738.3
#
#
# step = 3435000, num_env_steps = 3435000, scores =  9093.225 (n= 1), score_ema =  9130.385, actor_loss = -3201.096, entropy_coef_loss = -0.016, critic_loss = 308.853, entropy_coef = 1.495, rollout_stds = 0.349 ± 0.113, action_magnitude = 0.683 ± 0.287, n_updates = 3425001, time = 14.6, total_time = 44752.9
#
#
# step = 3436000, num_env_steps = 3436000, scores =  8997.489 (n= 1), score_ema =  9097.161, actor_loss = -3141.731, entropy_coef_loss = 0.040, critic_loss = 40968.805, entropy_coef = 1.494, rollout_stds = 0.292 ± 0.068, action_magnitude = 0.676 ± 0.291, n_updates = 3426001, time = 13.8, total_time = 44766.7
#
# saved experiment log 2024-10-05_13-18-07_731665~48j0N7 at experiment_logs/HalfCheetah-v4/sac/2024-10-05_13-18-07_731665~48j0N7.json
# keyboard interrupt
# closing envs
# envs closed
# model db closed
# done
