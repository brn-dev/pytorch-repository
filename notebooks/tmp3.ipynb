# %%
from gymnasium.wrappers import TransformReward
import gymnasium as gym

from stable_baselines3.sac.sac import SAC

env = gym.make("HalfCheetah-v4")
# env = TransformReward(env, lambda r: 5 * r)

model = SAC("MlpPolicy", env, verbose=10, learning_starts=10000) # , seed=594371)
model.learn(total_timesteps=1_500_000, log_interval=1)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -420     |
# | time/              |          |
# |    episodes        | 1        |
# |    fps             | 3570     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 1000     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -313     |
# | time/              |          |
# |    episodes        | 2        |
# |    fps             | 3779     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2000     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -317     |
# | time/              |          |
# |    episodes        | 3        |
# |    fps             | 3855     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 3000     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -351     |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 3901     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 4000     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -319     |
# | time/              |          |
# |    episodes        | 5        |
# |    fps             | 3926     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 5000     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -335     |
# | time/              |          |
# |    episodes        | 6        |
# |    fps             | 3944     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 6000     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -336     |
# | time/              |          |
# |    episodes        | 7        |
# |    fps             | 3956     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 7000     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -335     |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 3958     |
# |    time_elapsed    | 2        |
# |    total_timesteps | 8000     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -347     |
# | time/              |          |
# |    episodes        | 9        |
# |    fps             | 3971     |
# |    time_elapsed    | 2        |
# |    total_timesteps | 9000     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -341     |
# | time/              |          |
# |    episodes        | 10       |
# |    fps             | 3974     |
# |    time_elapsed    | 2        |
# |    total_timesteps | 10000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -343     |
# | time/              |          |
# |    episodes        | 11       |
# |    fps             | 670      |
# |    time_elapsed    | 16       |
# |    total_timesteps | 11000    |
# | train/             |          |
# |    actor_loss      | -17.6    |
# |    critic_loss     | 1.06     |
# |    ent_coef        | 0.741    |
# |    ent_coef_loss   | -3.01    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 999      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -339     |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 397      |
# |    time_elapsed    | 30       |
# |    total_timesteps | 12000    |
# | train/             |          |
# |    actor_loss      | -25.3    |
# |    critic_loss     | 0.983    |
# |    ent_coef        | 0.549    |
# |    ent_coef_loss   | -6.03    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1999     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -331     |
# | time/              |          |
# |    episodes        | 13       |
# |    fps             | 295      |
# |    time_elapsed    | 43       |
# |    total_timesteps | 13000    |
# | train/             |          |
# |    actor_loss      | -29.9    |
# |    critic_loss     | 1.7      |
# |    ent_coef        | 0.408    |
# |    ent_coef_loss   | -8.82    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2999     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -323     |
# | time/              |          |
# |    episodes        | 14       |
# |    fps             | 242      |
# |    time_elapsed    | 57       |
# |    total_timesteps | 14000    |
# | train/             |          |
# |    actor_loss      | -31.7    |
# |    critic_loss     | 1.57     |
# |    ent_coef        | 0.303    |
# |    ent_coef_loss   | -11.4    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3999     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -316     |
# | time/              |          |
# |    episodes        | 15       |
# |    fps             | 209      |
# |    time_elapsed    | 71       |
# |    total_timesteps | 15000    |
# | train/             |          |
# |    actor_loss      | -33.1    |
# |    critic_loss     | 1.54     |
# |    ent_coef        | 0.226    |
# |    ent_coef_loss   | -13.9    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4999     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -312     |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 186      |
# |    time_elapsed    | 85       |
# |    total_timesteps | 16000    |
# | train/             |          |
# |    actor_loss      | -33      |
# |    critic_loss     | 1.29     |
# |    ent_coef        | 0.169    |
# |    ent_coef_loss   | -16      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5999     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -307     |
# | time/              |          |
# |    episodes        | 17       |
# |    fps             | 170      |
# |    time_elapsed    | 99       |
# |    total_timesteps | 17000    |
# | train/             |          |
# |    actor_loss      | -32.5    |
# |    critic_loss     | 1.48     |
# |    ent_coef        | 0.128    |
# |    ent_coef_loss   | -16.8    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6999     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -305     |
# | time/              |          |
# |    episodes        | 18       |
# |    fps             | 158      |
# |    time_elapsed    | 113      |
# |    total_timesteps | 18000    |
# | train/             |          |
# |    actor_loss      | -31      |
# |    critic_loss     | 1.33     |
# |    ent_coef        | 0.0965   |
# |    ent_coef_loss   | -17.8    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7999     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -320     |
# | time/              |          |
# |    episodes        | 19       |
# |    fps             | 149      |
# |    time_elapsed    | 127      |
# |    total_timesteps | 19000    |
# | train/             |          |
# |    actor_loss      | -29.9    |
# |    critic_loss     | 1.24     |
# |    ent_coef        | 0.073    |
# |    ent_coef_loss   | -19.1    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 8999     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -322     |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 142      |
# |    time_elapsed    | 140      |
# |    total_timesteps | 20000    |
# | train/             |          |
# |    actor_loss      | -28.5    |
# |    critic_loss     | 1.83     |
# |    ent_coef        | 0.0554   |
# |    ent_coef_loss   | -19      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9999     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -315     |
# | time/              |          |
# |    episodes        | 21       |
# |    fps             | 135      |
# |    time_elapsed    | 154      |
# |    total_timesteps | 21000    |
# | train/             |          |
# |    actor_loss      | -27      |
# |    critic_loss     | 1.68     |
# |    ent_coef        | 0.0422   |
# |    ent_coef_loss   | -16.9    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 10999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -306     |
# | time/              |          |
# |    episodes        | 22       |
# |    fps             | 130      |
# |    time_elapsed    | 168      |
# |    total_timesteps | 22000    |
# | train/             |          |
# |    actor_loss      | -25.6    |
# |    critic_loss     | 1.49     |
# |    ent_coef        | 0.0324   |
# |    ent_coef_loss   | -17.6    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 11999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -298     |
# | time/              |          |
# |    episodes        | 23       |
# |    fps             | 126      |
# |    time_elapsed    | 181      |
# |    total_timesteps | 23000    |
# | train/             |          |
# |    actor_loss      | -24.5    |
# |    critic_loss     | 1.6      |
# |    ent_coef        | 0.0251   |
# |    ent_coef_loss   | -16      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 12999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -289     |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 122      |
# |    time_elapsed    | 195      |
# |    total_timesteps | 24000    |
# | train/             |          |
# |    actor_loss      | -23.6    |
# |    critic_loss     | 1.29     |
# |    ent_coef        | 0.0197   |
# |    ent_coef_loss   | -12.7    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 13999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -282     |
# | time/              |          |
# |    episodes        | 25       |
# |    fps             | 119      |
# |    time_elapsed    | 209      |
# |    total_timesteps | 25000    |
# | train/             |          |
# |    actor_loss      | -23.2    |
# |    critic_loss     | 1.25     |
# |    ent_coef        | 0.0157   |
# |    ent_coef_loss   | -9.55    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 14999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -271     |
# | time/              |          |
# |    episodes        | 26       |
# |    fps             | 116      |
# |    time_elapsed    | 222      |
# |    total_timesteps | 26000    |
# | train/             |          |
# |    actor_loss      | -23.3    |
# |    critic_loss     | 1.05     |
# |    ent_coef        | 0.0129   |
# |    ent_coef_loss   | -6.74    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 15999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -257     |
# | time/              |          |
# |    episodes        | 27       |
# |    fps             | 114      |
# |    time_elapsed    | 236      |
# |    total_timesteps | 27000    |
# | train/             |          |
# |    actor_loss      | -22.4    |
# |    critic_loss     | 1.44     |
# |    ent_coef        | 0.0106   |
# |    ent_coef_loss   | -6.81    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 16999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -213     |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 111      |
# |    time_elapsed    | 250      |
# |    total_timesteps | 28000    |
# | train/             |          |
# |    actor_loss      | -22.3    |
# |    critic_loss     | 1.14     |
# |    ent_coef        | 0.009    |
# |    ent_coef_loss   | -3.2     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 17999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -188     |
# | time/              |          |
# |    episodes        | 29       |
# |    fps             | 109      |
# |    time_elapsed    | 264      |
# |    total_timesteps | 29000    |
# | train/             |          |
# |    actor_loss      | -23.4    |
# |    critic_loss     | 1.36     |
# |    ent_coef        | 0.0083   |
# |    ent_coef_loss   | -0.698   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 18999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -148     |
# | time/              |          |
# |    episodes        | 30       |
# |    fps             | 108      |
# |    time_elapsed    | 277      |
# |    total_timesteps | 30000    |
# | train/             |          |
# |    actor_loss      | -24      |
# |    critic_loss     | 1.14     |
# |    ent_coef        | 0.00833  |
# |    ent_coef_loss   | 0.0773   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 19999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -134     |
# | time/              |          |
# |    episodes        | 31       |
# |    fps             | 106      |
# |    time_elapsed    | 291      |
# |    total_timesteps | 31000    |
# | train/             |          |
# |    actor_loss      | -23.5    |
# |    critic_loss     | 1.28     |
# |    ent_coef        | 0.00888  |
# |    ent_coef_loss   | 1.57     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 20999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -84.5    |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 104      |
# |    time_elapsed    | 305      |
# |    total_timesteps | 32000    |
# | train/             |          |
# |    actor_loss      | -26.1    |
# |    critic_loss     | 1.64     |
# |    ent_coef        | 0.00991  |
# |    ent_coef_loss   | 1.48     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 21999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -34.2    |
# | time/              |          |
# |    episodes        | 33       |
# |    fps             | 103      |
# |    time_elapsed    | 318      |
# |    total_timesteps | 33000    |
# | train/             |          |
# |    actor_loss      | -26.4    |
# |    critic_loss     | 1.97     |
# |    ent_coef        | 0.0112   |
# |    ent_coef_loss   | 1.5      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 22999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -4.69    |
# | time/              |          |
# |    episodes        | 34       |
# |    fps             | 102      |
# |    time_elapsed    | 332      |
# |    total_timesteps | 34000    |
# | train/             |          |
# |    actor_loss      | -28.2    |
# |    critic_loss     | 1.83     |
# |    ent_coef        | 0.0132   |
# |    ent_coef_loss   | 2.94     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 23999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 52       |
# | time/              |          |
# |    episodes        | 35       |
# |    fps             | 101      |
# |    time_elapsed    | 346      |
# |    total_timesteps | 35000    |
# | train/             |          |
# |    actor_loss      | -28.4    |
# |    critic_loss     | 2.08     |
# |    ent_coef        | 0.0145   |
# |    ent_coef_loss   | 2.15     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 24999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 109      |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 100      |
# |    time_elapsed    | 359      |
# |    total_timesteps | 36000    |
# | train/             |          |
# |    actor_loss      | -33      |
# |    critic_loss     | 2.69     |
# |    ent_coef        | 0.0167   |
# |    ent_coef_loss   | 1.69     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 25999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 158      |
# | time/              |          |
# |    episodes        | 37       |
# |    fps             | 99       |
# |    time_elapsed    | 373      |
# |    total_timesteps | 37000    |
# | train/             |          |
# |    actor_loss      | -34      |
# |    critic_loss     | 3.09     |
# |    ent_coef        | 0.0195   |
# |    ent_coef_loss   | 0.181    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 26999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 163      |
# | time/              |          |
# |    episodes        | 38       |
# |    fps             | 98       |
# |    time_elapsed    | 387      |
# |    total_timesteps | 38000    |
# | train/             |          |
# |    actor_loss      | -34.3    |
# |    critic_loss     | 2.52     |
# |    ent_coef        | 0.0203   |
# |    ent_coef_loss   | -2.63    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 27999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 215      |
# | time/              |          |
# |    episodes        | 39       |
# |    fps             | 97       |
# |    time_elapsed    | 400      |
# |    total_timesteps | 39000    |
# | train/             |          |
# |    actor_loss      | -39.5    |
# |    critic_loss     | 3.15     |
# |    ent_coef        | 0.0216   |
# |    ent_coef_loss   | 0.74     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 28999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 275      |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 96       |
# |    time_elapsed    | 414      |
# |    total_timesteps | 40000    |
# | train/             |          |
# |    actor_loss      | -42.8    |
# |    critic_loss     | 3.2      |
# |    ent_coef        | 0.0224   |
# |    ent_coef_loss   | 1.42     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 29999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 297      |
# | time/              |          |
# |    episodes        | 41       |
# |    fps             | 95       |
# |    time_elapsed    | 428      |
# |    total_timesteps | 41000    |
# | train/             |          |
# |    actor_loss      | -44.1    |
# |    critic_loss     | 2.74     |
# |    ent_coef        | 0.0243   |
# |    ent_coef_loss   | -1.33    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 30999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 295      |
# | time/              |          |
# |    episodes        | 42       |
# |    fps             | 95       |
# |    time_elapsed    | 442      |
# |    total_timesteps | 42000    |
# | train/             |          |
# |    actor_loss      | -47      |
# |    critic_loss     | 3.7      |
# |    ent_coef        | 0.0252   |
# |    ent_coef_loss   | -0.574   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 31999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 346      |
# | time/              |          |
# |    episodes        | 43       |
# |    fps             | 94       |
# |    time_elapsed    | 455      |
# |    total_timesteps | 43000    |
# | train/             |          |
# |    actor_loss      | -50.1    |
# |    critic_loss     | 2.86     |
# |    ent_coef        | 0.0271   |
# |    ent_coef_loss   | -0.217   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 32999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 405      |
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 93       |
# |    time_elapsed    | 469      |
# |    total_timesteps | 44000    |
# | train/             |          |
# |    actor_loss      | -52.4    |
# |    critic_loss     | 4.11     |
# |    ent_coef        | 0.0285   |
# |    ent_coef_loss   | -0.538   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 33999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 453      |
# | time/              |          |
# |    episodes        | 45       |
# |    fps             | 93       |
# |    time_elapsed    | 483      |
# |    total_timesteps | 45000    |
# | train/             |          |
# |    actor_loss      | -59.1    |
# |    critic_loss     | 4.08     |
# |    ent_coef        | 0.0303   |
# |    ent_coef_loss   | 1.54     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 34999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 504      |
# | time/              |          |
# |    episodes        | 46       |
# |    fps             | 92       |
# |    time_elapsed    | 496      |
# |    total_timesteps | 46000    |
# | train/             |          |
# |    actor_loss      | -59.8    |
# |    critic_loss     | 4.91     |
# |    ent_coef        | 0.0325   |
# |    ent_coef_loss   | 0.923    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 35999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 557      |
# | time/              |          |
# |    episodes        | 47       |
# |    fps             | 92       |
# |    time_elapsed    | 510      |
# |    total_timesteps | 47000    |
# | train/             |          |
# |    actor_loss      | -63.6    |
# |    critic_loss     | 5.85     |
# |    ent_coef        | 0.0344   |
# |    ent_coef_loss   | 0.545    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 36999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 603      |
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 91       |
# |    time_elapsed    | 524      |
# |    total_timesteps | 48000    |
# | train/             |          |
# |    actor_loss      | -71.7    |
# |    critic_loss     | 4.39     |
# |    ent_coef        | 0.0361   |
# |    ent_coef_loss   | 0.672    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 37999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 621      |
# | time/              |          |
# |    episodes        | 49       |
# |    fps             | 91       |
# |    time_elapsed    | 537      |
# |    total_timesteps | 49000    |
# | train/             |          |
# |    actor_loss      | -74.4    |
# |    critic_loss     | 8.22     |
# |    ent_coef        | 0.0374   |
# |    ent_coef_loss   | 0.818    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 38999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 636      |
# | time/              |          |
# |    episodes        | 50       |
# |    fps             | 90       |
# |    time_elapsed    | 551      |
# |    total_timesteps | 50000    |
# | train/             |          |
# |    actor_loss      | -69.4    |
# |    critic_loss     | 4.75     |
# |    ent_coef        | 0.0393   |
# |    ent_coef_loss   | 1.24     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 39999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 672      |
# | time/              |          |
# |    episodes        | 51       |
# |    fps             | 90       |
# |    time_elapsed    | 565      |
# |    total_timesteps | 51000    |
# | train/             |          |
# |    actor_loss      | -75.5    |
# |    critic_loss     | 7.79     |
# |    ent_coef        | 0.0404   |
# |    ent_coef_loss   | -0.797   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 40999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 662      |
# | time/              |          |
# |    episodes        | 52       |
# |    fps             | 89       |
# |    time_elapsed    | 578      |
# |    total_timesteps | 52000    |
# | train/             |          |
# |    actor_loss      | -74.3    |
# |    critic_loss     | 7.08     |
# |    ent_coef        | 0.0398   |
# |    ent_coef_loss   | -1.82    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 41999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 716      |
# | time/              |          |
# |    episodes        | 53       |
# |    fps             | 89       |
# |    time_elapsed    | 592      |
# |    total_timesteps | 53000    |
# | train/             |          |
# |    actor_loss      | -80.7    |
# |    critic_loss     | 5.14     |
# |    ent_coef        | 0.0416   |
# |    ent_coef_loss   | -0.73    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 42999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 757      |
# | time/              |          |
# |    episodes        | 54       |
# |    fps             | 89       |
# |    time_elapsed    | 606      |
# |    total_timesteps | 54000    |
# | train/             |          |
# |    actor_loss      | -83.3    |
# |    critic_loss     | 5.07     |
# |    ent_coef        | 0.0432   |
# |    ent_coef_loss   | -0.35    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 43999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 802      |
# | time/              |          |
# |    episodes        | 55       |
# |    fps             | 88       |
# |    time_elapsed    | 619      |
# |    total_timesteps | 55000    |
# | train/             |          |
# |    actor_loss      | -88.9    |
# |    critic_loss     | 8.48     |
# |    ent_coef        | 0.0431   |
# |    ent_coef_loss   | 1.11     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 44999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 848      |
# | time/              |          |
# |    episodes        | 56       |
# |    fps             | 88       |
# |    time_elapsed    | 633      |
# |    total_timesteps | 56000    |
# | train/             |          |
# |    actor_loss      | -86.8    |
# |    critic_loss     | 8.9      |
# |    ent_coef        | 0.0442   |
# |    ent_coef_loss   | -1.71    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 45999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 892      |
# | time/              |          |
# |    episodes        | 57       |
# |    fps             | 88       |
# |    time_elapsed    | 647      |
# |    total_timesteps | 57000    |
# | train/             |          |
# |    actor_loss      | -97.9    |
# |    critic_loss     | 6.59     |
# |    ent_coef        | 0.0462   |
# |    ent_coef_loss   | -0.441   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 46999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 939      |
# | time/              |          |
# |    episodes        | 58       |
# |    fps             | 87       |
# |    time_elapsed    | 660      |
# |    total_timesteps | 58000    |
# | train/             |          |
# |    actor_loss      | -102     |
# |    critic_loss     | 10.1     |
# |    ent_coef        | 0.0493   |
# |    ent_coef_loss   | -0.462   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 47999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 980      |
# | time/              |          |
# |    episodes        | 59       |
# |    fps             | 87       |
# |    time_elapsed    | 674      |
# |    total_timesteps | 59000    |
# | train/             |          |
# |    actor_loss      | -98.7    |
# |    critic_loss     | 8.9      |
# |    ent_coef        | 0.0517   |
# |    ent_coef_loss   | -2.23    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 48999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.02e+03 |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 87       |
# |    time_elapsed    | 688      |
# |    total_timesteps | 60000    |
# | train/             |          |
# |    actor_loss      | -111     |
# |    critic_loss     | 8.56     |
# |    ent_coef        | 0.0535   |
# |    ent_coef_loss   | -0.728   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 49999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.06e+03 |
# | time/              |          |
# |    episodes        | 61       |
# |    fps             | 86       |
# |    time_elapsed    | 702      |
# |    total_timesteps | 61000    |
# | train/             |          |
# |    actor_loss      | -107     |
# |    critic_loss     | 10.3     |
# |    ent_coef        | 0.0545   |
# |    ent_coef_loss   | 1.07     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 50999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.1e+03  |
# | time/              |          |
# |    episodes        | 62       |
# |    fps             | 86       |
# |    time_elapsed    | 715      |
# |    total_timesteps | 62000    |
# | train/             |          |
# |    actor_loss      | -111     |
# |    critic_loss     | 10.8     |
# |    ent_coef        | 0.0569   |
# |    ent_coef_loss   | -1.03    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 51999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.14e+03 |
# | time/              |          |
# |    episodes        | 63       |
# |    fps             | 86       |
# |    time_elapsed    | 729      |
# |    total_timesteps | 63000    |
# | train/             |          |
# |    actor_loss      | -115     |
# |    critic_loss     | 9.05     |
# |    ent_coef        | 0.058    |
# |    ent_coef_loss   | -1.1     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 52999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.18e+03 |
# | time/              |          |
# |    episodes        | 64       |
# |    fps             | 86       |
# |    time_elapsed    | 742      |
# |    total_timesteps | 64000    |
# | train/             |          |
# |    actor_loss      | -127     |
# |    critic_loss     | 9.03     |
# |    ent_coef        | 0.0612   |
# |    ent_coef_loss   | 1.5      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 53999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.22e+03 |
# | time/              |          |
# |    episodes        | 65       |
# |    fps             | 85       |
# |    time_elapsed    | 756      |
# |    total_timesteps | 65000    |
# | train/             |          |
# |    actor_loss      | -127     |
# |    critic_loss     | 10.3     |
# |    ent_coef        | 0.0638   |
# |    ent_coef_loss   | -0.717   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 54999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.26e+03 |
# | time/              |          |
# |    episodes        | 66       |
# |    fps             | 85       |
# |    time_elapsed    | 770      |
# |    total_timesteps | 66000    |
# | train/             |          |
# |    actor_loss      | -129     |
# |    critic_loss     | 9.05     |
# |    ent_coef        | 0.0643   |
# |    ent_coef_loss   | -0.337   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 55999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.3e+03  |
# | time/              |          |
# |    episodes        | 67       |
# |    fps             | 85       |
# |    time_elapsed    | 783      |
# |    total_timesteps | 67000    |
# | train/             |          |
# |    actor_loss      | -128     |
# |    critic_loss     | 9.2      |
# |    ent_coef        | 0.0666   |
# |    ent_coef_loss   | -0.535   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 56999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.33e+03 |
# | time/              |          |
# |    episodes        | 68       |
# |    fps             | 85       |
# |    time_elapsed    | 797      |
# |    total_timesteps | 68000    |
# | train/             |          |
# |    actor_loss      | -134     |
# |    critic_loss     | 11.8     |
# |    ent_coef        | 0.067    |
# |    ent_coef_loss   | 0.147    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 57999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.37e+03 |
# | time/              |          |
# |    episodes        | 69       |
# |    fps             | 85       |
# |    time_elapsed    | 811      |
# |    total_timesteps | 69000    |
# | train/             |          |
# |    actor_loss      | -142     |
# |    critic_loss     | 16.2     |
# |    ent_coef        | 0.07     |
# |    ent_coef_loss   | 0.801    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 58999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.41e+03 |
# | time/              |          |
# |    episodes        | 70       |
# |    fps             | 84       |
# |    time_elapsed    | 824      |
# |    total_timesteps | 70000    |
# | train/             |          |
# |    actor_loss      | -143     |
# |    critic_loss     | 8.81     |
# |    ent_coef        | 0.0721   |
# |    ent_coef_loss   | -0.574   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 59999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.45e+03 |
# | time/              |          |
# |    episodes        | 71       |
# |    fps             | 84       |
# |    time_elapsed    | 838      |
# |    total_timesteps | 71000    |
# | train/             |          |
# |    actor_loss      | -143     |
# |    critic_loss     | 8.52     |
# |    ent_coef        | 0.0735   |
# |    ent_coef_loss   | -0.763   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 60999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.48e+03 |
# | time/              |          |
# |    episodes        | 72       |
# |    fps             | 84       |
# |    time_elapsed    | 852      |
# |    total_timesteps | 72000    |
# | train/             |          |
# |    actor_loss      | -153     |
# |    critic_loss     | 12.5     |
# |    ent_coef        | 0.0759   |
# |    ent_coef_loss   | 0.517    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 61999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.52e+03 |
# | time/              |          |
# |    episodes        | 73       |
# |    fps             | 84       |
# |    time_elapsed    | 865      |
# |    total_timesteps | 73000    |
# | train/             |          |
# |    actor_loss      | -156     |
# |    critic_loss     | 9.41     |
# |    ent_coef        | 0.0758   |
# |    ent_coef_loss   | 1.15     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 62999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.55e+03 |
# | time/              |          |
# |    episodes        | 74       |
# |    fps             | 84       |
# |    time_elapsed    | 879      |
# |    total_timesteps | 74000    |
# | train/             |          |
# |    actor_loss      | -148     |
# |    critic_loss     | 10.8     |
# |    ent_coef        | 0.0777   |
# |    ent_coef_loss   | -0.0419  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 63999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.59e+03 |
# | time/              |          |
# |    episodes        | 75       |
# |    fps             | 84       |
# |    time_elapsed    | 892      |
# |    total_timesteps | 75000    |
# | train/             |          |
# |    actor_loss      | -161     |
# |    critic_loss     | 11.5     |
# |    ent_coef        | 0.0774   |
# |    ent_coef_loss   | 0.0335   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 64999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.62e+03 |
# | time/              |          |
# |    episodes        | 76       |
# |    fps             | 83       |
# |    time_elapsed    | 906      |
# |    total_timesteps | 76000    |
# | train/             |          |
# |    actor_loss      | -175     |
# |    critic_loss     | 13.9     |
# |    ent_coef        | 0.0788   |
# |    ent_coef_loss   | 1.46     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 65999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.65e+03 |
# | time/              |          |
# |    episodes        | 77       |
# |    fps             | 83       |
# |    time_elapsed    | 920      |
# |    total_timesteps | 77000    |
# | train/             |          |
# |    actor_loss      | -172     |
# |    critic_loss     | 9.15     |
# |    ent_coef        | 0.0821   |
# |    ent_coef_loss   | 0.464    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 66999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.68e+03 |
# | time/              |          |
# |    episodes        | 78       |
# |    fps             | 83       |
# |    time_elapsed    | 933      |
# |    total_timesteps | 78000    |
# | train/             |          |
# |    actor_loss      | -168     |
# |    critic_loss     | 9.82     |
# |    ent_coef        | 0.0834   |
# |    ent_coef_loss   | -0.149   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 67999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.72e+03 |
# | time/              |          |
# |    episodes        | 79       |
# |    fps             | 83       |
# |    time_elapsed    | 947      |
# |    total_timesteps | 79000    |
# | train/             |          |
# |    actor_loss      | -173     |
# |    critic_loss     | 9.24     |
# |    ent_coef        | 0.0859   |
# |    ent_coef_loss   | -0.844   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 68999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.75e+03 |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 83       |
# |    time_elapsed    | 961      |
# |    total_timesteps | 80000    |
# | train/             |          |
# |    actor_loss      | -168     |
# |    critic_loss     | 9.28     |
# |    ent_coef        | 0.0876   |
# |    ent_coef_loss   | -0.885   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 69999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.78e+03 |
# | time/              |          |
# |    episodes        | 81       |
# |    fps             | 83       |
# |    time_elapsed    | 974      |
# |    total_timesteps | 81000    |
# | train/             |          |
# |    actor_loss      | -161     |
# |    critic_loss     | 9.5      |
# |    ent_coef        | 0.0869   |
# |    ent_coef_loss   | -1.33    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 70999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.81e+03 |
# | time/              |          |
# |    episodes        | 82       |
# |    fps             | 82       |
# |    time_elapsed    | 988      |
# |    total_timesteps | 82000    |
# | train/             |          |
# |    actor_loss      | -184     |
# |    critic_loss     | 10.5     |
# |    ent_coef        | 0.0914   |
# |    ent_coef_loss   | -0.646   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 71999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.84e+03 |
# | time/              |          |
# |    episodes        | 83       |
# |    fps             | 82       |
# |    time_elapsed    | 1001     |
# |    total_timesteps | 83000    |
# | train/             |          |
# |    actor_loss      | -199     |
# |    critic_loss     | 13.2     |
# |    ent_coef        | 0.0933   |
# |    ent_coef_loss   | 0.854    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 72999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.87e+03 |
# | time/              |          |
# |    episodes        | 84       |
# |    fps             | 82       |
# |    time_elapsed    | 1015     |
# |    total_timesteps | 84000    |
# | train/             |          |
# |    actor_loss      | -187     |
# |    critic_loss     | 11.5     |
# |    ent_coef        | 0.0934   |
# |    ent_coef_loss   | 1.02     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 73999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.91e+03 |
# | time/              |          |
# |    episodes        | 85       |
# |    fps             | 82       |
# |    time_elapsed    | 1029     |
# |    total_timesteps | 85000    |
# | train/             |          |
# |    actor_loss      | -193     |
# |    critic_loss     | 10       |
# |    ent_coef        | 0.0957   |
# |    ent_coef_loss   | -0.396   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 74999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94e+03 |
# | time/              |          |
# |    episodes        | 86       |
# |    fps             | 82       |
# |    time_elapsed    | 1042     |
# |    total_timesteps | 86000    |
# | train/             |          |
# |    actor_loss      | -189     |
# |    critic_loss     | 9.83     |
# |    ent_coef        | 0.097    |
# |    ent_coef_loss   | -1.21    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 75999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.97e+03 |
# | time/              |          |
# |    episodes        | 87       |
# |    fps             | 82       |
# |    time_elapsed    | 1056     |
# |    total_timesteps | 87000    |
# | train/             |          |
# |    actor_loss      | -208     |
# |    critic_loss     | 10.4     |
# |    ent_coef        | 0.0976   |
# |    ent_coef_loss   | 0.868    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 76999    |
# ...
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.12e+04 |
# | time/              |          |
# |    episodes        | 1425     |
# |    fps             | 65       |
# |    time_elapsed    | 21776    |
# |    total_timesteps | 1425000  |
# | train/             |          |
# |    actor_loss      | -912     |
# |    critic_loss     | 13.7     |
# |    ent_coef        | 0.256    |
# |    ent_coef_loss   | -0.415   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1414999  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.12e+04 |
# | time/              |          |
# |    episodes        | 1426     |
# |    fps             | 65       |
# |    time_elapsed    | 21790    |
# |    total_timesteps | 1426000  |
# | train/             |          |
# |    actor_loss      | -921     |
# |    critic_loss     | 13.9     |
# |    ent_coef        | 0.259    |
# |    ent_coef_loss   | 0.202    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1415999  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.12e+04 |
# | time/              |          |
# |    episodes        | 1427     |
# |    fps             | 65       |
# |    time_elapsed    | 21804    |
# |    total_timesteps | 1427000  |
# | train/             |          |
# |    actor_loss      | -914     |
# |    critic_loss     | 21.6     |
# |    ent_coef        | 0.262    |
# |    ent_coef_loss   | -0.336   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1416999  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.12e+04 |
# | time/              |          |
# |    episodes        | 1428     |
# |    fps             | 65       |
# |    time_elapsed    | 21818    |
# |    total_timesteps | 1428000  |
# | train/             |          |
# |    actor_loss      | -922     |
# |    critic_loss     | 21.4     |
# |    ent_coef        | 0.254    |
# |    ent_coef_loss   | 0.186    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1417999  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.12e+04 |
# | time/              |          |
# |    episodes        | 1429     |
# |    fps             | 65       |
# |    time_elapsed    | 21832    |
# |    total_timesteps | 1429000  |
# | train/             |          |
# |    actor_loss      | -921     |
# |    critic_loss     | 43.8     |
# |    ent_coef        | 0.256    |
# |    ent_coef_loss   | 0.016    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1418999  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.12e+04 |
# | time/              |          |
# |    episodes        | 1430     |
# |    fps             | 65       |
# |    time_elapsed    | 21845    |
# |    total_timesteps | 1430000  |
# | train/             |          |
# |    actor_loss      | -923     |
# |    critic_loss     | 23.9     |
# |    ent_coef        | 0.257    |
# |    ent_coef_loss   | -0.187   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1419999  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.12e+04 |
# | time/              |          |
# |    episodes        | 1431     |
# |    fps             | 65       |
# |    time_elapsed    | 21859    |
# |    total_timesteps | 1431000  |
# | train/             |          |
# |    actor_loss      | -933     |
# |    critic_loss     | 15.7     |
# |    ent_coef        | 0.262    |
# |    ent_coef_loss   | -0.624   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1420999  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.12e+04 |
# | time/              |          |
# |    episodes        | 1432     |
# |    fps             | 65       |
# |    time_elapsed    | 21873    |
# |    total_timesteps | 1432000  |
# | train/             |          |
# |    actor_loss      | -931     |
# |    critic_loss     | 15.1     |
# |    ent_coef        | 0.257    |
# |    ent_coef_loss   | -0.455   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1421999  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.12e+04 |
# | time/              |          |
# |    episodes        | 1433     |
# |    fps             | 65       |
# |    time_elapsed    | 21887    |
# |    total_timesteps | 1433000  |
# | train/             |          |
# |    actor_loss      | -918     |
# |    critic_loss     | 26.4     |
# |    ent_coef        | 0.259    |
# |    ent_coef_loss   | 0.0974   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1422999  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.12e+04 |
# | time/              |          |
# |    episodes        | 1434     |
# |    fps             | 65       |
# |    time_elapsed    | 21901    |
# |    total_timesteps | 1434000  |
# | train/             |          |
# |    actor_loss      | -909     |
# |    critic_loss     | 13.3     |
# |    ent_coef        | 0.256    |
# |    ent_coef_loss   | -0.275   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1423999  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.13e+04 |
# | time/              |          |
# |    episodes        | 1435     |
# |    fps             | 65       |
# |    time_elapsed    | 21914    |
# |    total_timesteps | 1435000  |
# | train/             |          |
# |    actor_loss      | -920     |
# |    critic_loss     | 16.6     |
# |    ent_coef        | 0.258    |
# |    ent_coef_loss   | 0.354    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1424999  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.13e+04 |
# | time/              |          |
# |    episodes        | 1436     |
# |    fps             | 65       |
# |    time_elapsed    | 21928    |
# |    total_timesteps | 1436000  |
# | train/             |          |
# |    actor_loss      | -930     |
# |    critic_loss     | 11.9     |
# |    ent_coef        | 0.258    |
# |    ent_coef_loss   | 0.158    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1425999  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.13e+04 |
# | time/              |          |
# |    episodes        | 1437     |
# |    fps             | 65       |
# |    time_elapsed    | 21942    |
# |    total_timesteps | 1437000  |
# | train/             |          |
# |    actor_loss      | -925     |
# |    critic_loss     | 13.5     |
# |    ent_coef        | 0.256    |
# |    ent_coef_loss   | -0.568   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1426999  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.13e+04 |
# | time/              |          |
# |    episodes        | 1438     |
# |    fps             | 65       |
# |    time_elapsed    | 21956    |
# |    total_timesteps | 1438000  |
# | train/             |          |
# |    actor_loss      | -916     |
# |    critic_loss     | 14       |
# |    ent_coef        | 0.257    |
# |    ent_coef_loss   | -0.643   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1427999  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.13e+04 |
# | time/              |          |
# |    episodes        | 1439     |
# |    fps             | 65       |
# |    time_elapsed    | 21970    |
# |    total_timesteps | 1439000  |
# | train/             |          |
# |    actor_loss      | -926     |
# |    critic_loss     | 18.2     |
# |    ent_coef        | 0.259    |
# |    ent_coef_loss   | 0.388    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1428999  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.13e+04 |
# | time/              |          |
# |    episodes        | 1440     |
# |    fps             | 65       |
# |    time_elapsed    | 21984    |
# |    total_timesteps | 1440000  |
# | train/             |          |
# |    actor_loss      | -921     |
# |    critic_loss     | 20.8     |
# |    ent_coef        | 0.253    |
# |    ent_coef_loss   | 0.234    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1429999  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.13e+04 |
# | time/              |          |
# |    episodes        | 1441     |
# |    fps             | 65       |
# |    time_elapsed    | 21997    |
# |    total_timesteps | 1441000  |
# | train/             |          |
# |    actor_loss      | -918     |
# |    critic_loss     | 16.2     |
# |    ent_coef        | 0.256    |
# |    ent_coef_loss   | -0.431   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1430999  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.13e+04 |
# | time/              |          |
# |    episodes        | 1442     |
# |    fps             | 65       |
# |    time_elapsed    | 22012    |
# |    total_timesteps | 1442000  |
# | train/             |          |
# |    actor_loss      | -937     |
# |    critic_loss     | 25.4     |
# |    ent_coef        | 0.254    |
# |    ent_coef_loss   | -0.214   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1431999  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.13e+04 |
# | time/              |          |
# |    episodes        | 1443     |
# |    fps             | 65       |
# |    time_elapsed    | 22025    |
# |    total_timesteps | 1443000  |
# | train/             |          |
# |    actor_loss      | -923     |
# |    critic_loss     | 23.1     |
# |    ent_coef        | 0.256    |
# |    ent_coef_loss   | -0.00994 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1432999  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.13e+04 |
# | time/              |          |
# |    episodes        | 1444     |
# |    fps             | 65       |
# |    time_elapsed    | 22039    |
# |    total_timesteps | 1444000  |
# | train/             |          |
# |    actor_loss      | -927     |
# |    critic_loss     | 12.6     |
# |    ent_coef        | 0.26     |
# |    ent_coef_loss   | -0.269   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1433999  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.13e+04 |
# | time/              |          |
# |    episodes        | 1445     |
# |    fps             | 65       |
# |    time_elapsed    | 22052    |
# |    total_timesteps | 1445000  |
# | train/             |          |
# |    actor_loss      | -925     |
# |    critic_loss     | 48.2     |
# |    ent_coef        | 0.259    |
# |    ent_coef_loss   | -0.225   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1434999  |
# ---------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 10
#       7 # env = TransformReward(env, lambda r: 5 * r)
#       9 model = SAC("MlpPolicy", env, verbose=10, learning_starts=10000) # , seed=594371)
# ---> 10 model.learn(total_timesteps=1_500_000, log_interval=1)
#
# File C:\Program Files\Python311\Lib\site-packages\stable_baselines3\sac\sac.py:307, in SAC.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     298 def learn(
#     299     self: SelfSAC,
#     300     total_timesteps: int,
#    (...)
#     305     progress_bar: bool = False,
#     306 ) -> SelfSAC:
# --> 307     return super().learn(
#     308         total_timesteps=total_timesteps,
#     309         callback=callback,
#     310         log_interval=log_interval,
#     311         tb_log_name=tb_log_name,
#     312         reset_num_timesteps=reset_num_timesteps,
#     313         progress_bar=progress_bar,
#     314     )
#
# File C:\Program Files\Python311\Lib\site-packages\stable_baselines3\common\off_policy_algorithm.py:347, in OffPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     345         # Special case when the user passes `gradient_steps=0`
#     346         if gradient_steps > 0:
# --> 347             self.train(batch_size=self.batch_size, gradient_steps=gradient_steps)
#     349 callback.on_training_end()
#     351 return self
#
# File C:\Program Files\Python311\Lib\site-packages\stable_baselines3\sac\sac.py:215, in SAC.train(self, gradient_steps, batch_size)
#     211 actor_losses, critic_losses = [], []
#     213 for gradient_step in range(gradient_steps):
#     214     # Sample replay buffer
# --> 215     replay_data = self.replay_buffer.sample(batch_size, env=self._vec_normalize_env)  # type: ignore[union-attr]
#     217     # We need to sample because `log_std` may have changed between two gradient steps
#     218     if self.use_sde:
#
# File C:\Program Files\Python311\Lib\site-packages\stable_baselines3\common\buffers.py:297, in ReplayBuffer.sample(self, batch_size, env)
#     285 """
#     286 Sample elements from the replay buffer.
#     287 Custom sampling when using memory efficient variant,
#    (...)
#     294 :return:
#     295 """
#     296 if not self.optimize_memory_usage:
# --> 297     return super().sample(batch_size=batch_size, env=env)
#     298 # Do not sample the element with index `self.pos` as the transitions is invalid
#     299 # (we use only one array to store `obs` and `next_obs`)
#     300 if self.full:
#
# File C:\Program Files\Python311\Lib\site-packages\stable_baselines3\common\buffers.py:114, in BaseBuffer.sample(self, batch_size, env)
#     112 upper_bound = self.buffer_size if self.full else self.pos
#     113 batch_inds = np.random.randint(0, upper_bound, size=batch_size)
# --> 114 return self._get_samples(batch_inds, env=env)
#
# File C:\Program Files\Python311\Lib\site-packages\stable_baselines3\common\buffers.py:322, in ReplayBuffer._get_samples(self, batch_inds, env)
#     312 else:
#     313     next_obs = self._normalize_obs(self.next_observations[batch_inds, env_indices, :], env)
#     315 data = (
#     316     self._normalize_obs(self.observations[batch_inds, env_indices, :], env),
#     317     self.actions[batch_inds, env_indices, :],
#     318     next_obs,
#     319     # Only use dones that are not due to timeouts
#     320     # deactivated by default (timeouts is initialized as an array of False)
#     321     (self.dones[batch_inds, env_indices] * (1 - self.timeouts[batch_inds, env_indices])).reshape(-1, 1),
# --> 322     self._normalize_reward(self.rewards[batch_inds, env_indices].reshape(-1, 1), env),
#     323 )
#     324 return ReplayBufferSamples(*tuple(map(self.to_torch, data)))
#
# KeyboardInterrupt:
