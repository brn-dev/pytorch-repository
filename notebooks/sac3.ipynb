# %%
import inspect
import os
import time
from pathlib import Path

import gymnasium
from gymnasium import Env
from gymnasium.vector import VectorEnv

from sac import init_action_selector, init_policy, init_optimizer, wrap_env, policy_construction_hyper_parameter
from src.datetime import get_current_timestamp
from src.experiment_logging.experiment_logger import ExperimentLogger, log_experiment
from src.model_db.model_db import ModelDB
from src.model_db.dummy_model_db import DummyModelDB
from src.np_functions import inv_symmetric_log
from src.reinforcement_learning.algorithms.policy_mitosis.mitosis_policy_info import MitosisPolicyInfo
from src.model_db.tiny_model_db import TinyModelDB
from src.module_analysis import count_parameters, get_gradients_per_parameter
from src.moving_averages import ExponentialMovingAverage
from src.reinforcement_learning.core.action_selectors.action_selector import ActionSelector
from src.reinforcement_learning.core.action_selectors.predicted_std_action_selector import PredictedStdActionSelector
from src.reinforcement_learning.core.action_selectors.state_dependent_noise_action_selector import \
    StateDependentNoiseActionSelector
from src.reinforcement_learning.core.generalized_advantage_estimate import compute_episode_returns, compute_returns
from src.reinforcement_learning.core.policies.base_policy import BasePolicy
from src.reinforcement_learning.core.policy_construction import InitActionSelectorFunction, PolicyConstruction
from src.reinforcement_learning.gym.envs.test_env import TestEnv
from src.schedulers import FixedValueScheduler, OneStepRecursiveScheduler
from src.stopwatch import Stopwatch
from src.summary_statistics import format_summary_statics
from src.reinforcement_learning.core.policies.actor_critic_policy import ActorCriticPolicy
from typing import Any, SupportsFloat, Optional
from gymnasium.wrappers import RecordVideo, AutoResetWrapper, NormalizeReward, TransformReward, TransformObservation, ClipAction
from src.reinforcement_learning.core.callback import Callback
from src.reinforcement_learning.algorithms.sac.sac import SAC, SAC_DEFAULT_OPTIMIZER_PROVIDER
from src.reinforcement_learning.algorithms.ppo.ppo import PPO, PPOLoggingConfig
from src.reinforcement_learning.core.normalization import NormalizationType
from src.torch_device import set_default_torch_device, optimizer_to_device
from src.reinforcement_learning.gym.parallelize_env import parallelize_env_async
from torch.distributions import Normal, Categorical

import torch
from torch import optim, nn
import torch.distributions as dist
import gymnasium as gym
import numpy as np

from src.torch_functions import antisymmetric_power

# %load_ext autoreload
# %autoreload 2
# Out:
# pygame 2.5.2 (SDL 2.28.3, Python 3.11.7)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
from src.summary_statistics import maybe_compute_summary_statistics
from src.reinforcement_learning.core.loss_config import LossLoggingConfig
from src.reinforcement_learning.algorithms.sac.sac import SAC, SACLoggingConfig
def get_setup() -> dict[str, str]:
    import inspect
    import sac
    return {
        'sac.py': inspect.getsource(sac),
        'notebook': _ih[1] + '\n\n' + _ih[-1], # first and last cell input (imports and this cell)
    }

policy_id: str
policy: BasePolicy
optimizer: optim.Optimizer
wrapped_env: Env
steps_trained: int
def get_policy(create_new_if_exists: bool):
    
    global policy_id, policy, optimizer, wrapped_env, steps_trained
    
    policy_in_ram = 'policy' in globals()
    if not policy_in_ram or create_new_if_exists:
        if not policy_in_ram:
            print('No policy in RAM, creating a new one')
        
        policy_id = get_current_timestamp()
        policy, optimizer, wrapped_env = PolicyConstruction.init_from_info(
            env=env,
            info=PolicyConstruction.create_policy_initialization_info(
                init_action_selector=init_action_selector,
                init_policy=init_policy,
                init_optimizer=init_optimizer,
                wrap_env=wrap_env,
                hyper_parameters=policy_construction_hyper_parameter,
            ),
        )
        steps_trained = 0
        print(f'New policy {policy_id} created')
    
    if parent_policy_id is not None:
        model_entry = policy_db.load_model_state_dict(policy, parent_policy_id)
        steps_trained = model_entry['model_info']['steps_trained']
        print(f'Loading state dict from policy {parent_policy_id}')
    
    print(f'Using policy {policy_id} with parent policy {parent_policy_id}')
    return policy_id, policy, optimizer, wrapped_env, steps_trained

score_mean_ema = ExponentialMovingAverage(alpha=0.25)
step_stopwatch = Stopwatch()
total_stopwatch = Stopwatch()
best_iteration_score = -1e6

def on_rollout_done(rl: SAC, step: int, info: dict[str, Any], scheduler_values: dict[str, Any]):
    
    if step % 1000 != 0:
        return
    
    tail_indices = rl.buffer.tail_indices(1000)
    
    # rewards = rl.buffer.rewards[tail_indices]
    # if 'raw_rewards' in info['rollout']:
    #     rewards = info['rollout']['raw_rewards']
    
    # episode_scores = compute_episode_returns(
    #     rewards=rewards,
    #     episode_starts=np.repeat(np.arange(len(tail_indices)).reshape(-1, 1), num_envs, axis=1) % 1000 == 0,
    #     last_episode_starts=info['last_episode_starts'],
    #     gamma=1.0,
    #     gae_lambda=1.0,
    #     normalize_rewards=None,
    #     remove_unfinished_episodes=True,
    # )
    
    episode_scores = rl.buffer.compute_most_recent_episode_scores(rl.num_envs)
    
    if len(episode_scores) > 0:
    
        global best_iteration_score
        iteration_score = episode_scores.mean()
        score_moving_average = score_mean_ema.update(iteration_score)
        if iteration_score >= best_iteration_score:
            best_iteration_score = iteration_score
            policy_db.save_model_state_dict(
                model_id=policy_id,
                parent_model_id=parent_policy_id,
                model_info={
                    'score': iteration_score.item(),
                    'steps_trained': steps_trained,
                    'wrap_env_source_code': wrap_env_source_code_source,
                    'init_policy_source_code': init_policy_source
                },
                model=policy,
                optimizer=optimizer,
            )
        info['score_moving_average'] = score_moving_average
    
    info['episode_scores'] = episode_scores
        
def on_optimization_done(rl: SAC, step: int, info: dict[str, Any], scheduler_values: dict[str, Any]):
    # global steps_trained
    # steps_trained += rl.buffer.pos
    
    if step % 1000 != 0:
        return
    num_env_steps = step * rl.num_envs
    
    step_time = step_stopwatch.reset()
    total_time = total_stopwatch.time_passed()
    
    tail_indices = rl.buffer.tail_indices(1000)
    
    episode_scores = info.get('episode_scores')
    score_moving_average = info.get('score_moving_average') or 0.0
    
    scores = format_summary_statics(
        episode_scores, 
        mean_format=' 6.3f',
        std_format='4.3f',
        min_value_format=' 6.3f',
        max_value_format='5.3f',
        n_format='>2'
    )
    # scores2 = format_summary_statics(
    #     rl.buffer.compute_most_recent_episode_scores(rl.num_envs, lambda r: 1 * r), 
    #     mean_format=' 6.3f',
    #     std_format='4.3f',
    #     min_value_format=' 6.3f',
    #     max_value_format='5.3f',
    #     n_format='>2'
    # )
    # advantages = format_summary_statics(
    #     rl.buffer.advantages, 
    #     mean_format=' 6.3f',
    #     std_format='.1f',
    #     min_value_format=' 7.3f',
    #     max_value_format='6.3f',
    # )
    actor_loss = format_summary_statics(
        info['final_actor_loss'],  
        mean_format=' 5.3f',
        # std_format='5.3f',
        std_format=None,
        min_value_format=None,
        max_value_format=None,
    )
    # actor_loss_raw = format_summary_statics(
    #     info['raw_actor_loss'],  
    #     mean_format=' 5.3f',
    #     std_format='5.3f',
    #     min_value_format=None,
    #     max_value_format=None,
    # )
    entropy_coef_loss = None if 'final_entropy_coef_loss' not in info else format_summary_statics(
        info['final_entropy_coef_loss'], 
        mean_format='5.3f',
#         std_format='5.3f',
        std_format=None,
        min_value_format=None,
        max_value_format=None,
    )
    critic_loss = format_summary_statics(
        info['final_critic_loss'], 
        mean_format='5.3f',
#         std_format='5.3f',
        std_format=None,
        min_value_format=None,
        max_value_format=None,
    )
    entropy_coef = format_summary_statics(
        info['entropy_coef'],
        mean_format='5.3f',
#         std_format='5.3f',
        std_format=None,
        min_value_format=None,
        max_value_format=None,
    )
    # resets = format_summary_statics(
    #     rl.buffer.dones.astype(int).sum(axis=0), 
    #     mean_format='.2f',
    #     std_format=None,
    #     min_value_format='1d',
    #     max_value_format=None,
    # )
    # kl_div = info['actor_kl_divergence'][-1]
    # grad_norm = format_summary_statics(
    #     info['grad_norm'], 
    #     mean_format=' 6.3f',
    #     std_format='.1f',
    #     min_value_format=' 7.3f',
    #     max_value_format='6.3f',
    # )
    action_stds = info['rollout'].get('action_stds')
    if action_stds is not None:
        rollout_action_stds = format_summary_statics(
            action_stds,
            mean_format='5.3f',
            std_format='5.3f',
            min_value_format=None,
            max_value_format=None,
        )
    else:
        rollout_action_stds = 'N/A'
    action_magnitude = format_summary_statics(
        np.abs(rl.buffer.actions[tail_indices]),
        mean_format='5.3f',
        std_format='5.3f',
        min_value_format=None,
        max_value_format=None,
    )
    # ppo_epochs = info['nr_ppo_epochs']
    # ppo_updates = info['nr_ppo_updates']
    # expl_var = rl.buffer.compute_critic_explained_variance()
    print(f"{step = : >7}, "
          f"{num_env_steps = : >7}, "
          f"{scores = :s}, "
          # f"{scores2 = :s}, "
          f'score_ema = {score_moving_average: 6.3f}, '
          # f"{advantages = :s}, "
          f"{actor_loss = :s}, "
          # f"{actor_loss_raw = :s}, "
          +(f"{entropy_coef_loss = :s}, " if entropy_coef_loss is not None else '')+
          f"{critic_loss = :s}, "
          f"{entropy_coef = :s}, "
          f"rollout_stds = {rollout_action_stds:s}, "
          f"{action_magnitude = :s}, "
          # f"{expl_var = :.3f}, "
          # f"{kl_div = :.4f}, "
          # f"{ppo_epochs = }, "
          # f"{ppo_updates = }, "
          # f"{grad_norm = :s}, "
          f"n_updates = {rl.gradient_steps_performed}, "
          # f"{resets = :s}, "
          f"time = {step_time:4.1f}, "
          f"total_time = {total_time:4.1f} \n"
          )
    logger.add_item({
        'step': step,
        'num_env_steps': num_env_steps,
        'scores': maybe_compute_summary_statistics(episode_scores),
        'actor_loss': maybe_compute_summary_statistics(info['final_actor_loss']),
        'entropy_coef_loss': maybe_compute_summary_statistics(info.get('final_entropy_coef_loss')),
        'critic_loss': maybe_compute_summary_statistics(info['final_critic_loss']),
        'entropy_coef': maybe_compute_summary_statistics(info['entropy_coef']),
        'action_stds': maybe_compute_summary_statistics(action_stds),
        'action_magnitude': maybe_compute_summary_statistics(np.abs(rl.buffer.actions[tail_indices])),
        'num_gradient_steps': rl.gradient_steps_performed,
        'step_time': step_time,
        'total_time': total_time
    })
    if step % 10000 == 0:
        logger.save_experiment_log()
        print()
    print()
    
    # if episode_scores is not None and len(episode_scores) > 0 and episode_scores.mean().item() < -500:
    #     logger.save_experiment_log()
    #     raise ValueError('Score too low, policy probably fucked :(')

device = torch.device("cuda:0") if True else torch.device('cpu')
print(f'using device {device}')

def create_env(render_mode: str | None):
    return gym.make(env_name, render_mode=render_mode, **env_kwargs)

wrap_env_source_code_source = inspect.getsource(wrap_env)
init_policy_source = inspect.getsource(init_policy)

env_name = 'HalfCheetah-v4'
# env_kwargs = {'forward_reward_weight': 1.25, 'healthy_reward': 0.5, 'ctrl_cost_weight': 0.001 }
# env_kwargs = {'forward_reward_weight': 1.25, 'ctrl_cost_weight': 0.1 }
# env_kwargs = {'forward_reward_weight': 1.25, 'ctrl_cost_weight': 0.05 }
env_kwargs = {}
num_envs = 1
    
# policy_db = TinyModelDB[MitosisPolicyInfo](base_path=f'saved_models/rl/{env_name}')
policy_db = DummyModelDB[MitosisPolicyInfo]()
print(f'{policy_db = }')

parent_policy_id=None  # '2024-04-28_20.57.23'

# TODO
# env = parallelize_env_async(lambda: create_env(render_mode=None), num_envs)
env = create_env(render_mode=None)

logger = ExperimentLogger(f'experiment_logs/{env_name}/sac/')

try:
    policy_id, policy, optimizer, wrapped_env, steps_trained = get_policy(create_new_if_exists=False)
    print(f'{count_parameters(policy) = }')
    print(f'{env = }, {num_envs = }')
        
    with ((torch.autograd.set_detect_anomaly(False))):
        algo = SAC(
            env=wrapped_env,
            policy=policy,
            actor_optimizer_provider=lambda params: optim.Adam(params, lr=3e-4),  # (params, lr=3e-4, betas=(0.5, 0.999)),
            critic_optimizer_provider=lambda params: optim.Adam(params, lr=3e-4),  # (params, lr=3e-4, betas=(0.5, 0.999)),
            # weigh_and_reduce_actor_loss=lambda l: 1 * l.mean(),
            # weigh_critic_loss=lambda l: 1 * l,
            buffer_size=1_000_000,
            reward_scale=1,
            gamma=0.99,
            tau=0.005,
            entropy_coef_optimizer_provider=lambda params: optim.Adam(params, lr=3e-4),
            entropy_coef=1.0,
            rollout_steps=1,
            gradient_steps=1,
            warmup_steps=10_000,
            optimization_batch_size=256,
            target_update_interval=1,
            # sde_noise_sample_freq=50,
            callback=Callback(
                on_rollout_done=on_rollout_done,
                rollout_schedulers={},
                on_optimization_done=on_optimization_done,
                optimization_schedulers={},
            ),
            logging_config=SACLoggingConfig(log_rollout_infos=True, log_rollout_action_stds=True,
                                            log_last_obs=True, log_entropy_coef=True,
                                            entropy_coef_loss=LossLoggingConfig(log_final=True),
                                            actor_loss=LossLoggingConfig(log_final=True, log_raw=True),
                                            critic_loss=LossLoggingConfig(log_final=True)),
            torch_device=device,
        )
        total_stopwatch.reset()
        with log_experiment(
            logger,
            experiment_tags=algo.collect_tags(),
            hyper_parameters=algo.collect_hyper_parameters(),
            setup=get_setup(),
        ) as x:
            logger.save_experiment_log()
            print('\nStarting Training\n\n')
            # import cProfile
            # pr = cProfile.Profile()
            # pr.enable()
            algo.learn(5_000_000)
            # pr.disable()  
            # pr.dump_stats('profile_stats.pstat')
except KeyboardInterrupt:
    print('keyboard interrupt')
finally:
    print('closing envs')
    time.sleep(0.5)
    env.close()
    print('envs closed')
    policy_db.close()
    print('model db closed')
    

print('done')
# Out:
# using device cuda:0
# policy_db = DummyModelDB()
# No policy in RAM, creating a new one
# New policy 2024-10-05 14:48:29.364373 created
# Using policy 2024-10-05 14:48:29.364373 with parent policy None
# count_parameters(policy) = 217870
# env = <TimeLimit<OrderEnforcing<PassiveEnvChecker<HalfCheetahEnv<HalfCheetah-v4>>>>>, num_envs = 1
# Grabbing system information... done!
# saved experiment log 2024-10-05_14-48-29_860485~gaW9kQ at experiment_logs/HalfCheetah-v4/sac/2024-10-05_14-48-29_860485~gaW9kQ.json
#
# Starting Training
#
# step =   10000, num_env_steps =   10000, scores = -190.419 (n= 1), score_ema = -255.618, actor_loss = -3.480, entropy_coef_loss = 0.000, critic_loss = 10.148, entropy_coef = 1.000, rollout_stds = N/A, action_magnitude = 0.501 ± 0.289, n_updates = 1, time =  4.6, total_time =  4.1
#
# saved experiment log 2024-10-05_14-48-29_860485~gaW9kQ at experiment_logs/HalfCheetah-v4/sac/2024-10-05_14-48-29_860485~gaW9kQ.json
#
# step =   11000, num_env_steps =   11000, scores = -258.276 (n= 1), score_ema = -256.282, actor_loss = -17.984, entropy_coef_loss = -2.996, critic_loss = 1.023, entropy_coef = 0.741, rollout_stds = 0.872 ± 0.064, action_magnitude = 0.527 ± 0.286, n_updates = 1001, time = 13.3, total_time = 17.4
#
# step =   12000, num_env_steps =   12000, scores = -203.415 (n= 1), score_ema = -243.065, actor_loss = -26.029, entropy_coef_loss = -5.986, critic_loss = 1.192, entropy_coef = 0.549, rollout_stds = 0.896 ± 0.057, action_magnitude = 0.539 ± 0.289, n_updates = 2001, time = 13.5, total_time = 30.9
#
# step =   13000, num_env_steps =   13000, scores = -244.888 (n= 1), score_ema = -243.521, actor_loss = -30.129, entropy_coef_loss = -8.914, critic_loss = 6.614, entropy_coef = 0.407, rollout_stds = 0.935 ± 0.022, action_magnitude = 0.533 ± 0.289, n_updates = 3001, time = 13.6, total_time = 44.5
#
# step =   14000, num_env_steps =   14000, scores = -224.561 (n= 1), score_ema = -238.781, actor_loss = -32.677, entropy_coef_loss = -11.647, critic_loss = 1.424, entropy_coef = 0.302, rollout_stds = 0.935 ± 0.045, action_magnitude = 0.543 ± 0.292, n_updates = 4001, time = 13.7, total_time = 58.2
#
# step =   15000, num_env_steps =   15000, scores = -261.503 (n= 1), score_ema = -244.462, actor_loss = -32.696, entropy_coef_loss = -13.810, critic_loss = 4.361, entropy_coef = 0.225, rollout_stds = 0.884 ± 0.048, action_magnitude = 0.552 ± 0.289, n_updates = 5001, time = 13.5, total_time = 71.7
#
# step =   16000, num_env_steps =   16000, scores = -187.184 (n= 1), score_ema = -230.142, actor_loss = -32.756, entropy_coef_loss = -15.635, critic_loss = 1.783, entropy_coef = 0.169, rollout_stds = 0.900 ± 0.025, action_magnitude = 0.566 ± 0.291, n_updates = 6001, time = 13.5, total_time = 85.1
#
# step =   17000, num_env_steps =   17000, scores = -160.589 (n= 1), score_ema = -212.754, actor_loss = -32.400, entropy_coef_loss = -16.956, critic_loss = 1.460, entropy_coef = 0.128, rollout_stds = 0.867 ± 0.032, action_magnitude = 0.581 ± 0.293, n_updates = 7001, time = 14.0, total_time = 99.1
#
# step =   18000, num_env_steps =   18000, scores = -149.006 (n= 1), score_ema = -196.817, actor_loss = -31.831, entropy_coef_loss = -15.928, critic_loss = 1.403, entropy_coef = 0.097, rollout_stds = 0.844 ± 0.054, action_magnitude = 0.577 ± 0.298, n_updates = 8001, time = 13.6, total_time = 112.8
#
# step =   19000, num_env_steps =   19000, scores = -287.112 (n= 1), score_ema = -219.391, actor_loss = -30.236, entropy_coef_loss = -17.487, critic_loss = 3.645, entropy_coef = 0.074, rollout_stds = 0.730 ± 0.024, action_magnitude = 0.594 ± 0.298, n_updates = 9001, time = 13.6, total_time = 126.4
#
# step =   20000, num_env_steps =   20000, scores = -211.383 (n= 1), score_ema = -217.389, actor_loss = -29.493, entropy_coef_loss = -17.600, critic_loss = 1.513, entropy_coef = 0.057, rollout_stds = 0.799 ± 0.021, action_magnitude = 0.602 ± 0.298, n_updates = 10001, time = 13.8, total_time = 140.2
#
# saved experiment log 2024-10-05_14-48-29_860485~gaW9kQ at experiment_logs/HalfCheetah-v4/sac/2024-10-05_14-48-29_860485~gaW9kQ.json
#
# step =   21000, num_env_steps =   21000, scores = -231.970 (n= 1), score_ema = -221.034, actor_loss = -29.023, entropy_coef_loss = -13.173, critic_loss = 1.500, entropy_coef = 0.044, rollout_stds = 0.612 ± 0.058, action_magnitude = 0.617 ± 0.296, n_updates = 11001, time = 13.8, total_time = 154.0
#
# step =   22000, num_env_steps =   22000, scores = -339.328 (n= 1), score_ema = -250.608, actor_loss = -26.845, entropy_coef_loss = -14.384, critic_loss = 1.508, entropy_coef = 0.034, rollout_stds = 0.595 ± 0.070, action_magnitude = 0.615 ± 0.297, n_updates = 12001, time = 13.4, total_time = 167.4
#
# step =   23000, num_env_steps =   23000, scores = -285.496 (n= 1), score_ema = -259.330, actor_loss = -25.535, entropy_coef_loss = -12.498, critic_loss = 1.296, entropy_coef = 0.026, rollout_stds = 0.645 ± 0.074, action_magnitude = 0.627 ± 0.299, n_updates = 13001, time = 13.6, total_time = 181.0
#
# step =   24000, num_env_steps =   24000, scores = -497.676 (n= 1), score_ema = -318.916, actor_loss = -22.909, entropy_coef_loss = -13.541, critic_loss = 1.741, entropy_coef = 0.020, rollout_stds = 0.481 ± 0.059, action_magnitude = 0.593 ± 0.298, n_updates = 14001, time = 14.3, total_time = 195.4
#
# step =   25000, num_env_steps =   25000, scores = -95.341 (n= 1), score_ema = -263.022, actor_loss = -21.783, entropy_coef_loss = -10.645, critic_loss = 1.534, entropy_coef = 0.016, rollout_stds = 0.450 ± 0.102, action_magnitude = 0.589 ± 0.297, n_updates = 15001, time = 14.0, total_time = 209.3
#
# step =   26000, num_env_steps =   26000, scores = -17.446 (n= 1), score_ema = -201.628, actor_loss = -19.908, entropy_coef_loss = -8.594, critic_loss = 1.210, entropy_coef = 0.012, rollout_stds = 0.421 ± 0.069, action_magnitude = 0.615 ± 0.298, n_updates = 16001, time = 13.7, total_time = 223.0
#
# step =   27000, num_env_steps =   27000, scores = -31.517 (n= 1), score_ema = -159.100, actor_loss = -19.083, entropy_coef_loss = -6.952, critic_loss = 1.487, entropy_coef = 0.010, rollout_stds = 0.334 ± 0.069, action_magnitude = 0.603 ± 0.297, n_updates = 17001, time = 13.6, total_time = 236.7
#
# step =   28000, num_env_steps =   28000, scores = -76.725 (n= 1), score_ema = -138.507, actor_loss = -16.999, entropy_coef_loss = -5.324, critic_loss = 1.350, entropy_coef = 0.008, rollout_stds = 0.312 ± 0.094, action_magnitude = 0.566 ± 0.296, n_updates = 18001, time = 13.5, total_time = 250.2
#
# step =   29000, num_env_steps =   29000, scores = -74.973 (n= 1), score_ema = -122.623, actor_loss = -16.041, entropy_coef_loss = -3.018, critic_loss = 1.189, entropy_coef = 0.007, rollout_stds = 0.192 ± 0.041, action_magnitude = 0.513 ± 0.286, n_updates = 19001, time = 13.5, total_time = 263.7
#
# step =   30000, num_env_steps =   30000, scores =  13.810 (n= 1), score_ema = -88.515, actor_loss = -14.774, entropy_coef_loss = -3.187, critic_loss = 0.906, entropy_coef = 0.006, rollout_stds = 0.203 ± 0.041, action_magnitude = 0.487 ± 0.282, n_updates = 20001, time = 13.5, total_time = 277.2
#
# saved experiment log 2024-10-05_14-48-29_860485~gaW9kQ at experiment_logs/HalfCheetah-v4/sac/2024-10-05_14-48-29_860485~gaW9kQ.json
#
# step =   31000, num_env_steps =   31000, scores =  350.171 (n= 1), score_ema =  21.157, actor_loss = -15.094, entropy_coef_loss = -3.454, critic_loss = 0.976, entropy_coef = 0.006, rollout_stds = 0.185 ± 0.061, action_magnitude = 0.533 ± 0.292, n_updates = 21001, time = 14.8, total_time = 292.0
#
# step =   32000, num_env_steps =   32000, scores =  30.238 (n= 1), score_ema =  23.427, actor_loss = -14.951, entropy_coef_loss = 0.056, critic_loss = 1.153, entropy_coef = 0.005, rollout_stds = 0.390 ± 0.069, action_magnitude = 0.597 ± 0.305, n_updates = 22001, time = 17.2, total_time = 309.2
#
# step =   33000, num_env_steps =   33000, scores =  238.492 (n= 1), score_ema =  77.193, actor_loss = -14.404, entropy_coef_loss = 0.807, critic_loss = 0.884, entropy_coef = 0.005, rollout_stds = 0.187 ± 0.025, action_magnitude = 0.481 ± 0.286, n_updates = 23001, time = 17.1, total_time = 326.4
#
# step =   34000, num_env_steps =   34000, scores =  275.695 (n= 1), score_ema =  126.819, actor_loss = -13.834, entropy_coef_loss = -2.743, critic_loss = 0.977, entropy_coef = 0.005, rollout_stds = 0.220 ± 0.051, action_magnitude = 0.476 ± 0.282, n_updates = 24001, time = 15.0, total_time = 341.4
#
# step =   35000, num_env_steps =   35000, scores =  744.030 (n= 1), score_ema =  281.121, actor_loss = -13.738, entropy_coef_loss = -1.133, critic_loss = 0.978, entropy_coef = 0.006, rollout_stds = 0.202 ± 0.040, action_magnitude = 0.544 ± 0.296, n_updates = 25001, time = 13.7, total_time = 355.1
#
# step =   36000, num_env_steps =   36000, scores =  1040.408 (n= 1), score_ema =  470.943, actor_loss = -14.510, entropy_coef_loss = 1.492, critic_loss = 1.025, entropy_coef = 0.006, rollout_stds = 0.180 ± 0.035, action_magnitude = 0.587 ± 0.302, n_updates = 26001, time = 13.6, total_time = 368.7
#
# step =   37000, num_env_steps =   37000, scores =  741.480 (n= 1), score_ema =  538.577, actor_loss = -17.058, entropy_coef_loss = -0.062, critic_loss = 1.445, entropy_coef = 0.007, rollout_stds = 0.232 ± 0.047, action_magnitude = 0.596 ± 0.304, n_updates = 27001, time = 13.7, total_time = 382.4
#
# step =   38000, num_env_steps =   38000, scores =  1012.726 (n= 1), score_ema =  657.115, actor_loss = -14.151, entropy_coef_loss = 1.847, critic_loss = 1.543, entropy_coef = 0.008, rollout_stds = 0.267 ± 0.053, action_magnitude = 0.651 ± 0.304, n_updates = 28001, time = 13.6, total_time = 396.0
#
# step =   39000, num_env_steps =   39000, scores =  1054.485 (n= 1), score_ema =  756.457, actor_loss = -15.751, entropy_coef_loss = -2.588, critic_loss = 1.286, entropy_coef = 0.008, rollout_stds = 0.218 ± 0.075, action_magnitude = 0.688 ± 0.299, n_updates = 29001, time = 13.5, total_time = 409.5
#
# step =   40000, num_env_steps =   40000, scores =  1693.085 (n= 1), score_ema =  990.614, actor_loss = -18.475, entropy_coef_loss = -0.132, critic_loss = 2.051, entropy_coef = 0.009, rollout_stds = 0.272 ± 0.068, action_magnitude = 0.719 ± 0.298, n_updates = 30001, time = 13.5, total_time = 423.0
#
# saved experiment log 2024-10-05_14-48-29_860485~gaW9kQ at experiment_logs/HalfCheetah-v4/sac/2024-10-05_14-48-29_860485~gaW9kQ.json
#
# step =   41000, num_env_steps =   41000, scores =  1500.199 (n= 1), score_ema =  1118.011, actor_loss = -19.669, entropy_coef_loss = 1.115, critic_loss = 2.234, entropy_coef = 0.011, rollout_stds = 0.268 ± 0.030, action_magnitude = 0.723 ± 0.293, n_updates = 31001, time = 13.9, total_time = 436.9
#
# step =   42000, num_env_steps =   42000, scores =  1686.153 (n= 1), score_ema =  1260.046, actor_loss = -22.216, entropy_coef_loss = 0.552, critic_loss = 2.045, entropy_coef = 0.012, rollout_stds = 0.226 ± 0.086, action_magnitude = 0.737 ± 0.292, n_updates = 32001, time = 13.7, total_time = 450.5
#
# step =   43000, num_env_steps =   43000, scores =  1656.958 (n= 1), score_ema =  1359.274, actor_loss = -25.577, entropy_coef_loss = 1.200, critic_loss = 2.127, entropy_coef = 0.014, rollout_stds = 0.331 ± 0.164, action_magnitude = 0.729 ± 0.293, n_updates = 33001, time = 13.8, total_time = 464.3
#
# step =   44000, num_env_steps =   44000, scores =  2184.707 (n= 1), score_ema =  1565.632, actor_loss = -29.420, entropy_coef_loss = 0.944, critic_loss = 2.294, entropy_coef = 0.015, rollout_stds = 0.259 ± 0.140, action_magnitude = 0.736 ± 0.291, n_updates = 34001, time = 13.7, total_time = 478.0
#
# step =   45000, num_env_steps =   45000, scores =  1967.795 (n= 1), score_ema =  1666.173, actor_loss = -27.834, entropy_coef_loss = 0.270, critic_loss = 3.402, entropy_coef = 0.018, rollout_stds = 0.285 ± 0.059, action_magnitude = 0.732 ± 0.290, n_updates = 35001, time = 13.9, total_time = 491.9
#
# step =   46000, num_env_steps =   46000, scores =  1805.667 (n= 1), score_ema =  1701.047, actor_loss = -27.368, entropy_coef_loss = -2.357, critic_loss = 3.668, entropy_coef = 0.020, rollout_stds = 0.486 ± 0.134, action_magnitude = 0.722 ± 0.290, n_updates = 36001, time = 14.4, total_time = 506.3
#
# step =   47000, num_env_steps =   47000, scores =  2231.235 (n= 1), score_ema =  1833.594, actor_loss = -34.739, entropy_coef_loss = 0.057, critic_loss = 4.761, entropy_coef = 0.023, rollout_stds = 0.353 ± 0.093, action_magnitude = 0.732 ± 0.292, n_updates = 37001, time = 14.3, total_time = 520.6
#
# step =   48000, num_env_steps =   48000, scores =  2298.205 (n= 1), score_ema =  1949.746, actor_loss = -38.749, entropy_coef_loss = -0.513, critic_loss = 4.152, entropy_coef = 0.025, rollout_stds = 0.273 ± 0.100, action_magnitude = 0.726 ± 0.295, n_updates = 38001, time = 13.5, total_time = 534.1
#
# step =   49000, num_env_steps =   49000, scores =  2436.678 (n= 1), score_ema =  2071.479, actor_loss = -40.976, entropy_coef_loss = 0.970, critic_loss = 5.709, entropy_coef = 0.028, rollout_stds = 0.416 ± 0.160, action_magnitude = 0.733 ± 0.290, n_updates = 39001, time = 13.8, total_time = 548.0
#
# step =   50000, num_env_steps =   50000, scores =  2569.821 (n= 1), score_ema =  2196.065, actor_loss = -44.607, entropy_coef_loss = 0.788, critic_loss = 4.600, entropy_coef = 0.030, rollout_stds = 0.323 ± 0.089, action_magnitude = 0.734 ± 0.290, n_updates = 40001, time = 13.7, total_time = 561.7
#
# saved experiment log 2024-10-05_14-48-29_860485~gaW9kQ at experiment_logs/HalfCheetah-v4/sac/2024-10-05_14-48-29_860485~gaW9kQ.json
#
# step =   51000, num_env_steps =   51000, scores =  2554.991 (n= 1), score_ema =  2285.796, actor_loss = -44.362, entropy_coef_loss = -0.049, critic_loss = 4.455, entropy_coef = 0.032, rollout_stds = 0.425 ± 0.145, action_magnitude = 0.727 ± 0.293, n_updates = 41001, time = 13.9, total_time = 575.6
#
# step =   52000, num_env_steps =   52000, scores =  2757.027 (n= 1), score_ema =  2403.604, actor_loss = -51.625, entropy_coef_loss = -0.690, critic_loss = 4.401, entropy_coef = 0.034, rollout_stds = 0.415 ± 0.139, action_magnitude = 0.725 ± 0.295, n_updates = 42001, time = 13.9, total_time = 589.5
#
# step =   53000, num_env_steps =   53000, scores =  3067.404 (n= 1), score_ema =  2569.554, actor_loss = -53.867, entropy_coef_loss = -0.751, critic_loss = 5.663, entropy_coef = 0.037, rollout_stds = 0.314 ± 0.072, action_magnitude = 0.743 ± 0.285, n_updates = 43001, time = 13.8, total_time = 603.3
#
# step =   54000, num_env_steps =   54000, scores =  2725.767 (n= 1), score_ema =  2608.607, actor_loss = -56.660, entropy_coef_loss = 0.265, critic_loss = 6.480, entropy_coef = 0.039, rollout_stds = 0.374 ± 0.130, action_magnitude = 0.739 ± 0.284, n_updates = 44001, time = 14.3, total_time = 617.6
#
# step =   55000, num_env_steps =   55000, scores =  52.537 (n= 1), score_ema =  1969.590, actor_loss = -59.988, entropy_coef_loss = -0.169, critic_loss = 5.954, entropy_coef = 0.039, rollout_stds = 0.629 ± 0.154, action_magnitude = 0.676 ± 0.299, n_updates = 45001, time = 14.0, total_time = 631.5
#
# step =   56000, num_env_steps =   56000, scores =  3116.088 (n= 1), score_ema =  2256.214, actor_loss = -62.366, entropy_coef_loss = -2.241, critic_loss = 8.140, entropy_coef = 0.038, rollout_stds = 0.347 ± 0.119, action_magnitude = 0.753 ± 0.285, n_updates = 46001, time = 14.3, total_time = 645.9
#
# step =   57000, num_env_steps =   57000, scores =  2751.170 (n= 1), score_ema =  2379.953, actor_loss = -65.843, entropy_coef_loss = -1.837, critic_loss = 7.705, entropy_coef = 0.039, rollout_stds = 0.460 ± 0.145, action_magnitude = 0.751 ± 0.282, n_updates = 47001, time = 13.3, total_time = 659.2
#
# step =   58000, num_env_steps =   58000, scores =  2924.905 (n= 1), score_ema =  2516.191, actor_loss = -73.226, entropy_coef_loss = 0.634, critic_loss = 70.007, entropy_coef = 0.041, rollout_stds = 0.343 ± 0.144, action_magnitude = 0.746 ± 0.287, n_updates = 48001, time = 13.3, total_time = 672.5
#
# step =   59000, num_env_steps =   59000, scores =  2924.901 (n= 1), score_ema =  2618.369, actor_loss = -68.397, entropy_coef_loss = -1.980, critic_loss = 6.741, entropy_coef = 0.042, rollout_stds = 0.422 ± 0.150, action_magnitude = 0.757 ± 0.281, n_updates = 49001, time = 13.3, total_time = 685.8
#
# step =   60000, num_env_steps =   60000, scores =  3328.285 (n= 1), score_ema =  2795.848, actor_loss = -79.693, entropy_coef_loss = 1.229, critic_loss = 6.091, entropy_coef = 0.045, rollout_stds = 0.526 ± 0.238, action_magnitude = 0.765 ± 0.277, n_updates = 50001, time = 13.3, total_time = 699.0
#
# saved experiment log 2024-10-05_14-48-29_860485~gaW9kQ at experiment_logs/HalfCheetah-v4/sac/2024-10-05_14-48-29_860485~gaW9kQ.json
#
# step =   61000, num_env_steps =   61000, scores =  2879.438 (n= 1), score_ema =  2816.745, actor_loss = -73.636, entropy_coef_loss = -0.616, critic_loss = 6.577, entropy_coef = 0.046, rollout_stds = 0.378 ± 0.118, action_magnitude = 0.768 ± 0.274, n_updates = 51001, time = 13.5, total_time = 712.5
#
# step =   62000, num_env_steps =   62000, scores =  3102.790 (n= 1), score_ema =  2888.256, actor_loss = -77.817, entropy_coef_loss = -0.210, critic_loss = 16.951, entropy_coef = 0.047, rollout_stds = 0.340 ± 0.181, action_magnitude = 0.769 ± 0.276, n_updates = 52001, time = 13.6, total_time = 726.0
#
# step =   63000, num_env_steps =   63000, scores =  3227.984 (n= 1), score_ema =  2973.188, actor_loss = -86.949, entropy_coef_loss = -0.051, critic_loss = 26.195, entropy_coef = 0.049, rollout_stds = 0.383 ± 0.128, action_magnitude = 0.766 ± 0.278, n_updates = 53001, time = 13.3, total_time = 739.4
#
# step =   64000, num_env_steps =   64000, scores =  3405.580 (n= 1), score_ema =  3081.286, actor_loss = -86.775, entropy_coef_loss = -0.151, critic_loss = 9.215, entropy_coef = 0.050, rollout_stds = 0.392 ± 0.136, action_magnitude = 0.771 ± 0.277, n_updates = 54001, time = 13.4, total_time = 752.7
#
# step =   65000, num_env_steps =   65000, scores =  3134.469 (n= 1), score_ema =  3094.582, actor_loss = -94.255, entropy_coef_loss = 0.237, critic_loss = 10.044, entropy_coef = 0.050, rollout_stds = 0.375 ± 0.180, action_magnitude = 0.769 ± 0.276, n_updates = 55001, time = 13.6, total_time = 766.3
#
# step =   66000, num_env_steps =   66000, scores =  3313.534 (n= 1), score_ema =  3149.320, actor_loss = -99.385, entropy_coef_loss = -0.288, critic_loss = 7.595, entropy_coef = 0.053, rollout_stds = 0.366 ± 0.098, action_magnitude = 0.779 ± 0.268, n_updates = 56001, time = 13.8, total_time = 780.1
#
# step =   67000, num_env_steps =   67000, scores =  3332.206 (n= 1), score_ema =  3195.042, actor_loss = -101.494, entropy_coef_loss = 0.410, critic_loss = 9.130, entropy_coef = 0.052, rollout_stds = 0.350 ± 0.123, action_magnitude = 0.764 ± 0.280, n_updates = 57001, time = 13.7, total_time = 793.8
#
# step =   68000, num_env_steps =   68000, scores =  3434.114 (n= 1), score_ema =  3254.810, actor_loss = -99.761, entropy_coef_loss = 0.435, critic_loss = 9.610, entropy_coef = 0.053, rollout_stds = 0.400 ± 0.128, action_magnitude = 0.765 ± 0.280, n_updates = 58001, time = 13.5, total_time = 807.3
#
# step =   69000, num_env_steps =   69000, scores =  3525.958 (n= 1), score_ema =  3322.597, actor_loss = -106.798, entropy_coef_loss = -1.370, critic_loss = 7.299, entropy_coef = 0.055, rollout_stds = 0.393 ± 0.122, action_magnitude = 0.768 ± 0.278, n_updates = 59001, time = 13.5, total_time = 820.8
#
# step =   70000, num_env_steps =   70000, scores =  3314.662 (n= 1), score_ema =  3320.613, actor_loss = -112.202, entropy_coef_loss = 1.085, critic_loss = 8.505, entropy_coef = 0.056, rollout_stds = 0.366 ± 0.129, action_magnitude = 0.763 ± 0.277, n_updates = 60001, time = 13.4, total_time = 834.1
#
# saved experiment log 2024-10-05_14-48-29_860485~gaW9kQ at experiment_logs/HalfCheetah-v4/sac/2024-10-05_14-48-29_860485~gaW9kQ.json
#
# step =   71000, num_env_steps =   71000, scores =  1758.681 (n= 1), score_ema =  2930.130, actor_loss = -112.347, entropy_coef_loss = -0.829, critic_loss = 7.059, entropy_coef = 0.058, rollout_stds = 0.631 ± 0.082, action_magnitude = 0.718 ± 0.290, n_updates = 61001, time = 13.4, total_time = 847.5
#
# step =   72000, num_env_steps =   72000, scores =  3278.102 (n= 1), score_ema =  3017.123, actor_loss = -115.404, entropy_coef_loss = 1.384, critic_loss = 8.815, entropy_coef = 0.057, rollout_stds = 0.471 ± 0.142, action_magnitude = 0.769 ± 0.277, n_updates = 62001, time = 13.5, total_time = 861.0
#
# step =   73000, num_env_steps =   73000, scores =  3623.790 (n= 1), score_ema =  3168.790, actor_loss = -115.425, entropy_coef_loss = 0.915, critic_loss = 117.121, entropy_coef = 0.059, rollout_stds = 0.331 ± 0.136, action_magnitude = 0.774 ± 0.268, n_updates = 63001, time = 13.6, total_time = 874.6
#
# step =   74000, num_env_steps =   74000, scores =  3534.121 (n= 1), score_ema =  3260.123, actor_loss = -117.527, entropy_coef_loss = 0.241, critic_loss = 9.684, entropy_coef = 0.060, rollout_stds = 0.404 ± 0.113, action_magnitude = 0.774 ± 0.272, n_updates = 64001, time = 13.5, total_time = 888.0
#
# step =   75000, num_env_steps =   75000, scores =  3352.582 (n= 1), score_ema =  3283.238, actor_loss = -122.439, entropy_coef_loss = 0.533, critic_loss = 10.220, entropy_coef = 0.061, rollout_stds = 0.402 ± 0.108, action_magnitude = 0.776 ± 0.271, n_updates = 65001, time = 13.5, total_time = 901.5
#
# step =   76000, num_env_steps =   76000, scores =  135.491 (n= 1), score_ema =  2496.301, actor_loss = -117.138, entropy_coef_loss = -0.227, critic_loss = 8.373, entropy_coef = 0.061, rollout_stds = 0.610 ± 0.108, action_magnitude = 0.648 ± 0.300, n_updates = 66001, time = 14.1, total_time = 915.6
#
# step =   77000, num_env_steps =   77000, scores =  3055.935 (n= 1), score_ema =  2636.209, actor_loss = -118.956, entropy_coef_loss = -0.741, critic_loss = 10.303, entropy_coef = 0.062, rollout_stds = 0.604 ± 0.066, action_magnitude = 0.765 ± 0.279, n_updates = 67001, time = 14.2, total_time = 929.8
#
# step =   78000, num_env_steps =   78000, scores =  3851.146 (n= 1), score_ema =  2939.943, actor_loss = -128.218, entropy_coef_loss = 0.492, critic_loss = 59.335, entropy_coef = 0.062, rollout_stds = 0.360 ± 0.128, action_magnitude = 0.787 ± 0.264, n_updates = 68001, time = 13.9, total_time = 943.7
#
# step =   79000, num_env_steps =   79000, scores =  3290.718 (n= 1), score_ema =  3027.637, actor_loss = -132.175, entropy_coef_loss = 1.828, critic_loss = 9.960, entropy_coef = 0.062, rollout_stds = 0.356 ± 0.087, action_magnitude = 0.774 ± 0.270, n_updates = 69001, time = 13.8, total_time = 957.4
#
# step =   80000, num_env_steps =   80000, scores =  3475.245 (n= 1), score_ema =  3139.539, actor_loss = -123.013, entropy_coef_loss = -1.202, critic_loss = 11.573, entropy_coef = 0.063, rollout_stds = 0.458 ± 0.093, action_magnitude = 0.778 ± 0.272, n_updates = 70001, time = 13.7, total_time = 971.1
#
# saved experiment log 2024-10-05_14-48-29_860485~gaW9kQ at experiment_logs/HalfCheetah-v4/sac/2024-10-05_14-48-29_860485~gaW9kQ.json
#
# step =   81000, num_env_steps =   81000, scores =  3462.165 (n= 1), score_ema =  3220.196, actor_loss = -129.084, entropy_coef_loss = 1.056, critic_loss = 157.266, entropy_coef = 0.063, rollout_stds = 0.429 ± 0.095, action_magnitude = 0.771 ± 0.274, n_updates = 71001, time = 13.7, total_time = 984.7
#
# step =   82000, num_env_steps =   82000, scores =  3760.136 (n= 1), score_ema =  3355.181, actor_loss = -128.758, entropy_coef_loss = -0.397, critic_loss = 89.956, entropy_coef = 0.065, rollout_stds = 0.685 ± 0.060, action_magnitude = 0.783 ± 0.266, n_updates = 72001, time = 13.6, total_time = 998.4
#
# step =   83000, num_env_steps =   83000, scores =  3578.619 (n= 1), score_ema =  3411.040, actor_loss = -134.353, entropy_coef_loss = -0.673, critic_loss = 16.896, entropy_coef = 0.066, rollout_stds = 0.346 ± 0.102, action_magnitude = 0.780 ± 0.271, n_updates = 73001, time = 13.7, total_time = 1012.0
#
# step =   84000, num_env_steps =   84000, scores =  3840.856 (n= 1), score_ema =  3518.494, actor_loss = -143.203, entropy_coef_loss = 1.035, critic_loss = 14.209, entropy_coef = 0.066, rollout_stds = 0.401 ± 0.108, action_magnitude = 0.783 ± 0.268, n_updates = 74001, time = 13.7, total_time = 1025.7
#
# step =   85000, num_env_steps =   85000, scores =  3322.984 (n= 1), score_ema =  3469.617, actor_loss = -136.957, entropy_coef_loss = -0.279, critic_loss = 12.481, entropy_coef = 0.067, rollout_stds = 0.366 ± 0.089, action_magnitude = 0.770 ± 0.270, n_updates = 75001, time = 13.8, total_time = 1039.5
#
# step =   86000, num_env_steps =   86000, scores =  3363.106 (n= 1), score_ema =  3442.989, actor_loss = -139.800, entropy_coef_loss = -1.305, critic_loss = 13.988, entropy_coef = 0.066, rollout_stds = 0.342 ± 0.146, action_magnitude = 0.760 ± 0.278, n_updates = 76001, time = 13.7, total_time = 1053.2
#
# step =   87000, num_env_steps =   87000, scores =  3898.778 (n= 1), score_ema =  3556.936, actor_loss = -141.382, entropy_coef_loss = 0.125, critic_loss = 9.806, entropy_coef = 0.068, rollout_stds = 0.378 ± 0.101, action_magnitude = 0.774 ± 0.271, n_updates = 77001, time = 13.8, total_time = 1066.9
#
# step =   88000, num_env_steps =   88000, scores =  3777.008 (n= 1), score_ema =  3611.954, actor_loss = -148.925, entropy_coef_loss = 0.861, critic_loss = 17.047, entropy_coef = 0.069, rollout_stds = 0.429 ± 0.162, action_magnitude = 0.770 ± 0.271, n_updates = 78001, time = 13.8, total_time = 1080.7
#
# step =   89000, num_env_steps =   89000, scores =  2367.333 (n= 1), score_ema =  3300.799, actor_loss = -147.200, entropy_coef_loss = 0.846, critic_loss = 153.396, entropy_coef = 0.070, rollout_stds = 0.729 ± 0.112, action_magnitude = 0.710 ± 0.295, n_updates = 79001, time = 13.9, total_time = 1094.7
#
# step =   90000, num_env_steps =   90000, scores =  3846.264 (n= 1), score_ema =  3437.165, actor_loss = -151.910, entropy_coef_loss = 0.416, critic_loss = 14.498, entropy_coef = 0.071, rollout_stds = 0.342 ± 0.147, action_magnitude = 0.770 ± 0.272, n_updates = 80001, time = 14.2, total_time = 1108.9
#
# saved experiment log 2024-10-05_14-48-29_860485~gaW9kQ at experiment_logs/HalfCheetah-v4/sac/2024-10-05_14-48-29_860485~gaW9kQ.json
#
# step =   91000, num_env_steps =   91000, scores =  3687.814 (n= 1), score_ema =  3499.827, actor_loss = -145.860, entropy_coef_loss = 0.549, critic_loss = 11.058, entropy_coef = 0.072, rollout_stds = 0.443 ± 0.142, action_magnitude = 0.764 ± 0.274, n_updates = 81001, time = 14.2, total_time = 1123.1
#
# step =   92000, num_env_steps =   92000, scores =  3940.075 (n= 1), score_ema =  3609.889, actor_loss = -156.656, entropy_coef_loss = 0.856, critic_loss = 54.739, entropy_coef = 0.073, rollout_stds = 0.347 ± 0.087, action_magnitude = 0.778 ± 0.265, n_updates = 82001, time = 14.1, total_time = 1137.2
#
# step =   93000, num_env_steps =   93000, scores =  3786.217 (n= 1), score_ema =  3653.971, actor_loss = -148.532, entropy_coef_loss = -0.366, critic_loss = 82.965, entropy_coef = 0.072, rollout_stds = 0.495 ± 0.175, action_magnitude = 0.772 ± 0.270, n_updates = 83001, time = 13.8, total_time = 1151.0
#
# step =   94000, num_env_steps =   94000, scores =  3735.408 (n= 1), score_ema =  3674.330, actor_loss = -157.215, entropy_coef_loss = -0.777, critic_loss = 73.162, entropy_coef = 0.073, rollout_stds = 0.439 ± 0.084, action_magnitude = 0.764 ± 0.275, n_updates = 84001, time = 13.9, total_time = 1164.9
#
# step =   95000, num_env_steps =   95000, scores =  3972.399 (n= 1), score_ema =  3748.848, actor_loss = -165.051, entropy_coef_loss = 1.550, critic_loss = 10.087, entropy_coef = 0.074, rollout_stds = 0.392 ± 0.126, action_magnitude = 0.776 ± 0.268, n_updates = 85001, time = 13.8, total_time = 1178.7
#
# step =   96000, num_env_steps =   96000, scores =  4038.487 (n= 1), score_ema =  3821.257, actor_loss = -169.842, entropy_coef_loss = 1.463, critic_loss = 12.235, entropy_coef = 0.076, rollout_stds = 0.366 ± 0.105, action_magnitude = 0.773 ± 0.271, n_updates = 86001, time = 13.9, total_time = 1192.6
#
# step =   97000, num_env_steps =   97000, scores =  4166.223 (n= 1), score_ema =  3907.499, actor_loss = -156.712, entropy_coef_loss = -0.191, critic_loss = 12.402, entropy_coef = 0.077, rollout_stds = 0.498 ± 0.132, action_magnitude = 0.776 ± 0.270, n_updates = 87001, time = 13.9, total_time = 1206.5
#
# step =   98000, num_env_steps =   98000, scores =  3830.734 (n= 1), score_ema =  3888.308, actor_loss = -159.992, entropy_coef_loss = -1.916, critic_loss = 15.320, entropy_coef = 0.079, rollout_stds = 0.395 ± 0.127, action_magnitude = 0.771 ± 0.273, n_updates = 88001, time = 13.8, total_time = 1220.3
#
# step =   99000, num_env_steps =   99000, scores =  3908.319 (n= 1), score_ema =  3893.310, actor_loss = -164.115, entropy_coef_loss = -0.312, critic_loss = 15.063, entropy_coef = 0.082, rollout_stds = 0.348 ± 0.130, action_magnitude = 0.771 ± 0.270, n_updates = 89001, time = 13.8, total_time = 1234.1
#
# step =  100000, num_env_steps =  100000, scores =  3956.326 (n= 1), score_ema =  3909.064, actor_loss = -164.125, entropy_coef_loss = 0.004, critic_loss = 11.317, entropy_coef = 0.081, rollout_stds = 0.427 ± 0.097, action_magnitude = 0.773 ± 0.268, n_updates = 90001, time = 13.8, total_time = 1248.0
#
# saved experiment log 2024-10-05_14-48-29_860485~gaW9kQ at experiment_logs/HalfCheetah-v4/sac/2024-10-05_14-48-29_860485~gaW9kQ.json
#
# step =  101000, num_env_steps =  101000, scores =  3720.468 (n= 1), score_ema =  3861.915, actor_loss = -160.529, entropy_coef_loss = -0.791, critic_loss = 13.425, entropy_coef = 0.079, rollout_stds = 0.426 ± 0.117, action_magnitude = 0.760 ± 0.278, n_updates = 91001, time = 13.8, total_time = 1261.7
#
# step =  102000, num_env_steps =  102000, scores =  4090.504 (n= 1), score_ema =  3919.062, actor_loss = -170.611, entropy_coef_loss = -0.001, critic_loss = 15.364, entropy_coef = 0.081, rollout_stds = 0.519 ± 0.113, action_magnitude = 0.768 ± 0.275, n_updates = 92001, time = 13.6, total_time = 1275.4
#
# step =  103000, num_env_steps =  103000, scores =  4065.280 (n= 1), score_ema =  3955.617, actor_loss = -173.957, entropy_coef_loss = 0.395, critic_loss = 13.296, entropy_coef = 0.083, rollout_stds = 0.356 ± 0.067, action_magnitude = 0.763 ± 0.276, n_updates = 93001, time = 13.7, total_time = 1289.1
#
# step =  104000, num_env_steps =  104000, scores =  4251.528 (n= 1), score_ema =  4029.595, actor_loss = -170.012, entropy_coef_loss = -0.032, critic_loss = 14.338, entropy_coef = 0.085, rollout_stds = 0.424 ± 0.118, action_magnitude = 0.767 ± 0.270, n_updates = 94001, time = 13.6, total_time = 1302.7
#
# step =  105000, num_env_steps =  105000, scores =  3846.849 (n= 1), score_ema =  3983.908, actor_loss = -174.617, entropy_coef_loss = 1.844, critic_loss = 11.113, entropy_coef = 0.086, rollout_stds = 0.355 ± 0.134, action_magnitude = 0.758 ± 0.277, n_updates = 95001, time = 13.6, total_time = 1316.3
#
# step =  106000, num_env_steps =  106000, scores =  3667.112 (n= 1), score_ema =  3904.709, actor_loss = -174.794, entropy_coef_loss = 0.721, critic_loss = 11.940, entropy_coef = 0.088, rollout_stds = 0.424 ± 0.121, action_magnitude = 0.754 ± 0.278, n_updates = 96001, time = 13.6, total_time = 1329.9
#
# step =  107000, num_env_steps =  107000, scores =  3915.048 (n= 1), score_ema =  3907.294, actor_loss = -176.759, entropy_coef_loss = -1.453, critic_loss = 243.482, entropy_coef = 0.087, rollout_stds = 0.384 ± 0.138, action_magnitude = 0.760 ± 0.274, n_updates = 97001, time = 13.6, total_time = 1343.5
#
# step =  108000, num_env_steps =  108000, scores =  3954.738 (n= 1), score_ema =  3919.155, actor_loss = -173.940, entropy_coef_loss = 0.415, critic_loss = 14.041, entropy_coef = 0.086, rollout_stds = 0.475 ± 0.075, action_magnitude = 0.759 ± 0.274, n_updates = 98001, time = 13.9, total_time = 1357.3
#
# step =  109000, num_env_steps =  109000, scores =  4056.166 (n= 1), score_ema =  3953.408, actor_loss = -175.218, entropy_coef_loss = 0.503, critic_loss = 11.384, entropy_coef = 0.086, rollout_stds = 0.398 ± 0.102, action_magnitude = 0.760 ± 0.273, n_updates = 99001, time = 13.8, total_time = 1371.2
#
# step =  110000, num_env_steps =  110000, scores =  4187.657 (n= 1), score_ema =  4011.970, actor_loss = -187.916, entropy_coef_loss = 0.747, critic_loss = 10.602, entropy_coef = 0.087, rollout_stds = 0.412 ± 0.120, action_magnitude = 0.764 ± 0.272, n_updates = 100001, time = 13.8, total_time = 1385.0
#
# saved experiment log 2024-10-05_14-48-29_860485~gaW9kQ at experiment_logs/HalfCheetah-v4/sac/2024-10-05_14-48-29_860485~gaW9kQ.json
#
# step =  111000, num_env_steps =  111000, scores =  4269.739 (n= 1), score_ema =  4076.412, actor_loss = -180.112, entropy_coef_loss = -0.778, critic_loss = 14.906, entropy_coef = 0.086, rollout_stds = 0.350 ± 0.093, action_magnitude = 0.754 ± 0.276, n_updates = 101001, time = 14.6, total_time = 1399.5
#
# step =  112000, num_env_steps =  112000, scores =  4120.254 (n= 1), score_ema =  4087.373, actor_loss = -189.228, entropy_coef_loss = 1.053, critic_loss = 16.594, entropy_coef = 0.091, rollout_stds = 0.403 ± 0.096, action_magnitude = 0.764 ± 0.272, n_updates = 102001, time = 14.5, total_time = 1414.0
#
# step =  113000, num_env_steps =  113000, scores =  4116.938 (n= 1), score_ema =  4094.764, actor_loss = -184.569, entropy_coef_loss = -0.348, critic_loss = 19.008, entropy_coef = 0.090, rollout_stds = 0.366 ± 0.138, action_magnitude = 0.765 ± 0.273, n_updates = 103001, time = 14.3, total_time = 1428.3
#
# step =  114000, num_env_steps =  114000, scores =  4227.960 (n= 1), score_ema =  4128.063, actor_loss = -186.393, entropy_coef_loss = 1.491, critic_loss = 11.626, entropy_coef = 0.091, rollout_stds = 0.386 ± 0.127, action_magnitude = 0.768 ± 0.269, n_updates = 104001, time = 14.0, total_time = 1442.2
#
# step =  115000, num_env_steps =  115000, scores =  4026.087 (n= 1), score_ema =  4102.569, actor_loss = -193.355, entropy_coef_loss = 1.161, critic_loss = 15.665, entropy_coef = 0.093, rollout_stds = 0.469 ± 0.148, action_magnitude = 0.755 ± 0.280, n_updates = 105001, time = 13.8, total_time = 1456.1
#
# step =  116000, num_env_steps =  116000, scores =  4391.441 (n= 1), score_ema =  4174.787, actor_loss = -188.399, entropy_coef_loss = 0.548, critic_loss = 14.769, entropy_coef = 0.093, rollout_stds = 0.372 ± 0.119, action_magnitude = 0.760 ± 0.276, n_updates = 106001, time = 14.2, total_time = 1470.3
#
# step =  117000, num_env_steps =  117000, scores =  4361.505 (n= 1), score_ema =  4221.466, actor_loss = -191.458, entropy_coef_loss = -0.000, critic_loss = 11.973, entropy_coef = 0.093, rollout_stds = 0.447 ± 0.127, action_magnitude = 0.760 ± 0.274, n_updates = 107001, time = 13.9, total_time = 1484.2
#
# step =  118000, num_env_steps =  118000, scores =  4138.532 (n= 1), score_ema =  4200.733, actor_loss = -184.484, entropy_coef_loss = 0.154, critic_loss = 181.285, entropy_coef = 0.092, rollout_stds = 0.387 ± 0.114, action_magnitude = 0.755 ± 0.275, n_updates = 108001, time = 13.9, total_time = 1498.1
#
# step =  119000, num_env_steps =  119000, scores =  507.066 (n= 1), score_ema =  3277.316, actor_loss = -185.236, entropy_coef_loss = -0.254, critic_loss = 13.782, entropy_coef = 0.093, rollout_stds = 0.638 ± 0.109, action_magnitude = 0.626 ± 0.299, n_updates = 109001, time = 13.6, total_time = 1511.7
#
# step =  120000, num_env_steps =  120000, scores =  4276.828 (n= 1), score_ema =  3527.194, actor_loss = -177.898, entropy_coef_loss = -0.333, critic_loss = 11.842, entropy_coef = 0.094, rollout_stds = 0.377 ± 0.126, action_magnitude = 0.761 ± 0.271, n_updates = 110001, time = 13.9, total_time = 1525.7
#
# saved experiment log 2024-10-05_14-48-29_860485~gaW9kQ at experiment_logs/HalfCheetah-v4/sac/2024-10-05_14-48-29_860485~gaW9kQ.json
#
# step =  121000, num_env_steps =  121000, scores =  4426.415 (n= 1), score_ema =  3751.999, actor_loss = -200.300, entropy_coef_loss = 1.238, critic_loss = 15.294, entropy_coef = 0.093, rollout_stds = 0.389 ± 0.088, action_magnitude = 0.760 ± 0.275, n_updates = 111001, time = 13.9, total_time = 1539.6
#
# step =  122000, num_env_steps =  122000, scores =  4060.922 (n= 1), score_ema =  3829.230, actor_loss = -189.298, entropy_coef_loss = -0.982, critic_loss = 15.441, entropy_coef = 0.094, rollout_stds = 0.325 ± 0.083, action_magnitude = 0.757 ± 0.274, n_updates = 112001, time = 13.8, total_time = 1553.4
#
# step =  123000, num_env_steps =  123000, scores =  4094.474 (n= 1), score_ema =  3895.541, actor_loss = -197.190, entropy_coef_loss = 0.004, critic_loss = 13.830, entropy_coef = 0.097, rollout_stds = 0.395 ± 0.129, action_magnitude = 0.758 ± 0.274, n_updates = 113001, time = 13.7, total_time = 1567.1
#
# step =  124000, num_env_steps =  124000, scores =  4351.671 (n= 1), score_ema =  4009.574, actor_loss = -187.460, entropy_coef_loss = -0.712, critic_loss = 149.329, entropy_coef = 0.098, rollout_stds = 0.468 ± 0.139, action_magnitude = 0.754 ± 0.278, n_updates = 114001, time = 13.8, total_time = 1580.9
#
# step =  125000, num_env_steps =  125000, scores =  4324.366 (n= 1), score_ema =  4088.272, actor_loss = -207.705, entropy_coef_loss = -0.073, critic_loss = 12.626, entropy_coef = 0.097, rollout_stds = 0.383 ± 0.140, action_magnitude = 0.760 ± 0.274, n_updates = 115001, time = 13.9, total_time = 1594.8
#
# step =  126000, num_env_steps =  126000, scores =  4356.934 (n= 1), score_ema =  4155.437, actor_loss = -192.422, entropy_coef_loss = 0.270, critic_loss = 11.529, entropy_coef = 0.100, rollout_stds = 0.293 ± 0.156, action_magnitude = 0.766 ± 0.271, n_updates = 116001, time = 14.1, total_time = 1608.9
#
# step =  127000, num_env_steps =  127000, scores =  4422.815 (n= 1), score_ema =  4222.282, actor_loss = -200.966, entropy_coef_loss = -0.723, critic_loss = 11.813, entropy_coef = 0.099, rollout_stds = 0.390 ± 0.104, action_magnitude = 0.755 ± 0.279, n_updates = 117001, time = 13.8, total_time = 1622.6
#
# step =  128000, num_env_steps =  128000, scores =  3826.048 (n= 1), score_ema =  4123.223, actor_loss = -195.715, entropy_coef_loss = -1.239, critic_loss = 13.050, entropy_coef = 0.101, rollout_stds = 0.638 ± 0.100, action_magnitude = 0.731 ± 0.288, n_updates = 118001, time = 13.6, total_time = 1636.3
#
# step =  129000, num_env_steps =  129000, scores =  4508.015 (n= 1), score_ema =  4219.421, actor_loss = -199.717, entropy_coef_loss = 0.462, critic_loss = 14.358, entropy_coef = 0.098, rollout_stds = 0.353 ± 0.140, action_magnitude = 0.762 ± 0.273, n_updates = 119001, time = 14.1, total_time = 1650.4
#
# step =  130000, num_env_steps =  130000, scores =  4570.808 (n= 1), score_ema =  4307.268, actor_loss = -210.042, entropy_coef_loss = 1.231, critic_loss = 13.146, entropy_coef = 0.101, rollout_stds = 0.423 ± 0.135, action_magnitude = 0.752 ± 0.279, n_updates = 120001, time = 13.6, total_time = 1664.0
#
# saved experiment log 2024-10-05_14-48-29_860485~gaW9kQ at experiment_logs/HalfCheetah-v4/sac/2024-10-05_14-48-29_860485~gaW9kQ.json
#
# step =  131000, num_env_steps =  131000, scores =  4477.326 (n= 1), score_ema =  4349.783, actor_loss = -205.726, entropy_coef_loss = -0.544, critic_loss = 11.555, entropy_coef = 0.102, rollout_stds = 0.293 ± 0.149, action_magnitude = 0.758 ± 0.274, n_updates = 121001, time = 13.9, total_time = 1677.9
#
# step =  132000, num_env_steps =  132000, scores =  4356.731 (n= 1), score_ema =  4351.520, actor_loss = -208.318, entropy_coef_loss = 0.457, critic_loss = 17.250, entropy_coef = 0.104, rollout_stds = 0.370 ± 0.123, action_magnitude = 0.752 ± 0.280, n_updates = 122001, time = 13.6, total_time = 1691.5
#
# step =  133000, num_env_steps =  133000, scores =  4474.462 (n= 1), score_ema =  4382.255, actor_loss = -206.763, entropy_coef_loss = 0.516, critic_loss = 19.458, entropy_coef = 0.100, rollout_stds = 0.457 ± 0.122, action_magnitude = 0.744 ± 0.281, n_updates = 123001, time = 13.6, total_time = 1705.1
#
# step =  134000, num_env_steps =  134000, scores =  4521.472 (n= 1), score_ema =  4417.059, actor_loss = -203.328, entropy_coef_loss = -0.703, critic_loss = 19.004, entropy_coef = 0.103, rollout_stds = 0.363 ± 0.116, action_magnitude = 0.754 ± 0.274, n_updates = 124001, time = 13.6, total_time = 1718.7
#
# step =  135000, num_env_steps =  135000, scores =  4507.900 (n= 1), score_ema =  4439.770, actor_loss = -209.151, entropy_coef_loss = 0.561, critic_loss = 246.708, entropy_coef = 0.103, rollout_stds = 0.523 ± 0.052, action_magnitude = 0.753 ± 0.278, n_updates = 125001, time = 13.8, total_time = 1732.6
#
# step =  136000, num_env_steps =  136000, scores =  4353.804 (n= 1), score_ema =  4418.278, actor_loss = -213.648, entropy_coef_loss = -1.457, critic_loss = 12.389, entropy_coef = 0.103, rollout_stds = 0.390 ± 0.128, action_magnitude = 0.744 ± 0.284, n_updates = 126001, time = 14.7, total_time = 1747.3
#
# step =  137000, num_env_steps =  137000, scores =  4310.711 (n= 1), score_ema =  4391.387, actor_loss = -204.227, entropy_coef_loss = -0.616, critic_loss = 11.643, entropy_coef = 0.104, rollout_stds = 0.395 ± 0.114, action_magnitude = 0.749 ± 0.279, n_updates = 127001, time = 13.9, total_time = 1761.2
#
# step =  138000, num_env_steps =  138000, scores =  4615.235 (n= 1), score_ema =  4447.349, actor_loss = -216.422, entropy_coef_loss = 0.252, critic_loss = 14.906, entropy_coef = 0.107, rollout_stds = 0.414 ± 0.141, action_magnitude = 0.754 ± 0.273, n_updates = 128001, time = 13.8, total_time = 1774.9
#
# step =  139000, num_env_steps =  139000, scores =  4143.224 (n= 1), score_ema =  4371.317, actor_loss = -216.658, entropy_coef_loss = -0.127, critic_loss = 15.346, entropy_coef = 0.108, rollout_stds = 0.397 ± 0.092, action_magnitude = 0.749 ± 0.277, n_updates = 129001, time = 13.9, total_time = 1788.9
#
# step =  140000, num_env_steps =  140000, scores =  4621.790 (n= 1), score_ema =  4433.936, actor_loss = -205.120, entropy_coef_loss = -0.432, critic_loss = 16.493, entropy_coef = 0.107, rollout_stds = 0.416 ± 0.152, action_magnitude = 0.756 ± 0.274, n_updates = 130001, time = 13.9, total_time = 1802.8
#
# saved experiment log 2024-10-05_14-48-29_860485~gaW9kQ at experiment_logs/HalfCheetah-v4/sac/2024-10-05_14-48-29_860485~gaW9kQ.json
#
# step =  141000, num_env_steps =  141000, scores =  4491.807 (n= 1), score_ema =  4448.404, actor_loss = -216.351, entropy_coef_loss = 0.793, critic_loss = 18.891, entropy_coef = 0.109, rollout_stds = 0.405 ± 0.121, action_magnitude = 0.749 ± 0.281, n_updates = 131001, time = 14.2, total_time = 1816.9
#
# step =  142000, num_env_steps =  142000, scores =  4698.461 (n= 1), score_ema =  4510.918, actor_loss = -211.220, entropy_coef_loss = -1.146, critic_loss = 194.024, entropy_coef = 0.110, rollout_stds = 0.350 ± 0.129, action_magnitude = 0.759 ± 0.275, n_updates = 132001, time = 14.2, total_time = 1831.1
#
# step =  143000, num_env_steps =  143000, scores =  4637.810 (n= 1), score_ema =  4542.641, actor_loss = -209.976, entropy_coef_loss = -1.170, critic_loss = 13.148, entropy_coef = 0.109, rollout_stds = 0.355 ± 0.136, action_magnitude = 0.751 ± 0.281, n_updates = 133001, time = 13.9, total_time = 1845.0
#
# step =  144000, num_env_steps =  144000, scores =  4501.552 (n= 1), score_ema =  4532.369, actor_loss = -217.596, entropy_coef_loss = 1.257, critic_loss = 19.645, entropy_coef = 0.109, rollout_stds = 0.394 ± 0.134, action_magnitude = 0.752 ± 0.278, n_updates = 134001, time = 14.3, total_time = 1859.3
#
# step =  145000, num_env_steps =  145000, scores =  4441.748 (n= 1), score_ema =  4509.714, actor_loss = -216.896, entropy_coef_loss = 0.319, critic_loss = 18.336, entropy_coef = 0.111, rollout_stds = 0.368 ± 0.088, action_magnitude = 0.753 ± 0.278, n_updates = 135001, time = 14.1, total_time = 1873.5
#
# step =  146000, num_env_steps =  146000, scores =  4563.805 (n= 1), score_ema =  4523.236, actor_loss = -220.991, entropy_coef_loss = 0.171, critic_loss = 15.973, entropy_coef = 0.108, rollout_stds = 0.345 ± 0.095, action_magnitude = 0.750 ± 0.280, n_updates = 136001, time = 13.8, total_time = 1887.3
#
# step =  147000, num_env_steps =  147000, scores =  4754.756 (n= 1), score_ema =  4581.116, actor_loss = -221.446, entropy_coef_loss = 0.427, critic_loss = 58.272, entropy_coef = 0.111, rollout_stds = 0.463 ± 0.056, action_magnitude = 0.752 ± 0.281, n_updates = 137001, time = 13.7, total_time = 1901.0
#
# step =  148000, num_env_steps =  148000, scores =  4541.858 (n= 1), score_ema =  4571.302, actor_loss = -213.488, entropy_coef_loss = 0.146, critic_loss = 20.600, entropy_coef = 0.112, rollout_stds = 0.319 ± 0.148, action_magnitude = 0.748 ± 0.279, n_updates = 138001, time = 13.7, total_time = 1914.8
#
# step =  149000, num_env_steps =  149000, scores =  4264.894 (n= 1), score_ema =  4494.700, actor_loss = -220.540, entropy_coef_loss = 0.359, critic_loss = 16.248, entropy_coef = 0.112, rollout_stds = 0.378 ± 0.141, action_magnitude = 0.749 ± 0.278, n_updates = 139001, time = 13.8, total_time = 1928.6
#
# step =  150000, num_env_steps =  150000, scores =  4530.839 (n= 1), score_ema =  4503.735, actor_loss = -230.601, entropy_coef_loss = -0.053, critic_loss = 17.467, entropy_coef = 0.110, rollout_stds = 0.386 ± 0.139, action_magnitude = 0.745 ± 0.282, n_updates = 140001, time = 13.9, total_time = 1942.4
#
# saved experiment log 2024-10-05_14-48-29_860485~gaW9kQ at experiment_logs/HalfCheetah-v4/sac/2024-10-05_14-48-29_860485~gaW9kQ.json
#
# step =  151000, num_env_steps =  151000, scores =  4812.044 (n= 1), score_ema =  4580.812, actor_loss = -225.539, entropy_coef_loss = 0.294, critic_loss = 12.008, entropy_coef = 0.112, rollout_stds = 0.408 ± 0.103, action_magnitude = 0.751 ± 0.281, n_updates = 141001, time = 14.1, total_time = 1956.5
#
# step =  152000, num_env_steps =  152000, scores =  4550.253 (n= 1), score_ema =  4573.172, actor_loss = -218.499, entropy_coef_loss = -0.561, critic_loss = 263.830, entropy_coef = 0.115, rollout_stds = 0.450 ± 0.120, action_magnitude = 0.747 ± 0.284, n_updates = 142001, time = 14.4, total_time = 1970.9
#
# step =  153000, num_env_steps =  153000, scores =  4577.944 (n= 1), score_ema =  4574.365, actor_loss = -230.557, entropy_coef_loss = 0.844, critic_loss = 21.894, entropy_coef = 0.115, rollout_stds = 0.425 ± 0.092, action_magnitude = 0.749 ± 0.279, n_updates = 143001, time = 14.2, total_time = 1985.2
#
# step =  154000, num_env_steps =  154000, scores =  4574.962 (n= 1), score_ema =  4574.514, actor_loss = -226.480, entropy_coef_loss = 0.129, critic_loss = 15.070, entropy_coef = 0.115, rollout_stds = 0.513 ± 0.024, action_magnitude = 0.751 ± 0.278, n_updates = 144001, time = 14.0, total_time = 1999.2
#
# step =  155000, num_env_steps =  155000, scores =  4786.812 (n= 1), score_ema =  4627.589, actor_loss = -211.225, entropy_coef_loss = -0.341, critic_loss = 232.032, entropy_coef = 0.114, rollout_stds = 0.403 ± 0.161, action_magnitude = 0.752 ± 0.279, n_updates = 145001, time = 14.1, total_time = 2013.3
#
# step =  156000, num_env_steps =  156000, scores =  4893.074 (n= 1), score_ema =  4693.960, actor_loss = -220.371, entropy_coef_loss = -0.667, critic_loss = 15.609, entropy_coef = 0.117, rollout_stds = 0.388 ± 0.141, action_magnitude = 0.751 ± 0.282, n_updates = 146001, time = 13.8, total_time = 2027.0
#
# step =  157000, num_env_steps =  157000, scores =  4816.841 (n= 1), score_ema =  4724.680, actor_loss = -226.139, entropy_coef_loss = 0.089, critic_loss = 11.871, entropy_coef = 0.114, rollout_stds = 0.429 ± 0.179, action_magnitude = 0.749 ± 0.284, n_updates = 147001, time = 13.9, total_time = 2040.9
#
# step =  158000, num_env_steps =  158000, scores =  4777.574 (n= 1), score_ema =  4737.904, actor_loss = -233.555, entropy_coef_loss = 1.429, critic_loss = 205.185, entropy_coef = 0.115, rollout_stds = 0.424 ± 0.147, action_magnitude = 0.746 ± 0.282, n_updates = 148001, time = 13.9, total_time = 2054.8
#
# step =  159000, num_env_steps =  159000, scores =  4685.756 (n= 1), score_ema =  4724.867, actor_loss = -229.621, entropy_coef_loss = -0.013, critic_loss = 15.106, entropy_coef = 0.118, rollout_stds = 0.433 ± 0.115, action_magnitude = 0.744 ± 0.284, n_updates = 149001, time = 14.0, total_time = 2068.8
#
# ...
#
#
# step = 2893000, num_env_steps = 2893000, scores =  10089.856 (n= 1), score_ema =  9802.141, actor_loss = -679.894, entropy_coef_loss = 0.303, critic_loss = 32.260, entropy_coef = 0.298, rollout_stds = 0.339 ± 0.143, action_magnitude = 0.702 ± 0.285, n_updates = 2883001, time = 13.2, total_time = 38697.2
#
#
# step = 2894000, num_env_steps = 2894000, scores =  9750.743 (n= 1), score_ema =  9789.292, actor_loss = -678.074, entropy_coef_loss = -0.101, critic_loss = 39.334, entropy_coef = 0.318, rollout_stds = 0.331 ± 0.134, action_magnitude = 0.698 ± 0.286, n_updates = 2884001, time = 13.2, total_time = 38710.3
#
#
# step = 2895000, num_env_steps = 2895000, scores =  9749.705 (n= 1), score_ema =  9779.395, actor_loss = -673.948, entropy_coef_loss = 0.099, critic_loss = 1847.009, entropy_coef = 0.312, rollout_stds = 0.414 ± 0.155, action_magnitude = 0.702 ± 0.289, n_updates = 2885001, time = 13.2, total_time = 38723.5
#
#
# step = 2896000, num_env_steps = 2896000, scores =  9830.866 (n= 1), score_ema =  9792.263, actor_loss = -677.287, entropy_coef_loss = 0.043, critic_loss = 1895.524, entropy_coef = 0.320, rollout_stds = 0.355 ± 0.085, action_magnitude = 0.708 ± 0.283, n_updates = 2886001, time = 13.1, total_time = 38736.6
#
#
# step = 2897000, num_env_steps = 2897000, scores =  9535.604 (n= 1), score_ema =  9728.098, actor_loss = -672.824, entropy_coef_loss = -0.297, critic_loss = 1842.551, entropy_coef = 0.319, rollout_stds = 0.363 ± 0.156, action_magnitude = 0.694 ± 0.285, n_updates = 2887001, time = 13.2, total_time = 38749.8
#
#
# step = 2898000, num_env_steps = 2898000, scores =  9969.328 (n= 1), score_ema =  9788.405, actor_loss = -674.517, entropy_coef_loss = 0.238, critic_loss = 34.902, entropy_coef = 0.316, rollout_stds = 0.334 ± 0.124, action_magnitude = 0.712 ± 0.283, n_updates = 2888001, time = 13.2, total_time = 38762.9
#
#
# step = 2899000, num_env_steps = 2899000, scores =  9604.324 (n= 1), score_ema =  9742.385, actor_loss = -670.225, entropy_coef_loss = -0.315, critic_loss = 20.983, entropy_coef = 0.319, rollout_stds = 0.388 ± 0.145, action_magnitude = 0.693 ± 0.287, n_updates = 2889001, time = 13.2, total_time = 38776.1
#
#
# step = 2900000, num_env_steps = 2900000, scores =  9503.942 (n= 1), score_ema =  9682.774, actor_loss = -676.669, entropy_coef_loss = -0.233, critic_loss = 29.447, entropy_coef = 0.321, rollout_stds = 0.329 ± 0.089, action_magnitude = 0.695 ± 0.286, n_updates = 2890001, time = 13.2, total_time = 38789.3
#
# saved experiment log 2024-10-05_14-48-29_860485~gaW9kQ at experiment_logs/HalfCheetah-v4/sac/2024-10-05_14-48-29_860485~gaW9kQ.json
#
#
# step = 2901000, num_env_steps = 2901000, scores =  9503.771 (n= 1), score_ema =  9638.024, actor_loss = -682.532, entropy_coef_loss = -0.322, critic_loss = 35.035, entropy_coef = 0.326, rollout_stds = 0.338 ± 0.095, action_magnitude = 0.705 ± 0.281, n_updates = 2891001, time = 13.5, total_time = 38802.8
#
#
# step = 2902000, num_env_steps = 2902000, scores =  9626.941 (n= 1), score_ema =  9635.253, actor_loss = -670.601, entropy_coef_loss = -0.393, critic_loss = 19.767, entropy_coef = 0.313, rollout_stds = 0.336 ± 0.122, action_magnitude = 0.703 ± 0.284, n_updates = 2892001, time = 13.2, total_time = 38816.0
#
#
# step = 2903000, num_env_steps = 2903000, scores =  9826.714 (n= 1), score_ema =  9683.118, actor_loss = -680.404, entropy_coef_loss = -0.220, critic_loss = 26.106, entropy_coef = 0.299, rollout_stds = 0.315 ± 0.058, action_magnitude = 0.706 ± 0.283, n_updates = 2893001, time = 13.2, total_time = 38829.1
#
#
# step = 2904000, num_env_steps = 2904000, scores =  9867.999 (n= 1), score_ema =  9729.338, actor_loss = -674.490, entropy_coef_loss = -0.009, critic_loss = 18.046, entropy_coef = 0.315, rollout_stds = 0.299 ± 0.105, action_magnitude = 0.708 ± 0.280, n_updates = 2894001, time = 13.2, total_time = 38842.3
#
#
# step = 2905000, num_env_steps = 2905000, scores =  9654.832 (n= 1), score_ema =  9710.712, actor_loss = -669.459, entropy_coef_loss = -0.272, critic_loss = 26.740, entropy_coef = 0.309, rollout_stds = 0.349 ± 0.165, action_magnitude = 0.710 ± 0.280, n_updates = 2895001, time = 13.2, total_time = 38855.5
#
#
# step = 2906000, num_env_steps = 2906000, scores =  9811.715 (n= 1), score_ema =  9735.962, actor_loss = -679.022, entropy_coef_loss = 0.248, critic_loss = 26.193, entropy_coef = 0.313, rollout_stds = 0.324 ± 0.143, action_magnitude = 0.707 ± 0.284, n_updates = 2896001, time = 13.1, total_time = 38868.6
#
#
# step = 2907000, num_env_steps = 2907000, scores =  9563.934 (n= 1), score_ema =  9692.955, actor_loss = -671.380, entropy_coef_loss = -0.275, critic_loss = 1957.716, entropy_coef = 0.316, rollout_stds = 0.446 ± 0.132, action_magnitude = 0.705 ± 0.284, n_updates = 2897001, time = 13.2, total_time = 38881.7
#
#
# step = 2908000, num_env_steps = 2908000, scores =  9807.769 (n= 1), score_ema =  9721.659, actor_loss = -669.317, entropy_coef_loss = -0.295, critic_loss = 53.512, entropy_coef = 0.324, rollout_stds = 0.309 ± 0.134, action_magnitude = 0.706 ± 0.282, n_updates = 2898001, time = 13.2, total_time = 38894.9
#
#
# step = 2909000, num_env_steps = 2909000, scores =  9678.456 (n= 1), score_ema =  9710.858, actor_loss = -675.605, entropy_coef_loss = -0.098, critic_loss = 1766.347, entropy_coef = 0.314, rollout_stds = 0.310 ± 0.047, action_magnitude = 0.710 ± 0.282, n_updates = 2899001, time = 13.2, total_time = 38908.0
#
#
# step = 2910000, num_env_steps = 2910000, scores =  9804.309 (n= 1), score_ema =  9734.221, actor_loss = -666.947, entropy_coef_loss = -0.124, critic_loss = 1841.172, entropy_coef = 0.333, rollout_stds = 0.415 ± 0.132, action_magnitude = 0.712 ± 0.281, n_updates = 2900001, time = 13.2, total_time = 38921.2
#
# saved experiment log 2024-10-05_14-48-29_860485~gaW9kQ at experiment_logs/HalfCheetah-v4/sac/2024-10-05_14-48-29_860485~gaW9kQ.json
#
#
# step = 2911000, num_env_steps = 2911000, scores =  9660.026 (n= 1), score_ema =  9715.672, actor_loss = -667.823, entropy_coef_loss = 0.045, critic_loss = 39.878, entropy_coef = 0.318, rollout_stds = 0.334 ± 0.125, action_magnitude = 0.710 ± 0.283, n_updates = 2901001, time = 13.5, total_time = 38934.7
#
#
# step = 2912000, num_env_steps = 2912000, scores =  9574.518 (n= 1), score_ema =  9680.384, actor_loss = -676.130, entropy_coef_loss = 0.036, critic_loss = 27.692, entropy_coef = 0.311, rollout_stds = 0.352 ± 0.092, action_magnitude = 0.694 ± 0.289, n_updates = 2902001, time = 13.1, total_time = 38947.8
#
#
# step = 2913000, num_env_steps = 2913000, scores =  9742.813 (n= 1), score_ema =  9695.991, actor_loss = -675.271, entropy_coef_loss = -0.472, critic_loss = 1436.999, entropy_coef = 0.329, rollout_stds = 0.449 ± 0.123, action_magnitude = 0.713 ± 0.280, n_updates = 2903001, time = 13.2, total_time = 38961.0
#
#
# step = 2914000, num_env_steps = 2914000, scores =  9775.858 (n= 1), score_ema =  9715.958, actor_loss = -673.616, entropy_coef_loss = -0.182, critic_loss = 1891.616, entropy_coef = 0.333, rollout_stds = 0.367 ± 0.153, action_magnitude = 0.706 ± 0.284, n_updates = 2904001, time = 13.1, total_time = 38974.1
#
#
# step = 2915000, num_env_steps = 2915000, scores =  9959.881 (n= 1), score_ema =  9776.939, actor_loss = -674.699, entropy_coef_loss = 0.357, critic_loss = 1858.400, entropy_coef = 0.322, rollout_stds = 0.369 ± 0.140, action_magnitude = 0.713 ± 0.279, n_updates = 2905001, time = 13.2, total_time = 38987.2
#
#
# step = 2916000, num_env_steps = 2916000, scores =  9572.628 (n= 1), score_ema =  9725.861, actor_loss = -676.151, entropy_coef_loss = 0.219, critic_loss = 32.773, entropy_coef = 0.323, rollout_stds = 0.464 ± 0.037, action_magnitude = 0.701 ± 0.287, n_updates = 2906001, time = 13.0, total_time = 39000.3
#
#
# step = 2917000, num_env_steps = 2917000, scores =  9640.765 (n= 1), score_ema =  9704.587, actor_loss = -675.824, entropy_coef_loss = 0.400, critic_loss = 33.881, entropy_coef = 0.319, rollout_stds = 0.419 ± 0.168, action_magnitude = 0.716 ± 0.280, n_updates = 2907001, time = 13.1, total_time = 39013.4
#
#
# step = 2918000, num_env_steps = 2918000, scores =  9723.434 (n= 1), score_ema =  9709.299, actor_loss = -664.082, entropy_coef_loss = -0.159, critic_loss = 35.186, entropy_coef = 0.306, rollout_stds = 0.340 ± 0.139, action_magnitude = 0.693 ± 0.285, n_updates = 2908001, time = 13.2, total_time = 39026.6
#
#
# step = 2919000, num_env_steps = 2919000, scores =  9733.219 (n= 1), score_ema =  9715.279, actor_loss = -680.247, entropy_coef_loss = 0.039, critic_loss = 27.431, entropy_coef = 0.312, rollout_stds = 0.341 ± 0.069, action_magnitude = 0.698 ± 0.285, n_updates = 2909001, time = 13.2, total_time = 39039.8
#
#
# step = 2920000, num_env_steps = 2920000, scores =  9860.502 (n= 1), score_ema =  9751.585, actor_loss = -671.076, entropy_coef_loss = -0.284, critic_loss = 29.345, entropy_coef = 0.316, rollout_stds = 0.358 ± 0.156, action_magnitude = 0.703 ± 0.288, n_updates = 2910001, time = 13.6, total_time = 39053.4
#
# saved experiment log 2024-10-05_14-48-29_860485~gaW9kQ at experiment_logs/HalfCheetah-v4/sac/2024-10-05_14-48-29_860485~gaW9kQ.json
#
#
# step = 2921000, num_env_steps = 2921000, scores =  9973.753 (n= 1), score_ema =  9807.127, actor_loss = -681.566, entropy_coef_loss = 0.252, critic_loss = 1899.869, entropy_coef = 0.297, rollout_stds = 0.386 ± 0.092, action_magnitude = 0.699 ± 0.285, n_updates = 2911001, time = 13.5, total_time = 39066.8
#
#
# step = 2922000, num_env_steps = 2922000, scores =  9770.703 (n= 1), score_ema =  9798.021, actor_loss = -670.348, entropy_coef_loss = -0.538, critic_loss = 26.761, entropy_coef = 0.317, rollout_stds = 0.337 ± 0.089, action_magnitude = 0.693 ± 0.283, n_updates = 2912001, time = 13.2, total_time = 39080.0
#
#
# step = 2923000, num_env_steps = 2923000, scores =  9729.587 (n= 1), score_ema =  9780.913, actor_loss = -673.911, entropy_coef_loss = -0.335, critic_loss = 23.664, entropy_coef = 0.317, rollout_stds = 0.418 ± 0.125, action_magnitude = 0.708 ± 0.280, n_updates = 2913001, time = 13.2, total_time = 39093.2
#
#
# step = 2924000, num_env_steps = 2924000, scores =  9405.987 (n= 1), score_ema =  9687.181, actor_loss = -673.497, entropy_coef_loss = 0.831, critic_loss = 35.318, entropy_coef = 0.323, rollout_stds = 0.408 ± 0.160, action_magnitude = 0.708 ± 0.282, n_updates = 2914001, time = 13.2, total_time = 39106.4
#
#
# step = 2925000, num_env_steps = 2925000, scores =  9783.847 (n= 1), score_ema =  9711.348, actor_loss = -668.904, entropy_coef_loss = -0.241, critic_loss = 47.608, entropy_coef = 0.319, rollout_stds = 0.349 ± 0.078, action_magnitude = 0.698 ± 0.285, n_updates = 2915001, time = 13.5, total_time = 39119.9
#
#
# step = 2926000, num_env_steps = 2926000, scores =  9581.628 (n= 1), score_ema =  9678.918, actor_loss = -679.620, entropy_coef_loss = 0.565, critic_loss = 27.523, entropy_coef = 0.319, rollout_stds = 0.401 ± 0.114, action_magnitude = 0.700 ± 0.287, n_updates = 2916001, time = 13.6, total_time = 39133.4
#
#
# step = 2927000, num_env_steps = 2927000, scores =  9834.166 (n= 1), score_ema =  9717.730, actor_loss = -674.929, entropy_coef_loss = -0.296, critic_loss = 29.597, entropy_coef = 0.320, rollout_stds = 0.364 ± 0.131, action_magnitude = 0.701 ± 0.285, n_updates = 2917001, time = 13.7, total_time = 39147.1
#
#
# step = 2928000, num_env_steps = 2928000, scores =  9777.768 (n= 1), score_ema =  9732.739, actor_loss = -675.493, entropy_coef_loss = 0.003, critic_loss = 28.877, entropy_coef = 0.318, rollout_stds = 0.340 ± 0.140, action_magnitude = 0.704 ± 0.286, n_updates = 2918001, time = 13.6, total_time = 39160.7
#
#
# step = 2929000, num_env_steps = 2929000, scores =  9296.000 (n= 1), score_ema =  9623.554, actor_loss = -674.414, entropy_coef_loss = 0.059, critic_loss = 21.393, entropy_coef = 0.316, rollout_stds = 0.397 ± 0.094, action_magnitude = 0.695 ± 0.286, n_updates = 2919001, time = 14.4, total_time = 39175.0
#
#
# step = 2930000, num_env_steps = 2930000, scores =  8059.065 (n= 1), score_ema =  9232.432, actor_loss = -680.397, entropy_coef_loss = -0.209, critic_loss = 1927.456, entropy_coef = 0.306, rollout_stds = 0.594 ± 0.061, action_magnitude = 0.696 ± 0.289, n_updates = 2920001, time = 14.2, total_time = 39189.3
#
# saved experiment log 2024-10-05_14-48-29_860485~gaW9kQ at experiment_logs/HalfCheetah-v4/sac/2024-10-05_14-48-29_860485~gaW9kQ.json
#
#
# step = 2931000, num_env_steps = 2931000, scores =  9013.212 (n= 1), score_ema =  9177.627, actor_loss = -674.017, entropy_coef_loss = -0.037, critic_loss = 35.794, entropy_coef = 0.312, rollout_stds = 0.313 ± 0.086, action_magnitude = 0.685 ± 0.288, n_updates = 2921001, time = 14.6, total_time = 39203.8
#
#
# step = 2932000, num_env_steps = 2932000, scores =  9790.838 (n= 1), score_ema =  9330.930, actor_loss = -667.570, entropy_coef_loss = -0.087, critic_loss = 29.858, entropy_coef = 0.312, rollout_stds = 0.412 ± 0.189, action_magnitude = 0.684 ± 0.292, n_updates = 2922001, time = 14.0, total_time = 39217.8
#
#
# step = 2933000, num_env_steps = 2933000, scores =  9956.104 (n= 1), score_ema =  9487.223, actor_loss = -685.977, entropy_coef_loss = -0.076, critic_loss = 27.641, entropy_coef = 0.309, rollout_stds = 0.456 ± 0.103, action_magnitude = 0.706 ± 0.285, n_updates = 2923001, time = 14.3, total_time = 39232.0
#
#
# step = 2934000, num_env_steps = 2934000, scores =  8940.303 (n= 1), score_ema =  9350.493, actor_loss = -670.327, entropy_coef_loss = -0.298, critic_loss = 22.684, entropy_coef = 0.312, rollout_stds = 0.440 ± 0.110, action_magnitude = 0.705 ± 0.285, n_updates = 2924001, time = 13.3, total_time = 39245.3
#
#
# step = 2935000, num_env_steps = 2935000, scores =  9808.680 (n= 1), score_ema =  9465.040, actor_loss = -677.081, entropy_coef_loss = 0.140, critic_loss = 28.480, entropy_coef = 0.313, rollout_stds = 0.386 ± 0.113, action_magnitude = 0.718 ± 0.281, n_updates = 2925001, time = 13.2, total_time = 39258.5
#
#
# step = 2936000, num_env_steps = 2936000, scores =  9749.222 (n= 1), score_ema =  9536.085, actor_loss = -676.396, entropy_coef_loss = -0.031, critic_loss = 31.290, entropy_coef = 0.314, rollout_stds = 0.403 ± 0.082, action_magnitude = 0.706 ± 0.283, n_updates = 2926001, time = 14.2, total_time = 39272.7
#
#
# step = 2937000, num_env_steps = 2937000, scores =  9689.605 (n= 1), score_ema =  9574.465, actor_loss = -673.193, entropy_coef_loss = -0.553, critic_loss = 39.517, entropy_coef = 0.317, rollout_stds = 0.239 ± 0.029, action_magnitude = 0.703 ± 0.283, n_updates = 2927001, time = 13.3, total_time = 39286.0
#
#
# step = 2938000, num_env_steps = 2938000, scores =  9412.132 (n= 1), score_ema =  9533.882, actor_loss = -669.737, entropy_coef_loss = -0.509, critic_loss = 30.329, entropy_coef = 0.326, rollout_stds = 0.288 ± 0.119, action_magnitude = 0.699 ± 0.288, n_updates = 2928001, time = 13.3, total_time = 39299.3
#
#
# step = 2939000, num_env_steps = 2939000, scores =  9718.270 (n= 1), score_ema =  9579.979, actor_loss = -671.311, entropy_coef_loss = -0.089, critic_loss = 1847.628, entropy_coef = 0.325, rollout_stds = 0.375 ± 0.126, action_magnitude = 0.698 ± 0.286, n_updates = 2929001, time = 14.7, total_time = 39314.1
#
#
# step = 2940000, num_env_steps = 2940000, scores =  9697.508 (n= 1), score_ema =  9609.361, actor_loss = -674.630, entropy_coef_loss = 0.123, critic_loss = 1704.423, entropy_coef = 0.325, rollout_stds = 0.353 ± 0.166, action_magnitude = 0.702 ± 0.284, n_updates = 2930001, time = 15.4, total_time = 39329.5
#
# saved experiment log 2024-10-05_14-48-29_860485~gaW9kQ at experiment_logs/HalfCheetah-v4/sac/2024-10-05_14-48-29_860485~gaW9kQ.json
#
#
# step = 2941000, num_env_steps = 2941000, scores =  9970.871 (n= 1), score_ema =  9699.739, actor_loss = -675.749, entropy_coef_loss = 0.411, critic_loss = 24.390, entropy_coef = 0.320, rollout_stds = 0.273 ± 0.032, action_magnitude = 0.708 ± 0.279, n_updates = 2931001, time = 14.3, total_time = 39343.8
#
# saved experiment log 2024-10-05_14-48-29_860485~gaW9kQ at experiment_logs/HalfCheetah-v4/sac/2024-10-05_14-48-29_860485~gaW9kQ.json
# keyboard interrupt
# closing envs
# envs closed
# model db closed
# done
