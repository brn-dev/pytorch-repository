# %%
import inspect
import os
import time
from pathlib import Path

import gymnasium
from gymnasium import Env
from gymnasium.vector import VectorEnv

from sac import init_action_selector, init_policy, init_optimizer, wrap_env, policy_construction_hyper_parameter
from src.datetime import get_current_timestamp
from src.experiment_logging.experiment_logger import ExperimentLogger, log_experiment
from src.model_db.model_db import ModelDB
from src.model_db.dummy_model_db import DummyModelDB
from src.np_functions import inv_symmetric_log
from src.reinforcement_learning.algorithms.policy_mitosis.mitosis_policy_info import MitosisPolicyInfo
from src.model_db.tiny_model_db import TinyModelDB
from src.module_analysis import count_parameters, get_gradients_per_parameter
from src.moving_averages import ExponentialMovingAverage
from src.reinforcement_learning.core.action_selectors.action_selector import ActionSelector
from src.reinforcement_learning.core.action_selectors.predicted_std_action_selector import PredictedStdActionSelector
from src.reinforcement_learning.core.action_selectors.state_dependent_noise_action_selector import \
    StateDependentNoiseActionSelector
from src.reinforcement_learning.core.generalized_advantage_estimate import compute_episode_returns, compute_returns
from src.reinforcement_learning.core.policies.base_policy import BasePolicy
from src.reinforcement_learning.core.policy_construction import InitActionSelectorFunction, PolicyConstruction
from src.reinforcement_learning.gym.envs.test_env import TestEnv
from src.schedulers import FixedValueScheduler, OneStepRecursiveScheduler
from src.stopwatch import Stopwatch
from src.summary_statistics import format_summary_statics
from src.reinforcement_learning.core.policies.actor_critic_policy import ActorCriticPolicy
from typing import Any, SupportsFloat, Optional
from gymnasium.wrappers import RecordVideo, AutoResetWrapper, NormalizeReward, TransformReward, TransformObservation, ClipAction
from src.reinforcement_learning.core.callback import Callback
from src.reinforcement_learning.algorithms.sac.sac import SAC, SAC_DEFAULT_OPTIMIZER_PROVIDER
from src.reinforcement_learning.algorithms.ppo.ppo import PPO, PPOLoggingConfig
from src.reinforcement_learning.core.normalization import NormalizationType
from src.torch_device import set_default_torch_device, optimizer_to_device
from src.reinforcement_learning.gym.parallelize_env import parallelize_env_async
from torch.distributions import Normal, Categorical

import torch
from torch import optim, nn
import torch.distributions as dist
import gymnasium as gym
import numpy as np

from src.torch_functions import antisymmetric_power

# %load_ext autoreload
# %autoreload 2
# Out:
# pygame 2.5.2 (SDL 2.28.3, Python 3.11.7)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
from src.summary_statistics import maybe_compute_summary_statistics
from src.reinforcement_learning.core.loss_config import LossLoggingConfig
from src.reinforcement_learning.algorithms.sac.sac import SAC, SACLoggingConfig
def get_setup() -> dict[str, str]:
    import inspect
    import sac
    return {
        'sac.py': inspect.getsource(sac),
        'notebook': _ih[1] + '\n\n' + _ih[-1], # first and last cell input (imports and this cell)
    }

policy_id: str
policy: BasePolicy
optimizer: optim.Optimizer
wrapped_env: Env
steps_trained: int
def get_policy(create_new_if_exists: bool):
    
    global policy_id, policy, optimizer, wrapped_env, steps_trained
    
    policy_in_ram = 'policy' in globals()
    if not policy_in_ram or create_new_if_exists:
        if not policy_in_ram:
            print('No policy in RAM, creating a new one')
        
        policy_id = get_current_timestamp()
        policy, optimizer, wrapped_env = PolicyConstruction.init_from_info(
            env=env,
            info=PolicyConstruction.create_policy_initialization_info(
                init_action_selector=init_action_selector,
                init_policy=init_policy,
                init_optimizer=init_optimizer,
                wrap_env=wrap_env,
                hyper_parameters=policy_construction_hyper_parameter,
            ),
        )
        steps_trained = 0
        print(f'New policy {policy_id} created')
    
    if parent_policy_id is not None:
        model_entry = policy_db.load_model_state_dict(policy, parent_policy_id)
        steps_trained = model_entry['model_info']['steps_trained']
        print(f'Loading state dict from policy {parent_policy_id}')
    
    print(f'Using policy {policy_id} with parent policy {parent_policy_id}')
    return policy_id, policy, optimizer, wrapped_env, steps_trained

score_mean_ema = ExponentialMovingAverage(alpha=0.25)
step_stopwatch = Stopwatch()
total_stopwatch = Stopwatch()
best_iteration_score = -1e6

def on_rollout_done(rl: SAC, step: int, info: dict[str, Any], scheduler_values: dict[str, Any]):
    
    if step % 1000 != 0:
        return
    
    tail_indices = rl.buffer.tail_indices(1000)
    
    # rewards = rl.buffer.rewards[tail_indices]
    # if 'raw_rewards' in info['rollout']:
    #     rewards = info['rollout']['raw_rewards']
    
    # episode_scores = compute_episode_returns(
    #     rewards=rewards,
    #     episode_starts=np.repeat(np.arange(len(tail_indices)).reshape(-1, 1), num_envs, axis=1) % 1000 == 0,
    #     last_episode_starts=info['last_episode_starts'],
    #     gamma=1.0,
    #     gae_lambda=1.0,
    #     normalize_rewards=None,
    #     remove_unfinished_episodes=True,
    # )
    
    episode_scores = rl.buffer.compute_most_recent_episode_scores(rl.num_envs)
    
    if len(episode_scores) > 0:
    
        global best_iteration_score
        iteration_score = episode_scores.mean()
        score_moving_average = score_mean_ema.update(iteration_score)
        if iteration_score >= best_iteration_score:
            best_iteration_score = iteration_score
            policy_db.save_model_state_dict(
                model_id=policy_id,
                parent_model_id=parent_policy_id,
                model_info={
                    'score': iteration_score.item(),
                    'steps_trained': steps_trained,
                    'wrap_env_source_code': wrap_env_source_code_source,
                    'init_policy_source_code': init_policy_source
                },
                model=policy,
                optimizer=optimizer,
            )
        info['score_moving_average'] = score_moving_average
    
    info['episode_scores'] = episode_scores
        
def on_optimization_done(rl: SAC, step: int, info: dict[str, Any], scheduler_values: dict[str, Any]):
    # global steps_trained
    # steps_trained += rl.buffer.pos
    
    if step % 1000 != 0:
        return
    num_env_steps = step * rl.num_envs
    
    step_time = step_stopwatch.reset()
    total_time = total_stopwatch.time_passed()
    
    tail_indices = rl.buffer.tail_indices(1000)
    
    episode_scores = info.get('episode_scores')
    score_moving_average = info.get('score_moving_average') or 0.0
    
    scores = format_summary_statics(
        episode_scores, 
        mean_format=' 6.3f',
        std_format='4.3f',
        min_value_format=' 6.3f',
        max_value_format='5.3f',
        n_format='>2'
    )
    # scores2 = format_summary_statics(
    #     rl.buffer.compute_most_recent_episode_scores(rl.num_envs, lambda r: 1 * r), 
    #     mean_format=' 6.3f',
    #     std_format='4.3f',
    #     min_value_format=' 6.3f',
    #     max_value_format='5.3f',
    #     n_format='>2'
    # )
    # advantages = format_summary_statics(
    #     rl.buffer.advantages, 
    #     mean_format=' 6.3f',
    #     std_format='.1f',
    #     min_value_format=' 7.3f',
    #     max_value_format='6.3f',
    # )
    actor_loss = format_summary_statics(
        info['final_actor_loss'],  
        mean_format=' 5.3f',
        # std_format='5.3f',
        std_format=None,
        min_value_format=None,
        max_value_format=None,
    )
    # actor_loss_raw = format_summary_statics(
    #     info['raw_actor_loss'],  
    #     mean_format=' 5.3f',
    #     std_format='5.3f',
    #     min_value_format=None,
    #     max_value_format=None,
    # )
    entropy_coef_loss = None if 'final_entropy_coef_loss' not in info else format_summary_statics(
        info['final_entropy_coef_loss'], 
        mean_format='5.3f',
#         std_format='5.3f',
        std_format=None,
        min_value_format=None,
        max_value_format=None,
    )
    critic_loss = format_summary_statics(
        info['final_critic_loss'], 
        mean_format='5.3f',
#         std_format='5.3f',
        std_format=None,
        min_value_format=None,
        max_value_format=None,
    )
    entropy_coef = format_summary_statics(
        info['entropy_coef'],
        mean_format='5.3f',
#         std_format='5.3f',
        std_format=None,
        min_value_format=None,
        max_value_format=None,
    )
    # resets = format_summary_statics(
    #     rl.buffer.dones.astype(int).sum(axis=0), 
    #     mean_format='.2f',
    #     std_format=None,
    #     min_value_format='1d',
    #     max_value_format=None,
    # )
    # kl_div = info['actor_kl_divergence'][-1]
    # grad_norm = format_summary_statics(
    #     info['grad_norm'], 
    #     mean_format=' 6.3f',
    #     std_format='.1f',
    #     min_value_format=' 7.3f',
    #     max_value_format='6.3f',
    # )
    action_stds = info['rollout'].get('action_stds')
    if action_stds is not None:
        rollout_action_stds = format_summary_statics(
            action_stds,
            mean_format='5.3f',
            std_format='5.3f',
            min_value_format=None,
            max_value_format=None,
        )
    else:
        rollout_action_stds = 'N/A'
    action_magnitude = format_summary_statics(
        np.abs(rl.buffer.actions[tail_indices]),
        mean_format='5.3f',
        std_format='5.3f',
        min_value_format=None,
        max_value_format=None,
    )
    # ppo_epochs = info['nr_ppo_epochs']
    # ppo_updates = info['nr_ppo_updates']
    # expl_var = rl.buffer.compute_critic_explained_variance()
    print(f"{step = : >7}, "
          f"{num_env_steps = : >7}, "
          f"{scores = :s}, "
          # f"{scores2 = :s}, "
          f'score_ema = {score_moving_average: 6.3f}, '
          # f"{advantages = :s}, "
          f"{actor_loss = :s}, "
          # f"{actor_loss_raw = :s}, "
          f"{critic_loss = :s}, "
          +(f"{entropy_coef_loss = :s}, " if entropy_coef_loss is not None else '')+
          f"{entropy_coef = :s}, "
          f"rollout_stds = {rollout_action_stds:s}, "
          f"{action_magnitude = :s}, "
          # f"{expl_var = :.3f}, "
          # f"{kl_div = :.4f}, "
          # f"{ppo_epochs = }, "
          # f"{ppo_updates = }, "
          # f"{grad_norm = :s}, "
          f"n_updates = {rl.gradient_steps_performed}, "
          # f"{resets = :s}, "
          f"time = {step_time:4.1f}, "
          f"total_time = {total_time:4.1f} \n"
          )
    logger.add_item({
        'step': step,
        'num_env_steps': num_env_steps,
        'scores': maybe_compute_summary_statistics(episode_scores),
        'actor_loss': maybe_compute_summary_statistics(info['final_actor_loss']),
        'entropy_coef_loss': maybe_compute_summary_statistics(info.get('final_entropy_coef_loss')),
        'critic_loss': maybe_compute_summary_statistics(info['final_critic_loss']),
        'entropy_coef': maybe_compute_summary_statistics(info['entropy_coef']),
        'action_stds': maybe_compute_summary_statistics(action_stds),
        'action_magnitude': maybe_compute_summary_statistics(np.abs(rl.buffer.actions[tail_indices])),
        'num_gradient_steps': rl.gradient_steps_performed,
        'step_time': step_time,
        'total_time': total_time
    })
    if step % 10000 == 0:
        logger.save_experiment_log()
        print()
    print()
    
    # if episode_scores is not None and len(episode_scores) > 0 and episode_scores.mean().item() < -500:
    #     logger.save_experiment_log()
    #     raise ValueError('Score too low, policy probably fucked :(')

device = torch.device("cuda:0") if True else torch.device('cpu')
print(f'using device {device}')

def create_env(render_mode: str | None):
    return gym.make(env_name, render_mode=render_mode, **env_kwargs)

wrap_env_source_code_source = inspect.getsource(wrap_env)
init_policy_source = inspect.getsource(init_policy)

env_name = 'HalfCheetah-v4'
# env_kwargs = {'forward_reward_weight': 1.25, 'healthy_reward': 0.5, 'ctrl_cost_weight': 0.001 }
# env_kwargs = {'forward_reward_weight': 1.25, 'ctrl_cost_weight': 0.1 }
# env_kwargs = {'forward_reward_weight': 1.25, 'ctrl_cost_weight': 0.05 }
env_kwargs = {}
num_envs = 1
    
# policy_db = TinyModelDB[MitosisPolicyInfo](base_path=f'saved_models/rl/{env_name}')
policy_db = DummyModelDB[MitosisPolicyInfo]()
print(f'{policy_db = }')

parent_policy_id=None  # '2024-04-28_20.57.23'

# TODO
# env = parallelize_env_async(lambda: create_env(render_mode=None), num_envs)
env = create_env(render_mode=None)

logger = ExperimentLogger(f'experiment_logs/{env_name}/sac/')

try:
    policy_id, policy, optimizer, wrapped_env, steps_trained = get_policy(create_new_if_exists=False)
    print(f'{count_parameters(policy) = }')
    print(f'{env = }, {num_envs = }')
        
    with ((torch.autograd.set_detect_anomaly(False))):
        algo = SAC(
            env=wrapped_env,
            policy=policy,
            actor_optimizer_provider=lambda params: optim.Adam(params, lr=3e-4),  # (params, lr=3e-4, betas=(0.5, 0.999)),
            critic_optimizer_provider=lambda params: optim.Adam(params, lr=3e-4),  # (params, lr=3e-4, betas=(0.5, 0.999)),
            # weigh_and_reduce_actor_loss=lambda l: 1 * l.mean(),
            # weigh_critic_loss=lambda l: 1 * l,
            buffer_size=1_000_000,
            reward_scale=1,
            gamma=0.99,
            tau=0.005,
            entropy_coef_optimizer_provider=lambda params: optim.Adam(params, lr=3e-4),
            entropy_coef=1.0,
            rollout_steps=1,
            gradient_steps=1,
            warmup_steps=10_000,
            optimization_batch_size=256,
            target_update_interval=1,
            # sde_noise_sample_freq=50,
            callback=Callback(
                on_rollout_done=on_rollout_done,
                rollout_schedulers={},
                on_optimization_done=on_optimization_done,
                optimization_schedulers={},
            ),
            logging_config=SACLoggingConfig(log_rollout_infos=True, log_rollout_action_stds=True,
                                            log_last_obs=True, log_entropy_coef=True,
                                            entropy_coef_loss=LossLoggingConfig(log_final=True),
                                            actor_loss=LossLoggingConfig(log_final=True, log_raw=True),
                                            critic_loss=LossLoggingConfig(log_final=True)),
            torch_device=device,
        )
        total_stopwatch.reset()
        with log_experiment(
            logger,
            experiment_tags=algo.collect_tags(),
            hyper_parameters=algo.collect_hyper_parameters(),
            setup=get_setup(),
        ) as x:
            logger.save_experiment_log()
            print('\nStarting Training\n\n')
            # import cProfile
            # pr = cProfile.Profile()
            # pr.enable()
            algo.learn(5_000_000)
            # pr.disable()  
            # pr.dump_stats('profile_stats.pstat')
except KeyboardInterrupt:
    print('keyboard interrupt')
finally:
    print('closing envs')
    time.sleep(0.5)
    env.close()
    print('envs closed')
    policy_db.close()
    print('model db closed')
    

print('done')
# Out:
# using device cuda:0
# policy_db = DummyModelDB()
# No policy in RAM, creating a new one
# New policy 2024-10-11 12:33:23.543501 created
# Using policy 2024-10-11 12:33:23.543501 with parent policy None
# count_parameters(policy) = 217870
# env = <TimeLimit<OrderEnforcing<PassiveEnvChecker<HalfCheetahEnv<HalfCheetah-v4>>>>>, num_envs = 1
# Grabbing system information... done!
# saved experiment log 2024-10-11_12-33-24_001309~yZmsfr at experiment_logs/HalfCheetah-v4/sac/2024-10-11_12-33-24_001309~yZmsfr.json
#
# Starting Training
#
# step =   11000, num_env_steps =   11000, scores = -196.766 (n= 1), score_ema = -252.507, actor_loss = -17.814, critic_loss = 0.927, entropy_coef_loss = -3.004, entropy_coef = 0.741, rollout_stds = 0.911 ± 0.038, action_magnitude = 0.522 ± 0.285, n_updates = 1000, time = 17.6, total_time = 17.2
#
# step =   12000, num_env_steps =   12000, scores = -251.693 (n= 1), score_ema = -252.304, actor_loss = -25.571, critic_loss = 1.073, entropy_coef_loss = -5.985, entropy_coef = 0.549, rollout_stds = 0.901 ± 0.054, action_magnitude = 0.537 ± 0.292, n_updates = 2000, time = 13.2, total_time = 30.4
#
# step =   13000, num_env_steps =   13000, scores = -157.660 (n= 1), score_ema = -228.643, actor_loss = -30.684, critic_loss = 1.319, entropy_coef_loss = -8.952, entropy_coef = 0.407, rollout_stds = 0.945 ± 0.017, action_magnitude = 0.535 ± 0.285, n_updates = 3000, time = 13.1, total_time = 43.5
#
# step =   14000, num_env_steps =   14000, scores = -247.911 (n= 1), score_ema = -233.460, actor_loss = -33.192, critic_loss = 1.512, entropy_coef_loss = -11.685, entropy_coef = 0.302, rollout_stds = 0.867 ± 0.046, action_magnitude = 0.541 ± 0.288, n_updates = 4000, time = 13.9, total_time = 57.4
#
# step =   15000, num_env_steps =   15000, scores = -242.158 (n= 1), score_ema = -235.634, actor_loss = -34.212, critic_loss = 1.333, entropy_coef_loss = -13.811, entropy_coef = 0.226, rollout_stds = 0.901 ± 0.063, action_magnitude = 0.553 ± 0.290, n_updates = 5000, time = 13.5, total_time = 70.9
#
# step =   16000, num_env_steps =   16000, scores = -187.412 (n= 1), score_ema = -223.579, actor_loss = -34.554, critic_loss = 1.584, entropy_coef_loss = -16.018, entropy_coef = 0.169, rollout_stds = 0.899 ± 0.064, action_magnitude = 0.559 ± 0.294, n_updates = 6000, time = 13.2, total_time = 84.1
#
# step =   17000, num_env_steps =   17000, scores = -180.203 (n= 1), score_ema = -212.735, actor_loss = -34.369, critic_loss = 1.343, entropy_coef_loss = -17.238, entropy_coef = 0.128, rollout_stds = 0.839 ± 0.090, action_magnitude = 0.571 ± 0.297, n_updates = 7000, time = 13.4, total_time = 97.4
#
# step =   18000, num_env_steps =   18000, scores = -180.368 (n= 1), score_ema = -204.643, actor_loss = -33.522, critic_loss = 1.233, entropy_coef_loss = -17.194, entropy_coef = 0.097, rollout_stds = 0.880 ± 0.097, action_magnitude = 0.592 ± 0.293, n_updates = 8000, time = 13.2, total_time = 110.6
# step =   19000, num_env_steps =   19000, scores = -175.149 (n= 1), score_ema = -197.269, actor_loss = -32.835, critic_loss = 1.199, entropy_coef_loss = -15.967, entropy_coef = 0.074, rollout_stds = 0.846 ± 0.092, action_magnitude = 0.599 ± 0.293, n_updates = 9000, time = 14.5, total_time = 125.1
#
# step =   20000, num_env_steps =   20000, scores = -126.285 (n= 1), score_ema = -179.523, actor_loss = -32.298, critic_loss = 1.179, entropy_coef_loss = -16.415, entropy_coef = 0.057, rollout_stds = 0.803 ± 0.069, action_magnitude = 0.596 ± 0.296, n_updates = 10000, time = 13.5, total_time = 138.5
#
# saved experiment log 2024-10-11_12-33-24_001309~yZmsfr at experiment_logs/HalfCheetah-v4/sac/2024-10-11_12-33-24_001309~yZmsfr.json
#
# step =   21000, num_env_steps =   21000, scores = -177.775 (n= 1), score_ema = -179.086, actor_loss = -31.136, critic_loss = 1.169, entropy_coef_loss = -16.382, entropy_coef = 0.044, rollout_stds = 0.700 ± 0.045, action_magnitude = 0.612 ± 0.297, n_updates = 11000, time = 13.8, total_time = 152.4
#
# step =   22000, num_env_steps =   22000, scores = -247.446 (n= 1), score_ema = -196.176, actor_loss = -29.826, critic_loss = 1.128, entropy_coef_loss = -15.666, entropy_coef = 0.034, rollout_stds = 0.668 ± 0.023, action_magnitude = 0.629 ± 0.298, n_updates = 12000, time = 13.6, total_time = 166.0
#
# step =   23000, num_env_steps =   23000, scores = -509.854 (n= 1), score_ema = -274.596, actor_loss = -29.324, critic_loss = 1.654, entropy_coef_loss = -14.424, entropy_coef = 0.026, rollout_stds = 0.663 ± 0.073, action_magnitude = 0.663 ± 0.298, n_updates = 13000, time = 14.3, total_time = 180.3
#
# step =   24000, num_env_steps =   24000, scores = -148.767 (n= 1), score_ema = -243.138, actor_loss = -27.042, critic_loss = 1.157, entropy_coef_loss = -13.672, entropy_coef = 0.020, rollout_stds = 0.603 ± 0.089, action_magnitude = 0.628 ± 0.298, n_updates = 14000, time = 13.5, total_time = 193.8
#
# step =   25000, num_env_steps =   25000, scores =  119.034 (n= 1), score_ema = -152.595, actor_loss = -24.714, critic_loss = 1.264, entropy_coef_loss = -13.578, entropy_coef = 0.015, rollout_stds = 0.348 ± 0.079, action_magnitude = 0.635 ± 0.306, n_updates = 15000, time = 13.7, total_time = 207.5
#
# step =   26000, num_env_steps =   26000, scores =  424.371 (n= 1), score_ema = -8.354, actor_loss = -24.971, critic_loss = 1.456, entropy_coef_loss = -9.810, entropy_coef = 0.012, rollout_stds = 0.354 ± 0.089, action_magnitude = 0.626 ± 0.300, n_updates = 16000, time = 13.5, total_time = 220.9
#
# step =   27000, num_env_steps =   27000, scores =  865.827 (n= 1), score_ema =  210.192, actor_loss = -25.289, critic_loss = 1.383, entropy_coef_loss = -4.165, entropy_coef = 0.010, rollout_stds = 0.380 ± 0.122, action_magnitude = 0.678 ± 0.302, n_updates = 17000, time = 13.3, total_time = 234.2
#
# step =   28000, num_env_steps =   28000, scores =  1268.121 (n= 1), score_ema =  474.674, actor_loss = -23.662, critic_loss = 1.488, entropy_coef_loss = -1.307, entropy_coef = 0.010, rollout_stds = 0.227 ± 0.081, action_magnitude = 0.739 ± 0.294, n_updates = 18000, time = 13.2, total_time = 247.3
#
# step =   29000, num_env_steps =   29000, scores =  1371.389 (n= 1), score_ema =  698.853, actor_loss = -26.324, critic_loss = 1.817, entropy_coef_loss = 8.276, entropy_coef = 0.010, rollout_stds = 0.427 ± 0.149, action_magnitude = 0.758 ± 0.288, n_updates = 19000, time = 13.1, total_time = 260.5
#
# step =   30000, num_env_steps =   30000, scores =  2005.459 (n= 1), score_ema =  1025.504, actor_loss = -29.938, critic_loss = 1.969, entropy_coef_loss = 5.559, entropy_coef = 0.012, rollout_stds = 0.369 ± 0.205, action_magnitude = 0.812 ± 0.266, n_updates = 20000, time = 13.6, total_time = 274.1
#
# saved experiment log 2024-10-11_12-33-24_001309~yZmsfr at experiment_logs/HalfCheetah-v4/sac/2024-10-11_12-33-24_001309~yZmsfr.json
#
# step =   31000, num_env_steps =   31000, scores =  2062.635 (n= 1), score_ema =  1284.787, actor_loss = -29.742, critic_loss = 2.063, entropy_coef_loss = 1.961, entropy_coef = 0.014, rollout_stds = 0.369 ± 0.084, action_magnitude = 0.798 ± 0.273, n_updates = 21000, time = 13.4, total_time = 287.5
#
# step =   32000, num_env_steps =   32000, scores =  2541.124 (n= 1), score_ema =  1598.871, actor_loss = -31.503, critic_loss = 2.000, entropy_coef_loss = 0.796, entropy_coef = 0.017, rollout_stds = 0.452 ± 0.257, action_magnitude = 0.830 ± 0.250, n_updates = 22000, time = 13.3, total_time = 300.9
#
# step =   33000, num_env_steps =   33000, scores =  2267.008 (n= 1), score_ema =  1765.905, actor_loss = -35.809, critic_loss = 3.003, entropy_coef_loss = 2.804, entropy_coef = 0.021, rollout_stds = 0.470 ± 0.143, action_magnitude = 0.833 ± 0.246, n_updates = 23000, time = 13.0, total_time = 313.9
#
# step =   34000, num_env_steps =   34000, scores =  2861.998 (n= 1), score_ema =  2039.928, actor_loss = -39.406, critic_loss = 3.353, entropy_coef_loss = 1.040, entropy_coef = 0.024, rollout_stds = 0.490 ± 0.084, action_magnitude = 0.853 ± 0.236, n_updates = 24000, time = 13.1, total_time = 326.9
#
# step =   35000, num_env_steps =   35000, scores =  2662.560 (n= 1), score_ema =  2195.586, actor_loss = -43.808, critic_loss = 4.173, entropy_coef_loss = 0.949, entropy_coef = 0.029, rollout_stds = 0.413 ± 0.099, action_magnitude = 0.834 ± 0.248, n_updates = 25000, time = 13.0, total_time = 340.0
#
# step =   36000, num_env_steps =   36000, scores =  3113.766 (n= 1), score_ema =  2425.131, actor_loss = -49.690, critic_loss = 4.754, entropy_coef_loss = 2.604, entropy_coef = 0.033, rollout_stds = 0.475 ± 0.025, action_magnitude = 0.848 ± 0.234, n_updates = 26000, time = 13.0, total_time = 353.0
#
# step =   37000, num_env_steps =   37000, scores =  149.518 (n= 1), score_ema =  1856.228, actor_loss = -50.143, critic_loss = 4.936, entropy_coef_loss = -0.854, entropy_coef = 0.035, rollout_stds = 0.511 ± 0.066, action_magnitude = 0.689 ± 0.297, n_updates = 27000, time = 13.0, total_time = 366.0
#
# step =   38000, num_env_steps =   38000, scores =  3405.912 (n= 1), score_ema =  2243.649, actor_loss = -53.630, critic_loss = 8.828, entropy_coef_loss = -1.050, entropy_coef = 0.037, rollout_stds = 0.543 ± 0.079, action_magnitude = 0.846 ± 0.233, n_updates = 28000, time = 13.0, total_time = 379.1
#
# step =   39000, num_env_steps =   39000, scores =  679.344 (n= 1), score_ema =  1852.573, actor_loss = -54.970, critic_loss = 6.749, entropy_coef_loss = -1.440, entropy_coef = 0.039, rollout_stds = 0.654 ± 0.052, action_magnitude = 0.720 ± 0.291, n_updates = 29000, time = 13.0, total_time = 392.1
#
# step =   40000, num_env_steps =   40000, scores =  2918.854 (n= 1), score_ema =  2119.143, actor_loss = -57.513, critic_loss = 5.938, entropy_coef_loss = -1.252, entropy_coef = 0.041, rollout_stds = 0.393 ± 0.110, action_magnitude = 0.840 ± 0.238, n_updates = 30000, time = 13.0, total_time = 405.2
#
# saved experiment log 2024-10-11_12-33-24_001309~yZmsfr at experiment_logs/HalfCheetah-v4/sac/2024-10-11_12-33-24_001309~yZmsfr.json
#
# step =   41000, num_env_steps =   41000, scores =  1692.441 (n= 1), score_ema =  2012.468, actor_loss = -66.000, critic_loss = 6.186, entropy_coef_loss = 0.250, entropy_coef = 0.042, rollout_stds = 0.633 ± 0.048, action_magnitude = 0.747 ± 0.288, n_updates = 31000, time = 13.0, total_time = 418.2
#
# step =   42000, num_env_steps =   42000, scores =  2680.883 (n= 1), score_ema =  2179.571, actor_loss = -73.175, critic_loss = 8.520, entropy_coef_loss = 1.185, entropy_coef = 0.045, rollout_stds = 0.666 ± 0.048, action_magnitude = 0.802 ± 0.264, n_updates = 32000, time = 13.1, total_time = 431.3
#
# step =   43000, num_env_steps =   43000, scores =  3810.084 (n= 1), score_ema =  2587.200, actor_loss = -71.677, critic_loss = 8.024, entropy_coef_loss = 1.324, entropy_coef = 0.047, rollout_stds = 0.521 ± 0.060, action_magnitude = 0.865 ± 0.216, n_updates = 33000, time = 13.1, total_time = 444.3
#
# step =   44000, num_env_steps =   44000, scores =  1009.661 (n= 1), score_ema =  2192.815, actor_loss = -79.015, critic_loss = 8.897, entropy_coef_loss = 0.309, entropy_coef = 0.048, rollout_stds = 0.617 ± 0.074, action_magnitude = 0.707 ± 0.293, n_updates = 34000, time = 13.0, total_time = 457.3
#
# step =   45000, num_env_steps =   45000, scores =  3592.149 (n= 1), score_ema =  2542.648, actor_loss = -83.171, critic_loss = 11.140, entropy_coef_loss = 2.031, entropy_coef = 0.050, rollout_stds = 0.506 ± 0.081, action_magnitude = 0.871 ± 0.205, n_updates = 35000, time = 13.1, total_time = 470.4
#
# step =   46000, num_env_steps =   46000, scores =  3550.998 (n= 1), score_ema =  2794.736, actor_loss = -79.377, critic_loss = 7.057, entropy_coef_loss = 0.138, entropy_coef = 0.052, rollout_stds = 0.442 ± 0.074, action_magnitude = 0.863 ± 0.212, n_updates = 36000, time = 13.0, total_time = 483.4
#
# step =   47000, num_env_steps =   47000, scores =  3076.278 (n= 1), score_ema =  2865.121, actor_loss = -91.515, critic_loss = 13.760, entropy_coef_loss = -0.603, entropy_coef = 0.055, rollout_stds = 0.679 ± 0.052, action_magnitude = 0.821 ± 0.248, n_updates = 37000, time = 13.1, total_time = 496.5
#
# step =   48000, num_env_steps =   48000, scores =  3488.873 (n= 1), score_ema =  3021.059, actor_loss = -84.380, critic_loss = 10.635, entropy_coef_loss = -0.413, entropy_coef = 0.056, rollout_stds = 0.480 ± 0.128, action_magnitude = 0.854 ± 0.219, n_updates = 38000, time = 13.1, total_time = 509.6
#
# step =   49000, num_env_steps =   49000, scores =  3745.145 (n= 1), score_ema =  3202.080, actor_loss = -100.437, critic_loss = 11.461, entropy_coef_loss = 1.839, entropy_coef = 0.059, rollout_stds = 0.389 ± 0.063, action_magnitude = 0.858 ± 0.219, n_updates = 39000, time = 13.1, total_time = 522.7
#
# step =   50000, num_env_steps =   50000, scores =  4187.926 (n= 1), score_ema =  3448.542, actor_loss = -102.180, critic_loss = 12.852, entropy_coef_loss = -1.132, entropy_coef = 0.062, rollout_stds = 0.436 ± 0.101, action_magnitude = 0.875 ± 0.199, n_updates = 40000, time = 13.1, total_time = 535.7
#
# saved experiment log 2024-10-11_12-33-24_001309~yZmsfr at experiment_logs/HalfCheetah-v4/sac/2024-10-11_12-33-24_001309~yZmsfr.json
#
# step =   51000, num_env_steps =   51000, scores =  3699.026 (n= 1), score_ema =  3511.163, actor_loss = -110.527, critic_loss = 12.840, entropy_coef_loss = -0.076, entropy_coef = 0.065, rollout_stds = 0.503 ± 0.043, action_magnitude = 0.848 ± 0.224, n_updates = 41000, time = 13.7, total_time = 549.4
#
# step =   52000, num_env_steps =   52000, scores =  4184.712 (n= 1), score_ema =  3679.550, actor_loss = -106.646, critic_loss = 12.960, entropy_coef_loss = 1.130, entropy_coef = 0.068, rollout_stds = 0.454 ± 0.022, action_magnitude = 0.865 ± 0.208, n_updates = 42000, time = 13.4, total_time = 562.8
#
# step =   53000, num_env_steps =   53000, scores =  4171.696 (n= 1), score_ema =  3802.587, actor_loss = -117.915, critic_loss = 14.532, entropy_coef_loss = 0.467, entropy_coef = 0.071, rollout_stds = 0.548 ± 0.089, action_magnitude = 0.864 ± 0.207, n_updates = 43000, time = 13.1, total_time = 575.9
#
# step =   54000, num_env_steps =   54000, scores =  4496.514 (n= 1), score_ema =  3976.068, actor_loss = -117.739, critic_loss = 19.835, entropy_coef_loss = -0.420, entropy_coef = 0.076, rollout_stds = 0.481 ± 0.038, action_magnitude = 0.882 ± 0.190, n_updates = 44000, time = 13.2, total_time = 589.1
#
# step =   55000, num_env_steps =   55000, scores =  4296.364 (n= 1), score_ema =  4056.142, actor_loss = -131.206, critic_loss = 13.480, entropy_coef_loss = 1.819, entropy_coef = 0.079, rollout_stds = 0.500 ± 0.032, action_magnitude = 0.873 ± 0.196, n_updates = 45000, time = 13.2, total_time = 602.4
#
# step =   56000, num_env_steps =   56000, scores =  4338.190 (n= 1), score_ema =  4126.654, actor_loss = -135.633, critic_loss = 10.600, entropy_coef_loss = 1.691, entropy_coef = 0.084, rollout_stds = 0.483 ± 0.059, action_magnitude = 0.873 ± 0.195, n_updates = 46000, time = 13.2, total_time = 615.6
#
# step =   57000, num_env_steps =   57000, scores =  4611.655 (n= 1), score_ema =  4247.904, actor_loss = -124.592, critic_loss = 19.387, entropy_coef_loss = -1.128, entropy_coef = 0.088, rollout_stds = 0.403 ± 0.069, action_magnitude = 0.881 ± 0.187, n_updates = 47000, time = 13.2, total_time = 628.8
#
# step =   58000, num_env_steps =   58000, scores =  4574.769 (n= 1), score_ema =  4329.621, actor_loss = -135.653, critic_loss = 26.891, entropy_coef_loss = 0.275, entropy_coef = 0.091, rollout_stds = 0.575 ± 0.219, action_magnitude = 0.879 ± 0.192, n_updates = 48000, time = 13.2, total_time = 642.0
#
# step =   59000, num_env_steps =   59000, scores =  4382.586 (n= 1), score_ema =  4342.862, actor_loss = -147.815, critic_loss = 16.268, entropy_coef_loss = 1.890, entropy_coef = 0.095, rollout_stds = 0.488 ± 0.039, action_magnitude = 0.871 ± 0.198, n_updates = 49000, time = 13.2, total_time = 655.2
#
# step =   60000, num_env_steps =   60000, scores =  4576.278 (n= 1), score_ema =  4401.216, actor_loss = -146.342, critic_loss = 12.377, entropy_coef_loss = 0.251, entropy_coef = 0.098, rollout_stds = 0.435 ± 0.072, action_magnitude = 0.876 ± 0.193, n_updates = 50000, time = 13.2, total_time = 668.4
#
# saved experiment log 2024-10-11_12-33-24_001309~yZmsfr at experiment_logs/HalfCheetah-v4/sac/2024-10-11_12-33-24_001309~yZmsfr.json
#
# step =   61000, num_env_steps =   61000, scores =  4819.936 (n= 1), score_ema =  4505.896, actor_loss = -143.745, critic_loss = 15.543, entropy_coef_loss = 0.744, entropy_coef = 0.100, rollout_stds = 0.491 ± 0.039, action_magnitude = 0.890 ± 0.172, n_updates = 51000, time = 13.2, total_time = 681.7
#
# step =   62000, num_env_steps =   62000, scores =  4598.848 (n= 1), score_ema =  4529.134, actor_loss = -148.556, critic_loss = 14.535, entropy_coef_loss = -0.226, entropy_coef = 0.104, rollout_stds = 0.446 ± 0.078, action_magnitude = 0.877 ± 0.186, n_updates = 52000, time = 13.2, total_time = 694.9
#
# step =   63000, num_env_steps =   63000, scores =  4768.834 (n= 1), score_ema =  4589.059, actor_loss = -148.944, critic_loss = 20.989, entropy_coef_loss = -0.077, entropy_coef = 0.104, rollout_stds = 0.473 ± 0.038, action_magnitude = 0.880 ± 0.182, n_updates = 53000, time = 13.2, total_time = 708.1
#
# step =   64000, num_env_steps =   64000, scores =  4907.177 (n= 1), score_ema =  4668.589, actor_loss = -155.181, critic_loss = 21.263, entropy_coef_loss = -0.649, entropy_coef = 0.107, rollout_stds = 0.480 ± 0.042, action_magnitude = 0.881 ± 0.186, n_updates = 54000, time = 13.2, total_time = 721.3
#
# step =   65000, num_env_steps =   65000, scores =  4748.615 (n= 1), score_ema =  4688.595, actor_loss = -164.911, critic_loss = 31.842, entropy_coef_loss = 0.471, entropy_coef = 0.109, rollout_stds = 0.507 ± 0.030, action_magnitude = 0.871 ± 0.194, n_updates = 55000, time = 13.1, total_time = 734.4
#
# step =   66000, num_env_steps =   66000, scores =  5021.427 (n= 1), score_ema =  4771.803, actor_loss = -174.636, critic_loss = 16.199, entropy_coef_loss = 1.084, entropy_coef = 0.112, rollout_stds = 0.416 ± 0.055, action_magnitude = 0.881 ± 0.179, n_updates = 56000, time = 13.1, total_time = 747.5
#
# step =   67000, num_env_steps =   67000, scores =  4969.179 (n= 1), score_ema =  4821.147, actor_loss = -172.126, critic_loss = 15.596, entropy_coef_loss = 0.717, entropy_coef = 0.113, rollout_stds = 0.380 ± 0.120, action_magnitude = 0.867 ± 0.198, n_updates = 57000, time = 13.1, total_time = 760.6
#
# step =   68000, num_env_steps =   68000, scores =  5027.928 (n= 1), score_ema =  4872.842, actor_loss = -156.551, critic_loss = 13.359, entropy_coef_loss = -1.148, entropy_coef = 0.115, rollout_stds = 0.432 ± 0.111, action_magnitude = 0.870 ± 0.193, n_updates = 58000, time = 13.2, total_time = 773.8
#
# step =   69000, num_env_steps =   69000, scores =  4935.312 (n= 1), score_ema =  4888.460, actor_loss = -187.744, critic_loss = 16.394, entropy_coef_loss = 1.504, entropy_coef = 0.119, rollout_stds = 0.394 ± 0.127, action_magnitude = 0.872 ± 0.192, n_updates = 59000, time = 13.2, total_time = 787.0
#
# step =   70000, num_env_steps =   70000, scores =  4831.448 (n= 1), score_ema =  4874.207, actor_loss = -179.605, critic_loss = 14.000, entropy_coef_loss = 0.150, entropy_coef = 0.120, rollout_stds = 0.407 ± 0.074, action_magnitude = 0.859 ± 0.205, n_updates = 60000, time = 13.5, total_time = 800.4
#
# saved experiment log 2024-10-11_12-33-24_001309~yZmsfr at experiment_logs/HalfCheetah-v4/sac/2024-10-11_12-33-24_001309~yZmsfr.json
#
# step =   71000, num_env_steps =   71000, scores =  5194.427 (n= 1), score_ema =  4954.262, actor_loss = -185.439, critic_loss = 25.646, entropy_coef_loss = 0.366, entropy_coef = 0.122, rollout_stds = 0.468 ± 0.081, action_magnitude = 0.874 ± 0.189, n_updates = 61000, time = 13.4, total_time = 813.9
#
# step =   72000, num_env_steps =   72000, scores =  5248.133 (n= 1), score_ema =  5027.730, actor_loss = -184.724, critic_loss = 9.661, entropy_coef_loss = -0.944, entropy_coef = 0.127, rollout_stds = 0.490 ± 0.037, action_magnitude = 0.877 ± 0.183, n_updates = 62000, time = 13.5, total_time = 827.4
#
# step =   73000, num_env_steps =   73000, scores =  5024.077 (n= 1), score_ema =  5026.817, actor_loss = -191.634, critic_loss = 23.116, entropy_coef_loss = -0.199, entropy_coef = 0.128, rollout_stds = 0.511 ± 0.029, action_magnitude = 0.866 ± 0.193, n_updates = 63000, time = 13.6, total_time = 840.9
#
# step =   74000, num_env_steps =   74000, scores =  5001.733 (n= 1), score_ema =  5020.546, actor_loss = -188.675, critic_loss = 21.932, entropy_coef_loss = -0.323, entropy_coef = 0.127, rollout_stds = 0.491 ± 0.046, action_magnitude = 0.863 ± 0.199, n_updates = 64000, time = 13.5, total_time = 854.4
#
# step =   75000, num_env_steps =   75000, scores =  5070.027 (n= 1), score_ema =  5032.916, actor_loss = -201.394, critic_loss = 15.649, entropy_coef_loss = 0.254, entropy_coef = 0.131, rollout_stds = 0.430 ± 0.074, action_magnitude = 0.863 ± 0.198, n_updates = 65000, time = 13.6, total_time = 868.0
#
# step =   76000, num_env_steps =   76000, scores =  5091.858 (n= 1), score_ema =  5047.652, actor_loss = -206.620, critic_loss = 15.062, entropy_coef_loss = 1.437, entropy_coef = 0.134, rollout_stds = 0.499 ± 0.068, action_magnitude = 0.869 ± 0.193, n_updates = 66000, time = 13.4, total_time = 881.4
#
# step =   77000, num_env_steps =   77000, scores =  4807.699 (n= 1), score_ema =  4987.663, actor_loss = -199.260, critic_loss = 13.815, entropy_coef_loss = -0.379, entropy_coef = 0.136, rollout_stds = 0.482 ± 0.055, action_magnitude = 0.852 ± 0.212, n_updates = 67000, time = 13.1, total_time = 894.5
#
# step =   78000, num_env_steps =   78000, scores =  5214.055 (n= 1), score_ema =  5044.261, actor_loss = -192.754, critic_loss = 11.813, entropy_coef_loss = -1.195, entropy_coef = 0.137, rollout_stds = 0.424 ± 0.098, action_magnitude = 0.863 ± 0.199, n_updates = 68000, time = 13.1, total_time = 907.6
#
# step =   79000, num_env_steps =   79000, scores =  5167.597 (n= 1), score_ema =  5075.095, actor_loss = -200.831, critic_loss = 15.227, entropy_coef_loss = -0.233, entropy_coef = 0.142, rollout_stds = 0.508 ± 0.047, action_magnitude = 0.864 ± 0.200, n_updates = 69000, time = 13.1, total_time = 920.7
#
# step =   80000, num_env_steps =   80000, scores =  5256.236 (n= 1), score_ema =  5120.381, actor_loss = -211.645, critic_loss = 10.848, entropy_coef_loss = -0.041, entropy_coef = 0.142, rollout_stds = 0.452 ± 0.079, action_magnitude = 0.866 ± 0.195, n_updates = 70000, time = 13.1, total_time = 933.7
#
# saved experiment log 2024-10-11_12-33-24_001309~yZmsfr at experiment_logs/HalfCheetah-v4/sac/2024-10-11_12-33-24_001309~yZmsfr.json
#
# step =   81000, num_env_steps =   81000, scores =  5366.518 (n= 1), score_ema =  5181.915, actor_loss = -204.934, critic_loss = 10.751, entropy_coef_loss = -1.174, entropy_coef = 0.142, rollout_stds = 0.503 ± 0.028, action_magnitude = 0.872 ± 0.188, n_updates = 71000, time = 13.1, total_time = 946.9
#
# step =   82000, num_env_steps =   82000, scores =  5315.252 (n= 1), score_ema =  5215.249, actor_loss = -212.115, critic_loss = 16.842, entropy_coef_loss = -0.467, entropy_coef = 0.144, rollout_stds = 0.397 ± 0.130, action_magnitude = 0.867 ± 0.194, n_updates = 72000, time = 13.1, total_time = 960.0
#
# step =   83000, num_env_steps =   83000, scores =  5049.225 (n= 1), score_ema =  5173.743, actor_loss = -222.614, critic_loss = 16.138, entropy_coef_loss = 0.708, entropy_coef = 0.145, rollout_stds = 0.406 ± 0.114, action_magnitude = 0.850 ± 0.208, n_updates = 73000, time = 13.1, total_time = 973.0
#
# step =   84000, num_env_steps =   84000, scores =  5262.110 (n= 1), score_ema =  5195.835, actor_loss = -230.510, critic_loss = 13.829, entropy_coef_loss = 0.264, entropy_coef = 0.148, rollout_stds = 0.396 ± 0.133, action_magnitude = 0.858 ± 0.201, n_updates = 74000, time = 13.1, total_time = 986.1
#
# step =   85000, num_env_steps =   85000, scores =  4945.826 (n= 1), score_ema =  5133.333, actor_loss = -214.731, critic_loss = 13.298, entropy_coef_loss = 0.372, entropy_coef = 0.148, rollout_stds = 0.506 ± 0.027, action_magnitude = 0.849 ± 0.210, n_updates = 75000, time = 13.1, total_time = 999.2
#
# step =   86000, num_env_steps =   86000, scores =  5133.819 (n= 1), score_ema =  5133.454, actor_loss = -226.541, critic_loss = 22.258, entropy_coef_loss = 0.732, entropy_coef = 0.152, rollout_stds = 0.475 ± 0.073, action_magnitude = 0.860 ± 0.194, n_updates = 76000, time = 13.1, total_time = 1012.3
#
# step =   87000, num_env_steps =   87000, scores =  5239.741 (n= 1), score_ema =  5160.026, actor_loss = -222.726, critic_loss = 12.020, entropy_coef_loss = -0.666, entropy_coef = 0.152, rollout_stds = 0.492 ± 0.053, action_magnitude = 0.860 ± 0.195, n_updates = 77000, time = 13.1, total_time = 1025.4
#
# step =   88000, num_env_steps =   88000, scores =  5283.127 (n= 1), score_ema =  5190.801, actor_loss = -233.322, critic_loss = 15.557, entropy_coef_loss = 0.513, entropy_coef = 0.154, rollout_stds = 0.414 ± 0.129, action_magnitude = 0.862 ± 0.194, n_updates = 78000, time = 13.1, total_time = 1038.5
#
# step =   89000, num_env_steps =   89000, scores =  5223.476 (n= 1), score_ema =  5198.970, actor_loss = -240.120, critic_loss = 13.771, entropy_coef_loss = 0.590, entropy_coef = 0.155, rollout_stds = 0.499 ± 0.041, action_magnitude = 0.854 ± 0.200, n_updates = 79000, time = 13.1, total_time = 1051.5
#
# step =   90000, num_env_steps =   90000, scores =  5430.916 (n= 1), score_ema =  5256.956, actor_loss = -235.996, critic_loss = 13.356, entropy_coef_loss = -0.508, entropy_coef = 0.158, rollout_stds = 0.509 ± 0.038, action_magnitude = 0.862 ± 0.192, n_updates = 80000, time = 13.1, total_time = 1064.6
#
# saved experiment log 2024-10-11_12-33-24_001309~yZmsfr at experiment_logs/HalfCheetah-v4/sac/2024-10-11_12-33-24_001309~yZmsfr.json
#
# step =   91000, num_env_steps =   91000, scores =  5245.725 (n= 1), score_ema =  5254.149, actor_loss = -238.613, critic_loss = 9.092, entropy_coef_loss = -0.000, entropy_coef = 0.158, rollout_stds = 0.464 ± 0.041, action_magnitude = 0.856 ± 0.196, n_updates = 81000, time = 13.1, total_time = 1077.7
#
# step =   92000, num_env_steps =   92000, scores =  5271.451 (n= 1), score_ema =  5258.474, actor_loss = -241.986, critic_loss = 16.406, entropy_coef_loss = 0.353, entropy_coef = 0.159, rollout_stds = 0.453 ± 0.086, action_magnitude = 0.857 ± 0.196, n_updates = 82000, time = 13.1, total_time = 1090.8
#
# step =   93000, num_env_steps =   93000, scores =  5403.562 (n= 1), score_ema =  5294.746, actor_loss = -243.387, critic_loss = 10.551, entropy_coef_loss = 0.695, entropy_coef = 0.160, rollout_stds = 0.519 ± 0.027, action_magnitude = 0.856 ± 0.198, n_updates = 83000, time = 13.1, total_time = 1103.9
#
# step =   94000, num_env_steps =   94000, scores =  5138.466 (n= 1), score_ema =  5255.676, actor_loss = -229.293, critic_loss = 12.712, entropy_coef_loss = -0.840, entropy_coef = 0.159, rollout_stds = 0.408 ± 0.131, action_magnitude = 0.847 ± 0.204, n_updates = 84000, time = 13.1, total_time = 1117.0
#
# step =   95000, num_env_steps =   95000, scores =  5468.385 (n= 1), score_ema =  5308.853, actor_loss = -220.877, critic_loss = 12.688, entropy_coef_loss = -1.313, entropy_coef = 0.164, rollout_stds = 0.477 ± 0.027, action_magnitude = 0.856 ± 0.197, n_updates = 85000, time = 13.1, total_time = 1130.1
#
# step =   96000, num_env_steps =   96000, scores =  5452.538 (n= 1), score_ema =  5344.774, actor_loss = -240.342, critic_loss = 11.135, entropy_coef_loss = 0.009, entropy_coef = 0.164, rollout_stds = 0.472 ± 0.079, action_magnitude = 0.856 ± 0.197, n_updates = 86000, time = 13.3, total_time = 1143.4
#
# step =   97000, num_env_steps =   97000, scores =  5473.219 (n= 1), score_ema =  5376.886, actor_loss = -242.564, critic_loss = 15.772, entropy_coef_loss = 0.488, entropy_coef = 0.165, rollout_stds = 0.484 ± 0.040, action_magnitude = 0.853 ± 0.199, n_updates = 87000, time = 13.2, total_time = 1156.6
#
# step =   98000, num_env_steps =   98000, scores =  5308.265 (n= 1), score_ema =  5359.730, actor_loss = -248.646, critic_loss = 9.443, entropy_coef_loss = 0.207, entropy_coef = 0.164, rollout_stds = 0.510 ± 0.025, action_magnitude = 0.842 ± 0.213, n_updates = 88000, time = 13.1, total_time = 1169.7
#
# step =   99000, num_env_steps =   99000, scores =  5353.358 (n= 1), score_ema =  5358.137, actor_loss = -252.038, critic_loss = 11.205, entropy_coef_loss = 0.753, entropy_coef = 0.166, rollout_stds = 0.383 ± 0.130, action_magnitude = 0.844 ± 0.210, n_updates = 89000, time = 13.1, total_time = 1182.8
#
# step =  100000, num_env_steps =  100000, scores =  5440.762 (n= 1), score_ema =  5378.794, actor_loss = -253.351, critic_loss = 9.289, entropy_coef_loss = -0.444, entropy_coef = 0.166, rollout_stds = 0.380 ± 0.125, action_magnitude = 0.844 ± 0.209, n_updates = 90000, time = 13.1, total_time = 1195.9
#
# saved experiment log 2024-10-11_12-33-24_001309~yZmsfr at experiment_logs/HalfCheetah-v4/sac/2024-10-11_12-33-24_001309~yZmsfr.json
#
# step =  101000, num_env_steps =  101000, scores =  5418.602 (n= 1), score_ema =  5388.746, actor_loss = -248.127, critic_loss = 9.077, entropy_coef_loss = -0.779, entropy_coef = 0.168, rollout_stds = 0.512 ± 0.021, action_magnitude = 0.843 ± 0.208, n_updates = 91000, time = 13.1, total_time = 1209.0
#
# step =  102000, num_env_steps =  102000, scores =  5191.719 (n= 1), score_ema =  5339.489, actor_loss = -262.142, critic_loss = 11.736, entropy_coef_loss = 0.567, entropy_coef = 0.171, rollout_stds = 0.477 ± 0.054, action_magnitude = 0.835 ± 0.216, n_updates = 92000, time = 13.1, total_time = 1222.1
#
# step =  103000, num_env_steps =  103000, scores =  5676.956 (n= 1), score_ema =  5423.856, actor_loss = -246.787, critic_loss = 12.387, entropy_coef_loss = -0.192, entropy_coef = 0.174, rollout_stds = 0.504 ± 0.074, action_magnitude = 0.846 ± 0.209, n_updates = 93000, time = 13.1, total_time = 1235.2
#
# step =  104000, num_env_steps =  104000, scores =  5119.548 (n= 1), score_ema =  5347.779, actor_loss = -256.352, critic_loss = 17.642, entropy_coef_loss = 0.700, entropy_coef = 0.173, rollout_stds = 0.386 ± 0.157, action_magnitude = 0.832 ± 0.222, n_updates = 94000, time = 13.1, total_time = 1248.2
#
# step =  105000, num_env_steps =  105000, scores =  5723.596 (n= 1), score_ema =  5441.733, actor_loss = -248.684, critic_loss = 11.376, entropy_coef_loss = -0.222, entropy_coef = 0.176, rollout_stds = 0.487 ± 0.033, action_magnitude = 0.846 ± 0.208, n_updates = 95000, time = 13.1, total_time = 1261.3
#
# step =  106000, num_env_steps =  106000, scores =  5446.070 (n= 1), score_ema =  5442.817, actor_loss = -263.400, critic_loss = 11.696, entropy_coef_loss = 0.272, entropy_coef = 0.174, rollout_stds = 0.515 ± 0.033, action_magnitude = 0.837 ± 0.214, n_updates = 96000, time = 13.1, total_time = 1274.4
#
# step =  107000, num_env_steps =  107000, scores =  5516.600 (n= 1), score_ema =  5461.263, actor_loss = -270.460, critic_loss = 20.134, entropy_coef_loss = 0.746, entropy_coef = 0.174, rollout_stds = 0.484 ± 0.083, action_magnitude = 0.837 ± 0.216, n_updates = 97000, time = 13.1, total_time = 1287.5
#
# step =  108000, num_env_steps =  108000, scores =  5585.394 (n= 1), score_ema =  5492.296, actor_loss = -261.442, critic_loss = 10.838, entropy_coef_loss = -0.132, entropy_coef = 0.177, rollout_stds = 0.485 ± 0.064, action_magnitude = 0.842 ± 0.211, n_updates = 98000, time = 13.1, total_time = 1300.6
#
# step =  109000, num_env_steps =  109000, scores =  5367.847 (n= 1), score_ema =  5461.184, actor_loss = -272.708, critic_loss = 12.179, entropy_coef_loss = 0.214, entropy_coef = 0.179, rollout_stds = 0.481 ± 0.026, action_magnitude = 0.833 ± 0.218, n_updates = 99000, time = 13.1, total_time = 1313.7
#
# step =  110000, num_env_steps =  110000, scores =  5569.218 (n= 1), score_ema =  5488.192, actor_loss = -269.120, critic_loss = 16.277, entropy_coef_loss = -0.240, entropy_coef = 0.175, rollout_stds = 0.506 ± 0.022, action_magnitude = 0.836 ± 0.218, n_updates = 100000, time = 13.1, total_time = 1326.8
#
# saved experiment log 2024-10-11_12-33-24_001309~yZmsfr at experiment_logs/HalfCheetah-v4/sac/2024-10-11_12-33-24_001309~yZmsfr.json
#
# step =  111000, num_env_steps =  111000, scores =  5631.469 (n= 1), score_ema =  5524.011, actor_loss = -274.695, critic_loss = 14.954, entropy_coef_loss = 0.458, entropy_coef = 0.178, rollout_stds = 0.386 ± 0.130, action_magnitude = 0.840 ± 0.212, n_updates = 101000, time = 13.1, total_time = 1339.9
#
# step =  112000, num_env_steps =  112000, scores =  5698.350 (n= 1), score_ema =  5567.596, actor_loss = -273.450, critic_loss = 30.167, entropy_coef_loss = 0.657, entropy_coef = 0.178, rollout_stds = 0.486 ± 0.082, action_magnitude = 0.830 ± 0.227, n_updates = 102000, time = 13.1, total_time = 1352.9
#
# step =  113000, num_env_steps =  113000, scores =  5618.990 (n= 1), score_ema =  5580.445, actor_loss = -278.208, critic_loss = 11.372, entropy_coef_loss = 0.380, entropy_coef = 0.178, rollout_stds = 0.492 ± 0.070, action_magnitude = 0.831 ± 0.223, n_updates = 103000, time = 13.1, total_time = 1366.1
#
# step =  114000, num_env_steps =  114000, scores =  5583.822 (n= 1), score_ema =  5581.289, actor_loss = -270.569, critic_loss = 18.013, entropy_coef_loss = 0.786, entropy_coef = 0.180, rollout_stds = 0.505 ± 0.041, action_magnitude = 0.827 ± 0.226, n_updates = 104000, time = 13.1, total_time = 1379.1
#
# step =  115000, num_env_steps =  115000, scores =  5891.890 (n= 1), score_ema =  5658.939, actor_loss = -283.968, critic_loss = 10.027, entropy_coef_loss = 1.493, entropy_coef = 0.182, rollout_stds = 0.526 ± 0.048, action_magnitude = 0.839 ± 0.211, n_updates = 105000, time = 13.1, total_time = 1392.2
#
# step =  116000, num_env_steps =  116000, scores =  5524.207 (n= 1), score_ema =  5625.256, actor_loss = -272.469, critic_loss = 8.523, entropy_coef_loss = 0.086, entropy_coef = 0.181, rollout_stds = 0.484 ± 0.057, action_magnitude = 0.832 ± 0.217, n_updates = 106000, time = 13.1, total_time = 1405.3
#
# step =  117000, num_env_steps =  117000, scores =  5787.011 (n= 1), score_ema =  5665.695, actor_loss = -272.007, critic_loss = 12.824, entropy_coef_loss = -0.253, entropy_coef = 0.183, rollout_stds = 0.391 ± 0.143, action_magnitude = 0.830 ± 0.223, n_updates = 107000, time = 13.1, total_time = 1418.4
#
# step =  118000, num_env_steps =  118000, scores =  5681.600 (n= 1), score_ema =  5669.671, actor_loss = -276.287, critic_loss = 9.842, entropy_coef_loss = 0.416, entropy_coef = 0.184, rollout_stds = 0.476 ± 0.055, action_magnitude = 0.834 ± 0.219, n_updates = 108000, time = 13.1, total_time = 1431.5
#
# step =  119000, num_env_steps =  119000, scores =  5611.686 (n= 1), score_ema =  5655.175, actor_loss = -278.119, critic_loss = 10.336, entropy_coef_loss = 0.544, entropy_coef = 0.185, rollout_stds = 0.433 ± 0.066, action_magnitude = 0.820 ± 0.231, n_updates = 109000, time = 13.1, total_time = 1444.6
#
# step =  120000, num_env_steps =  120000, scores =  5780.110 (n= 1), score_ema =  5686.409, actor_loss = -282.786, critic_loss = 7.988, entropy_coef_loss = -0.004, entropy_coef = 0.184, rollout_stds = 0.480 ± 0.066, action_magnitude = 0.824 ± 0.228, n_updates = 110000, time = 13.1, total_time = 1457.7
#
# saved experiment log 2024-10-11_12-33-24_001309~yZmsfr at experiment_logs/HalfCheetah-v4/sac/2024-10-11_12-33-24_001309~yZmsfr.json
#
# step =  121000, num_env_steps =  121000, scores =  5818.235 (n= 1), score_ema =  5719.365, actor_loss = -266.434, critic_loss = 9.850, entropy_coef_loss = -0.109, entropy_coef = 0.185, rollout_stds = 0.431 ± 0.130, action_magnitude = 0.827 ± 0.224, n_updates = 111000, time = 13.1, total_time = 1470.8
#
# step =  122000, num_env_steps =  122000, scores =  5794.912 (n= 1), score_ema =  5738.252, actor_loss = -284.366, critic_loss = 10.846, entropy_coef_loss = 0.619, entropy_coef = 0.184, rollout_stds = 0.439 ± 0.052, action_magnitude = 0.822 ± 0.227, n_updates = 112000, time = 13.1, total_time = 1483.9
#
# step =  123000, num_env_steps =  123000, scores =  6010.072 (n= 1), score_ema =  5806.207, actor_loss = -279.403, critic_loss = 18.949, entropy_coef_loss = 0.437, entropy_coef = 0.185, rollout_stds = 0.383 ± 0.166, action_magnitude = 0.829 ± 0.221, n_updates = 113000, time = 13.1, total_time = 1497.0
#
# step =  124000, num_env_steps =  124000, scores =  5931.763 (n= 1), score_ema =  5837.596, actor_loss = -289.466, critic_loss = 14.807, entropy_coef_loss = 0.417, entropy_coef = 0.185, rollout_stds = 0.471 ± 0.062, action_magnitude = 0.822 ± 0.229, n_updates = 114000, time = 13.1, total_time = 1510.1
#
# step =  125000, num_env_steps =  125000, scores =  5822.398 (n= 1), score_ema =  5833.796, actor_loss = -282.409, critic_loss = 28.509, entropy_coef_loss = -0.039, entropy_coef = 0.188, rollout_stds = 0.494 ± 0.072, action_magnitude = 0.819 ± 0.230, n_updates = 115000, time = 13.1, total_time = 1523.2
#
# step =  126000, num_env_steps =  126000, scores =  5810.126 (n= 1), score_ema =  5827.879, actor_loss = -289.834, critic_loss = 7.522, entropy_coef_loss = -0.550, entropy_coef = 0.188, rollout_stds = 0.467 ± 0.040, action_magnitude = 0.824 ± 0.225, n_updates = 116000, time = 13.1, total_time = 1536.2
#
# step =  127000, num_env_steps =  127000, scores =  5875.511 (n= 1), score_ema =  5839.787, actor_loss = -294.056, critic_loss = 11.159, entropy_coef_loss = 1.046, entropy_coef = 0.190, rollout_stds = 0.374 ± 0.126, action_magnitude = 0.819 ± 0.231, n_updates = 117000, time = 13.1, total_time = 1549.3
#
# step =  128000, num_env_steps =  128000, scores =  5879.978 (n= 1), score_ema =  5849.835, actor_loss = -295.765, critic_loss = 8.896, entropy_coef_loss = 0.240, entropy_coef = 0.192, rollout_stds = 0.490 ± 0.080, action_magnitude = 0.813 ± 0.237, n_updates = 118000, time = 13.1, total_time = 1562.4
#
# step =  129000, num_env_steps =  129000, scores =  5854.267 (n= 1), score_ema =  5850.943, actor_loss = -298.721, critic_loss = 10.079, entropy_coef_loss = -0.319, entropy_coef = 0.193, rollout_stds = 0.494 ± 0.017, action_magnitude = 0.823 ± 0.223, n_updates = 119000, time = 13.1, total_time = 1575.5
#
# step =  130000, num_env_steps =  130000, scores =  5919.606 (n= 1), score_ema =  5868.109, actor_loss = -276.120, critic_loss = 10.297, entropy_coef_loss = -0.575, entropy_coef = 0.192, rollout_stds = 0.449 ± 0.050, action_magnitude = 0.818 ± 0.230, n_updates = 120000, time = 13.1, total_time = 1588.5
#
# saved experiment log 2024-10-11_12-33-24_001309~yZmsfr at experiment_logs/HalfCheetah-v4/sac/2024-10-11_12-33-24_001309~yZmsfr.json
#
# step =  131000, num_env_steps =  131000, scores =  6065.351 (n= 1), score_ema =  5917.419, actor_loss = -294.864, critic_loss = 12.778, entropy_coef_loss = 0.227, entropy_coef = 0.190, rollout_stds = 0.460 ± 0.049, action_magnitude = 0.813 ± 0.236, n_updates = 121000, time = 13.1, total_time = 1601.6
#
# step =  132000, num_env_steps =  132000, scores =  6038.099 (n= 1), score_ema =  5947.589, actor_loss = -295.162, critic_loss = 9.782, entropy_coef_loss = -0.516, entropy_coef = 0.195, rollout_stds = 0.465 ± 0.066, action_magnitude = 0.817 ± 0.231, n_updates = 122000, time = 13.1, total_time = 1614.7
#
# step =  133000, num_env_steps =  133000, scores =  5964.515 (n= 1), score_ema =  5951.821, actor_loss = -277.171, critic_loss = 11.531, entropy_coef_loss = -0.211, entropy_coef = 0.192, rollout_stds = 0.483 ± 0.024, action_magnitude = 0.816 ± 0.231, n_updates = 123000, time = 13.1, total_time = 1627.8
#
# step =  134000, num_env_steps =  134000, scores =  6022.845 (n= 1), score_ema =  5969.577, actor_loss = -300.327, critic_loss = 9.407, entropy_coef_loss = 0.235, entropy_coef = 0.192, rollout_stds = 0.475 ± 0.018, action_magnitude = 0.816 ± 0.232, n_updates = 124000, time = 13.1, total_time = 1640.8
#
# step =  135000, num_env_steps =  135000, scores =  5926.700 (n= 1), score_ema =  5958.857, actor_loss = -298.618, critic_loss = 11.724, entropy_coef_loss = 0.406, entropy_coef = 0.192, rollout_stds = 0.475 ± 0.110, action_magnitude = 0.815 ± 0.229, n_updates = 125000, time = 13.1, total_time = 1653.9
#
# step =  136000, num_env_steps =  136000, scores =  5837.245 (n= 1), score_ema =  5928.454, actor_loss = -295.722, critic_loss = 13.914, entropy_coef_loss = -0.341, entropy_coef = 0.195, rollout_stds = 0.508 ± 0.025, action_magnitude = 0.807 ± 0.241, n_updates = 126000, time = 13.1, total_time = 1667.0
#
# step =  137000, num_env_steps =  137000, scores =  6036.753 (n= 1), score_ema =  5955.529, actor_loss = -302.920, critic_loss = 8.201, entropy_coef_loss = -0.160, entropy_coef = 0.196, rollout_stds = 0.490 ± 0.034, action_magnitude = 0.812 ± 0.234, n_updates = 127000, time = 13.1, total_time = 1680.1
#
# step =  138000, num_env_steps =  138000, scores =  6125.304 (n= 1), score_ema =  5997.973, actor_loss = -307.418, critic_loss = 18.295, entropy_coef_loss = 0.495, entropy_coef = 0.196, rollout_stds = 0.533 ± 0.105, action_magnitude = 0.812 ± 0.234, n_updates = 128000, time = 13.1, total_time = 1693.2
#
# step =  139000, num_env_steps =  139000, scores =  6194.526 (n= 1), score_ema =  6047.111, actor_loss = -298.016, critic_loss = 9.962, entropy_coef_loss = -0.692, entropy_coef = 0.197, rollout_stds = 0.447 ± 0.077, action_magnitude = 0.809 ± 0.237, n_updates = 129000, time = 13.1, total_time = 1706.3
#
# step =  140000, num_env_steps =  140000, scores =  5944.287 (n= 1), score_ema =  6021.405, actor_loss = -319.940, critic_loss = 11.179, entropy_coef_loss = 0.728, entropy_coef = 0.196, rollout_stds = 0.500 ± 0.024, action_magnitude = 0.809 ± 0.234, n_updates = 130000, time = 13.1, total_time = 1719.3
#
# saved experiment log 2024-10-11_12-33-24_001309~yZmsfr at experiment_logs/HalfCheetah-v4/sac/2024-10-11_12-33-24_001309~yZmsfr.json
#
# step =  141000, num_env_steps =  141000, scores =  6136.160 (n= 1), score_ema =  6050.094, actor_loss = -320.243, critic_loss = 28.871, entropy_coef_loss = 0.457, entropy_coef = 0.200, rollout_stds = 0.445 ± 0.046, action_magnitude = 0.808 ± 0.236, n_updates = 131000, time = 13.1, total_time = 1732.4
#
# step =  142000, num_env_steps =  142000, scores =  6003.711 (n= 1), score_ema =  6038.498, actor_loss = -307.887, critic_loss = 9.582, entropy_coef_loss = -0.213, entropy_coef = 0.200, rollout_stds = 0.405 ± 0.131, action_magnitude = 0.813 ± 0.231, n_updates = 132000, time = 13.1, total_time = 1745.5
#
# step =  143000, num_env_steps =  143000, scores =  6391.718 (n= 1), score_ema =  6126.803, actor_loss = -305.251, critic_loss = 10.180, entropy_coef_loss = -0.305, entropy_coef = 0.201, rollout_stds = 0.406 ± 0.109, action_magnitude = 0.815 ± 0.231, n_updates = 133000, time = 13.1, total_time = 1758.6
#
# step =  144000, num_env_steps =  144000, scores =  6132.886 (n= 1), score_ema =  6128.324, actor_loss = -316.550, critic_loss = 10.059, entropy_coef_loss = 0.236, entropy_coef = 0.200, rollout_stds = 0.415 ± 0.077, action_magnitude = 0.812 ± 0.230, n_updates = 134000, time = 13.1, total_time = 1771.7
#
# step =  145000, num_env_steps =  145000, scores =  6187.018 (n= 1), score_ema =  6142.997, actor_loss = -326.586, critic_loss = 12.640, entropy_coef_loss = 0.176, entropy_coef = 0.203, rollout_stds = 0.542 ± 0.033, action_magnitude = 0.815 ± 0.230, n_updates = 135000, time = 13.1, total_time = 1784.8
#
# step =  146000, num_env_steps =  146000, scores =  6402.836 (n= 1), score_ema =  6207.957, actor_loss = -318.634, critic_loss = 8.798, entropy_coef_loss = 0.925, entropy_coef = 0.203, rollout_stds = 0.465 ± 0.064, action_magnitude = 0.815 ± 0.231, n_updates = 136000, time = 13.1, total_time = 1797.9
#
# step =  147000, num_env_steps =  147000, scores =  6209.341 (n= 1), score_ema =  6208.303, actor_loss = -318.393, critic_loss = 9.260, entropy_coef_loss = 0.030, entropy_coef = 0.202, rollout_stds = 0.469 ± 0.009, action_magnitude = 0.808 ± 0.236, n_updates = 137000, time = 13.1, total_time = 1811.0
#
# step =  148000, num_env_steps =  148000, scores =  6071.076 (n= 1), score_ema =  6173.996, actor_loss = -317.688, critic_loss = 11.768, entropy_coef_loss = -0.332, entropy_coef = 0.204, rollout_stds = 0.489 ± 0.041, action_magnitude = 0.810 ± 0.231, n_updates = 138000, time = 13.1, total_time = 1824.1
#
# step =  149000, num_env_steps =  149000, scores =  6357.497 (n= 1), score_ema =  6219.872, actor_loss = -321.643, critic_loss = 15.478, entropy_coef_loss = -0.484, entropy_coef = 0.205, rollout_stds = 0.470 ± 0.074, action_magnitude = 0.814 ± 0.229, n_updates = 139000, time = 13.1, total_time = 1837.2
#
# step =  150000, num_env_steps =  150000, scores =  6310.561 (n= 1), score_ema =  6242.544, actor_loss = -331.496, critic_loss = 10.228, entropy_coef_loss = 0.436, entropy_coef = 0.208, rollout_stds = 0.529 ± 0.045, action_magnitude = 0.813 ± 0.230, n_updates = 140000, time = 13.1, total_time = 1850.3
#
# saved experiment log 2024-10-11_12-33-24_001309~yZmsfr at experiment_logs/HalfCheetah-v4/sac/2024-10-11_12-33-24_001309~yZmsfr.json
#
# step =  151000, num_env_steps =  151000, scores =  6232.922 (n= 1), score_ema =  6240.138, actor_loss = -335.018, critic_loss = 25.972, entropy_coef_loss = 0.751, entropy_coef = 0.207, rollout_stds = 0.476 ± 0.103, action_magnitude = 0.810 ± 0.235, n_updates = 141000, time = 13.1, total_time = 1863.4
#
# step =  152000, num_env_steps =  152000, scores =  6309.137 (n= 1), score_ema =  6257.388, actor_loss = -319.882, critic_loss = 10.183, entropy_coef_loss = -0.035, entropy_coef = 0.207, rollout_stds = 0.378 ± 0.143, action_magnitude = 0.814 ± 0.228, n_updates = 142000, time = 13.1, total_time = 1876.5
#
# step =  153000, num_env_steps =  153000, scores =  6204.626 (n= 1), score_ema =  6244.198, actor_loss = -329.753, critic_loss = 20.195, entropy_coef_loss = 0.076, entropy_coef = 0.207, rollout_stds = 0.395 ± 0.146, action_magnitude = 0.813 ± 0.229, n_updates = 143000, time = 13.1, total_time = 1889.5
#
# step =  154000, num_env_steps =  154000, scores =  6438.205 (n= 1), score_ema =  6292.699, actor_loss = -336.888, critic_loss = 11.217, entropy_coef_loss = 0.213, entropy_coef = 0.208, rollout_stds = 0.461 ± 0.079, action_magnitude = 0.812 ± 0.230, n_updates = 144000, time = 13.1, total_time = 1902.6
#
# step =  155000, num_env_steps =  155000, scores =  6465.050 (n= 1), score_ema =  6335.787, actor_loss = -309.136, critic_loss = 10.975, entropy_coef_loss = -1.408, entropy_coef = 0.207, rollout_stds = 0.453 ± 0.044, action_magnitude = 0.812 ± 0.231, n_updates = 145000, time = 13.1, total_time = 1915.7
#
# step =  156000, num_env_steps =  156000, scores =  6213.643 (n= 1), score_ema =  6305.251, actor_loss = -328.215, critic_loss = 9.746, entropy_coef_loss = -0.038, entropy_coef = 0.210, rollout_stds = 0.364 ± 0.118, action_magnitude = 0.809 ± 0.232, n_updates = 146000, time = 13.1, total_time = 1928.8
#
# step =  157000, num_env_steps =  157000, scores =  6380.051 (n= 1), score_ema =  6323.951, actor_loss = -335.995, critic_loss = 11.125, entropy_coef_loss = 0.460, entropy_coef = 0.208, rollout_stds = 0.480 ± 0.037, action_magnitude = 0.807 ± 0.231, n_updates = 147000, time = 13.1, total_time = 1941.8
#
# step =  158000, num_env_steps =  158000, scores =  6564.328 (n= 1), score_ema =  6384.045, actor_loss = -341.062, critic_loss = 8.412, entropy_coef_loss = 0.246, entropy_coef = 0.208, rollout_stds = 0.491 ± 0.068, action_magnitude = 0.814 ± 0.226, n_updates = 148000, time = 13.1, total_time = 1954.9
#
# step =  159000, num_env_steps =  159000, scores =  6332.497 (n= 1), score_ema =  6371.158, actor_loss = -328.165, critic_loss = 12.251, entropy_coef_loss = 0.270, entropy_coef = 0.209, rollout_stds = 0.460 ± 0.054, action_magnitude = 0.807 ± 0.232, n_updates = 149000, time = 13.1, total_time = 1968.0
#
# step =  160000, num_env_steps =  160000, scores =  5843.493 (n= 1), score_ema =  6239.242, actor_loss = -338.782, critic_loss = 12.371, entropy_coef_loss = 0.326, entropy_coef = 0.211, rollout_stds = 0.409 ± 0.118, action_magnitude = 0.804 ± 0.234, n_updates = 150000, time = 13.1, total_time = 1981.0
#
# saved experiment log 2024-10-11_12-33-24_001309~yZmsfr at experiment_logs/HalfCheetah-v4/sac/2024-10-11_12-33-24_001309~yZmsfr.json
#
# ...
#
#
# step = 3574000, num_env_steps = 3574000, scores =  14039.685 (n= 1), score_ema =  14112.693, actor_loss = -1203.463, critic_loss = 29.935, entropy_coef_loss = 0.076, entropy_coef = 0.429, rollout_stds = 0.408 ± 0.160, action_magnitude = 0.732 ± 0.265, n_updates = 3564000, time = 13.2, total_time = 47601.4
#
#
# step = 3575000, num_env_steps = 3575000, scores =  14242.933 (n= 1), score_ema =  14145.253, actor_loss = -1185.301, critic_loss = 25.760, entropy_coef_loss = -0.078, entropy_coef = 0.437, rollout_stds = 0.405 ± 0.128, action_magnitude = 0.729 ± 0.269, n_updates = 3565000, time = 13.3, total_time = 47614.7
#
#
# step = 3576000, num_env_steps = 3576000, scores =  13834.501 (n= 1), score_ema =  14067.565, actor_loss = -1206.397, critic_loss = 7.784, entropy_coef_loss = -0.147, entropy_coef = 0.423, rollout_stds = 0.324 ± 0.206, action_magnitude = 0.728 ± 0.269, n_updates = 3566000, time = 13.2, total_time = 47628.0
#
#
# step = 3577000, num_env_steps = 3577000, scores =  13531.177 (n= 1), score_ema =  13933.468, actor_loss = -1197.463, critic_loss = 20.161, entropy_coef_loss = 0.128, entropy_coef = 0.429, rollout_stds = 0.552 ± 0.093, action_magnitude = 0.728 ± 0.269, n_updates = 3567000, time = 13.2, total_time = 47641.2
#
#
# step = 3578000, num_env_steps = 3578000, scores =  14287.383 (n= 1), score_ema =  14021.947, actor_loss = -1192.433, critic_loss = 21.158, entropy_coef_loss = -0.232, entropy_coef = 0.426, rollout_stds = 0.359 ± 0.187, action_magnitude = 0.730 ± 0.267, n_updates = 3568000, time = 13.3, total_time = 47654.5
#
#
# step = 3579000, num_env_steps = 3579000, scores =  13592.440 (n= 1), score_ema =  13914.570, actor_loss = -1205.782, critic_loss = 20.636, entropy_coef_loss = -0.022, entropy_coef = 0.427, rollout_stds = 0.299 ± 0.183, action_magnitude = 0.728 ± 0.267, n_updates = 3569000, time = 13.2, total_time = 47667.7
#
#
# step = 3580000, num_env_steps = 3580000, scores =  13835.941 (n= 1), score_ema =  13894.913, actor_loss = -1172.342, critic_loss = 40.291, entropy_coef_loss = 0.134, entropy_coef = 0.426, rollout_stds = 0.357 ± 0.208, action_magnitude = 0.723 ± 0.272, n_updates = 3570000, time = 13.3, total_time = 47681.0
#
# saved experiment log 2024-10-11_12-33-24_001309~yZmsfr at experiment_logs/HalfCheetah-v4/sac/2024-10-11_12-33-24_001309~yZmsfr.json
#
#
# step = 3581000, num_env_steps = 3581000, scores =  14312.049 (n= 1), score_ema =  13999.197, actor_loss = -1198.213, critic_loss = 54.569, entropy_coef_loss = 0.583, entropy_coef = 0.424, rollout_stds = 0.299 ± 0.177, action_magnitude = 0.729 ± 0.264, n_updates = 3571000, time = 13.6, total_time = 47694.6
#
#
# step = 3582000, num_env_steps = 3582000, scores =  14290.375 (n= 1), score_ema =  14071.992, actor_loss = -1200.239, critic_loss = 57.788, entropy_coef_loss = 0.206, entropy_coef = 0.415, rollout_stds = 0.574 ± 0.105, action_magnitude = 0.728 ± 0.265, n_updates = 3572000, time = 13.2, total_time = 47707.8
#
#
# step = 3583000, num_env_steps = 3583000, scores =  13787.962 (n= 1), score_ema =  14000.984, actor_loss = -1197.636, critic_loss = 14.595, entropy_coef_loss = -0.188, entropy_coef = 0.408, rollout_stds = 0.477 ± 0.109, action_magnitude = 0.723 ± 0.275, n_updates = 3573000, time = 13.2, total_time = 47721.0
#
#
# step = 3584000, num_env_steps = 3584000, scores =  13761.284 (n= 1), score_ema =  13941.059, actor_loss = -1207.558, critic_loss = 11.498, entropy_coef_loss = -0.118, entropy_coef = 0.423, rollout_stds = 0.459 ± 0.194, action_magnitude = 0.729 ± 0.270, n_updates = 3574000, time = 13.2, total_time = 47734.2
#
#
# step = 3585000, num_env_steps = 3585000, scores =  14168.085 (n= 1), score_ema =  13997.816, actor_loss = -1180.539, critic_loss = 17.175, entropy_coef_loss = -0.125, entropy_coef = 0.431, rollout_stds = 0.461 ± 0.123, action_magnitude = 0.738 ± 0.263, n_updates = 3575000, time = 13.3, total_time = 47747.5
#
#
# step = 3586000, num_env_steps = 3586000, scores =  14269.200 (n= 1), score_ema =  14065.662, actor_loss = -1213.469, critic_loss = 12.030, entropy_coef_loss = 0.301, entropy_coef = 0.434, rollout_stds = 0.396 ± 0.139, action_magnitude = 0.736 ± 0.261, n_updates = 3576000, time = 13.3, total_time = 47760.7
#
#
# step = 3587000, num_env_steps = 3587000, scores =  14240.873 (n= 1), score_ema =  14109.464, actor_loss = -1180.030, critic_loss = 108.423, entropy_coef_loss = -0.006, entropy_coef = 0.446, rollout_stds = 0.485 ± 0.078, action_magnitude = 0.731 ± 0.265, n_updates = 3577000, time = 13.3, total_time = 47774.0
#
#
# step = 3588000, num_env_steps = 3588000, scores =  14214.253 (n= 1), score_ema =  14135.662, actor_loss = -1204.570, critic_loss = 15.547, entropy_coef_loss = 0.325, entropy_coef = 0.442, rollout_stds = 0.479 ± 0.174, action_magnitude = 0.730 ± 0.262, n_updates = 3578000, time = 13.2, total_time = 47787.2
#
#
# step = 3589000, num_env_steps = 3589000, scores =  14346.388 (n= 1), score_ema =  14188.343, actor_loss = -1199.378, critic_loss = 17.647, entropy_coef_loss = -0.098, entropy_coef = 0.428, rollout_stds = 0.400 ± 0.129, action_magnitude = 0.733 ± 0.262, n_updates = 3579000, time = 13.3, total_time = 47800.5
#
#
# step = 3590000, num_env_steps = 3590000, scores =  14232.433 (n= 1), score_ema =  14199.366, actor_loss = -1208.213, critic_loss = 17.820, entropy_coef_loss = 0.138, entropy_coef = 0.431, rollout_stds = 0.376 ± 0.183, action_magnitude = 0.731 ± 0.265, n_updates = 3580000, time = 13.3, total_time = 47813.7
#
# saved experiment log 2024-10-11_12-33-24_001309~yZmsfr at experiment_logs/HalfCheetah-v4/sac/2024-10-11_12-33-24_001309~yZmsfr.json
#
#
# step = 3591000, num_env_steps = 3591000, scores =  14311.870 (n= 1), score_ema =  14227.492, actor_loss = -1195.076, critic_loss = 44.737, entropy_coef_loss = -0.180, entropy_coef = 0.425, rollout_stds = 0.407 ± 0.123, action_magnitude = 0.731 ± 0.267, n_updates = 3581000, time = 13.6, total_time = 47827.4
#
#
# step = 3592000, num_env_steps = 3592000, scores =  14185.354 (n= 1), score_ema =  14216.957, actor_loss = -1199.738, critic_loss = 20.333, entropy_coef_loss = 0.397, entropy_coef = 0.437, rollout_stds = 0.558 ± 0.126, action_magnitude = 0.731 ± 0.268, n_updates = 3582000, time = 13.3, total_time = 47840.7
#
#
# step = 3593000, num_env_steps = 3593000, scores =  14191.893 (n= 1), score_ema =  14210.691, actor_loss = -1203.988, critic_loss = 100.678, entropy_coef_loss = 0.011, entropy_coef = 0.447, rollout_stds = 0.557 ± 0.119, action_magnitude = 0.729 ± 0.268, n_updates = 3583000, time = 13.2, total_time = 47853.8
#
#
# step = 3594000, num_env_steps = 3594000, scores =  14124.632 (n= 1), score_ema =  14189.177, actor_loss = -1184.902, critic_loss = 25.178, entropy_coef_loss = 0.034, entropy_coef = 0.449, rollout_stds = 0.346 ± 0.173, action_magnitude = 0.729 ± 0.269, n_updates = 3584000, time = 13.2, total_time = 47867.0
#
#
# step = 3595000, num_env_steps = 3595000, scores =  14267.893 (n= 1), score_ema =  14208.856, actor_loss = -1187.934, critic_loss = 36.149, entropy_coef_loss = -0.171, entropy_coef = 0.432, rollout_stds = 0.566 ± 0.092, action_magnitude = 0.731 ± 0.265, n_updates = 3585000, time = 13.3, total_time = 47880.3
#
#
# step = 3596000, num_env_steps = 3596000, scores =  13739.078 (n= 1), score_ema =  14091.411, actor_loss = -1195.718, critic_loss = 28.149, entropy_coef_loss = -0.352, entropy_coef = 0.421, rollout_stds = 0.400 ± 0.148, action_magnitude = 0.730 ± 0.269, n_updates = 3586000, time = 13.3, total_time = 47893.6
#
#
# step = 3597000, num_env_steps = 3597000, scores =  14424.830 (n= 1), score_ema =  14174.766, actor_loss = -1180.396, critic_loss = 14.395, entropy_coef_loss = 0.022, entropy_coef = 0.434, rollout_stds = 0.385 ± 0.169, action_magnitude = 0.732 ± 0.267, n_updates = 3587000, time = 13.3, total_time = 47906.8
#
#
# step = 3598000, num_env_steps = 3598000, scores =  14278.004 (n= 1), score_ema =  14200.576, actor_loss = -1187.962, critic_loss = 31.087, entropy_coef_loss = -0.232, entropy_coef = 0.431, rollout_stds = 0.312 ± 0.163, action_magnitude = 0.729 ± 0.265, n_updates = 3588000, time = 13.2, total_time = 47920.0
#
#
# step = 3599000, num_env_steps = 3599000, scores =  13762.975 (n= 1), score_ema =  14091.175, actor_loss = -1198.731, critic_loss = 18.082, entropy_coef_loss = -0.167, entropy_coef = 0.440, rollout_stds = 0.407 ± 0.116, action_magnitude = 0.728 ± 0.268, n_updates = 3589000, time = 13.3, total_time = 47933.3
#
#
# step = 3600000, num_env_steps = 3600000, scores =  14184.926 (n= 1), score_ema =  14114.613, actor_loss = -1176.930, critic_loss = 11.525, entropy_coef_loss = -0.252, entropy_coef = 0.435, rollout_stds = 0.548 ± 0.090, action_magnitude = 0.731 ± 0.263, n_updates = 3590000, time = 13.3, total_time = 47946.6
#
# saved experiment log 2024-10-11_12-33-24_001309~yZmsfr at experiment_logs/HalfCheetah-v4/sac/2024-10-11_12-33-24_001309~yZmsfr.json
#
#
# step = 3601000, num_env_steps = 3601000, scores =  14411.533 (n= 1), score_ema =  14188.843, actor_loss = -1215.027, critic_loss = 14.635, entropy_coef_loss = 0.042, entropy_coef = 0.442, rollout_stds = 0.339 ± 0.150, action_magnitude = 0.732 ± 0.266, n_updates = 3591000, time = 13.6, total_time = 47960.2
#
#
# step = 3602000, num_env_steps = 3602000, scores =  14016.902 (n= 1), score_ema =  14145.858, actor_loss = -1199.989, critic_loss = 8.426, entropy_coef_loss = -0.156, entropy_coef = 0.447, rollout_stds = 0.565 ± 0.129, action_magnitude = 0.731 ± 0.264, n_updates = 3592000, time = 13.2, total_time = 47973.5
#
#
# step = 3603000, num_env_steps = 3603000, scores =  14327.882 (n= 1), score_ema =  14191.364, actor_loss = -1190.433, critic_loss = 12.369, entropy_coef_loss = 0.296, entropy_coef = 0.432, rollout_stds = 0.569 ± 0.095, action_magnitude = 0.728 ± 0.268, n_updates = 3593000, time = 13.2, total_time = 47986.7
#
#
# step = 3604000, num_env_steps = 3604000, scores =  14231.915 (n= 1), score_ema =  14201.502, actor_loss = -1192.119, critic_loss = 20.420, entropy_coef_loss = 0.160, entropy_coef = 0.442, rollout_stds = 0.420 ± 0.074, action_magnitude = 0.729 ± 0.268, n_updates = 3594000, time = 13.2, total_time = 47999.9
#
#
# step = 3605000, num_env_steps = 3605000, scores =  13903.200 (n= 1), score_ema =  14126.926, actor_loss = -1190.462, critic_loss = 18.062, entropy_coef_loss = 0.024, entropy_coef = 0.439, rollout_stds = 0.551 ± 0.091, action_magnitude = 0.726 ± 0.269, n_updates = 3595000, time = 13.3, total_time = 48013.1
#
#
# step = 3606000, num_env_steps = 3606000, scores =  13825.019 (n= 1), score_ema =  14051.449, actor_loss = -1212.250, critic_loss = 112.650, entropy_coef_loss = -0.084, entropy_coef = 0.429, rollout_stds = 0.368 ± 0.234, action_magnitude = 0.726 ± 0.266, n_updates = 3596000, time = 13.3, total_time = 48026.4
#
#
# step = 3607000, num_env_steps = 3607000, scores =  13721.832 (n= 1), score_ema =  13969.045, actor_loss = -1194.783, critic_loss = 23.796, entropy_coef_loss = -0.031, entropy_coef = 0.427, rollout_stds = 0.326 ± 0.209, action_magnitude = 0.722 ± 0.272, n_updates = 3597000, time = 13.3, total_time = 48039.6
#
#
# step = 3608000, num_env_steps = 3608000, scores =  14230.299 (n= 1), score_ema =  14034.358, actor_loss = -1204.002, critic_loss = 7.766, entropy_coef_loss = 0.024, entropy_coef = 0.427, rollout_stds = 0.478 ± 0.129, action_magnitude = 0.729 ± 0.268, n_updates = 3598000, time = 13.2, total_time = 48052.9
#
#
# step = 3609000, num_env_steps = 3609000, scores =  14336.922 (n= 1), score_ema =  14109.999, actor_loss = -1199.265, critic_loss = 9.962, entropy_coef_loss = -0.209, entropy_coef = 0.424, rollout_stds = 0.458 ± 0.138, action_magnitude = 0.733 ± 0.266, n_updates = 3599000, time = 13.3, total_time = 48066.2
#
#
# step = 3610000, num_env_steps = 3610000, scores =  14150.757 (n= 1), score_ema =  14120.189, actor_loss = -1212.644, critic_loss = 20.744, entropy_coef_loss = 0.181, entropy_coef = 0.430, rollout_stds = 0.373 ± 0.158, action_magnitude = 0.735 ± 0.267, n_updates = 3600000, time = 13.3, total_time = 48079.4
#
# saved experiment log 2024-10-11_12-33-24_001309~yZmsfr at experiment_logs/HalfCheetah-v4/sac/2024-10-11_12-33-24_001309~yZmsfr.json
#
#
# step = 3611000, num_env_steps = 3611000, scores =  14212.402 (n= 1), score_ema =  14143.242, actor_loss = -1210.918, critic_loss = 11.515, entropy_coef_loss = 0.050, entropy_coef = 0.427, rollout_stds = 0.556 ± 0.099, action_magnitude = 0.730 ± 0.266, n_updates = 3601000, time = 13.6, total_time = 48093.1
#
#
# step = 3612000, num_env_steps = 3612000, scores =  14052.685 (n= 1), score_ema =  14120.603, actor_loss = -1182.206, critic_loss = 11.971, entropy_coef_loss = -0.397, entropy_coef = 0.435, rollout_stds = 0.332 ± 0.190, action_magnitude = 0.734 ± 0.265, n_updates = 3602000, time = 13.3, total_time = 48106.3
#
#
# step = 3613000, num_env_steps = 3613000, scores =  14249.303 (n= 1), score_ema =  14152.778, actor_loss = -1210.486, critic_loss = 29.943, entropy_coef_loss = -0.009, entropy_coef = 0.425, rollout_stds = 0.443 ± 0.110, action_magnitude = 0.736 ± 0.262, n_updates = 3603000, time = 13.2, total_time = 48119.5
#
#
# step = 3614000, num_env_steps = 3614000, scores =  14400.572 (n= 1), score_ema =  14214.726, actor_loss = -1206.788, critic_loss = 12.437, entropy_coef_loss = -0.091, entropy_coef = 0.436, rollout_stds = 0.576 ± 0.134, action_magnitude = 0.730 ± 0.264, n_updates = 3604000, time = 13.2, total_time = 48132.7
#
#
# step = 3615000, num_env_steps = 3615000, scores =  14333.091 (n= 1), score_ema =  14244.318, actor_loss = -1201.538, critic_loss = 22.301, entropy_coef_loss = -0.074, entropy_coef = 0.432, rollout_stds = 0.461 ± 0.023, action_magnitude = 0.729 ± 0.266, n_updates = 3605000, time = 13.3, total_time = 48146.0
#
#
# step = 3616000, num_env_steps = 3616000, scores =  14402.114 (n= 1), score_ema =  14283.767, actor_loss = -1196.082, critic_loss = 24.532, entropy_coef_loss = 0.067, entropy_coef = 0.432, rollout_stds = 0.320 ± 0.152, action_magnitude = 0.734 ± 0.262, n_updates = 3606000, time = 13.3, total_time = 48159.3
#
#
# step = 3617000, num_env_steps = 3617000, scores =  14101.973 (n= 1), score_ema =  14238.318, actor_loss = -1210.955, critic_loss = 16.806, entropy_coef_loss = 0.179, entropy_coef = 0.430, rollout_stds = 0.464 ± 0.107, action_magnitude = 0.732 ± 0.267, n_updates = 3607000, time = 13.3, total_time = 48172.6
#
#
# step = 3618000, num_env_steps = 3618000, scores =  14216.426 (n= 1), score_ema =  14232.845, actor_loss = -1197.302, critic_loss = 14.564, entropy_coef_loss = 0.276, entropy_coef = 0.433, rollout_stds = 0.526 ± 0.096, action_magnitude = 0.731 ± 0.263, n_updates = 3608000, time = 13.3, total_time = 48185.8
#
#
# step = 3619000, num_env_steps = 3619000, scores =  14038.881 (n= 1), score_ema =  14184.354, actor_loss = -1175.725, critic_loss = 17.545, entropy_coef_loss = -0.041, entropy_coef = 0.427, rollout_stds = 0.504 ± 0.117, action_magnitude = 0.725 ± 0.270, n_updates = 3609000, time = 13.3, total_time = 48199.1
#
#
# step = 3620000, num_env_steps = 3620000, scores =  14333.681 (n= 1), score_ema =  14221.686, actor_loss = -1200.101, critic_loss = 13.052, entropy_coef_loss = -0.096, entropy_coef = 0.424, rollout_stds = 0.391 ± 0.215, action_magnitude = 0.730 ± 0.266, n_updates = 3610000, time = 13.9, total_time = 48213.0
#
# saved experiment log 2024-10-11_12-33-24_001309~yZmsfr at experiment_logs/HalfCheetah-v4/sac/2024-10-11_12-33-24_001309~yZmsfr.json
#
#
# step = 3621000, num_env_steps = 3621000, scores =  14229.582 (n= 1), score_ema =  14223.660, actor_loss = -1219.019, critic_loss = 20.111, entropy_coef_loss = -0.140, entropy_coef = 0.432, rollout_stds = 0.443 ± 0.228, action_magnitude = 0.731 ± 0.268, n_updates = 3611000, time = 14.1, total_time = 48227.1
#
# saved experiment log 2024-10-11_12-33-24_001309~yZmsfr at experiment_logs/HalfCheetah-v4/sac/2024-10-11_12-33-24_001309~yZmsfr.json
# keyboard interrupt
# closing envs
# envs closed
# model db closed
# done

# %%
algo.policy
