# %%
from gymnasium.wrappers import TransformReward
import gymnasium as gym

from stable_baselines3.sac.sac import SAC

env = gym.make("HalfCheetah-v4")
# env = TransformReward(env, lambda r: 5 * r)

model = SAC("MlpPolicy", env, verbose=10, learning_starts=10000, stats_window_size=1) # , seed=594371)
model.learn(total_timesteps=3_500_000, log_interval=1)
# Out:
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 1.38e+04  |
# | time/              |           |
# |    episodes        | 2483      |
# |    fps             | 71        |
# |    time_elapsed    | 34528     |
# |    total_timesteps | 2483000   |
# | train/             |           |
# |    actor_loss      | -1.09e+03 |
# |    critic_loss     | 45.2      |
# |    ent_coef        | 0.398     |
# |    ent_coef_loss   | 0.0317    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2472999   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 1.41e+04  |
# | time/              |           |
# |    episodes        | 2484      |
# |    fps             | 71        |
# |    time_elapsed    | 34545     |
# |    total_timesteps | 2484000   |
# | train/             |           |
# |    actor_loss      | -1.08e+03 |
# |    critic_loss     | 46.6      |
# |    ent_coef        | 0.407     |
# |    ent_coef_loss   | -0.0502   |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2473999   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 1.41e+04  |
# | time/              |           |
# |    episodes        | 2485      |
# |    fps             | 71        |
# |    time_elapsed    | 34562     |
# |    total_timesteps | 2485000   |
# | train/             |           |
# |    actor_loss      | -1.05e+03 |
# |    critic_loss     | 153       |
# |    ent_coef        | 0.396     |
# |    ent_coef_loss   | -0.463    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2474999   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 1.41e+04  |
# | time/              |           |
# |    episodes        | 2486      |
# |    fps             | 71        |
# |    time_elapsed    | 34578     |
# |    total_timesteps | 2486000   |
# | train/             |           |
# |    actor_loss      | -1.06e+03 |
# |    critic_loss     | 46.1      |
# |    ent_coef        | 0.397     |
# |    ent_coef_loss   | 0.0217    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2475999   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 1.35e+04  |
# | time/              |           |
# |    episodes        | 2487      |
# |    fps             | 71        |
# |    time_elapsed    | 34594     |
# |    total_timesteps | 2487000   |
# | train/             |           |
# |    actor_loss      | -1.07e+03 |
# |    critic_loss     | 64.1      |
# |    ent_coef        | 0.406     |
# |    ent_coef_loss   | 0.121     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2476999   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 1.34e+04  |
# | time/              |           |
# |    episodes        | 2488      |
# |    fps             | 71        |
# |    time_elapsed    | 34611     |
# |    total_timesteps | 2488000   |
# | train/             |           |
# |    actor_loss      | -1.09e+03 |
# |    critic_loss     | 44.2      |
# |    ent_coef        | 0.4       |
# |    ent_coef_loss   | 0.264     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2477999   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 1.37e+04  |
# | time/              |           |
# |    episodes        | 2489      |
# |    fps             | 71        |
# |    time_elapsed    | 34627     |
# |    total_timesteps | 2489000   |
# | train/             |           |
# |    actor_loss      | -1.08e+03 |
# |    critic_loss     | 70.7      |
# |    ent_coef        | 0.414     |
# |    ent_coef_loss   | 0.309     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2478999   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 1.4e+04   |
# | time/              |           |
# |    episodes        | 2490      |
# |    fps             | 71        |
# |    time_elapsed    | 34641     |
# |    total_timesteps | 2490000   |
# | train/             |           |
# |    actor_loss      | -1.09e+03 |
# |    critic_loss     | 62.5      |
# |    ent_coef        | 0.408     |
# |    ent_coef_loss   | 0.275     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2479999   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 1.3e+04   |
# | time/              |           |
# |    episodes        | 2491      |
# |    fps             | 71        |
# |    time_elapsed    | 34656     |
# |    total_timesteps | 2491000   |
# | train/             |           |
# |    actor_loss      | -1.07e+03 |
# |    critic_loss     | 39.6      |
# |    ent_coef        | 0.401     |
# |    ent_coef_loss   | -0.49     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2480999   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 1.43e+04  |
# | time/              |           |
# |    episodes        | 2492      |
# |    fps             | 71        |
# |    time_elapsed    | 34670     |
# |    total_timesteps | 2492000   |
# | train/             |           |
# |    actor_loss      | -1.08e+03 |
# |    critic_loss     | 58.4      |
# |    ent_coef        | 0.4       |
# |    ent_coef_loss   | 0.0328    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2481999   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 1.38e+04  |
# | time/              |           |
# |    episodes        | 2493      |
# |    fps             | 71        |
# |    time_elapsed    | 34685     |
# |    total_timesteps | 2493000   |
# | train/             |           |
# |    actor_loss      | -1.08e+03 |
# |    critic_loss     | 54.5      |
# |    ent_coef        | 0.41      |
# |    ent_coef_loss   | -0.0828   |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2482999   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 1.4e+04   |
# | time/              |           |
# |    episodes        | 2494      |
# |    fps             | 71        |
# |    time_elapsed    | 34699     |
# |    total_timesteps | 2494000   |
# | train/             |           |
# |    actor_loss      | -1.09e+03 |
# |    critic_loss     | 47.4      |
# |    ent_coef        | 0.405     |
# |    ent_coef_loss   | 0.16      |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2483999   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 1.37e+04  |
# | time/              |           |
# |    episodes        | 2495      |
# |    fps             | 71        |
# |    time_elapsed    | 34713     |
# |    total_timesteps | 2495000   |
# | train/             |           |
# |    actor_loss      | -1.09e+03 |
# |    critic_loss     | 34.2      |
# |    ent_coef        | 0.398     |
# |    ent_coef_loss   | 0.0459    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2484999   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 1.39e+04  |
# | time/              |           |
# |    episodes        | 2496      |
# |    fps             | 71        |
# |    time_elapsed    | 34727     |
# |    total_timesteps | 2496000   |
# | train/             |           |
# |    actor_loss      | -1.07e+03 |
# |    critic_loss     | 48.4      |
# |    ent_coef        | 0.401     |
# |    ent_coef_loss   | -0.287    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2485999   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 1.41e+04  |
# | time/              |           |
# |    episodes        | 2497      |
# |    fps             | 71        |
# |    time_elapsed    | 34742     |
# |    total_timesteps | 2497000   |
# | train/             |           |
# |    actor_loss      | -1.08e+03 |
# |    critic_loss     | 67.5      |
# |    ent_coef        | 0.411     |
# |    ent_coef_loss   | -0.058    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2486999   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 1.38e+04  |
# | time/              |           |
# |    episodes        | 2498      |
# |    fps             | 71        |
# |    time_elapsed    | 34756     |
# |    total_timesteps | 2498000   |
# | train/             |           |
# |    actor_loss      | -1.08e+03 |
# |    critic_loss     | 49.3      |
# |    ent_coef        | 0.405     |
# |    ent_coef_loss   | -0.441    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2487999   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 1.41e+04  |
# | time/              |           |
# |    episodes        | 2499      |
# |    fps             | 71        |
# |    time_elapsed    | 34770     |
# |    total_timesteps | 2499000   |
# | train/             |           |
# |    actor_loss      | -1.07e+03 |
# |    critic_loss     | 53.3      |
# |    ent_coef        | 0.412     |
# |    ent_coef_loss   | -0.325    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2488999   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 1.4e+04   |
# | time/              |           |
# |    episodes        | 2500      |
# |    fps             | 71        |
# |    time_elapsed    | 34784     |
# |    total_timesteps | 2500000   |
# | train/             |           |
# |    actor_loss      | -1.08e+03 |
# |    critic_loss     | 98.4      |
# |    ent_coef        | 0.412     |
# |    ent_coef_loss   | 0.015     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2489999   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 1.43e+04  |
# | time/              |           |
# |    episodes        | 2501      |
# |    fps             | 71        |
# |    time_elapsed    | 34799     |
# |    total_timesteps | 2501000   |
# | train/             |           |
# |    actor_loss      | -1.08e+03 |
# |    critic_loss     | 82.6      |
# |    ent_coef        | 0.406     |
# |    ent_coef_loss   | 0.94      |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2490999   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 1.4e+04   |
# | time/              |           |
# |    episodes        | 2502      |
# |    fps             | 71        |
# |    time_elapsed    | 34813     |
# |    total_timesteps | 2502000   |
# | train/             |           |
# |    actor_loss      | -1.08e+03 |
# |    critic_loss     | 49        |
# |    ent_coef        | 0.412     |
# |    ent_coef_loss   | 0.339     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2491999   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 1.41e+04  |
# | time/              |           |
# |    episodes        | 2503      |
# |    fps             | 71        |
# |    time_elapsed    | 34828     |
# |    total_timesteps | 2503000   |
# | train/             |           |
# |    actor_loss      | -1.09e+03 |
# |    critic_loss     | 65.4      |
# |    ent_coef        | 0.403     |
# |    ent_coef_loss   | 0.209     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2492999   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 1.42e+04  |
# | time/              |           |
# |    episodes        | 2504      |
# |    fps             | 71        |
# |    time_elapsed    | 34843     |
# |    total_timesteps | 2504000   |
# | train/             |           |
# |    actor_loss      | -1.06e+03 |
# |    critic_loss     | 91.4      |
# |    ent_coef        | 0.401     |
# |    ent_coef_loss   | -0.124    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2493999   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 1.39e+04  |
# | time/              |           |
# |    episodes        | 2505      |
# |    fps             | 71        |
# |    time_elapsed    | 34857     |
# |    total_timesteps | 2505000   |
# | train/             |           |
# |    actor_loss      | -1.08e+03 |
# |    critic_loss     | 60.7      |
# |    ent_coef        | 0.408     |
# |    ent_coef_loss   | -0.165    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2494999   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 1.43e+04  |
# | time/              |           |
# |    episodes        | 2506      |
# |    fps             | 71        |
# |    time_elapsed    | 34872     |
# |    total_timesteps | 2506000   |
# | train/             |           |
# |    actor_loss      | -1.06e+03 |
# |    critic_loss     | 44.8      |
# |    ent_coef        | 0.402     |
# |    ent_coef_loss   | -0.17     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2495999   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 1.34e+04  |
# | time/              |           |
# |    episodes        | 2507      |
# |    fps             | 71        |
# |    time_elapsed    | 34886     |
# |    total_timesteps | 2507000   |
# | train/             |           |
# |    actor_loss      | -1.07e+03 |
# |    critic_loss     | 74.5      |
# |    ent_coef        | 0.409     |
# |    ent_coef_loss   | 0.333     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2496999   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 1.36e+04  |
# | time/              |           |
# |    episodes        | 2508      |
# |    fps             | 71        |
# |    time_elapsed    | 34901     |
# |    total_timesteps | 2508000   |
# | train/             |           |
# |    actor_loss      | -1.08e+03 |
# |    critic_loss     | 93.7      |
# |    ent_coef        | 0.406     |
# |    ent_coef_loss   | -0.238    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2497999   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 1.38e+04  |
# | time/              |           |
# |    episodes        | 2509      |
# |    fps             | 71        |
# |    time_elapsed    | 34915     |
# |    total_timesteps | 2509000   |
# | train/             |           |
# |    actor_loss      | -1.09e+03 |
# |    critic_loss     | 62.6      |
# |    ent_coef        | 0.407     |
# |    ent_coef_loss   | 0.169     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2498999   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 1.41e+04  |
# | time/              |           |
# |    episodes        | 2510      |
# |    fps             | 71        |
# |    time_elapsed    | 34930     |
# |    total_timesteps | 2510000   |
# | train/             |           |
# |    actor_loss      | -1.08e+03 |
# |    critic_loss     | 47.3      |
# |    ent_coef        | 0.396     |
# |    ent_coef_loss   | 0.204     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2499999   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 1.38e+04  |
# | time/              |           |
# |    episodes        | 2511      |
# |    fps             | 71        |
# |    time_elapsed    | 34945     |
# |    total_timesteps | 2511000   |
# | train/             |           |
# |    actor_loss      | -1.06e+03 |
# |    critic_loss     | 47.8      |
# |    ent_coef        | 0.411     |
# |    ent_coef_loss   | -0.535    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2500999   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 1.38e+04  |
# | time/              |           |
# |    episodes        | 2512      |
# |    fps             | 71        |
# |    time_elapsed    | 34960     |
# |    total_timesteps | 2512000   |
# | train/             |           |
# |    actor_loss      | -1.07e+03 |
# |    critic_loss     | 43.7      |
# |    ent_coef        | 0.401     |
# |    ent_coef_loss   | -0.0524   |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2501999   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 1.39e+04  |
# | time/              |           |
# |    episodes        | 2513      |
# |    fps             | 71        |
# |    time_elapsed    | 34974     |
# |    total_timesteps | 2513000   |
# | train/             |           |
# |    actor_loss      | -1.08e+03 |
# |    critic_loss     | 74.8      |
# |    ent_coef        | 0.402     |
# |    ent_coef_loss   | 0.171     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2502999   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 1.4e+04   |
# | time/              |           |
# |    episodes        | 2514      |
# |    fps             | 71        |
# |    time_elapsed    | 34989     |
# |    total_timesteps | 2514000   |
# | train/             |           |
# |    actor_loss      | -1.08e+03 |
# |    critic_loss     | 24.8      |
# |    ent_coef        | 0.408     |
# |    ent_coef_loss   | 0.213     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2503999   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 1.4e+04   |
# | time/              |           |
# |    episodes        | 2515      |
# |    fps             | 71        |
# |    time_elapsed    | 35004     |
# |    total_timesteps | 2515000   |
# | train/             |           |
# |    actor_loss      | -1.09e+03 |
# |    critic_loss     | 55.3      |
# |    ent_coef        | 0.412     |
# |    ent_coef_loss   | -0.072    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2504999   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 1.4e+04   |
# | time/              |           |
# |    episodes        | 2516      |
# |    fps             | 71        |
# |    time_elapsed    | 35019     |
# |    total_timesteps | 2516000   |
# | train/             |           |
# |    actor_loss      | -1.06e+03 |
# |    critic_loss     | 86        |
# |    ent_coef        | 0.403     |
# |    ent_coef_loss   | 0.133     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2505999   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 1.39e+04  |
# | time/              |           |
# |    episodes        | 2517      |
# |    fps             | 71        |
# |    time_elapsed    | 35034     |
# |    total_timesteps | 2517000   |
# | train/             |           |
# |    actor_loss      | -1.07e+03 |
# |    critic_loss     | 88.8      |
# |    ent_coef        | 0.407     |
# |    ent_coef_loss   | 0.207     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2506999   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 1.38e+04  |
# | time/              |           |
# |    episodes        | 2518      |
# |    fps             | 71        |
# |    time_elapsed    | 35048     |
# |    total_timesteps | 2518000   |
# | train/             |           |
# |    actor_loss      | -1.07e+03 |
# |    critic_loss     | 122       |
# |    ent_coef        | 0.407     |
# |    ent_coef_loss   | 0.297     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2507999   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 1.4e+04   |
# | time/              |           |
# |    episodes        | 2519      |
# |    fps             | 71        |
# |    time_elapsed    | 35063     |
# |    total_timesteps | 2519000   |
# | train/             |           |
# |    actor_loss      | -1.09e+03 |
# |    critic_loss     | 27.4      |
# |    ent_coef        | 0.403     |
# |    ent_coef_loss   | -0.0507   |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2508999   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 1.43e+04  |
# | time/              |           |
# |    episodes        | 2520      |
# |    fps             | 71        |
# |    time_elapsed    | 35077     |
# |    total_timesteps | 2520000   |
# | train/             |           |
# |    actor_loss      | -1.06e+03 |
# |    critic_loss     | 60.7      |
# |    ent_coef        | 0.403     |
# |    ent_coef_loss   | 0.118     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2509999   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 1.38e+04  |
# | time/              |           |
# |    episodes        | 2521      |
# |    fps             | 71        |
# |    time_elapsed    | 35092     |
# |    total_timesteps | 2521000   |
# | train/             |           |
# |    actor_loss      | -1.06e+03 |
# |    critic_loss     | 94.3      |
# |    ent_coef        | 0.408     |
# |    ent_coef_loss   | -0.0749   |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2510999   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 1.4e+04   |
# | time/              |           |
# |    episodes        | 2522      |
# |    fps             | 71        |
# |    time_elapsed    | 35108     |
# |    total_timesteps | 2522000   |
# | train/             |           |
# |    actor_loss      | -1.07e+03 |
# |    critic_loss     | 84        |
# |    ent_coef        | 0.412     |
# |    ent_coef_loss   | -0.00438  |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2511999   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 1.41e+04  |
# | time/              |           |
# |    episodes        | 2523      |
# |    fps             | 71        |
# |    time_elapsed    | 35125     |
# |    total_timesteps | 2523000   |
# | train/             |           |
# |    actor_loss      | -1.07e+03 |
# |    critic_loss     | 52.9      |
# |    ent_coef        | 0.416     |
# |    ent_coef_loss   | -0.0813   |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2512999   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 1.4e+04   |
# | time/              |           |
# |    episodes        | 2524      |
# |    fps             | 71        |
# |    time_elapsed    | 35140     |
# |    total_timesteps | 2524000   |
# | train/             |           |
# |    actor_loss      | -1.09e+03 |
# |    critic_loss     | 39.1      |
# |    ent_coef        | 0.408     |
# |    ent_coef_loss   | -0.121    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2513999   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 1.42e+04  |
# | time/              |           |
# |    episodes        | 2525      |
# |    fps             | 71        |
# |    time_elapsed    | 35156     |
# |    total_timesteps | 2525000   |
# | train/             |           |
# |    actor_loss      | -1.09e+03 |
# |    critic_loss     | 43.4      |
# |    ent_coef        | 0.406     |
# |    ent_coef_loss   | -0.153    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2514999   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 1.41e+04  |
# | time/              |           |
# |    episodes        | 2526      |
# |    fps             | 71        |
# |    time_elapsed    | 35170     |
# |    total_timesteps | 2526000   |
# | train/             |           |
# |    actor_loss      | -1.07e+03 |
# |    critic_loss     | 26        |
# |    ent_coef        | 0.398     |
# |    ent_coef_loss   | 0.148     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2515999   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 1.42e+04  |
# | time/              |           |
# |    episodes        | 2527      |
# |    fps             | 71        |
# |    time_elapsed    | 35184     |
# |    total_timesteps | 2527000   |
# | train/             |           |
# |    actor_loss      | -1.08e+03 |
# |    critic_loss     | 44.3      |
# |    ent_coef        | 0.414     |
# |    ent_coef_loss   | -0.527    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2516999   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 1.36e+04  |
# | time/              |           |
# |    episodes        | 2528      |
# |    fps             | 71        |
# |    time_elapsed    | 35198     |
# |    total_timesteps | 2528000   |
# | train/             |           |
# |    actor_loss      | -1.09e+03 |
# |    critic_loss     | 70.5      |
# |    ent_coef        | 0.415     |
# |    ent_coef_loss   | -0.146    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2517999   |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.43e+04 |
# | time/              |          |
# |    episodes        | 2529     |
# |    fps             | 71       |
# |    time_elapsed    | 35213    |
# |    total_timesteps | 2529000  |
# | train/             |          |
# |    actor_loss      | -1.1e+03 |
# |    critic_loss     | 58.8     |
# |    ent_coef        | 0.409    |
# |    ent_coef_loss   | 0.251    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2518999  |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 1.4e+04   |
# | time/              |           |
# |    episodes        | 2530      |
# |    fps             | 71        |
# |    time_elapsed    | 35227     |
# |    total_timesteps | 2530000   |
# | train/             |           |
# |    actor_loss      | -1.07e+03 |
# |    critic_loss     | 78.2      |
# |    ent_coef        | 0.408     |
# |    ent_coef_loss   | -0.162    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2519999   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 1.41e+04  |
# | time/              |           |
# |    episodes        | 2531      |
# |    fps             | 71        |
# |    time_elapsed    | 35241     |
# |    total_timesteps | 2531000   |
# | train/             |           |
# |    actor_loss      | -1.09e+03 |
# |    critic_loss     | 179       |
# |    ent_coef        | 0.408     |
# |    ent_coef_loss   | 0.139     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2520999   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 1.38e+04  |
# | time/              |           |
# |    episodes        | 2532      |
# |    fps             | 71        |
# |    time_elapsed    | 35256     |
# |    total_timesteps | 2532000   |
# | train/             |           |
# |    actor_loss      | -1.05e+03 |
# |    critic_loss     | 36.1      |
# |    ent_coef        | 0.403     |
# |    ent_coef_loss   | -0.00598  |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2521999   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 1.43e+04  |
# | time/              |           |
# |    episodes        | 2533      |
# |    fps             | 71        |
# |    time_elapsed    | 35270     |
# |    total_timesteps | 2533000   |
# | train/             |           |
# |    actor_loss      | -1.08e+03 |
# |    critic_loss     | 97.9      |
# |    ent_coef        | 0.404     |
# |    ent_coef_loss   | 0.521     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2522999   |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.41e+04 |
# | time/              |          |
# |    episodes        | 2534     |
# |    fps             | 71       |
# |    time_elapsed    | 35285    |
# |    total_timesteps | 2534000  |
# | train/             |          |
# |    actor_loss      | -1.1e+03 |
# |    critic_loss     | 83.9     |
# |    ent_coef        | 0.395    |
# |    ent_coef_loss   | 0.00312  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2523999  |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 1.41e+04  |
# | time/              |           |
# |    episodes        | 2535      |
# |    fps             | 71        |
# |    time_elapsed    | 35299     |
# |    total_timesteps | 2535000   |
# | train/             |           |
# |    actor_loss      | -1.06e+03 |
# |    critic_loss     | 51.9      |
# |    ent_coef        | 0.407     |
# |    ent_coef_loss   | 0.185     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2524999   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 1.36e+04  |
# | time/              |           |
# |    episodes        | 2536      |
# |    fps             | 71        |
# |    time_elapsed    | 35314     |
# |    total_timesteps | 2536000   |
# | train/             |           |
# |    actor_loss      | -1.09e+03 |
# |    critic_loss     | 74.2      |
# |    ent_coef        | 0.409     |
# |    ent_coef_loss   | -0.0219   |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2525999   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 1.39e+04  |
# | time/              |           |
# |    episodes        | 2537      |
# |    fps             | 71        |
# |    time_elapsed    | 35328     |
# |    total_timesteps | 2537000   |
# | train/             |           |
# |    actor_loss      | -1.08e+03 |
# |    critic_loss     | 55.2      |
# |    ent_coef        | 0.411     |
# |    ent_coef_loss   | 0.297     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2526999   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 1.4e+04   |
# | time/              |           |
# |    episodes        | 2538      |
# |    fps             | 71        |
# |    time_elapsed    | 35343     |
# |    total_timesteps | 2538000   |
# | train/             |           |
# |    actor_loss      | -1.07e+03 |
# |    critic_loss     | 173       |
# |    ent_coef        | 0.418     |
# |    ent_coef_loss   | -0.201    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2527999   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 1.44e+04  |
# | time/              |           |
# |    episodes        | 2539      |
# |    fps             | 71        |
# |    time_elapsed    | 35357     |
# |    total_timesteps | 2539000   |
# | train/             |           |
# |    actor_loss      | -1.06e+03 |
# |    critic_loss     | 44.2      |
# |    ent_coef        | 0.414     |
# |    ent_coef_loss   | -0.217    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2528999   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 1.39e+04  |
# | time/              |           |
# |    episodes        | 2540      |
# |    fps             | 71        |
# |    time_elapsed    | 35371     |
# |    total_timesteps | 2540000   |
# | train/             |           |
# |    actor_loss      | -1.09e+03 |
# |    critic_loss     | 53.4      |
# |    ent_coef        | 0.407     |
# |    ent_coef_loss   | 0.0339    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2529999   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 1.42e+04  |
# | time/              |           |
# |    episodes        | 2541      |
# |    fps             | 71        |
# |    time_elapsed    | 35386     |
# |    total_timesteps | 2541000   |
# | train/             |           |
# |    actor_loss      | -1.09e+03 |
# |    critic_loss     | 61.9      |
# |    ent_coef        | 0.411     |
# |    ent_coef_loss   | 0.504     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2530999   |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.37e+04 |
# | time/              |          |
# |    episodes        | 2542     |
# |    fps             | 71       |
# |    time_elapsed    | 35400    |
# |    total_timesteps | 2542000  |
# | train/             |          |
# |    actor_loss      | -1.1e+03 |
# |    critic_loss     | 49.1     |
# |    ent_coef        | 0.415    |
# |    ent_coef_loss   | -0.0264  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2531999  |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 1.38e+04  |
# | time/              |           |
# |    episodes        | 2543      |
# |    fps             | 71        |
# |    time_elapsed    | 35415     |
# |    total_timesteps | 2543000   |
# | train/             |           |
# |    actor_loss      | -1.08e+03 |
# |    critic_loss     | 42.4      |
# |    ent_coef        | 0.41      |
# |    ent_coef_loss   | -0.018    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2532999   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 1.34e+04  |
# | time/              |           |
# |    episodes        | 2544      |
# |    fps             | 71        |
# |    time_elapsed    | 35429     |
# |    total_timesteps | 2544000   |
# | train/             |           |
# |    actor_loss      | -1.08e+03 |
# |    critic_loss     | 88.2      |
# |    ent_coef        | 0.407     |
# |    ent_coef_loss   | 0.144     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2533999   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 1.4e+04   |
# | time/              |           |
# |    episodes        | 2545      |
# |    fps             | 71        |
# |    time_elapsed    | 35444     |
# |    total_timesteps | 2545000   |
# | train/             |           |
# |    actor_loss      | -1.08e+03 |
# |    critic_loss     | 46.1      |
# |    ent_coef        | 0.418     |
# |    ent_coef_loss   | 0.268     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2534999   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 1.4e+04   |
# | time/              |           |
# |    episodes        | 2546      |
# |    fps             | 71        |
# |    time_elapsed    | 35458     |
# |    total_timesteps | 2546000   |
# | train/             |           |
# |    actor_loss      | -1.08e+03 |
# |    critic_loss     | 107       |
# |    ent_coef        | 0.415     |
# |    ent_coef_loss   | 0.334     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2535999   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 1.43e+04  |
# | time/              |           |
# |    episodes        | 2547      |
# |    fps             | 71        |
# |    time_elapsed    | 35473     |
# |    total_timesteps | 2547000   |
# | train/             |           |
# |    actor_loss      | -1.07e+03 |
# |    critic_loss     | 105       |
# |    ent_coef        | 0.415     |
# |    ent_coef_loss   | 0.22      |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2536999   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 1.41e+04  |
# | time/              |           |
# |    episodes        | 2548      |
# |    fps             | 71        |
# |    time_elapsed    | 35487     |
# |    total_timesteps | 2548000   |
# | train/             |           |
# |    actor_loss      | -1.08e+03 |
# |    critic_loss     | 94.7      |
# |    ent_coef        | 0.414     |
# |    ent_coef_loss   | -0.333    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2537999   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 1.41e+04  |
# | time/              |           |
# |    episodes        | 2549      |
# |    fps             | 71        |
# |    time_elapsed    | 35501     |
# |    total_timesteps | 2549000   |
# | train/             |           |
# |    actor_loss      | -1.07e+03 |
# |    critic_loss     | 77.3      |
# |    ent_coef        | 0.419     |
# |    ent_coef_loss   | 0.26      |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2538999   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 1.4e+04   |
# | time/              |           |
# |    episodes        | 2550      |
# |    fps             | 71        |
# |    time_elapsed    | 35516     |
# |    total_timesteps | 2550000   |
# | train/             |           |
# |    actor_loss      | -1.08e+03 |
# |    critic_loss     | 60.5      |
# |    ent_coef        | 0.409     |
# |    ent_coef_loss   | -0.205    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2539999   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 1.43e+04  |
# | time/              |           |
# |    episodes        | 2551      |
# |    fps             | 71        |
# |    time_elapsed    | 35532     |
# |    total_timesteps | 2551000   |
# | train/             |           |
# |    actor_loss      | -1.07e+03 |
# |    critic_loss     | 48.6      |
# |    ent_coef        | 0.421     |
# |    ent_coef_loss   | 0.119     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2540999   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 1.42e+04  |
# | time/              |           |
# |    episodes        | 2552      |
# |    fps             | 71        |
# |    time_elapsed    | 35548     |
# |    total_timesteps | 2552000   |
# | train/             |           |
# |    actor_loss      | -1.07e+03 |
# |    critic_loss     | 42.9      |
# |    ent_coef        | 0.413     |
# |    ent_coef_loss   | 0.117     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2541999   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 1.39e+04  |
# | time/              |           |
# |    episodes        | 2553      |
# |    fps             | 71        |
# |    time_elapsed    | 35563     |
# |    total_timesteps | 2553000   |
# | train/             |           |
# |    actor_loss      | -1.06e+03 |
# |    critic_loss     | 76.2      |
# |    ent_coef        | 0.414     |
# |    ent_coef_loss   | -0.446    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2542999   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 1.43e+04  |
# | time/              |           |
# |    episodes        | 2554      |
# |    fps             | 71        |
# |    time_elapsed    | 35579     |
# |    total_timesteps | 2554000   |
# | train/             |           |
# |    actor_loss      | -1.11e+03 |
# |    critic_loss     | 119       |
# |    ent_coef        | 0.414     |
# |    ent_coef_loss   | 0.103     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2543999   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 1.43e+04  |
# | time/              |           |
# |    episodes        | 2555      |
# |    fps             | 71        |
# |    time_elapsed    | 35596     |
# |    total_timesteps | 2555000   |
# | train/             |           |
# |    actor_loss      | -1.09e+03 |
# |    critic_loss     | 60.1      |
# |    ent_coef        | 0.417     |
# |    ent_coef_loss   | -0.0888   |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2544999   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 1.39e+04  |
# | time/              |           |
# |    episodes        | 2556      |
# |    fps             | 71        |
# |    time_elapsed    | 35611     |
# |    total_timesteps | 2556000   |
# | train/             |           |
# |    actor_loss      | -1.09e+03 |
# |    critic_loss     | 43.3      |
# |    ent_coef        | 0.409     |
# |    ent_coef_loss   | -0.0463   |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2545999   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 1.42e+04  |
# | time/              |           |
# |    episodes        | 2557      |
# |    fps             | 71        |
# |    time_elapsed    | 35627     |
# |    total_timesteps | 2557000   |
# | train/             |           |
# |    actor_loss      | -1.06e+03 |
# |    critic_loss     | 75.2      |
# |    ent_coef        | 0.415     |
# |    ent_coef_loss   | 0.0381    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2546999   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 1.35e+04  |
# | time/              |           |
# |    episodes        | 2558      |
# |    fps             | 71        |
# |    time_elapsed    | 35643     |
# |    total_timesteps | 2558000   |
# | train/             |           |
# |    actor_loss      | -1.09e+03 |
# |    critic_loss     | 90        |
# |    ent_coef        | 0.422     |
# |    ent_coef_loss   | 0.0916    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2547999   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 1.39e+04  |
# | time/              |           |
# |    episodes        | 2559      |
# |    fps             | 71        |
# |    time_elapsed    | 35659     |
# |    total_timesteps | 2559000   |
# | train/             |           |
# |    actor_loss      | -1.06e+03 |
# |    critic_loss     | 101       |
# |    ent_coef        | 0.422     |
# |    ent_coef_loss   | 0.298     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2548999   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 1.36e+04  |
# | time/              |           |
# |    episodes        | 2560      |
# |    fps             | 71        |
# |    time_elapsed    | 35675     |
# |    total_timesteps | 2560000   |
# | train/             |           |
# |    actor_loss      | -1.09e+03 |
# |    critic_loss     | 38.8      |
# |    ent_coef        | 0.419     |
# |    ent_coef_loss   | -0.267    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2549999   |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.41e+04 |
# | time/              |          |
# |    episodes        | 2561     |
# |    fps             | 71       |
# |    time_elapsed    | 35691    |
# |    total_timesteps | 2561000  |
# | train/             |          |
# |    actor_loss      | -1.1e+03 |
# |    critic_loss     | 57.2     |
# |    ent_coef        | 0.409    |
# |    ent_coef_loss   | -0.278   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2550999  |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 1.3e+04   |
# | time/              |           |
# |    episodes        | 2562      |
# |    fps             | 71        |
# |    time_elapsed    | 35707     |
# |    total_timesteps | 2562000   |
# | train/             |           |
# |    actor_loss      | -1.07e+03 |
# |    critic_loss     | 44.6      |
# |    ent_coef        | 0.421     |
# |    ent_coef_loss   | -0.325    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2551999   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 1.41e+04  |
# | time/              |           |
# |    episodes        | 2563      |
# |    fps             | 71        |
# |    time_elapsed    | 35723     |
# |    total_timesteps | 2563000   |
# | train/             |           |
# |    actor_loss      | -1.09e+03 |
# |    critic_loss     | 46.1      |
# |    ent_coef        | 0.422     |
# ...
# |    ent_coef_loss   | 0.146     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3008999   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 1.45e+04  |
# | time/              |           |
# |    episodes        | 3020      |
# |    fps             | 71        |
# |    time_elapsed    | 42088     |
# |    total_timesteps | 3020000   |
# | train/             |           |
# |    actor_loss      | -1.15e+03 |
# |    critic_loss     | 35.3      |
# |    ent_coef        | 0.466     |
# |    ent_coef_loss   | 0.45      |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3009999   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 1.46e+04  |
# | time/              |           |
# |    episodes        | 3021      |
# |    fps             | 71        |
# |    time_elapsed    | 42102     |
# |    total_timesteps | 3021000   |
# | train/             |           |
# |    actor_loss      | -1.16e+03 |
# |    critic_loss     | 41.3      |
# |    ent_coef        | 0.47      |
# |    ent_coef_loss   | 0.00663   |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3010999   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 1.48e+04  |
# | time/              |           |
# |    episodes        | 3022      |
# |    fps             | 71        |
# |    time_elapsed    | 42116     |
# |    total_timesteps | 3022000   |
# | train/             |           |
# |    actor_loss      | -1.16e+03 |
# |    critic_loss     | 93.5      |
# |    ent_coef        | 0.465     |
# |    ent_coef_loss   | -0.077    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3011999   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 1.48e+04  |
# | time/              |           |
# |    episodes        | 3023      |
# |    fps             | 71        |
# |    time_elapsed    | 42130     |
# |    total_timesteps | 3023000   |
# | train/             |           |
# |    actor_loss      | -1.15e+03 |
# |    critic_loss     | 41.8      |
# |    ent_coef        | 0.485     |
# |    ent_coef_loss   | 0.194     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3012999   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 1.48e+04  |
# | time/              |           |
# |    episodes        | 3024      |
# |    fps             | 71        |
# |    time_elapsed    | 42144     |
# |    total_timesteps | 3024000   |
# | train/             |           |
# |    actor_loss      | -1.16e+03 |
# |    critic_loss     | 203       |
# |    ent_coef        | 0.477     |
# |    ent_coef_loss   | 0.111     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3013999   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 1.44e+04  |
# | time/              |           |
# |    episodes        | 3025      |
# |    fps             | 71        |
# |    time_elapsed    | 42158     |
# |    total_timesteps | 3025000   |
# | train/             |           |
# |    actor_loss      | -1.16e+03 |
# |    critic_loss     | 89.2      |
# |    ent_coef        | 0.471     |
# |    ent_coef_loss   | -0.181    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3014999   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 1.42e+04  |
# | time/              |           |
# |    episodes        | 3026      |
# |    fps             | 71        |
# |    time_elapsed    | 42171     |
# |    total_timesteps | 3026000   |
# | train/             |           |
# |    actor_loss      | -1.15e+03 |
# |    critic_loss     | 49.8      |
# |    ent_coef        | 0.468     |
# |    ent_coef_loss   | 0.0893    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3015999   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 1.47e+04  |
# | time/              |           |
# |    episodes        | 3027      |
# |    fps             | 71        |
# |    time_elapsed    | 42185     |
# |    total_timesteps | 3027000   |
# | train/             |           |
# |    actor_loss      | -1.12e+03 |
# |    critic_loss     | 179       |
# |    ent_coef        | 0.475     |
# |    ent_coef_loss   | 0.155     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3016999   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 1.46e+04  |
# | time/              |           |
# |    episodes        | 3028      |
# |    fps             | 71        |
# |    time_elapsed    | 42199     |
# |    total_timesteps | 3028000   |
# | train/             |           |
# |    actor_loss      | -1.16e+03 |
# |    critic_loss     | 56.2      |
# |    ent_coef        | 0.477     |
# |    ent_coef_loss   | 0.229     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3017999   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 1.46e+04  |
# | time/              |           |
# |    episodes        | 3029      |
# |    fps             | 71        |
# |    time_elapsed    | 42213     |
# |    total_timesteps | 3029000   |
# | train/             |           |
# |    actor_loss      | -1.15e+03 |
# |    critic_loss     | 95        |
# |    ent_coef        | 0.478     |
# |    ent_coef_loss   | -0.118    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3018999   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 1.46e+04  |
# | time/              |           |
# |    episodes        | 3030      |
# |    fps             | 71        |
# |    time_elapsed    | 42227     |
# |    total_timesteps | 3030000   |
# | train/             |           |
# |    actor_loss      | -1.14e+03 |
# |    critic_loss     | 59.9      |
# |    ent_coef        | 0.472     |
# |    ent_coef_loss   | 0.213     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3019999   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 1.48e+04  |
# | time/              |           |
# |    episodes        | 3031      |
# |    fps             | 71        |
# |    time_elapsed    | 42241     |
# |    total_timesteps | 3031000   |
# | train/             |           |
# |    actor_loss      | -1.17e+03 |
# |    critic_loss     | 48        |
# |    ent_coef        | 0.463     |
# |    ent_coef_loss   | -0.163    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3020999   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 1.48e+04  |
# | time/              |           |
# |    episodes        | 3032      |
# |    fps             | 71        |
# |    time_elapsed    | 42255     |
# |    total_timesteps | 3032000   |
# | train/             |           |
# |    actor_loss      | -1.14e+03 |
# |    critic_loss     | 16.1      |
# |    ent_coef        | 0.466     |
# |    ent_coef_loss   | -0.164    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3021999   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 1.48e+04  |
# | time/              |           |
# |    episodes        | 3033      |
# |    fps             | 71        |
# |    time_elapsed    | 42268     |
# |    total_timesteps | 3033000   |
# | train/             |           |
# |    actor_loss      | -1.15e+03 |
# |    critic_loss     | 74.4      |
# |    ent_coef        | 0.457     |
# |    ent_coef_loss   | 0.00711   |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3022999   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 1.49e+04  |
# | time/              |           |
# |    episodes        | 3034      |
# |    fps             | 71        |
# |    time_elapsed    | 42283     |
# |    total_timesteps | 3034000   |
# | train/             |           |
# |    actor_loss      | -1.17e+03 |
# |    critic_loss     | 40.3      |
# |    ent_coef        | 0.465     |
# |    ent_coef_loss   | -0.00771  |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3023999   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 1.46e+04  |
# | time/              |           |
# |    episodes        | 3035      |
# |    fps             | 71        |
# |    time_elapsed    | 42297     |
# |    total_timesteps | 3035000   |
# | train/             |           |
# |    actor_loss      | -1.14e+03 |
# |    critic_loss     | 66.4      |
# |    ent_coef        | 0.458     |
# |    ent_coef_loss   | -0.272    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3024999   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 1.48e+04  |
# | time/              |           |
# |    episodes        | 3036      |
# |    fps             | 71        |
# |    time_elapsed    | 42311     |
# |    total_timesteps | 3036000   |
# | train/             |           |
# |    actor_loss      | -1.18e+03 |
# |    critic_loss     | 77.7      |
# |    ent_coef        | 0.473     |
# |    ent_coef_loss   | -0.241    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3025999   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 1.46e+04  |
# | time/              |           |
# |    episodes        | 3037      |
# |    fps             | 71        |
# |    time_elapsed    | 42323     |
# |    total_timesteps | 3037000   |
# | train/             |           |
# |    actor_loss      | -1.16e+03 |
# |    critic_loss     | 25.6      |
# |    ent_coef        | 0.462     |
# |    ent_coef_loss   | -1.04e-05 |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3026999   |
# ----------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 10
#       7 # env = TransformReward(env, lambda r: 5 * r)
#       9 model = SAC("MlpPolicy", env, verbose=10, learning_starts=10000, stats_window_size=1) # , seed=594371)
# ---> 10 model.learn(total_timesteps=3_500_000, log_interval=1)
#
# File C:\Program Files\Python311\Lib\site-packages\stable_baselines3\sac\sac.py:307, in SAC.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     298 def learn(
#     299     self: SelfSAC,
#     300     total_timesteps: int,
#    (...)
#     305     progress_bar: bool = False,
#     306 ) -> SelfSAC:
# --> 307     return super().learn(
#     308         total_timesteps=total_timesteps,
#     309         callback=callback,
#     310         log_interval=log_interval,
#     311         tb_log_name=tb_log_name,
#     312         reset_num_timesteps=reset_num_timesteps,
#     313         progress_bar=progress_bar,
#     314     )
#
# File C:\Program Files\Python311\Lib\site-packages\stable_baselines3\common\off_policy_algorithm.py:347, in OffPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     345         # Special case when the user passes `gradient_steps=0`
#     346         if gradient_steps > 0:
# --> 347             self.train(batch_size=self.batch_size, gradient_steps=gradient_steps)
#     349 callback.on_training_end()
#     351 return self
#
# File C:\Program Files\Python311\Lib\site-packages\stable_baselines3\sac\sac.py:247, in SAC.train(self, gradient_steps, batch_size)
#     243     self.ent_coef_optimizer.step()
#     245 with th.no_grad():
#     246     # Select action according to policy
# --> 247     next_actions, next_log_prob = self.actor.action_log_prob(replay_data.next_observations)
#     248     # Compute the next Q values: min over all critics targets
#     249     next_q_values = th.cat(self.critic_target(replay_data.next_observations, next_actions), dim=1)
#
# File C:\Program Files\Python311\Lib\site-packages\stable_baselines3\sac\policies.py:175, in Actor.action_log_prob(self, obs)
#     173 mean_actions, log_std, kwargs = self.get_action_dist_params(obs)
#     174 # return action and associated log prob
# --> 175 return self.action_dist.log_prob_from_params(mean_actions, log_std, **kwargs)
#
# File C:\Program Files\Python311\Lib\site-packages\stable_baselines3\common\distributions.py:258, in SquashedDiagGaussianDistribution.log_prob_from_params(self, mean_actions, log_std)
#     257 def log_prob_from_params(self, mean_actions: th.Tensor, log_std: th.Tensor) -> Tuple[th.Tensor, th.Tensor]:
# --> 258     action = self.actions_from_params(mean_actions, log_std)
#     259     log_prob = self.log_prob(action, self.gaussian_actions)
#     260     return action, log_prob
#
# File C:\Program Files\Python311\Lib\site-packages\stable_baselines3\common\distributions.py:190, in DiagGaussianDistribution.actions_from_params(self, mean_actions, log_std, deterministic)
#     188 def actions_from_params(self, mean_actions: th.Tensor, log_std: th.Tensor, deterministic: bool = False) -> th.Tensor:
#     189     # Update the proba distribution
# --> 190     self.proba_distribution(mean_actions, log_std)
#     191     return self.get_actions(deterministic=deterministic)
#
# File C:\Program Files\Python311\Lib\site-packages\stable_baselines3\common\distributions.py:224, in SquashedDiagGaussianDistribution.proba_distribution(self, mean_actions, log_std)
#     221 def proba_distribution(
#     222     self: SelfSquashedDiagGaussianDistribution, mean_actions: th.Tensor, log_std: th.Tensor
#     223 ) -> SelfSquashedDiagGaussianDistribution:
# --> 224     super().proba_distribution(mean_actions, log_std)
#     225     return self
#
# File C:\Program Files\Python311\Lib\site-packages\stable_baselines3\common\distributions.py:164, in DiagGaussianDistribution.proba_distribution(self, mean_actions, log_std)
#     156 """
#     157 Create the distribution given its parameters (mean, std)
#     158
#    (...)
#     161 :return:
#     162 """
#     163 action_std = th.ones_like(mean_actions) * log_std.exp()
# --> 164 self.distribution = Normal(mean_actions, action_std)
#     165 return self
#
# File C:\Program Files\Python311\Lib\site-packages\torch\distributions\normal.py:56, in Normal.__init__(self, loc, scale, validate_args)
#      54 else:
#      55     batch_shape = self.loc.size()
# ---> 56 super().__init__(batch_shape, validate_args=validate_args)
#
# File C:\Program Files\Python311\Lib\site-packages\torch\distributions\distribution.py:67, in Distribution.__init__(self, batch_shape, event_shape, validate_args)
#      65         value = getattr(self, param)
#      66         valid = constraint.check(value)
# ---> 67         if not valid.all():
#      68             raise ValueError(
#      69                 f"Expected parameter {param} "
#      70                 f"({type(value).__name__} of shape {tuple(value.shape)}) "
#    (...)
#      73                 f"but found invalid values:\n{value}"
#      74             )
#      75 super().__init__()
#
# KeyboardInterrupt:
